# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import dask.array as da
from hyss_util import *

# %%
# %matplotlib widget

# %%
# -- set mpl defaults
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gist_gray"
plt.rcParams["figure.figsize"] = (10, 5)

# %%
# -- set the data paths
dpath0 = os.path.join(os.environ["LTCO_HSI0"], "full frame 20ms faster_VNIR.raw")
dpath1 = os.path.join(os.environ["LTCO_HSI1"], "night_00000.raw")

# %%
def sigma_clipping(cubedata, half):
    
    """ 
  Read half of the raw data and then clean it 

  Parameters:
  ----------

    cubedata: data cube 
  three dimentional array
  
    half: str   


  Returns：
  -------
  A three dimentional numpy array

    """  

    if half == "half0":
        spec = cubedata.data[:, :800, :]
    else:
        spec = cubedata.data[:, 800:1600, :]
        
        
    # -- apply 20 times 30sig clipping 
    filtered_hsi = np.empty(shape = spec.shape, dtype = "float64")
    for i in range(len(spec)):
        start_time = time.time()
        print("20fold 3-sigma clipping for {0}".format(i))
        # -- row first
        data_row = sig_clipping_row(spec[i])
        # -- then column
        data_col = sig_clipping_col(data_row)
        # -- row again
        data_row_2 = sig_clipping_row(data_col)
        # -- another column
        data_col_2 = sig_clipping_col(data_row_2)
        print("--- %s seconds ---" % (time.time() - start_time))
        filtered_hsi[i] = data_col_2
    return filtered_hsi

# %%
# -- apply 3-sigma clipping of HSI0
# -- read HSI0
cube0 = read_hyper(dpath0)
# Out:
# reading and parsing full frame 20ms faster_VNIR.hdr...
# reading full frame 20ms faster_VNIR.raw...

# %%
# -- data proprecessing for the image from row0 to row800
filtered_hsi0_half0 = sigma_clipping(cube0, "half0")
np.save("filtered_hsi0_half0.npy", filtered_hsi0_half0)
# Out:
# 20fold 3-sigma clipping for 0
# --- 3.438382863998413 seconds ---
# 20fold 3-sigma clipping for 1
# --- 3.263838291168213 seconds ---
# 20fold 3-sigma clipping for 2
# --- 3.2842814922332764 seconds ---
# 20fold 3-sigma clipping for 3
# --- 3.1924667358398438 seconds ---
# 20fold 3-sigma clipping for 4
# --- 3.2965705394744873 seconds ---
# 20fold 3-sigma clipping for 5
# --- 3.3204562664031982 seconds ---
# 20fold 3-sigma clipping for 6
# --- 3.3094522953033447 seconds ---
# 20fold 3-sigma clipping for 7
# --- 3.2590298652648926 seconds ---
# 20fold 3-sigma clipping for 8
# --- 3.2635226249694824 seconds ---
# 20fold 3-sigma clipping for 9
# --- 3.314502239227295 seconds ---
# 20fold 3-sigma clipping for 10
# --- 3.303922176361084 seconds ---
# 20fold 3-sigma clipping for 11
# --- 3.243962287902832 seconds ---
# 20fold 3-sigma clipping for 12
# --- 3.2462680339813232 seconds ---
# 20fold 3-sigma clipping for 13
# --- 3.299382209777832 seconds ---
# 20fold 3-sigma clipping for 14
# --- 3.301801919937134 seconds ---
# 20fold 3-sigma clipping for 15
# --- 3.250817060470581 seconds ---
# 20fold 3-sigma clipping for 16
# --- 3.28549861907959 seconds ---
# 20fold 3-sigma clipping for 17
# --- 3.2614803314208984 seconds ---
# 20fold 3-sigma clipping for 18
# --- 3.3095650672912598 seconds ---
# 20fold 3-sigma clipping for 19
# --- 3.240558385848999 seconds ---
# 20fold 3-sigma clipping for 20
# --- 3.2826859951019287 seconds ---
# 20fold 3-sigma clipping for 21
# --- 3.3077969551086426 seconds ---
# 20fold 3-sigma clipping for 22
# --- 3.2869179248809814 seconds ---
# 20fold 3-sigma clipping for 23
# --- 3.2451634407043457 seconds ---
# 20fold 3-sigma clipping for 24
# --- 3.2796738147735596 seconds ---
# 20fold 3-sigma clipping for 25
# --- 3.30255389213562 seconds ---
# 20fold 3-sigma clipping for 26
# --- 3.3435540199279785 seconds ---
# 20fold 3-sigma clipping for 27
# --- 3.315882921218872 seconds ---
# 20fold 3-sigma clipping for 28
# --- 3.262022018432617 seconds ---
# 20fold 3-sigma clipping for 29
# --- 3.3090052604675293 seconds ---
# 20fold 3-sigma clipping for 30
# --- 3.324141025543213 seconds ---
# 20fold 3-sigma clipping for 31
# --- 3.3437893390655518 seconds ---
# 20fold 3-sigma clipping for 32
# --- 3.2831473350524902 seconds ---
# 20fold 3-sigma clipping for 33
# --- 3.280775785446167 seconds ---
# 20fold 3-sigma clipping for 34
# --- 3.3131585121154785 seconds ---
# 20fold 3-sigma clipping for 35
# --- 3.276012897491455 seconds ---
# 20fold 3-sigma clipping for 36
# --- 3.233508348464966 seconds ---
# 20fold 3-sigma clipping for 37
# --- 3.266805648803711 seconds ---
# 20fold 3-sigma clipping for 38
# --- 3.2718124389648438 seconds ---
# 20fold 3-sigma clipping for 39
# --- 3.2868471145629883 seconds ---
# 20fold 3-sigma clipping for 40
# --- 3.254446506500244 seconds ---
# 20fold 3-sigma clipping for 41
# --- 3.260657787322998 seconds ---
# 20fold 3-sigma clipping for 42
# --- 3.2801997661590576 seconds ---
# 20fold 3-sigma clipping for 43
# --- 3.286496162414551 seconds ---
# 20fold 3-sigma clipping for 44
# --- 3.2161195278167725 seconds ---
# 20fold 3-sigma clipping for 45
# --- 3.247000217437744 seconds ---
# 20fold 3-sigma clipping for 46
# --- 3.2944753170013428 seconds ---
# 20fold 3-sigma clipping for 47
# --- 3.3060667514801025 seconds ---
# 20fold 3-sigma clipping for 48
# --- 3.2189507484436035 seconds ---
# 20fold 3-sigma clipping for 49
# --- 3.251289129257202 seconds ---
# 20fold 3-sigma clipping for 50
# --- 3.2995078563690186 seconds ---
# 20fold 3-sigma clipping for 51
# --- 3.304866313934326 seconds ---
# 20fold 3-sigma clipping for 52
# --- 3.2228431701660156 seconds ---
# 20fold 3-sigma clipping for 53
# --- 3.25380277633667 seconds ---
# 20fold 3-sigma clipping for 54
# --- 3.2992424964904785 seconds ---
# 20fold 3-sigma clipping for 55
# --- 3.29709792137146 seconds ---
# 20fold 3-sigma clipping for 56
# --- 3.2246344089508057 seconds ---
# 20fold 3-sigma clipping for 57
# --- 3.269061326980591 seconds ---
# 20fold 3-sigma clipping for 58
# --- 3.309629201889038 seconds ---
# 20fold 3-sigma clipping for 59
# --- 3.3075926303863525 seconds ---
# 20fold 3-sigma clipping for 60
# --- 3.222465753555298 seconds ---
# 20fold 3-sigma clipping for 61
# --- 3.24824595451355 seconds ---
# 20fold 3-sigma clipping for 62
# --- 3.255436658859253 seconds ---
# 20fold 3-sigma clipping for 63
# --- 3.2705888748168945 seconds ---
# 20fold 3-sigma clipping for 64
# --- 3.2882821559906006 seconds ---
# 20fold 3-sigma clipping for 65
# --- 3.2248644828796387 seconds ---
# 20fold 3-sigma clipping for 66
# --- 3.286656379699707 seconds ---
# 20fold 3-sigma clipping for 67
# --- 3.301396608352661 seconds ---
# 20fold 3-sigma clipping for 68
# --- 3.3083033561706543 seconds ---
# 20fold 3-sigma clipping for 69
# --- 3.225273609161377 seconds ---
# 20fold 3-sigma clipping for 70
# --- 3.248084306716919 seconds ---
# 20fold 3-sigma clipping for 71
# --- 3.343482255935669 seconds ---
# 20fold 3-sigma clipping for 72
# --- 3.2545325756073 seconds ---
# 20fold 3-sigma clipping for 73
# --- 3.2713234424591064 seconds ---
# 20fold 3-sigma clipping for 74
# --- 3.272761344909668 seconds ---
# 20fold 3-sigma clipping for 75
# --- 3.321227550506592 seconds ---
# 20fold 3-sigma clipping for 76
# --- 3.237443685531616 seconds ---
# 20fold 3-sigma clipping for 77
# --- 3.254432439804077 seconds ---
# 20fold 3-sigma clipping for 78
# --- 3.3432347774505615 seconds ---
# 20fold 3-sigma clipping for 79
# --- 3.2812283039093018 seconds ---
# 20fold 3-sigma clipping for 80
# --- 3.2247397899627686 seconds ---
# 20fold 3-sigma clipping for 81
# --- 3.2604362964630127 seconds ---
# 20fold 3-sigma clipping for 82
# --- 3.3078362941741943 seconds ---
# 20fold 3-sigma clipping for 83
# --- 3.2995285987854004 seconds ---
# 20fold 3-sigma clipping for 84
# --- 3.222158670425415 seconds ---
# 20fold 3-sigma clipping for 85
# --- 3.255664348602295 seconds ---
# 20fold 3-sigma clipping for 86
# --- 3.3548715114593506 seconds ---
# 20fold 3-sigma clipping for 87
# --- 3.2502822875976562 seconds ---
# 20fold 3-sigma clipping for 88
# --- 3.260838270187378 seconds ---
# 20fold 3-sigma clipping for 89
# --- 3.2742574214935303 seconds ---
# 20fold 3-sigma clipping for 90
# --- 3.3305397033691406 seconds ---
# 20fold 3-sigma clipping for 91
# --- 3.245272397994995 seconds ---
# 20fold 3-sigma clipping for 92
# --- 3.2543561458587646 seconds ---
# 20fold 3-sigma clipping for 93
# --- 3.309903860092163 seconds ---
# 20fold 3-sigma clipping for 94
# --- 3.3173880577087402 seconds ---
# 20fold 3-sigma clipping for 95
# --- 3.2233099937438965 seconds ---
# 20fold 3-sigma clipping for 96
# --- 3.2642247676849365 seconds ---
# 20fold 3-sigma clipping for 97
# --- 3.3233494758605957 seconds ---
# 20fold 3-sigma clipping for 98
# --- 3.3069849014282227 seconds ---
# 20fold 3-sigma clipping for 99
# --- 3.2273108959198 seconds ---
# 20fold 3-sigma clipping for 100
# --- 3.263922691345215 seconds ---
# 20fold 3-sigma clipping for 101
# --- 3.316641330718994 seconds ---
# 20fold 3-sigma clipping for 102
# --- 3.3130667209625244 seconds ---
# 20fold 3-sigma clipping for 103
# --- 3.2262635231018066 seconds ---
# 20fold 3-sigma clipping for 104
# --- 3.2663321495056152 seconds ---
# 20fold 3-sigma clipping for 105
# --- 3.307887315750122 seconds ---
# 20fold 3-sigma clipping for 106
# --- 3.310234308242798 seconds ---
# 20fold 3-sigma clipping for 107
# --- 3.221909523010254 seconds ---
# 20fold 3-sigma clipping for 108
# --- 3.2631301879882812 seconds ---
# 20fold 3-sigma clipping for 109
# --- 3.304034948348999 seconds ---
# 20fold 3-sigma clipping for 110
# --- 3.305265188217163 seconds ---
# 20fold 3-sigma clipping for 111
# --- 3.221815824508667 seconds ---
# 20fold 3-sigma clipping for 112
# --- 3.2554244995117188 seconds ---
# 20fold 3-sigma clipping for 113
# --- 3.310655117034912 seconds ---
# 20fold 3-sigma clipping for 114
# --- 3.285445213317871 seconds ---
# 20fold 3-sigma clipping for 115
# --- 3.3218069076538086 seconds ---
# 20fold 3-sigma clipping for 116
# --- 3.287660837173462 seconds ---
# 20fold 3-sigma clipping for 117
# --- 3.2225382328033447 seconds ---
# 20fold 3-sigma clipping for 118
# --- 3.262120246887207 seconds ---
# 20fold 3-sigma clipping for 119
# --- 3.2880966663360596 seconds ---
# 20fold 3-sigma clipping for 120
# --- 3.284114122390747 seconds ---
# 20fold 3-sigma clipping for 121
# --- 3.270068645477295 seconds ---
# 20fold 3-sigma clipping for 122
# --- 3.2230241298675537 seconds ---
# 20fold 3-sigma clipping for 123
# --- 3.260174036026001 seconds ---
# 20fold 3-sigma clipping for 124
# --- 3.30781626701355 seconds ---
# 20fold 3-sigma clipping for 125
# --- 3.3145737648010254 seconds ---
# 20fold 3-sigma clipping for 126
# --- 3.2158114910125732 seconds ---
# 20fold 3-sigma clipping for 127
# --- 3.248377561569214 seconds ---
# 20fold 3-sigma clipping for 128
# --- 3.3063106536865234 seconds ---
# 20fold 3-sigma clipping for 129
# --- 3.2918996810913086 seconds ---
# 20fold 3-sigma clipping for 130
# --- 3.2183115482330322 seconds ---
# 20fold 3-sigma clipping for 131
# --- 3.254680633544922 seconds ---
# 20fold 3-sigma clipping for 132
# --- 3.2919604778289795 seconds ---
# 20fold 3-sigma clipping for 133
# --- 3.2918217182159424 seconds ---
# 20fold 3-sigma clipping for 134
# --- 3.2077629566192627 seconds ---
# 20fold 3-sigma clipping for 135
# --- 3.246974229812622 seconds ---
# 20fold 3-sigma clipping for 136
# --- 3.3419458866119385 seconds ---
# 20fold 3-sigma clipping for 137
# --- 3.2443792819976807 seconds ---
# 20fold 3-sigma clipping for 138
# --- 3.2627832889556885 seconds ---
# 20fold 3-sigma clipping for 139
# --- 3.268235683441162 seconds ---
# 20fold 3-sigma clipping for 140
# --- 3.318272113800049 seconds ---
# 20fold 3-sigma clipping for 141
# --- 3.2437021732330322 seconds ---
# 20fold 3-sigma clipping for 142
# --- 3.251217842102051 seconds ---
# 20fold 3-sigma clipping for 143
# --- 3.312568187713623 seconds ---
# 20fold 3-sigma clipping for 144
# --- 3.314005136489868 seconds ---
# 20fold 3-sigma clipping for 145
# --- 3.220227003097534 seconds ---
# 20fold 3-sigma clipping for 146
# --- 3.2584712505340576 seconds ---
# 20fold 3-sigma clipping for 147
# --- 3.313904285430908 seconds ---
# 20fold 3-sigma clipping for 148
# --- 3.3080127239227295 seconds ---
# 20fold 3-sigma clipping for 149
# --- 3.2199454307556152 seconds ---
# 20fold 3-sigma clipping for 150
# --- 3.2601418495178223 seconds ---
# 20fold 3-sigma clipping for 151
# --- 3.3028738498687744 seconds ---
# 20fold 3-sigma clipping for 152
# --- 3.308403253555298 seconds ---
# 20fold 3-sigma clipping for 153
# --- 3.2204859256744385 seconds ---
# 20fold 3-sigma clipping for 154
# --- 3.258286952972412 seconds ---
# 20fold 3-sigma clipping for 155
# --- 3.2619011402130127 seconds ---
# 20fold 3-sigma clipping for 156
# --- 3.2799015045166016 seconds ---
# 20fold 3-sigma clipping for 157
# --- 3.2866921424865723 seconds ---
# 20fold 3-sigma clipping for 158
# --- 3.213574171066284 seconds ---
# 20fold 3-sigma clipping for 159
# --- 3.282815933227539 seconds ---
# 20fold 3-sigma clipping for 160
# --- 3.3081777095794678 seconds ---
# 20fold 3-sigma clipping for 161
# --- 3.3189167976379395 seconds ---
# 20fold 3-sigma clipping for 162
# --- 3.222583293914795 seconds ---
# 20fold 3-sigma clipping for 163
# --- 3.2561874389648438 seconds ---
# 20fold 3-sigma clipping for 164
# --- 3.304313898086548 seconds ---
# 20fold 3-sigma clipping for 165
# --- 3.3061587810516357 seconds ---
# 20fold 3-sigma clipping for 166
# --- 3.221518039703369 seconds ---
# 20fold 3-sigma clipping for 167
# --- 3.262355327606201 seconds ---
# 20fold 3-sigma clipping for 168
# --- 3.274732828140259 seconds ---
# 20fold 3-sigma clipping for 169
# --- 3.279242515563965 seconds ---
# 20fold 3-sigma clipping for 170
# --- 3.2391958236694336 seconds ---
# 20fold 3-sigma clipping for 171
# --- 3.249699354171753 seconds ---
# 20fold 3-sigma clipping for 172
# --- 3.304165840148926 seconds ---
# 20fold 3-sigma clipping for 173
# --- 3.3165597915649414 seconds ---
# 20fold 3-sigma clipping for 174
# --- 3.258624792098999 seconds ---
# 20fold 3-sigma clipping for 175
# --- 3.2547028064727783 seconds ---
# 20fold 3-sigma clipping for 176
# --- 3.272862434387207 seconds ---
# 20fold 3-sigma clipping for 177
# --- 3.314331293106079 seconds ---
# 20fold 3-sigma clipping for 178
# --- 3.241107225418091 seconds ---
# 20fold 3-sigma clipping for 179
# --- 3.2582995891571045 seconds ---
# 20fold 3-sigma clipping for 180
# --- 3.3543179035186768 seconds ---
# 20fold 3-sigma clipping for 181
# --- 3.2894275188446045 seconds ---
# 20fold 3-sigma clipping for 182
# --- 3.2197797298431396 seconds ---
# 20fold 3-sigma clipping for 183
# --- 3.262427568435669 seconds ---
# 20fold 3-sigma clipping for 184
# --- 3.314357280731201 seconds ---
# 20fold 3-sigma clipping for 185
# --- 3.3104066848754883 seconds ---
# 20fold 3-sigma clipping for 186
# --- 3.224609136581421 seconds ---
# 20fold 3-sigma clipping for 187
# --- 3.2528023719787598 seconds ---
# 20fold 3-sigma clipping for 188
# --- 3.304595470428467 seconds ---
# 20fold 3-sigma clipping for 189
# --- 3.303595542907715 seconds ---
# 20fold 3-sigma clipping for 190
# --- 3.223905086517334 seconds ---
# 20fold 3-sigma clipping for 191
# --- 3.264119863510132 seconds ---
# 20fold 3-sigma clipping for 192
# --- 3.3071401119232178 seconds ---
# 20fold 3-sigma clipping for 193
# --- 3.3029263019561768 seconds ---
# 20fold 3-sigma clipping for 194
# --- 3.214771270751953 seconds ---
# 20fold 3-sigma clipping for 195
# --- 3.2449417114257812 seconds ---
# 20fold 3-sigma clipping for 196
# --- 3.3034088611602783 seconds ---
# 20fold 3-sigma clipping for 197
# --- 3.304734706878662 seconds ---
# 20fold 3-sigma clipping for 198
# --- 3.2184181213378906 seconds ---
# 20fold 3-sigma clipping for 199
# --- 3.263601303100586 seconds ---
# 20fold 3-sigma clipping for 200
# --- 3.3580925464630127 seconds ---
# 20fold 3-sigma clipping for 201
# --- 3.25431752204895 seconds ---
# 20fold 3-sigma clipping for 202
# --- 3.2639992237091064 seconds ---
# 20fold 3-sigma clipping for 203
# --- 3.2697136402130127 seconds ---
# 20fold 3-sigma clipping for 204
# --- 3.328852653503418 seconds ---
# 20fold 3-sigma clipping for 205
# --- 3.251816987991333 seconds ---
# 20fold 3-sigma clipping for 206
# --- 3.261204957962036 seconds ---
# 20fold 3-sigma clipping for 207
# --- 3.3094940185546875 seconds ---
# 20fold 3-sigma clipping for 208
# --- 3.303420066833496 seconds ---
# 20fold 3-sigma clipping for 209
# --- 3.2250473499298096 seconds ---
# 20fold 3-sigma clipping for 210
# --- 3.2649190425872803 seconds ---
# 20fold 3-sigma clipping for 211
# --- 3.3247592449188232 seconds ---
# 20fold 3-sigma clipping for 212
# --- 3.3099615573883057 seconds ---
# 20fold 3-sigma clipping for 213
# --- 3.2262656688690186 seconds ---
# 20fold 3-sigma clipping for 214
# --- 3.2633044719696045 seconds ---
# 20fold 3-sigma clipping for 215
# --- 3.3059744834899902 seconds ---
# 20fold 3-sigma clipping for 216
# --- 3.310633420944214 seconds ---
# 20fold 3-sigma clipping for 217
# --- 3.2224936485290527 seconds ---
# 20fold 3-sigma clipping for 218
# --- 3.2643821239471436 seconds ---
# 20fold 3-sigma clipping for 219
# --- 3.3165457248687744 seconds ---
# 20fold 3-sigma clipping for 220
# --- 3.3132712841033936 seconds ---
# 20fold 3-sigma clipping for 221
# --- 3.2303078174591064 seconds ---
# 20fold 3-sigma clipping for 222
# --- 3.264986991882324 seconds ---
# 20fold 3-sigma clipping for 223
# --- 3.307952880859375 seconds ---
# 20fold 3-sigma clipping for 224
# --- 3.3118622303009033 seconds ---
# 20fold 3-sigma clipping for 225
# --- 3.236480712890625 seconds ---
# 20fold 3-sigma clipping for 226
# --- 3.271411657333374 seconds ---
# 20fold 3-sigma clipping for 227
# --- 3.3675119876861572 seconds ---
# 20fold 3-sigma clipping for 228
# --- 3.263582944869995 seconds ---
# 20fold 3-sigma clipping for 229
# --- 3.28767728805542 seconds ---
# 20fold 3-sigma clipping for 230
# --- 3.3016021251678467 seconds ---
# 20fold 3-sigma clipping for 231
# --- 3.3397793769836426 seconds ---
# 20fold 3-sigma clipping for 232
# --- 3.251911163330078 seconds ---
# 20fold 3-sigma clipping for 233
# --- 3.286505937576294 seconds ---
# 20fold 3-sigma clipping for 234
# --- 3.3611197471618652 seconds ---
# 20fold 3-sigma clipping for 235
# --- 3.3042614459991455 seconds ---
# 20fold 3-sigma clipping for 236
# --- 3.225827217102051 seconds ---
# 20fold 3-sigma clipping for 237
# --- 3.276294708251953 seconds ---
# 20fold 3-sigma clipping for 238
# --- 3.3623099327087402 seconds ---
# 20fold 3-sigma clipping for 239
# --- 3.296093463897705 seconds ---
# 20fold 3-sigma clipping for 240
# --- 3.2259724140167236 seconds ---
# 20fold 3-sigma clipping for 241
# --- 3.272780179977417 seconds ---
# 20fold 3-sigma clipping for 242
# --- 3.3713583946228027 seconds ---
# 20fold 3-sigma clipping for 243
# --- 3.2630245685577393 seconds ---
# 20fold 3-sigma clipping for 244
# --- 3.2793514728546143 seconds ---
# 20fold 3-sigma clipping for 245
# --- 3.2894845008850098 seconds ---
# 20fold 3-sigma clipping for 246
# --- 3.3323888778686523 seconds ---
# 20fold 3-sigma clipping for 247
# --- 3.2558751106262207 seconds ---
# 20fold 3-sigma clipping for 248
# --- 3.2668962478637695 seconds ---
# 20fold 3-sigma clipping for 249
# --- 3.325453042984009 seconds ---
# 20fold 3-sigma clipping for 250
# --- 3.3274879455566406 seconds ---
# 20fold 3-sigma clipping for 251
# --- 3.2268476486206055 seconds ---
# 20fold 3-sigma clipping for 252
# --- 3.2771079540252686 seconds ---
# 20fold 3-sigma clipping for 253
# --- 3.335352897644043 seconds ---
# 20fold 3-sigma clipping for 254
# --- 3.3115999698638916 seconds ---
# 20fold 3-sigma clipping for 255
# --- 3.240860939025879 seconds ---
# 20fold 3-sigma clipping for 256
# --- 3.269840717315674 seconds ---
# 20fold 3-sigma clipping for 257
# --- 3.2845869064331055 seconds ---
# 20fold 3-sigma clipping for 258
# --- 3.2920238971710205 seconds ---
# 20fold 3-sigma clipping for 259
# --- 3.30642032623291 seconds ---
# 20fold 3-sigma clipping for 260
# --- 3.2382829189300537 seconds ---
# 20fold 3-sigma clipping for 261
# --- 3.282463788986206 seconds ---
# 20fold 3-sigma clipping for 262
# --- 3.2866604328155518 seconds ---
# 20fold 3-sigma clipping for 263
# --- 3.293804168701172 seconds ---
# 20fold 3-sigma clipping for 264
# --- 3.3019776344299316 seconds ---
# 20fold 3-sigma clipping for 265
# --- 3.243516445159912 seconds ---
# 20fold 3-sigma clipping for 266
# --- 3.272134780883789 seconds ---
# 20fold 3-sigma clipping for 267
# --- 3.2839560508728027 seconds ---
# 20fold 3-sigma clipping for 268
# --- 3.2894177436828613 seconds ---
# 20fold 3-sigma clipping for 269
# --- 3.3070173263549805 seconds ---
# 20fold 3-sigma clipping for 270
# --- 3.2354137897491455 seconds ---
# 20fold 3-sigma clipping for 271
# --- 3.2761013507843018 seconds ---
# 20fold 3-sigma clipping for 272
# --- 3.279291868209839 seconds ---
# 20fold 3-sigma clipping for 273
# --- 3.2967658042907715 seconds ---
# 20fold 3-sigma clipping for 274
# --- 3.319690704345703 seconds ---
# 20fold 3-sigma clipping for 275
# --- 3.2307069301605225 seconds ---
# 20fold 3-sigma clipping for 276
# --- 3.2719602584838867 seconds ---
# 20fold 3-sigma clipping for 277
# --- 3.293260335922241 seconds ---
# 20fold 3-sigma clipping for 278
# --- 3.304525852203369 seconds ---
# 20fold 3-sigma clipping for 279
# --- 3.2999656200408936 seconds ---
# 20fold 3-sigma clipping for 280
# --- 3.237128496170044 seconds ---
# 20fold 3-sigma clipping for 281
# --- 3.2856438159942627 seconds ---
# 20fold 3-sigma clipping for 282
# --- 3.289123296737671 seconds ---
# 20fold 3-sigma clipping for 283
# --- 3.306706666946411 seconds ---
# 20fold 3-sigma clipping for 284
# --- 3.312450885772705 seconds ---
# 20fold 3-sigma clipping for 285
# --- 3.2389233112335205 seconds ---
# 20fold 3-sigma clipping for 286
# --- 3.2794265747070312 seconds ---
# 20fold 3-sigma clipping for 287
# --- 3.293632745742798 seconds ---
# 20fold 3-sigma clipping for 288
# --- 3.3038692474365234 seconds ---
# 20fold 3-sigma clipping for 289
# --- 3.3125438690185547 seconds ---
# 20fold 3-sigma clipping for 290
# --- 3.239870071411133 seconds ---
# 20fold 3-sigma clipping for 291
# --- 3.2781219482421875 seconds ---
# 20fold 3-sigma clipping for 292
# --- 3.292011260986328 seconds ---
# 20fold 3-sigma clipping for 293
# --- 3.30315899848938 seconds ---
# 20fold 3-sigma clipping for 294
# --- 3.3170008659362793 seconds ---
# 20fold 3-sigma clipping for 295
# --- 3.245347023010254 seconds ---
# 20fold 3-sigma clipping for 296
# --- 3.281827211380005 seconds ---
# 20fold 3-sigma clipping for 297
# --- 3.2877278327941895 seconds ---
# 20fold 3-sigma clipping for 298
# --- 3.3157243728637695 seconds ---
# 20fold 3-sigma clipping for 299
# --- 3.3289525508880615 seconds ---
# 20fold 3-sigma clipping for 300
# --- 3.245300054550171 seconds ---
# 20fold 3-sigma clipping for 301
# --- 3.2938828468322754 seconds ---
# 20fold 3-sigma clipping for 302
# --- 3.3024449348449707 seconds ---
# 20fold 3-sigma clipping for 303
# --- 3.3317856788635254 seconds ---
# 20fold 3-sigma clipping for 304
# --- 3.31606388092041 seconds ---
# 20fold 3-sigma clipping for 305
# --- 3.259498357772827 seconds ---
# 20fold 3-sigma clipping for 306
# --- 3.2883224487304688 seconds ---
# 20fold 3-sigma clipping for 307
# --- 3.2969939708709717 seconds ---
# 20fold 3-sigma clipping for 308
# --- 3.3111655712127686 seconds ---
# 20fold 3-sigma clipping for 309
# --- 3.3191347122192383 seconds ---
# 20fold 3-sigma clipping for 310
# --- 3.2385401725769043 seconds ---
# 20fold 3-sigma clipping for 311
# --- 3.27919602394104 seconds ---
# 20fold 3-sigma clipping for 312
# --- 3.287465810775757 seconds ---
# 20fold 3-sigma clipping for 313
# --- 3.3027031421661377 seconds ---
# 20fold 3-sigma clipping for 314
# --- 3.31744384765625 seconds ---
# 20fold 3-sigma clipping for 315
# --- 3.2392470836639404 seconds ---
# 20fold 3-sigma clipping for 316
# --- 3.2765374183654785 seconds ---
# 20fold 3-sigma clipping for 317
# --- 3.2878670692443848 seconds ---
# 20fold 3-sigma clipping for 318
# --- 3.311549425125122 seconds ---
# 20fold 3-sigma clipping for 319
# --- 3.311915397644043 seconds ---
# 20fold 3-sigma clipping for 320
# --- 3.248138427734375 seconds ---
# 20fold 3-sigma clipping for 321
# --- 3.275174379348755 seconds ---
# 20fold 3-sigma clipping for 322
# --- 3.285675287246704 seconds ---
# 20fold 3-sigma clipping for 323
# --- 3.2972986698150635 seconds ---
# 20fold 3-sigma clipping for 324
# --- 3.299607753753662 seconds ---
# 20fold 3-sigma clipping for 325
# --- 3.2431812286376953 seconds ---
# 20fold 3-sigma clipping for 326
# --- 3.270693063735962 seconds ---
# 20fold 3-sigma clipping for 327
# --- 3.2933621406555176 seconds ---
# 20fold 3-sigma clipping for 328
# --- 3.302659273147583 seconds ---
# 20fold 3-sigma clipping for 329
# --- 3.3136720657348633 seconds ---
# 20fold 3-sigma clipping for 330
# --- 3.2316946983337402 seconds ---
# 20fold 3-sigma clipping for 331
# --- 3.27305269241333 seconds ---
# 20fold 3-sigma clipping for 332
# --- 3.283581256866455 seconds ---
# 20fold 3-sigma clipping for 333
# --- 3.289470672607422 seconds ---
# 20fold 3-sigma clipping for 334
# --- 3.291867971420288 seconds ---
# 20fold 3-sigma clipping for 335
# --- 3.240272045135498 seconds ---
# 20fold 3-sigma clipping for 336
# --- 3.274404764175415 seconds ---
# 20fold 3-sigma clipping for 337
# --- 3.282074213027954 seconds ---
# 20fold 3-sigma clipping for 338
# --- 3.295515537261963 seconds ---
# 20fold 3-sigma clipping for 339
# --- 3.2967026233673096 seconds ---
# 20fold 3-sigma clipping for 340
# --- 3.231308698654175 seconds ---
# 20fold 3-sigma clipping for 341
# --- 3.2599544525146484 seconds ---
# 20fold 3-sigma clipping for 342
# --- 3.2889461517333984 seconds ---
# 20fold 3-sigma clipping for 343
# --- 3.3061161041259766 seconds ---
# 20fold 3-sigma clipping for 344
# --- 3.3154778480529785 seconds ---
# 20fold 3-sigma clipping for 345
# --- 3.2431347370147705 seconds ---
# 20fold 3-sigma clipping for 346
# --- 3.282745838165283 seconds ---
# 20fold 3-sigma clipping for 347
# --- 3.3097121715545654 seconds ---
# 20fold 3-sigma clipping for 348
# --- 3.300051689147949 seconds ---
# 20fold 3-sigma clipping for 349
# --- 3.3243775367736816 seconds ---
# 20fold 3-sigma clipping for 350
# --- 3.2448971271514893 seconds ---
# 20fold 3-sigma clipping for 351
# --- 3.290458917617798 seconds ---
# 20fold 3-sigma clipping for 352
# --- 3.283055067062378 seconds ---
# 20fold 3-sigma clipping for 353
# --- 3.3008458614349365 seconds ---
# 20fold 3-sigma clipping for 354
# --- 3.3186838626861572 seconds ---
# 20fold 3-sigma clipping for 355
# --- 3.248070478439331 seconds ---
# 20fold 3-sigma clipping for 356
# --- 3.2892258167266846 seconds ---
# 20fold 3-sigma clipping for 357
# --- 3.2990639209747314 seconds ---
# 20fold 3-sigma clipping for 358
# --- 3.3074300289154053 seconds ---
# 20fold 3-sigma clipping for 359
# --- 3.302283763885498 seconds ---
# 20fold 3-sigma clipping for 360
# --- 3.253899097442627 seconds ---
# 20fold 3-sigma clipping for 361
# --- 3.2768452167510986 seconds ---
# 20fold 3-sigma clipping for 362
# --- 3.294402837753296 seconds ---
# 20fold 3-sigma clipping for 363
# --- 3.298549175262451 seconds ---
# 20fold 3-sigma clipping for 364
# --- 3.3156228065490723 seconds ---
# 20fold 3-sigma clipping for 365
# --- 3.2409825325012207 seconds ---
# 20fold 3-sigma clipping for 366
# --- 3.275735855102539 seconds ---
# 20fold 3-sigma clipping for 367
# --- 3.296983003616333 seconds ---
# 20fold 3-sigma clipping for 368
# --- 3.29789137840271 seconds ---
# 20fold 3-sigma clipping for 369
# --- 3.3092689514160156 seconds ---
# 20fold 3-sigma clipping for 370
# --- 3.221859931945801 seconds ---
# 20fold 3-sigma clipping for 371
# --- 3.2804923057556152 seconds ---
# 20fold 3-sigma clipping for 372
# --- 3.287163019180298 seconds ---
# 20fold 3-sigma clipping for 373
# --- 3.306471347808838 seconds ---
# 20fold 3-sigma clipping for 374
# --- 3.320553779602051 seconds ---
# 20fold 3-sigma clipping for 375
# --- 3.2353408336639404 seconds ---
# 20fold 3-sigma clipping for 376
# --- 3.278028964996338 seconds ---
# 20fold 3-sigma clipping for 377
# --- 3.27976393699646 seconds ---
# 20fold 3-sigma clipping for 378
# --- 3.291111707687378 seconds ---
# 20fold 3-sigma clipping for 379
# --- 3.317502975463867 seconds ---
# 20fold 3-sigma clipping for 380
# --- 3.2353410720825195 seconds ---
# 20fold 3-sigma clipping for 381
# --- 3.2720651626586914 seconds ---
# 20fold 3-sigma clipping for 382
# --- 3.286405563354492 seconds ---
# 20fold 3-sigma clipping for 383
# --- 3.294541597366333 seconds ---
# 20fold 3-sigma clipping for 384
# --- 3.3032238483428955 seconds ---
# 20fold 3-sigma clipping for 385
# --- 3.2253339290618896 seconds ---
# 20fold 3-sigma clipping for 386
# --- 3.278240919113159 seconds ---
# 20fold 3-sigma clipping for 387
# --- 3.2884116172790527 seconds ---
# 20fold 3-sigma clipping for 388
# --- 3.308305263519287 seconds ---
# 20fold 3-sigma clipping for 389
# --- 3.30425763130188 seconds ---
# 20fold 3-sigma clipping for 390
# --- 3.229159116744995 seconds ---
# 20fold 3-sigma clipping for 391
# --- 3.2771267890930176 seconds ---
# 20fold 3-sigma clipping for 392
# --- 3.281839370727539 seconds ---
# 20fold 3-sigma clipping for 393
# --- 3.30649471282959 seconds ---
# 20fold 3-sigma clipping for 394
# --- 3.3056037425994873 seconds ---
# 20fold 3-sigma clipping for 395
# --- 3.245847225189209 seconds ---
# 20fold 3-sigma clipping for 396
# --- 3.2743351459503174 seconds ---
# 20fold 3-sigma clipping for 397
# --- 3.282491445541382 seconds ---
# 20fold 3-sigma clipping for 398
# --- 3.298764944076538 seconds ---
# 20fold 3-sigma clipping for 399
# --- 3.3084402084350586 seconds ---
# 20fold 3-sigma clipping for 400
# --- 3.223998785018921 seconds ---
# 20fold 3-sigma clipping for 401
# --- 3.27820086479187 seconds ---
# 20fold 3-sigma clipping for 402
# --- 3.2814245223999023 seconds ---
# 20fold 3-sigma clipping for 403
# --- 3.2939980030059814 seconds ---
# 20fold 3-sigma clipping for 404
# --- 3.29233717918396 seconds ---
# 20fold 3-sigma clipping for 405
# --- 3.2218968868255615 seconds ---
# 20fold 3-sigma clipping for 406
# --- 3.259014129638672 seconds ---
# 20fold 3-sigma clipping for 407
# --- 3.2778849601745605 seconds ---
# 20fold 3-sigma clipping for 408
# --- 3.305061101913452 seconds ---
# 20fold 3-sigma clipping for 409
# --- 3.304199695587158 seconds ---
# 20fold 3-sigma clipping for 410
# --- 3.246476888656616 seconds ---
# 20fold 3-sigma clipping for 411
# --- 3.2724506855010986 seconds ---
# 20fold 3-sigma clipping for 412
# --- 3.2846381664276123 seconds ---
# 20fold 3-sigma clipping for 413
# --- 3.2971932888031006 seconds ---
# 20fold 3-sigma clipping for 414
# --- 3.305122137069702 seconds ---
# 20fold 3-sigma clipping for 415
# --- 3.2359607219696045 seconds ---
# 20fold 3-sigma clipping for 416
# --- 3.3008387088775635 seconds ---
# 20fold 3-sigma clipping for 417
# --- 3.3091201782226562 seconds ---
# 20fold 3-sigma clipping for 418
# --- 3.3263518810272217 seconds ---
# 20fold 3-sigma clipping for 419
# --- 3.332623243331909 seconds ---
# 20fold 3-sigma clipping for 420
# --- 3.2517170906066895 seconds ---
# 20fold 3-sigma clipping for 421
# --- 3.2733139991760254 seconds ---
# 20fold 3-sigma clipping for 422
# --- 3.2885591983795166 seconds ---
# 20fold 3-sigma clipping for 423
# --- 3.315035343170166 seconds ---
# 20fold 3-sigma clipping for 424
# --- 3.3288822174072266 seconds ---
# 20fold 3-sigma clipping for 425
# --- 3.2499516010284424 seconds ---
# 20fold 3-sigma clipping for 426
# --- 3.2788281440734863 seconds ---
# 20fold 3-sigma clipping for 427
# --- 3.2877604961395264 seconds ---
# 20fold 3-sigma clipping for 428
# --- 3.2975680828094482 seconds ---
# 20fold 3-sigma clipping for 429
# --- 3.3136792182922363 seconds ---
# 20fold 3-sigma clipping for 430
# --- 3.245375633239746 seconds ---
# 20fold 3-sigma clipping for 431
# --- 3.292426109313965 seconds ---
# 20fold 3-sigma clipping for 432
# --- 3.296692132949829 seconds ---
# 20fold 3-sigma clipping for 433
# --- 3.299041271209717 seconds ---
# 20fold 3-sigma clipping for 434
# --- 3.313610315322876 seconds ---
# 20fold 3-sigma clipping for 435
# --- 3.2285571098327637 seconds ---
# 20fold 3-sigma clipping for 436
# --- 3.2692768573760986 seconds ---
# 20fold 3-sigma clipping for 437
# --- 3.285961151123047 seconds ---
# 20fold 3-sigma clipping for 438
# --- 3.3199381828308105 seconds ---
# 20fold 3-sigma clipping for 439
# --- 3.3207952976226807 seconds ---
# 20fold 3-sigma clipping for 440
# --- 3.2359588146209717 seconds ---
# 20fold 3-sigma clipping for 441
# --- 3.2677762508392334 seconds ---
# 20fold 3-sigma clipping for 442
# --- 3.279850721359253 seconds ---
# 20fold 3-sigma clipping for 443
# --- 3.297631025314331 seconds ---
# 20fold 3-sigma clipping for 444
# --- 3.3104043006896973 seconds ---
# 20fold 3-sigma clipping for 445
# --- 3.250854730606079 seconds ---
# 20fold 3-sigma clipping for 446
# --- 3.2813143730163574 seconds ---
# 20fold 3-sigma clipping for 447
# --- 3.3122215270996094 seconds ---
# 20fold 3-sigma clipping for 448
# --- 3.3076131343841553 seconds ---
# 20fold 3-sigma clipping for 449
# --- 3.3304848670959473 seconds ---
# 20fold 3-sigma clipping for 450
# --- 3.246934413909912 seconds ---
# 20fold 3-sigma clipping for 451
# --- 3.2858614921569824 seconds ---
# 20fold 3-sigma clipping for 452
# --- 3.304727792739868 seconds ---
# 20fold 3-sigma clipping for 453
# --- 3.3108346462249756 seconds ---
# 20fold 3-sigma clipping for 454
# --- 3.3234009742736816 seconds ---
# 20fold 3-sigma clipping for 455
# --- 3.2525229454040527 seconds ---
# 20fold 3-sigma clipping for 456
# --- 3.2889797687530518 seconds ---
# 20fold 3-sigma clipping for 457
# --- 3.292217969894409 seconds ---
# 20fold 3-sigma clipping for 458
# --- 3.312929630279541 seconds ---
# 20fold 3-sigma clipping for 459
# --- 3.3267087936401367 seconds ---
# 20fold 3-sigma clipping for 460
# --- 3.251286506652832 seconds ---
# 20fold 3-sigma clipping for 461
# --- 3.29487681388855 seconds ---
# 20fold 3-sigma clipping for 462
# --- 3.3067338466644287 seconds ---
# 20fold 3-sigma clipping for 463
# --- 3.3133625984191895 seconds ---
# 20fold 3-sigma clipping for 464
# --- 3.319934844970703 seconds ---
# 20fold 3-sigma clipping for 465
# --- 3.2457430362701416 seconds ---
# 20fold 3-sigma clipping for 466
# --- 3.29608416557312 seconds ---
# 20fold 3-sigma clipping for 467
# --- 3.2875072956085205 seconds ---
# 20fold 3-sigma clipping for 468
# --- 3.317666530609131 seconds ---
# 20fold 3-sigma clipping for 469
# --- 3.317152261734009 seconds ---
# 20fold 3-sigma clipping for 470
# --- 3.251577854156494 seconds ---
# 20fold 3-sigma clipping for 471
# --- 3.2801244258880615 seconds ---
# 20fold 3-sigma clipping for 472
# --- 3.3016109466552734 seconds ---
# 20fold 3-sigma clipping for 473
# --- 3.322904348373413 seconds ---
# 20fold 3-sigma clipping for 474
# --- 3.323596239089966 seconds ---
# 20fold 3-sigma clipping for 475
# --- 3.252662420272827 seconds ---
# 20fold 3-sigma clipping for 476
# --- 3.286632537841797 seconds ---
# 20fold 3-sigma clipping for 477
# --- 3.29715895652771 seconds ---
# 20fold 3-sigma clipping for 478
# --- 3.3178465366363525 seconds ---
# 20fold 3-sigma clipping for 479
# --- 3.323374032974243 seconds ---
# 20fold 3-sigma clipping for 480
# --- 3.2467589378356934 seconds ---
# 20fold 3-sigma clipping for 481
# --- 3.289379835128784 seconds ---
# 20fold 3-sigma clipping for 482
# --- 3.2874183654785156 seconds ---
# 20fold 3-sigma clipping for 483
# --- 3.3064563274383545 seconds ---
# 20fold 3-sigma clipping for 484
# --- 3.3233447074890137 seconds ---
# 20fold 3-sigma clipping for 485
# --- 3.2404115200042725 seconds ---
# 20fold 3-sigma clipping for 486
# --- 3.2873482704162598 seconds ---
# 20fold 3-sigma clipping for 487
# --- 3.2864933013916016 seconds ---
# 20fold 3-sigma clipping for 488
# --- 3.3158695697784424 seconds ---
# 20fold 3-sigma clipping for 489
# --- 3.3107547760009766 seconds ---
# 20fold 3-sigma clipping for 490
# --- 3.243098497390747 seconds ---
# 20fold 3-sigma clipping for 491
# --- 3.2731478214263916 seconds ---
# 20fold 3-sigma clipping for 492
# --- 3.29052472114563 seconds ---
# 20fold 3-sigma clipping for 493
# --- 3.2996551990509033 seconds ---
# 20fold 3-sigma clipping for 494
# --- 3.2979307174682617 seconds ---
# 20fold 3-sigma clipping for 495
# --- 3.2222917079925537 seconds ---
# 20fold 3-sigma clipping for 496
# --- 3.2710559368133545 seconds ---
# 20fold 3-sigma clipping for 497
# --- 3.2879257202148438 seconds ---
# 20fold 3-sigma clipping for 498
# --- 3.3032333850860596 seconds ---
# 20fold 3-sigma clipping for 499
# --- 3.316999673843384 seconds ---
# 20fold 3-sigma clipping for 500
# --- 3.236060619354248 seconds ---
# 20fold 3-sigma clipping for 501
# --- 3.281167984008789 seconds ---
# 20fold 3-sigma clipping for 502
# --- 3.2985756397247314 seconds ---
# 20fold 3-sigma clipping for 503
# --- 3.3105931282043457 seconds ---
# 20fold 3-sigma clipping for 504
# --- 3.3096938133239746 seconds ---
# 20fold 3-sigma clipping for 505
# --- 3.2395665645599365 seconds ---
# 20fold 3-sigma clipping for 506
# --- 3.274646282196045 seconds ---
# 20fold 3-sigma clipping for 507
# --- 3.286787509918213 seconds ---
# 20fold 3-sigma clipping for 508
# --- 3.2931151390075684 seconds ---
# 20fold 3-sigma clipping for 509
# --- 3.3086349964141846 seconds ---
# 20fold 3-sigma clipping for 510
# --- 3.2453906536102295 seconds ---
# 20fold 3-sigma clipping for 511
# --- 3.2738990783691406 seconds ---
# 20fold 3-sigma clipping for 512
# --- 3.281921148300171 seconds ---
# 20fold 3-sigma clipping for 513
# --- 3.3005197048187256 seconds ---
# 20fold 3-sigma clipping for 514
# --- 3.3114259243011475 seconds ---
# 20fold 3-sigma clipping for 515
# --- 3.231921911239624 seconds ---
# 20fold 3-sigma clipping for 516
# --- 3.2657063007354736 seconds ---
# 20fold 3-sigma clipping for 517
# --- 3.2866928577423096 seconds ---
# 20fold 3-sigma clipping for 518
# --- 3.3195791244506836 seconds ---
# 20fold 3-sigma clipping for 519
# --- 3.3199989795684814 seconds ---
# 20fold 3-sigma clipping for 520
# --- 3.250568389892578 seconds ---
# 20fold 3-sigma clipping for 521
# --- 3.2793970108032227 seconds ---
# 20fold 3-sigma clipping for 522
# --- 3.295025587081909 seconds ---
# 20fold 3-sigma clipping for 523
# --- 3.299818992614746 seconds ---
# 20fold 3-sigma clipping for 524
# --- 3.3125648498535156 seconds ---
# 20fold 3-sigma clipping for 525
# --- 3.2428035736083984 seconds ---
# 20fold 3-sigma clipping for 526
# --- 3.277771472930908 seconds ---
# 20fold 3-sigma clipping for 527
# --- 3.3009896278381348 seconds ---
# 20fold 3-sigma clipping for 528
# --- 3.3001480102539062 seconds ---
# 20fold 3-sigma clipping for 529
# --- 3.3146352767944336 seconds ---
# 20fold 3-sigma clipping for 530
# --- 3.2434539794921875 seconds ---
# 20fold 3-sigma clipping for 531
# --- 3.2831828594207764 seconds ---
# 20fold 3-sigma clipping for 532
# --- 3.293658494949341 seconds ---
# 20fold 3-sigma clipping for 533
# --- 3.300597667694092 seconds ---
# 20fold 3-sigma clipping for 534
# --- 3.312443971633911 seconds ---
# 20fold 3-sigma clipping for 535
# --- 3.229292631149292 seconds ---
# 20fold 3-sigma clipping for 536
# --- 3.2703278064727783 seconds ---
# 20fold 3-sigma clipping for 537
# --- 3.290592908859253 seconds ---
# 20fold 3-sigma clipping for 538
# --- 3.311464309692383 seconds ---
# 20fold 3-sigma clipping for 539
# --- 3.3238000869750977 seconds ---
# 20fold 3-sigma clipping for 540
# --- 3.248398542404175 seconds ---
# 20fold 3-sigma clipping for 541
# --- 3.2769179344177246 seconds ---
# 20fold 3-sigma clipping for 542
# --- 3.294447660446167 seconds ---
# 20fold 3-sigma clipping for 543
# --- 3.3096389770507812 seconds ---
# 20fold 3-sigma clipping for 544
# --- 3.3224754333496094 seconds ---
# 20fold 3-sigma clipping for 545
# --- 3.246255874633789 seconds ---
# 20fold 3-sigma clipping for 546
# --- 3.2763614654541016 seconds ---
# 20fold 3-sigma clipping for 547
# --- 3.294633388519287 seconds ---
# 20fold 3-sigma clipping for 548
# --- 3.3054299354553223 seconds ---
# 20fold 3-sigma clipping for 549
# --- 3.324125051498413 seconds ---
# 20fold 3-sigma clipping for 550
# --- 3.251613140106201 seconds ---
# 20fold 3-sigma clipping for 551
# --- 3.2959396839141846 seconds ---
# 20fold 3-sigma clipping for 552
# --- 3.2988336086273193 seconds ---
# 20fold 3-sigma clipping for 553
# --- 3.3066136837005615 seconds ---
# 20fold 3-sigma clipping for 554
# --- 3.3169381618499756 seconds ---
# 20fold 3-sigma clipping for 555
# --- 3.2339158058166504 seconds ---
# 20fold 3-sigma clipping for 556
# --- 3.2874953746795654 seconds ---
# 20fold 3-sigma clipping for 557
# --- 3.284235715866089 seconds ---
# 20fold 3-sigma clipping for 558
# --- 3.3060576915740967 seconds ---
# 20fold 3-sigma clipping for 559
# --- 3.2983553409576416 seconds ---
# 20fold 3-sigma clipping for 560
# --- 3.224667549133301 seconds ---
# 20fold 3-sigma clipping for 561
# --- 3.272479772567749 seconds ---
# 20fold 3-sigma clipping for 562
# --- 3.2958145141601562 seconds ---
# 20fold 3-sigma clipping for 563
# --- 3.3019185066223145 seconds ---
# 20fold 3-sigma clipping for 564
# --- 3.3030097484588623 seconds ---
# 20fold 3-sigma clipping for 565
# --- 3.228062629699707 seconds ---
# 20fold 3-sigma clipping for 566
# --- 3.2802910804748535 seconds ---
# 20fold 3-sigma clipping for 567
# --- 3.2899229526519775 seconds ---
# 20fold 3-sigma clipping for 568
# --- 3.3008453845977783 seconds ---
# 20fold 3-sigma clipping for 569
# --- 3.313124895095825 seconds ---
# 20fold 3-sigma clipping for 570
# --- 3.2316482067108154 seconds ---
# 20fold 3-sigma clipping for 571
# --- 3.2608139514923096 seconds ---
# 20fold 3-sigma clipping for 572
# --- 3.2757349014282227 seconds ---
# 20fold 3-sigma clipping for 573
# --- 3.2899365425109863 seconds ---
# 20fold 3-sigma clipping for 574
# --- 3.296821117401123 seconds ---
# 20fold 3-sigma clipping for 575
# --- 3.2414586544036865 seconds ---
# 20fold 3-sigma clipping for 576
# --- 3.2850382328033447 seconds ---
# 20fold 3-sigma clipping for 577
# --- 3.286867618560791 seconds ---
# 20fold 3-sigma clipping for 578
# --- 3.3041093349456787 seconds ---
# 20fold 3-sigma clipping for 579
# --- 3.2935447692871094 seconds ---
# 20fold 3-sigma clipping for 580
# --- 3.231375217437744 seconds ---
# 20fold 3-sigma clipping for 581
# --- 3.269181489944458 seconds ---
# 20fold 3-sigma clipping for 582
# --- 3.2746198177337646 seconds ---
# 20fold 3-sigma clipping for 583
# --- 3.301802635192871 seconds ---
# 20fold 3-sigma clipping for 584
# --- 3.31725811958313 seconds ---
# 20fold 3-sigma clipping for 585
# --- 3.2354068756103516 seconds ---
# 20fold 3-sigma clipping for 586
# --- 3.2765986919403076 seconds ---
# 20fold 3-sigma clipping for 587
# --- 3.2783620357513428 seconds ---
# 20fold 3-sigma clipping for 588
# --- 3.2970902919769287 seconds ---
# 20fold 3-sigma clipping for 589
# --- 3.3020896911621094 seconds ---
# 20fold 3-sigma clipping for 590
# --- 3.2379093170166016 seconds ---
# 20fold 3-sigma clipping for 591
# --- 3.2774698734283447 seconds ---
# 20fold 3-sigma clipping for 592
# --- 3.279989004135132 seconds ---
# 20fold 3-sigma clipping for 593
# --- 3.300316333770752 seconds ---
# 20fold 3-sigma clipping for 594
# --- 3.307593584060669 seconds ---
# 20fold 3-sigma clipping for 595
# --- 3.234365940093994 seconds ---
# 20fold 3-sigma clipping for 596
# --- 3.2652714252471924 seconds ---
# 20fold 3-sigma clipping for 597
# --- 3.2779054641723633 seconds ---
# 20fold 3-sigma clipping for 598
# --- 3.3078067302703857 seconds ---
# 20fold 3-sigma clipping for 599
# --- 3.305790901184082 seconds ---
# 20fold 3-sigma clipping for 600
# --- 3.2408549785614014 seconds ---
# 20fold 3-sigma clipping for 601
# --- 3.2728376388549805 seconds ---
# 20fold 3-sigma clipping for 602
# --- 3.2848119735717773 seconds ---
# 20fold 3-sigma clipping for 603
# --- 3.296980619430542 seconds ---
# 20fold 3-sigma clipping for 604
# --- 3.3050649166107178 seconds ---
# 20fold 3-sigma clipping for 605
# --- 3.23018217086792 seconds ---
# 20fold 3-sigma clipping for 606
# --- 3.2781949043273926 seconds ---
# 20fold 3-sigma clipping for 607
# --- 3.2900776863098145 seconds ---
# 20fold 3-sigma clipping for 608
# --- 3.307910680770874 seconds ---
# 20fold 3-sigma clipping for 609
# --- 3.3092260360717773 seconds ---
# 20fold 3-sigma clipping for 610
# --- 3.2291929721832275 seconds ---
# 20fold 3-sigma clipping for 611
# --- 3.2664477825164795 seconds ---
# 20fold 3-sigma clipping for 612
# --- 3.292712688446045 seconds ---
# 20fold 3-sigma clipping for 613
# --- 3.310866117477417 seconds ---
# 20fold 3-sigma clipping for 614
# --- 3.3160901069641113 seconds ---
# 20fold 3-sigma clipping for 615
# --- 3.237924337387085 seconds ---
# 20fold 3-sigma clipping for 616
# --- 3.2766165733337402 seconds ---
# 20fold 3-sigma clipping for 617
# --- 3.2851366996765137 seconds ---
# 20fold 3-sigma clipping for 618
# --- 3.2931325435638428 seconds ---
# 20fold 3-sigma clipping for 619
# --- 3.305979013442993 seconds ---
# 20fold 3-sigma clipping for 620
# --- 3.2447433471679688 seconds ---
# 20fold 3-sigma clipping for 621
# --- 3.274421215057373 seconds ---
# 20fold 3-sigma clipping for 622
# --- 3.2987053394317627 seconds ---
# 20fold 3-sigma clipping for 623
# --- 3.301107406616211 seconds ---
# 20fold 3-sigma clipping for 624
# --- 3.3067126274108887 seconds ---
# 20fold 3-sigma clipping for 625
# --- 3.2328529357910156 seconds ---
# 20fold 3-sigma clipping for 626
# --- 3.2722127437591553 seconds ---
# 20fold 3-sigma clipping for 627
# --- 3.287846565246582 seconds ---
# 20fold 3-sigma clipping for 628
# --- 3.3178699016571045 seconds ---
# 20fold 3-sigma clipping for 629
# --- 3.315864324569702 seconds ---
# 20fold 3-sigma clipping for 630
# --- 3.2435309886932373 seconds ---
# 20fold 3-sigma clipping for 631
# --- 3.2699227333068848 seconds ---
# 20fold 3-sigma clipping for 632
# --- 3.281008720397949 seconds ---
# 20fold 3-sigma clipping for 633
# --- 3.290525197982788 seconds ---
# 20fold 3-sigma clipping for 634
# --- 3.3013498783111572 seconds ---
# 20fold 3-sigma clipping for 635
# --- 3.2440080642700195 seconds ---
# 20fold 3-sigma clipping for 636
# --- 3.271768808364868 seconds ---
# 20fold 3-sigma clipping for 637
# --- 3.2805662155151367 seconds ---
# 20fold 3-sigma clipping for 638
# --- 3.282996416091919 seconds ---
# 20fold 3-sigma clipping for 639
# --- 3.3025379180908203 seconds ---
# 20fold 3-sigma clipping for 640
# --- 3.2222816944122314 seconds ---
# 20fold 3-sigma clipping for 641
# --- 3.266014337539673 seconds ---
# 20fold 3-sigma clipping for 642
# --- 3.2875356674194336 seconds ---
# 20fold 3-sigma clipping for 643
# --- 3.3098881244659424 seconds ---
# 20fold 3-sigma clipping for 644
# --- 3.3110880851745605 seconds ---
# 20fold 3-sigma clipping for 645
# --- 3.248260021209717 seconds ---
# 20fold 3-sigma clipping for 646
# --- 3.2893788814544678 seconds ---
# 20fold 3-sigma clipping for 647
# --- 3.2931089401245117 seconds ---
# 20fold 3-sigma clipping for 648
# --- 3.317178249359131 seconds ---
# 20fold 3-sigma clipping for 649
# --- 3.3209986686706543 seconds ---
# 20fold 3-sigma clipping for 650
# --- 3.2431681156158447 seconds ---
# 20fold 3-sigma clipping for 651
# --- 3.2708311080932617 seconds ---
# 20fold 3-sigma clipping for 652
# --- 3.294288396835327 seconds ---
# 20fold 3-sigma clipping for 653
# --- 3.310410737991333 seconds ---
# 20fold 3-sigma clipping for 654
# --- 3.322751522064209 seconds ---
# 20fold 3-sigma clipping for 655
# --- 3.2292394638061523 seconds ---
# 20fold 3-sigma clipping for 656
# --- 3.281628370285034 seconds ---
# 20fold 3-sigma clipping for 657
# --- 3.298832893371582 seconds ---
# 20fold 3-sigma clipping for 658
# --- 3.3057138919830322 seconds ---
# 20fold 3-sigma clipping for 659
# --- 3.3040034770965576 seconds ---
# 20fold 3-sigma clipping for 660
# --- 3.239957332611084 seconds ---
# 20fold 3-sigma clipping for 661
# --- 3.294860601425171 seconds ---
# 20fold 3-sigma clipping for 662
# --- 3.296734094619751 seconds ---
# 20fold 3-sigma clipping for 663
# --- 3.3150832653045654 seconds ---
# 20fold 3-sigma clipping for 664
# --- 3.309382200241089 seconds ---
# 20fold 3-sigma clipping for 665
# --- 3.245779275894165 seconds ---
# 20fold 3-sigma clipping for 666
# --- 3.2826223373413086 seconds ---
# 20fold 3-sigma clipping for 667
# --- 3.2907536029815674 seconds ---
# 20fold 3-sigma clipping for 668
# --- 3.2973031997680664 seconds ---
# 20fold 3-sigma clipping for 669
# --- 3.298970937728882 seconds ---
# 20fold 3-sigma clipping for 670
# --- 3.2332139015197754 seconds ---
# 20fold 3-sigma clipping for 671
# --- 3.285506248474121 seconds ---
# 20fold 3-sigma clipping for 672
# --- 3.288898229598999 seconds ---
# 20fold 3-sigma clipping for 673
# --- 3.3045716285705566 seconds ---
# 20fold 3-sigma clipping for 674
# --- 3.318913698196411 seconds ---
# 20fold 3-sigma clipping for 675
# --- 3.2308223247528076 seconds ---
# 20fold 3-sigma clipping for 676
# --- 3.271702289581299 seconds ---
# 20fold 3-sigma clipping for 677
# --- 3.272207021713257 seconds ---
# 20fold 3-sigma clipping for 678
# --- 3.299994468688965 seconds ---
# 20fold 3-sigma clipping for 679
# --- 3.3094496726989746 seconds ---
# 20fold 3-sigma clipping for 680
# --- 3.23298978805542 seconds ---
# 20fold 3-sigma clipping for 681
# --- 3.2694039344787598 seconds ---
# 20fold 3-sigma clipping for 682
# --- 3.275895833969116 seconds ---
# 20fold 3-sigma clipping for 683
# --- 3.297001361846924 seconds ---
# 20fold 3-sigma clipping for 684
# --- 3.29718279838562 seconds ---
# 20fold 3-sigma clipping for 685
# --- 3.247077465057373 seconds ---
# 20fold 3-sigma clipping for 686
# --- 3.2869958877563477 seconds ---
# 20fold 3-sigma clipping for 687
# --- 3.2943220138549805 seconds ---
# 20fold 3-sigma clipping for 688
# --- 3.299909830093384 seconds ---
# 20fold 3-sigma clipping for 689
# --- 3.3091747760772705 seconds ---
# 20fold 3-sigma clipping for 690
# --- 3.232189416885376 seconds ---
# 20fold 3-sigma clipping for 691
# --- 3.277100086212158 seconds ---
# 20fold 3-sigma clipping for 692
# --- 3.286897897720337 seconds ---
# 20fold 3-sigma clipping for 693
# --- 3.310762643814087 seconds ---
# 20fold 3-sigma clipping for 694
# --- 3.3158411979675293 seconds ---
# 20fold 3-sigma clipping for 695
# --- 3.247849225997925 seconds ---
# 20fold 3-sigma clipping for 696
# --- 3.279042959213257 seconds ---
# 20fold 3-sigma clipping for 697
# --- 3.308021306991577 seconds ---
# 20fold 3-sigma clipping for 698
# --- 3.3231024742126465 seconds ---
# 20fold 3-sigma clipping for 699
# --- 3.3260772228240967 seconds ---
# 20fold 3-sigma clipping for 700
# --- 3.2476933002471924 seconds ---
# 20fold 3-sigma clipping for 701
# --- 3.283332586288452 seconds ---
# 20fold 3-sigma clipping for 702
# --- 3.2940139770507812 seconds ---
# 20fold 3-sigma clipping for 703
# --- 3.307199001312256 seconds ---
# 20fold 3-sigma clipping for 704
# --- 3.3180832862854004 seconds ---
# 20fold 3-sigma clipping for 705
# --- 3.2535948753356934 seconds ---
# 20fold 3-sigma clipping for 706
# --- 3.279249429702759 seconds ---
# 20fold 3-sigma clipping for 707
# --- 3.2997617721557617 seconds ---
# 20fold 3-sigma clipping for 708
# --- 3.3160572052001953 seconds ---
# 20fold 3-sigma clipping for 709
# --- 3.32647705078125 seconds ---
# 20fold 3-sigma clipping for 710
# --- 3.243896484375 seconds ---
# 20fold 3-sigma clipping for 711
# --- 3.286320209503174 seconds ---
# 20fold 3-sigma clipping for 712
# --- 3.2988088130950928 seconds ---
# 20fold 3-sigma clipping for 713
# --- 3.3006041049957275 seconds ---
# 20fold 3-sigma clipping for 714
# --- 3.3174028396606445 seconds ---
# 20fold 3-sigma clipping for 715
# --- 3.2412288188934326 seconds ---
# 20fold 3-sigma clipping for 716
# --- 3.2897634506225586 seconds ---
# 20fold 3-sigma clipping for 717
# --- 3.2941806316375732 seconds ---
# 20fold 3-sigma clipping for 718
# --- 3.31097674369812 seconds ---
# 20fold 3-sigma clipping for 719
# --- 3.325191020965576 seconds ---
# 20fold 3-sigma clipping for 720
# --- 3.2530531883239746 seconds ---
# 20fold 3-sigma clipping for 721
# --- 3.292600154876709 seconds ---
# 20fold 3-sigma clipping for 722
# --- 3.2955844402313232 seconds ---
# 20fold 3-sigma clipping for 723
# --- 3.3021373748779297 seconds ---
# 20fold 3-sigma clipping for 724
# --- 3.314955472946167 seconds ---
# 20fold 3-sigma clipping for 725
# --- 3.241988182067871 seconds ---
# 20fold 3-sigma clipping for 726
# --- 3.279836416244507 seconds ---
# 20fold 3-sigma clipping for 727
# --- 3.285250186920166 seconds ---
# 20fold 3-sigma clipping for 728
# --- 3.295485496520996 seconds ---
# 20fold 3-sigma clipping for 729
# --- 3.3139472007751465 seconds ---
# 20fold 3-sigma clipping for 730
# --- 3.250493288040161 seconds ---
# 20fold 3-sigma clipping for 731
# --- 3.2728354930877686 seconds ---
# 20fold 3-sigma clipping for 732
# --- 3.285323143005371 seconds ---
# 20fold 3-sigma clipping for 733
# --- 3.303863525390625 seconds ---
# 20fold 3-sigma clipping for 734
# --- 3.3051650524139404 seconds ---
# 20fold 3-sigma clipping for 735
# --- 3.2211756706237793 seconds ---
# 20fold 3-sigma clipping for 736
# --- 3.2656261920928955 seconds ---
# 20fold 3-sigma clipping for 737
# --- 3.28637433052063 seconds ---
# 20fold 3-sigma clipping for 738
# --- 3.303173065185547 seconds ---
# 20fold 3-sigma clipping for 739
# --- 3.3001134395599365 seconds ---
# 20fold 3-sigma clipping for 740
# --- 3.2308480739593506 seconds ---
# 20fold 3-sigma clipping for 741
# --- 3.27205753326416 seconds ---
# 20fold 3-sigma clipping for 742
# --- 3.2802305221557617 seconds ---
# 20fold 3-sigma clipping for 743
# --- 3.296982765197754 seconds ---
# 20fold 3-sigma clipping for 744
# --- 3.3305752277374268 seconds ---
# 20fold 3-sigma clipping for 745
# --- 3.2327020168304443 seconds ---
# 20fold 3-sigma clipping for 746
# --- 3.2718169689178467 seconds ---
# 20fold 3-sigma clipping for 747
# --- 3.273911714553833 seconds ---
# 20fold 3-sigma clipping for 748
# --- 3.2981410026550293 seconds ---
# 20fold 3-sigma clipping for 749
# --- 3.3070297241210938 seconds ---
# 20fold 3-sigma clipping for 750
# --- 3.2318787574768066 seconds ---
# 20fold 3-sigma clipping for 751
# --- 3.278945207595825 seconds ---
# 20fold 3-sigma clipping for 752
# --- 3.29156231880188 seconds ---
# 20fold 3-sigma clipping for 753
# --- 3.2997963428497314 seconds ---
# 20fold 3-sigma clipping for 754
# --- 3.301682233810425 seconds ---
# 20fold 3-sigma clipping for 755
# --- 3.228785753250122 seconds ---
# 20fold 3-sigma clipping for 756
# --- 3.2674126625061035 seconds ---
# 20fold 3-sigma clipping for 757
# --- 3.284715175628662 seconds ---
# 20fold 3-sigma clipping for 758
# --- 3.3150582313537598 seconds ---
# 20fold 3-sigma clipping for 759
# --- 3.324157953262329 seconds ---
# 20fold 3-sigma clipping for 760
# --- 3.254096746444702 seconds ---
# 20fold 3-sigma clipping for 761
# --- 3.291304588317871 seconds ---
# 20fold 3-sigma clipping for 762
# --- 3.292161464691162 seconds ---
# 20fold 3-sigma clipping for 763
# --- 3.3096330165863037 seconds ---
# 20fold 3-sigma clipping for 764
# --- 3.3202290534973145 seconds ---
# 20fold 3-sigma clipping for 765
# --- 3.249129056930542 seconds ---
# 20fold 3-sigma clipping for 766
# --- 3.293926477432251 seconds ---
# 20fold 3-sigma clipping for 767
# --- 3.285104751586914 seconds ---
# 20fold 3-sigma clipping for 768
# --- 3.3168959617614746 seconds ---
# 20fold 3-sigma clipping for 769
# --- 3.3021349906921387 seconds ---
# 20fold 3-sigma clipping for 770
# --- 3.2386460304260254 seconds ---
# 20fold 3-sigma clipping for 771
# --- 3.272578239440918 seconds ---
# 20fold 3-sigma clipping for 772
# --- 3.2859439849853516 seconds ---
# 20fold 3-sigma clipping for 773
# --- 3.31577730178833 seconds ---
# 20fold 3-sigma clipping for 774
# --- 3.3179221153259277 seconds ---
# 20fold 3-sigma clipping for 775
# --- 3.250342845916748 seconds ---
# 20fold 3-sigma clipping for 776
# --- 3.28338885307312 seconds ---
# 20fold 3-sigma clipping for 777
# --- 3.2839112281799316 seconds ---
# 20fold 3-sigma clipping for 778
# --- 3.306877374649048 seconds ---
# 20fold 3-sigma clipping for 779
# --- 3.3160693645477295 seconds ---
# 20fold 3-sigma clipping for 780
# --- 3.256793260574341 seconds ---
# 20fold 3-sigma clipping for 781
# --- 3.297300100326538 seconds ---
# 20fold 3-sigma clipping for 782
# --- 3.2927074432373047 seconds ---
# 20fold 3-sigma clipping for 783
# --- 3.3168444633483887 seconds ---
# 20fold 3-sigma clipping for 784
# --- 3.319854497909546 seconds ---
# 20fold 3-sigma clipping for 785
# --- 3.2594735622406006 seconds ---
# 20fold 3-sigma clipping for 786
# --- 3.29036545753479 seconds ---
# 20fold 3-sigma clipping for 787
# --- 3.2953500747680664 seconds ---
# 20fold 3-sigma clipping for 788
# --- 3.3084781169891357 seconds ---
# 20fold 3-sigma clipping for 789
# --- 3.3183295726776123 seconds ---
# 20fold 3-sigma clipping for 790
# --- 3.2549943923950195 seconds ---
# 20fold 3-sigma clipping for 791
# --- 3.285916805267334 seconds ---
# 20fold 3-sigma clipping for 792
# --- 3.287942886352539 seconds ---
# 20fold 3-sigma clipping for 793
# --- 3.3023552894592285 seconds ---
# 20fold 3-sigma clipping for 794
# --- 3.3163788318634033 seconds ---
# 20fold 3-sigma clipping for 795
# --- 3.2444775104522705 seconds ---
# 20fold 3-sigma clipping for 796
# --- 3.280409574508667 seconds ---
# 20fold 3-sigma clipping for 797
# --- 3.2969307899475098 seconds ---
# 20fold 3-sigma clipping for 798
# --- 3.300098180770874 seconds ---
# 20fold 3-sigma clipping for 799
# --- 3.315558433532715 seconds ---
# 20fold 3-sigma clipping for 800
# --- 3.2337794303894043 seconds ---
# 20fold 3-sigma clipping for 801
# --- 3.2768425941467285 seconds ---
# 20fold 3-sigma clipping for 802
# --- 3.293902635574341 seconds ---
# 20fold 3-sigma clipping for 803
# --- 3.294959783554077 seconds ---
# 20fold 3-sigma clipping for 804
# --- 3.303946018218994 seconds ---
# 20fold 3-sigma clipping for 805
# --- 3.2261054515838623 seconds ---
# 20fold 3-sigma clipping for 806
# --- 3.2688963413238525 seconds ---
# 20fold 3-sigma clipping for 807
# --- 3.2788491249084473 seconds ---
# 20fold 3-sigma clipping for 808
# --- 3.2936673164367676 seconds ---
# 20fold 3-sigma clipping for 809
# --- 3.3081178665161133 seconds ---
# 20fold 3-sigma clipping for 810
# --- 3.2576682567596436 seconds ---
# 20fold 3-sigma clipping for 811
# --- 3.3000216484069824 seconds ---
# 20fold 3-sigma clipping for 812
# --- 3.305584669113159 seconds ---
# 20fold 3-sigma clipping for 813
# --- 3.302957534790039 seconds ---
# 20fold 3-sigma clipping for 814
# --- 3.3108174800872803 seconds ---
# 20fold 3-sigma clipping for 815
# --- 3.22886323928833 seconds ---
# 20fold 3-sigma clipping for 816
# --- 3.2721197605133057 seconds ---
# 20fold 3-sigma clipping for 817
# --- 3.30078125 seconds ---
# 20fold 3-sigma clipping for 818
# --- 3.312018394470215 seconds ---
# 20fold 3-sigma clipping for 819
# --- 3.3213155269622803 seconds ---
# 20fold 3-sigma clipping for 820
# --- 3.231872320175171 seconds ---
# 20fold 3-sigma clipping for 821
# --- 3.266669988632202 seconds ---
# 20fold 3-sigma clipping for 822
# --- 3.277008295059204 seconds ---
# 20fold 3-sigma clipping for 823
# --- 3.2955615520477295 seconds ---
# 20fold 3-sigma clipping for 824
# --- 3.311312437057495 seconds ---
# 20fold 3-sigma clipping for 825
# --- 3.2404141426086426 seconds ---
# 20fold 3-sigma clipping for 826
# --- 3.2713232040405273 seconds ---
# 20fold 3-sigma clipping for 827
# --- 3.2830898761749268 seconds ---
# 20fold 3-sigma clipping for 828
# --- 3.291990280151367 seconds ---
# 20fold 3-sigma clipping for 829
# --- 3.3060688972473145 seconds ---
# 20fold 3-sigma clipping for 830
# --- 3.240077257156372 seconds ---
# 20fold 3-sigma clipping for 831
# --- 3.296584367752075 seconds ---
# 20fold 3-sigma clipping for 832
# --- 3.3096120357513428 seconds ---
# 20fold 3-sigma clipping for 833
# --- 3.315624237060547 seconds ---
# 20fold 3-sigma clipping for 834
# --- 3.325533866882324 seconds ---
# 20fold 3-sigma clipping for 835
# --- 3.241541862487793 seconds ---
# 20fold 3-sigma clipping for 836
# --- 3.279467821121216 seconds ---
# 20fold 3-sigma clipping for 837
# --- 3.279827833175659 seconds ---
# 20fold 3-sigma clipping for 838
# --- 3.2931907176971436 seconds ---
# 20fold 3-sigma clipping for 839
# --- 3.3082871437072754 seconds ---
# 20fold 3-sigma clipping for 840
# --- 3.243025064468384 seconds ---
# 20fold 3-sigma clipping for 841
# --- 3.2970352172851562 seconds ---
# 20fold 3-sigma clipping for 842
# --- 3.296300172805786 seconds ---
# 20fold 3-sigma clipping for 843
# --- 3.3087310791015625 seconds ---
# 20fold 3-sigma clipping for 844
# --- 3.301480293273926 seconds ---
# 20fold 3-sigma clipping for 845
# --- 3.235304355621338 seconds ---
# 20fold 3-sigma clipping for 846
# --- 3.2869608402252197 seconds ---
# 20fold 3-sigma clipping for 847
# --- 3.297067403793335 seconds ---
# 20fold 3-sigma clipping for 848
# --- 3.3090593814849854 seconds ---
# 20fold 3-sigma clipping for 849
# --- 3.315351963043213 seconds ---
# 20fold 3-sigma clipping for 850
# --- 3.2335124015808105 seconds ---
# 20fold 3-sigma clipping for 851
# --- 3.27066969871521 seconds ---
# 20fold 3-sigma clipping for 852
# --- 3.2863051891326904 seconds ---
# 20fold 3-sigma clipping for 853
# --- 3.301711082458496 seconds ---
# 20fold 3-sigma clipping for 854
# --- 3.3242969512939453 seconds ---
# 20fold 3-sigma clipping for 855
# --- 3.2335660457611084 seconds ---
# 20fold 3-sigma clipping for 856
# --- 3.27543306350708 seconds ---
# 20fold 3-sigma clipping for 857
# --- 3.2712526321411133 seconds ---
# 20fold 3-sigma clipping for 858
# --- 3.2955124378204346 seconds ---
# 20fold 3-sigma clipping for 859
# --- 3.3135735988616943 seconds ---
# 20fold 3-sigma clipping for 860
# --- 3.242584228515625 seconds ---
# 20fold 3-sigma clipping for 861
# --- 3.2903852462768555 seconds ---
# 20fold 3-sigma clipping for 862
# --- 3.2858083248138428 seconds ---
# 20fold 3-sigma clipping for 863
# --- 3.2932283878326416 seconds ---
# 20fold 3-sigma clipping for 864
# --- 3.301694393157959 seconds ---
# 20fold 3-sigma clipping for 865
# --- 3.2357778549194336 seconds ---
# 20fold 3-sigma clipping for 866
# --- 3.2692501544952393 seconds ---
# 20fold 3-sigma clipping for 867
# --- 3.293954372406006 seconds ---
# 20fold 3-sigma clipping for 868
# --- 3.324594736099243 seconds ---
# 20fold 3-sigma clipping for 869
# --- 3.322155475616455 seconds ---
# 20fold 3-sigma clipping for 870
# --- 3.249821424484253 seconds ---
# 20fold 3-sigma clipping for 871
# --- 3.2799670696258545 seconds ---

# %%
# -- data proprecessing for the image from row0 to row800
filtered_hsi0_half1 = sigma_clipping(cube0, "half1")
np.save("filtered_hsi0_half1.npy", filtered_hsi0_half1)
# Out:
# 20fold 3-sigma clipping for 0
# --- 3.273256540298462 seconds ---
# 20fold 3-sigma clipping for 1
# --- 3.208207368850708 seconds ---
# 20fold 3-sigma clipping for 2
# --- 3.216503143310547 seconds ---
# 20fold 3-sigma clipping for 3
# --- 3.217857599258423 seconds ---
# 20fold 3-sigma clipping for 4
# --- 3.2098405361175537 seconds ---
# 20fold 3-sigma clipping for 5
# --- 3.1718127727508545 seconds ---
# 20fold 3-sigma clipping for 6
# --- 3.2114007472991943 seconds ---
# 20fold 3-sigma clipping for 7
# --- 3.2195656299591064 seconds ---
# 20fold 3-sigma clipping for 8
# --- 3.2327518463134766 seconds ---
# 20fold 3-sigma clipping for 9
# --- 3.213893413543701 seconds ---
# 20fold 3-sigma clipping for 10
# --- 3.1724023818969727 seconds ---
# 20fold 3-sigma clipping for 11
# --- 3.2035529613494873 seconds ---
# 20fold 3-sigma clipping for 12
# --- 3.2206244468688965 seconds ---
# 20fold 3-sigma clipping for 13
# --- 3.228658437728882 seconds ---
# 20fold 3-sigma clipping for 14
# --- 3.2167515754699707 seconds ---
# 20fold 3-sigma clipping for 15
# --- 3.1728992462158203 seconds ---
# 20fold 3-sigma clipping for 16
# --- 3.2132601737976074 seconds ---
# 20fold 3-sigma clipping for 17
# --- 3.2195212841033936 seconds ---
# 20fold 3-sigma clipping for 18
# --- 3.2330870628356934 seconds ---
# 20fold 3-sigma clipping for 19
# --- 3.2485063076019287 seconds ---
# 20fold 3-sigma clipping for 20
# --- 3.2390646934509277 seconds ---
# 20fold 3-sigma clipping for 21
# --- 3.2949156761169434 seconds ---
# 20fold 3-sigma clipping for 22
# --- 3.2789511680603027 seconds ---
# 20fold 3-sigma clipping for 23
# --- 3.2986955642700195 seconds ---
# 20fold 3-sigma clipping for 24
# --- 3.282170057296753 seconds ---
# 20fold 3-sigma clipping for 25
# --- 3.232952117919922 seconds ---
# 20fold 3-sigma clipping for 26
# --- 3.273188591003418 seconds ---
# 20fold 3-sigma clipping for 27
# --- 3.2808220386505127 seconds ---
# 20fold 3-sigma clipping for 28
# --- 3.3058438301086426 seconds ---
# 20fold 3-sigma clipping for 29
# --- 3.276679515838623 seconds ---
# 20fold 3-sigma clipping for 30
# --- 3.2415175437927246 seconds ---
# 20fold 3-sigma clipping for 31
# --- 3.2790894508361816 seconds ---
# 20fold 3-sigma clipping for 32
# --- 3.281895399093628 seconds ---
# 20fold 3-sigma clipping for 33
# --- 3.300908088684082 seconds ---
# 20fold 3-sigma clipping for 34
# --- 3.2775931358337402 seconds ---
# 20fold 3-sigma clipping for 35
# --- 3.241941213607788 seconds ---
# 20fold 3-sigma clipping for 36
# --- 3.2807929515838623 seconds ---
# 20fold 3-sigma clipping for 37
# --- 3.288456439971924 seconds ---
# 20fold 3-sigma clipping for 38
# --- 3.3281142711639404 seconds ---
# 20fold 3-sigma clipping for 39
# --- 3.3014042377471924 seconds ---
# 20fold 3-sigma clipping for 40
# --- 3.2418601512908936 seconds ---
# 20fold 3-sigma clipping for 41
# --- 3.2716104984283447 seconds ---
# 20fold 3-sigma clipping for 42
# --- 3.288935899734497 seconds ---
# 20fold 3-sigma clipping for 43
# --- 3.3114213943481445 seconds ---
# 20fold 3-sigma clipping for 44
# --- 3.2948341369628906 seconds ---
# 20fold 3-sigma clipping for 45
# --- 3.2541887760162354 seconds ---
# 20fold 3-sigma clipping for 46
# --- 3.2977890968322754 seconds ---
# 20fold 3-sigma clipping for 47
# --- 3.2861685752868652 seconds ---
# 20fold 3-sigma clipping for 48
# --- 3.2980260848999023 seconds ---
# 20fold 3-sigma clipping for 49
# --- 3.288778305053711 seconds ---
# 20fold 3-sigma clipping for 50
# --- 3.2496213912963867 seconds ---
# 20fold 3-sigma clipping for 51
# --- 3.2839853763580322 seconds ---
# 20fold 3-sigma clipping for 52
# --- 3.2904036045074463 seconds ---
# 20fold 3-sigma clipping for 53
# --- 3.307649612426758 seconds ---
# 20fold 3-sigma clipping for 54
# --- 3.2897911071777344 seconds ---
# 20fold 3-sigma clipping for 55
# --- 3.2498960494995117 seconds ---
# 20fold 3-sigma clipping for 56
# --- 3.2702417373657227 seconds ---
# 20fold 3-sigma clipping for 57
# --- 3.2857885360717773 seconds ---
# 20fold 3-sigma clipping for 58
# --- 3.2776715755462646 seconds ---
# 20fold 3-sigma clipping for 59
# --- 3.280000925064087 seconds ---
# 20fold 3-sigma clipping for 60
# --- 3.239259719848633 seconds ---
# 20fold 3-sigma clipping for 61
# --- 3.2694711685180664 seconds ---
# 20fold 3-sigma clipping for 62
# --- 3.2916696071624756 seconds ---
# 20fold 3-sigma clipping for 63
# --- 3.2936606407165527 seconds ---
# 20fold 3-sigma clipping for 64
# --- 3.2694694995880127 seconds ---
# 20fold 3-sigma clipping for 65
# --- 3.228590488433838 seconds ---
# 20fold 3-sigma clipping for 66
# --- 3.2738144397735596 seconds ---
# 20fold 3-sigma clipping for 67
# --- 3.296142578125 seconds ---
# 20fold 3-sigma clipping for 68
# --- 3.3101089000701904 seconds ---
# 20fold 3-sigma clipping for 69
# --- 3.290187120437622 seconds ---
# 20fold 3-sigma clipping for 70
# --- 3.240448474884033 seconds ---
# 20fold 3-sigma clipping for 71
# --- 3.27254319190979 seconds ---
# 20fold 3-sigma clipping for 72
# --- 3.2853217124938965 seconds ---
# 20fold 3-sigma clipping for 73
# --- 3.3066883087158203 seconds ---
# 20fold 3-sigma clipping for 74
# --- 3.2705142498016357 seconds ---
# 20fold 3-sigma clipping for 75
# --- 3.2396202087402344 seconds ---
# 20fold 3-sigma clipping for 76
# --- 3.261507034301758 seconds ---
# 20fold 3-sigma clipping for 77
# --- 3.269146680831909 seconds ---
# 20fold 3-sigma clipping for 78
# --- 3.296419620513916 seconds ---
# 20fold 3-sigma clipping for 79
# --- 3.280266284942627 seconds ---
# 20fold 3-sigma clipping for 80
# --- 3.228830575942993 seconds ---
# 20fold 3-sigma clipping for 81
# --- 3.2794077396392822 seconds ---
# 20fold 3-sigma clipping for 82
# --- 3.3121230602264404 seconds ---
# 20fold 3-sigma clipping for 83
# --- 3.303330183029175 seconds ---
# 20fold 3-sigma clipping for 84
# --- 3.3033368587493896 seconds ---
# 20fold 3-sigma clipping for 85
# --- 3.2401387691497803 seconds ---
# 20fold 3-sigma clipping for 86
# --- 3.2770819664001465 seconds ---
# 20fold 3-sigma clipping for 87
# --- 3.2949600219726562 seconds ---
# 20fold 3-sigma clipping for 88
# --- 3.3058207035064697 seconds ---
# 20fold 3-sigma clipping for 89
# --- 3.2839951515197754 seconds ---
# 20fold 3-sigma clipping for 90
# --- 3.2389883995056152 seconds ---
# 20fold 3-sigma clipping for 91
# --- 3.287142515182495 seconds ---
# 20fold 3-sigma clipping for 92
# --- 3.288729190826416 seconds ---
# 20fold 3-sigma clipping for 93
# --- 3.312762498855591 seconds ---
# 20fold 3-sigma clipping for 94
# --- 3.2931747436523438 seconds ---
# 20fold 3-sigma clipping for 95
# --- 3.2495064735412598 seconds ---
# 20fold 3-sigma clipping for 96
# --- 3.2845983505249023 seconds ---
# 20fold 3-sigma clipping for 97
# --- 3.2997617721557617 seconds ---
# 20fold 3-sigma clipping for 98
# --- 3.3235578536987305 seconds ---
# 20fold 3-sigma clipping for 99
# --- 3.2871646881103516 seconds ---
# 20fold 3-sigma clipping for 100
# --- 3.2618467807769775 seconds ---
# 20fold 3-sigma clipping for 101
# --- 3.3050878047943115 seconds ---
# 20fold 3-sigma clipping for 102
# --- 3.3288772106170654 seconds ---
# 20fold 3-sigma clipping for 103
# --- 3.329418420791626 seconds ---
# 20fold 3-sigma clipping for 104
# --- 3.2987539768218994 seconds ---
# 20fold 3-sigma clipping for 105
# --- 3.2737245559692383 seconds ---
# 20fold 3-sigma clipping for 106
# --- 3.3020780086517334 seconds ---
# 20fold 3-sigma clipping for 107
# --- 3.299426317214966 seconds ---
# 20fold 3-sigma clipping for 108
# --- 3.310347080230713 seconds ---
# 20fold 3-sigma clipping for 109
# --- 3.281467914581299 seconds ---
# 20fold 3-sigma clipping for 110
# --- 3.2650766372680664 seconds ---
# 20fold 3-sigma clipping for 111
# --- 3.296962261199951 seconds ---
# 20fold 3-sigma clipping for 112
# --- 3.308306932449341 seconds ---
# 20fold 3-sigma clipping for 113
# --- 3.313380718231201 seconds ---
# 20fold 3-sigma clipping for 114
# --- 3.299600601196289 seconds ---
# 20fold 3-sigma clipping for 115
# --- 3.250598430633545 seconds ---
# 20fold 3-sigma clipping for 116
# --- 3.2913875579833984 seconds ---
# 20fold 3-sigma clipping for 117
# --- 3.2891502380371094 seconds ---
# 20fold 3-sigma clipping for 118
# --- 3.308292865753174 seconds ---
# 20fold 3-sigma clipping for 119
# --- 3.3004584312438965 seconds ---
# 20fold 3-sigma clipping for 120
# --- 3.2420430183410645 seconds ---
# 20fold 3-sigma clipping for 121
# --- 3.2830164432525635 seconds ---
# 20fold 3-sigma clipping for 122
# --- 3.2793238162994385 seconds ---
# 20fold 3-sigma clipping for 123
# --- 3.2935616970062256 seconds ---
# 20fold 3-sigma clipping for 124
# --- 3.267354726791382 seconds ---
# 20fold 3-sigma clipping for 125
# --- 3.2246499061584473 seconds ---
# 20fold 3-sigma clipping for 126
# --- 3.270350456237793 seconds ---
# 20fold 3-sigma clipping for 127
# --- 3.2683422565460205 seconds ---
# 20fold 3-sigma clipping for 128
# --- 3.2873620986938477 seconds ---
# 20fold 3-sigma clipping for 129
# --- 3.2715322971343994 seconds ---
# 20fold 3-sigma clipping for 130
# --- 3.224076986312866 seconds ---
# 20fold 3-sigma clipping for 131
# --- 3.261122465133667 seconds ---
# 20fold 3-sigma clipping for 132
# --- 3.28871488571167 seconds ---
# 20fold 3-sigma clipping for 133
# --- 3.2953391075134277 seconds ---
# 20fold 3-sigma clipping for 134
# --- 3.283313512802124 seconds ---
# 20fold 3-sigma clipping for 135
# --- 3.241725444793701 seconds ---
# 20fold 3-sigma clipping for 136
# --- 3.2869186401367188 seconds ---
# 20fold 3-sigma clipping for 137
# --- 3.2853498458862305 seconds ---
# 20fold 3-sigma clipping for 138
# --- 3.3055624961853027 seconds ---
# 20fold 3-sigma clipping for 139
# --- 3.2930328845977783 seconds ---
# 20fold 3-sigma clipping for 140
# --- 3.261394739151001 seconds ---
# 20fold 3-sigma clipping for 141
# --- 3.2924575805664062 seconds ---
# 20fold 3-sigma clipping for 142
# --- 3.312678337097168 seconds ---
# 20fold 3-sigma clipping for 143
# --- 3.3144280910491943 seconds ---
# 20fold 3-sigma clipping for 144
# --- 3.3096508979797363 seconds ---
# 20fold 3-sigma clipping for 145
# --- 3.270197868347168 seconds ---
# 20fold 3-sigma clipping for 146
# --- 3.2938807010650635 seconds ---
# 20fold 3-sigma clipping for 147
# --- 3.2980923652648926 seconds ---
# 20fold 3-sigma clipping for 148
# --- 3.3106682300567627 seconds ---
# 20fold 3-sigma clipping for 149
# --- 3.291450023651123 seconds ---
# 20fold 3-sigma clipping for 150
# --- 3.2503440380096436 seconds ---
# 20fold 3-sigma clipping for 151
# --- 3.290475368499756 seconds ---
# 20fold 3-sigma clipping for 152
# --- 3.2817275524139404 seconds ---
# 20fold 3-sigma clipping for 153
# --- 3.2950398921966553 seconds ---
# 20fold 3-sigma clipping for 154
# --- 3.283832311630249 seconds ---
# 20fold 3-sigma clipping for 155
# --- 3.236934185028076 seconds ---
# 20fold 3-sigma clipping for 156
# --- 3.292015314102173 seconds ---
# 20fold 3-sigma clipping for 157
# --- 3.290735960006714 seconds ---
# 20fold 3-sigma clipping for 158
# --- 3.3112213611602783 seconds ---
# 20fold 3-sigma clipping for 159
# --- 3.289167881011963 seconds ---
# 20fold 3-sigma clipping for 160
# --- 4.096213340759277 seconds ---
# 20fold 3-sigma clipping for 161
# --- 4.762705087661743 seconds ---
# 20fold 3-sigma clipping for 162
# --- 4.804168224334717 seconds ---
# 20fold 3-sigma clipping for 163
# --- 4.851450681686401 seconds ---
# 20fold 3-sigma clipping for 164
# --- 4.788310289382935 seconds ---
# 20fold 3-sigma clipping for 165
# --- 4.737246036529541 seconds ---
# 20fold 3-sigma clipping for 166
# --- 4.433383941650391 seconds ---
# 20fold 3-sigma clipping for 167
# --- 3.329815626144409 seconds ---
# 20fold 3-sigma clipping for 168
# --- 3.3667380809783936 seconds ---
# 20fold 3-sigma clipping for 169
# --- 3.326786756515503 seconds ---
# 20fold 3-sigma clipping for 170
# --- 3.273099184036255 seconds ---
# 20fold 3-sigma clipping for 171
# --- 3.305896282196045 seconds ---
# 20fold 3-sigma clipping for 172
# --- 3.330151081085205 seconds ---
# 20fold 3-sigma clipping for 173
# --- 3.332249879837036 seconds ---
# 20fold 3-sigma clipping for 174
# --- 3.322654962539673 seconds ---
# 20fold 3-sigma clipping for 175
# --- 3.256798028945923 seconds ---
# 20fold 3-sigma clipping for 176
# --- 3.3144495487213135 seconds ---
# 20fold 3-sigma clipping for 177
# --- 3.3049075603485107 seconds ---
# 20fold 3-sigma clipping for 178
# --- 3.3130602836608887 seconds ---
# 20fold 3-sigma clipping for 179
# --- 3.2879128456115723 seconds ---
# 20fold 3-sigma clipping for 180
# --- 3.230074882507324 seconds ---
# 20fold 3-sigma clipping for 181
# --- 3.2770540714263916 seconds ---
# 20fold 3-sigma clipping for 182
# --- 3.284665822982788 seconds ---
# 20fold 3-sigma clipping for 183
# --- 3.2996623516082764 seconds ---
# 20fold 3-sigma clipping for 184
# --- 3.28155255317688 seconds ---
# 20fold 3-sigma clipping for 185
# --- 3.2342886924743652 seconds ---
# 20fold 3-sigma clipping for 186
# --- 3.294671058654785 seconds ---
# 20fold 3-sigma clipping for 187
# --- 3.2934892177581787 seconds ---
# 20fold 3-sigma clipping for 188
# --- 3.3126301765441895 seconds ---
# 20fold 3-sigma clipping for 189
# --- 3.2995057106018066 seconds ---
# 20fold 3-sigma clipping for 190
# --- 3.232210159301758 seconds ---
# 20fold 3-sigma clipping for 191
# --- 3.273778200149536 seconds ---
# 20fold 3-sigma clipping for 192
# --- 3.2692348957061768 seconds ---
# 20fold 3-sigma clipping for 193
# --- 3.299422025680542 seconds ---
# 20fold 3-sigma clipping for 194
# --- 3.27189564704895 seconds ---
# 20fold 3-sigma clipping for 195
# --- 3.2195544242858887 seconds ---
# 20fold 3-sigma clipping for 196
# --- 3.273689031600952 seconds ---
# 20fold 3-sigma clipping for 197
# --- 3.283834457397461 seconds ---
# 20fold 3-sigma clipping for 198
# --- 3.320481777191162 seconds ---
# 20fold 3-sigma clipping for 199
# --- 3.3005480766296387 seconds ---
# 20fold 3-sigma clipping for 200
# --- 3.239149570465088 seconds ---
# 20fold 3-sigma clipping for 201
# --- 3.2930524349212646 seconds ---
# 20fold 3-sigma clipping for 202
# --- 3.286755084991455 seconds ---
# 20fold 3-sigma clipping for 203
# --- 3.304658889770508 seconds ---
# 20fold 3-sigma clipping for 204
# --- 3.3052947521209717 seconds ---
# 20fold 3-sigma clipping for 205
# --- 3.2472405433654785 seconds ---
# 20fold 3-sigma clipping for 206
# --- 3.2938997745513916 seconds ---
# 20fold 3-sigma clipping for 207
# --- 3.3069517612457275 seconds ---
# 20fold 3-sigma clipping for 208
# --- 3.3291242122650146 seconds ---
# 20fold 3-sigma clipping for 209
# --- 3.2982709407806396 seconds ---
# 20fold 3-sigma clipping for 210
# --- 3.2622439861297607 seconds ---
# 20fold 3-sigma clipping for 211
# --- 3.3003880977630615 seconds ---
# 20fold 3-sigma clipping for 212
# --- 3.308286190032959 seconds ---
# 20fold 3-sigma clipping for 213
# --- 3.311497688293457 seconds ---
# 20fold 3-sigma clipping for 214
# --- 3.2995474338531494 seconds ---
# 20fold 3-sigma clipping for 215
# --- 3.2722671031951904 seconds ---
# 20fold 3-sigma clipping for 216
# --- 3.310129165649414 seconds ---
# 20fold 3-sigma clipping for 217
# --- 3.2992968559265137 seconds ---
# 20fold 3-sigma clipping for 218
# --- 3.324178457260132 seconds ---
# 20fold 3-sigma clipping for 219
# --- 3.2983734607696533 seconds ---
# 20fold 3-sigma clipping for 220
# --- 3.24615216255188 seconds ---
# 20fold 3-sigma clipping for 221
# --- 3.3036656379699707 seconds ---
# 20fold 3-sigma clipping for 222
# --- 3.3084113597869873 seconds ---
# 20fold 3-sigma clipping for 223
# --- 3.3223025798797607 seconds ---
# 20fold 3-sigma clipping for 224
# --- 3.2913315296173096 seconds ---
# 20fold 3-sigma clipping for 225
# --- 3.239179849624634 seconds ---
# 20fold 3-sigma clipping for 226
# --- 3.293022871017456 seconds ---
# 20fold 3-sigma clipping for 227
# --- 3.3048641681671143 seconds ---
# 20fold 3-sigma clipping for 228
# --- 3.308807849884033 seconds ---
# 20fold 3-sigma clipping for 229
# --- 3.2718193531036377 seconds ---
# 20fold 3-sigma clipping for 230
# --- 3.2386269569396973 seconds ---
# 20fold 3-sigma clipping for 231
# --- 3.266712188720703 seconds ---
# 20fold 3-sigma clipping for 232
# --- 3.2804784774780273 seconds ---
# 20fold 3-sigma clipping for 233
# --- 3.329799175262451 seconds ---
# 20fold 3-sigma clipping for 234
# --- 3.2982003688812256 seconds ---
# 20fold 3-sigma clipping for 235
# --- 3.242812395095825 seconds ---
# 20fold 3-sigma clipping for 236
# --- 3.3024892807006836 seconds ---
# 20fold 3-sigma clipping for 237
# --- 3.310271978378296 seconds ---
# 20fold 3-sigma clipping for 238
# --- 3.3431949615478516 seconds ---
# 20fold 3-sigma clipping for 239
# --- 3.3271474838256836 seconds ---
# 20fold 3-sigma clipping for 240
# --- 3.2630748748779297 seconds ---
# 20fold 3-sigma clipping for 241
# --- 3.3054590225219727 seconds ---
# 20fold 3-sigma clipping for 242
# --- 3.3278841972351074 seconds ---
# 20fold 3-sigma clipping for 243
# --- 3.3353986740112305 seconds ---
# 20fold 3-sigma clipping for 244
# --- 3.32365345954895 seconds ---
# 20fold 3-sigma clipping for 245
# --- 3.277463436126709 seconds ---
# 20fold 3-sigma clipping for 246
# --- 3.296546697616577 seconds ---
# 20fold 3-sigma clipping for 247
# --- 3.3138608932495117 seconds ---
# 20fold 3-sigma clipping for 248
# --- 3.3205630779266357 seconds ---
# 20fold 3-sigma clipping for 249
# --- 3.3027150630950928 seconds ---
# 20fold 3-sigma clipping for 250
# --- 3.2501132488250732 seconds ---
# 20fold 3-sigma clipping for 251
# --- 3.3017523288726807 seconds ---
# 20fold 3-sigma clipping for 252
# --- 3.3229236602783203 seconds ---
# 20fold 3-sigma clipping for 253
# --- 3.350982666015625 seconds ---
# 20fold 3-sigma clipping for 254
# --- 3.3073854446411133 seconds ---
# 20fold 3-sigma clipping for 255
# --- 3.261211395263672 seconds ---
# 20fold 3-sigma clipping for 256
# --- 3.300546169281006 seconds ---
# 20fold 3-sigma clipping for 257
# --- 3.305305004119873 seconds ---
# 20fold 3-sigma clipping for 258
# --- 4.205855131149292 seconds ---
# 20fold 3-sigma clipping for 259
# --- 4.274038314819336 seconds ---
# 20fold 3-sigma clipping for 260
# --- 3.283858299255371 seconds ---
# 20fold 3-sigma clipping for 261
# --- 3.3254892826080322 seconds ---
# 20fold 3-sigma clipping for 262
# --- 3.3263471126556396 seconds ---
# 20fold 3-sigma clipping for 263
# --- 3.323293924331665 seconds ---
# 20fold 3-sigma clipping for 264
# --- 3.317889451980591 seconds ---
# 20fold 3-sigma clipping for 265
# --- 3.2760167121887207 seconds ---
# 20fold 3-sigma clipping for 266
# --- 3.300833225250244 seconds ---
# 20fold 3-sigma clipping for 267
# --- 3.3203697204589844 seconds ---
# 20fold 3-sigma clipping for 268
# --- 3.336836099624634 seconds ---
# 20fold 3-sigma clipping for 269
# --- 3.3205549716949463 seconds ---
# 20fold 3-sigma clipping for 270
# --- 3.280482292175293 seconds ---
# 20fold 3-sigma clipping for 271
# --- 3.3102946281433105 seconds ---
# 20fold 3-sigma clipping for 272
# --- 3.303474187850952 seconds ---
# 20fold 3-sigma clipping for 273
# --- 3.3319756984710693 seconds ---
# 20fold 3-sigma clipping for 274
# --- 3.3241868019104004 seconds ---
# 20fold 3-sigma clipping for 275
# --- 3.2760133743286133 seconds ---
# 20fold 3-sigma clipping for 276
# --- 3.319061279296875 seconds ---
# 20fold 3-sigma clipping for 277
# --- 3.3197224140167236 seconds ---
# 20fold 3-sigma clipping for 278
# --- 3.3455519676208496 seconds ---
# 20fold 3-sigma clipping for 279
# --- 3.3226611614227295 seconds ---
# 20fold 3-sigma clipping for 280
# --- 3.2795820236206055 seconds ---
# 20fold 3-sigma clipping for 281
# --- 3.3043813705444336 seconds ---
# 20fold 3-sigma clipping for 282
# --- 3.3262743949890137 seconds ---
# 20fold 3-sigma clipping for 283
# --- 3.350463390350342 seconds ---
# 20fold 3-sigma clipping for 284
# --- 3.3319191932678223 seconds ---
# 20fold 3-sigma clipping for 285
# --- 3.281855583190918 seconds ---
# 20fold 3-sigma clipping for 286
# --- 3.316547393798828 seconds ---
# 20fold 3-sigma clipping for 287
# --- 3.3316144943237305 seconds ---
# 20fold 3-sigma clipping for 288
# --- 3.3241710662841797 seconds ---
# 20fold 3-sigma clipping for 289
# --- 3.3155062198638916 seconds ---
# 20fold 3-sigma clipping for 290
# --- 3.277888774871826 seconds ---
# 20fold 3-sigma clipping for 291
# --- 3.324946403503418 seconds ---
# 20fold 3-sigma clipping for 292
# --- 3.3329145908355713 seconds ---
# 20fold 3-sigma clipping for 293
# --- 3.3456037044525146 seconds ---
# 20fold 3-sigma clipping for 294
# --- 3.3264946937561035 seconds ---
# 20fold 3-sigma clipping for 295
# --- 3.2775204181671143 seconds ---
# 20fold 3-sigma clipping for 296
# --- 3.3148436546325684 seconds ---
# 20fold 3-sigma clipping for 297
# --- 3.3359997272491455 seconds ---
# 20fold 3-sigma clipping for 298
# --- 3.347517490386963 seconds ---
# 20fold 3-sigma clipping for 299
# --- 3.326543092727661 seconds ---
# 20fold 3-sigma clipping for 300
# --- 3.2949752807617188 seconds ---
# 20fold 3-sigma clipping for 301
# --- 3.33708119392395 seconds ---
# 20fold 3-sigma clipping for 302
# --- 3.3358609676361084 seconds ---
# 20fold 3-sigma clipping for 303
# --- 3.336333990097046 seconds ---
# 20fold 3-sigma clipping for 304
# --- 3.3283276557922363 seconds ---
# 20fold 3-sigma clipping for 305
# --- 3.276059865951538 seconds ---
# 20fold 3-sigma clipping for 306
# --- 3.307577133178711 seconds ---
# 20fold 3-sigma clipping for 307
# --- 3.318929672241211 seconds ---
# 20fold 3-sigma clipping for 308
# --- 3.3379695415496826 seconds ---
# 20fold 3-sigma clipping for 309
# --- 3.3265092372894287 seconds ---
# 20fold 3-sigma clipping for 310
# --- 3.2744762897491455 seconds ---
# 20fold 3-sigma clipping for 311
# --- 3.3084516525268555 seconds ---
# 20fold 3-sigma clipping for 312
# --- 3.3090624809265137 seconds ---
# 20fold 3-sigma clipping for 313
# --- 3.325993061065674 seconds ---
# 20fold 3-sigma clipping for 314
# --- 3.3120265007019043 seconds ---
# 20fold 3-sigma clipping for 315
# --- 3.2690019607543945 seconds ---
# 20fold 3-sigma clipping for 316
# --- 3.3087353706359863 seconds ---
# 20fold 3-sigma clipping for 317
# --- 3.3226399421691895 seconds ---
# 20fold 3-sigma clipping for 318
# --- 3.3289315700531006 seconds ---
# 20fold 3-sigma clipping for 319
# --- 3.3089702129364014 seconds ---
# 20fold 3-sigma clipping for 320
# --- 3.268728494644165 seconds ---
# 20fold 3-sigma clipping for 321
# --- 3.3058314323425293 seconds ---
# 20fold 3-sigma clipping for 322
# --- 3.31852388381958 seconds ---
# 20fold 3-sigma clipping for 323
# --- 3.3374977111816406 seconds ---
# 20fold 3-sigma clipping for 324
# --- 3.3026654720306396 seconds ---
# 20fold 3-sigma clipping for 325
# --- 3.2674291133880615 seconds ---
# 20fold 3-sigma clipping for 326
# --- 3.2927803993225098 seconds ---
# 20fold 3-sigma clipping for 327
# --- 3.3198399543762207 seconds ---
# 20fold 3-sigma clipping for 328
# --- 3.331270217895508 seconds ---
# 20fold 3-sigma clipping for 329
# --- 3.3088557720184326 seconds ---
# 20fold 3-sigma clipping for 330
# --- 3.2617366313934326 seconds ---
# 20fold 3-sigma clipping for 331
# --- 3.2850277423858643 seconds ---
# 20fold 3-sigma clipping for 332
# --- 3.3083293437957764 seconds ---
# 20fold 3-sigma clipping for 333
# --- 3.325711965560913 seconds ---
# 20fold 3-sigma clipping for 334
# --- 3.3017022609710693 seconds ---
# 20fold 3-sigma clipping for 335
# --- 3.254087448120117 seconds ---
# 20fold 3-sigma clipping for 336
# --- 3.2777810096740723 seconds ---
# 20fold 3-sigma clipping for 337
# --- 3.299964427947998 seconds ---
# 20fold 3-sigma clipping for 338
# --- 3.312103509902954 seconds ---
# 20fold 3-sigma clipping for 339
# --- 3.300625801086426 seconds ---
# 20fold 3-sigma clipping for 340
# --- 3.264411449432373 seconds ---
# 20fold 3-sigma clipping for 341
# --- 3.3077118396759033 seconds ---
# 20fold 3-sigma clipping for 342
# --- 3.324506998062134 seconds ---
# 20fold 3-sigma clipping for 343
# --- 3.3355562686920166 seconds ---
# 20fold 3-sigma clipping for 344
# --- 3.3246586322784424 seconds ---
# 20fold 3-sigma clipping for 345
# --- 3.263094902038574 seconds ---
# 20fold 3-sigma clipping for 346
# --- 3.293724298477173 seconds ---
# 20fold 3-sigma clipping for 347
# --- 3.301297187805176 seconds ---
# 20fold 3-sigma clipping for 348
# --- 3.33579158782959 seconds ---
# 20fold 3-sigma clipping for 349
# --- 3.3155815601348877 seconds ---
# 20fold 3-sigma clipping for 350
# --- 3.271150827407837 seconds ---
# 20fold 3-sigma clipping for 351
# --- 3.2876269817352295 seconds ---
# 20fold 3-sigma clipping for 352
# --- 3.293792963027954 seconds ---
# 20fold 3-sigma clipping for 353
# --- 3.293280601501465 seconds ---
# 20fold 3-sigma clipping for 354
# --- 3.2631537914276123 seconds ---
# 20fold 3-sigma clipping for 355
# --- 3.278715133666992 seconds ---
# 20fold 3-sigma clipping for 356
# --- 3.330723285675049 seconds ---
# 20fold 3-sigma clipping for 357
# --- 3.355018138885498 seconds ---
# 20fold 3-sigma clipping for 358
# --- 3.3610928058624268 seconds ---
# 20fold 3-sigma clipping for 359
# --- 3.34273624420166 seconds ---
# 20fold 3-sigma clipping for 360
# --- 3.3043487071990967 seconds ---
# 20fold 3-sigma clipping for 361
# --- 3.3329014778137207 seconds ---
# 20fold 3-sigma clipping for 362
# --- 3.3485496044158936 seconds ---
# 20fold 3-sigma clipping for 363
# --- 3.3578202724456787 seconds ---
# 20fold 3-sigma clipping for 364
# --- 3.3454740047454834 seconds ---
# 20fold 3-sigma clipping for 365
# --- 3.2964742183685303 seconds ---
# 20fold 3-sigma clipping for 366
# --- 3.3465158939361572 seconds ---
# 20fold 3-sigma clipping for 367
# --- 3.3585455417633057 seconds ---
# 20fold 3-sigma clipping for 368
# --- 3.3497188091278076 seconds ---
# 20fold 3-sigma clipping for 369
# --- 3.341949701309204 seconds ---
# 20fold 3-sigma clipping for 370
# --- 3.2916269302368164 seconds ---
# 20fold 3-sigma clipping for 371
# --- 3.3442277908325195 seconds ---
# 20fold 3-sigma clipping for 372
# --- 3.342813730239868 seconds ---
# 20fold 3-sigma clipping for 373
# --- 3.359865188598633 seconds ---
# 20fold 3-sigma clipping for 374
# --- 3.35500168800354 seconds ---
# 20fold 3-sigma clipping for 375
# --- 3.3201417922973633 seconds ---
# 20fold 3-sigma clipping for 376
# --- 3.356046676635742 seconds ---
# 20fold 3-sigma clipping for 377
# --- 3.3576295375823975 seconds ---
# 20fold 3-sigma clipping for 378
# --- 3.3760547637939453 seconds ---
# 20fold 3-sigma clipping for 379
# --- 3.3451244831085205 seconds ---
# 20fold 3-sigma clipping for 380
# --- 3.311552047729492 seconds ---
# 20fold 3-sigma clipping for 381
# --- 3.3468313217163086 seconds ---
# 20fold 3-sigma clipping for 382
# --- 3.3492681980133057 seconds ---
# 20fold 3-sigma clipping for 383
# --- 3.3678998947143555 seconds ---
# 20fold 3-sigma clipping for 384
# --- 3.349769115447998 seconds ---
# 20fold 3-sigma clipping for 385
# --- 3.303236484527588 seconds ---
# 20fold 3-sigma clipping for 386
# --- 3.3421401977539062 seconds ---
# 20fold 3-sigma clipping for 387
# --- 3.348578691482544 seconds ---
# 20fold 3-sigma clipping for 388
# --- 3.371918201446533 seconds ---
# 20fold 3-sigma clipping for 389
# --- 3.3351454734802246 seconds ---
# 20fold 3-sigma clipping for 390
# --- 3.296396255493164 seconds ---
# 20fold 3-sigma clipping for 391
# --- 3.3366200923919678 seconds ---
# 20fold 3-sigma clipping for 392
# --- 3.3479795455932617 seconds ---
# 20fold 3-sigma clipping for 393
# --- 3.3584320545196533 seconds ---
# 20fold 3-sigma clipping for 394
# --- 3.34114933013916 seconds ---
# 20fold 3-sigma clipping for 395
# --- 3.3056674003601074 seconds ---
# 20fold 3-sigma clipping for 396
# --- 3.3334248065948486 seconds ---
# 20fold 3-sigma clipping for 397
# --- 3.354412317276001 seconds ---
# 20fold 3-sigma clipping for 398
# --- 3.3585622310638428 seconds ---
# 20fold 3-sigma clipping for 399
# --- 3.3429198265075684 seconds ---
# 20fold 3-sigma clipping for 400
# --- 3.2999372482299805 seconds ---
# 20fold 3-sigma clipping for 401
# --- 3.34674334526062 seconds ---
# 20fold 3-sigma clipping for 402
# --- 3.34873366355896 seconds ---
# 20fold 3-sigma clipping for 403
# --- 3.372253894805908 seconds ---
# 20fold 3-sigma clipping for 404
# --- 3.351269483566284 seconds ---
# 20fold 3-sigma clipping for 405
# --- 3.2969374656677246 seconds ---
# 20fold 3-sigma clipping for 406
# --- 3.3380141258239746 seconds ---
# 20fold 3-sigma clipping for 407
# --- 3.34077525138855 seconds ---
# 20fold 3-sigma clipping for 408
# --- 3.359480142593384 seconds ---
# 20fold 3-sigma clipping for 409
# --- 3.33961820602417 seconds ---
# 20fold 3-sigma clipping for 410
# --- 3.2956159114837646 seconds ---
# 20fold 3-sigma clipping for 411
# --- 3.322733163833618 seconds ---
# 20fold 3-sigma clipping for 412
# --- 3.337690830230713 seconds ---
# 20fold 3-sigma clipping for 413
# --- 3.363680362701416 seconds ---
# 20fold 3-sigma clipping for 414
# --- 3.334657669067383 seconds ---
# 20fold 3-sigma clipping for 415
# --- 3.281867265701294 seconds ---
# 20fold 3-sigma clipping for 416
# --- 3.3260793685913086 seconds ---
# 20fold 3-sigma clipping for 417
# --- 3.3358161449432373 seconds ---
# 20fold 3-sigma clipping for 418
# --- 3.341622829437256 seconds ---
# 20fold 3-sigma clipping for 419
# --- 3.3314828872680664 seconds ---
# 20fold 3-sigma clipping for 420
# --- 3.315312385559082 seconds ---
# 20fold 3-sigma clipping for 421
# --- 3.3520708084106445 seconds ---
# 20fold 3-sigma clipping for 422
# --- 3.354802370071411 seconds ---
# 20fold 3-sigma clipping for 423
# --- 3.3727903366088867 seconds ---
# 20fold 3-sigma clipping for 424
# --- 3.3602700233459473 seconds ---
# 20fold 3-sigma clipping for 425
# --- 3.3197367191314697 seconds ---
# 20fold 3-sigma clipping for 426
# --- 3.3617918491363525 seconds ---
# 20fold 3-sigma clipping for 427
# --- 3.3608264923095703 seconds ---
# 20fold 3-sigma clipping for 428
# --- 3.3731281757354736 seconds ---
# 20fold 3-sigma clipping for 429
# --- 3.3556370735168457 seconds ---
# 20fold 3-sigma clipping for 430
# --- 3.30894136428833 seconds ---
# 20fold 3-sigma clipping for 431
# --- 3.347083568572998 seconds ---
# 20fold 3-sigma clipping for 432
# --- 3.355581283569336 seconds ---
# 20fold 3-sigma clipping for 433
# --- 3.370572090148926 seconds ---
# 20fold 3-sigma clipping for 434
# --- 3.352487802505493 seconds ---
# 20fold 3-sigma clipping for 435
# --- 3.3030922412872314 seconds ---
# 20fold 3-sigma clipping for 436
# --- 3.3405582904815674 seconds ---
# 20fold 3-sigma clipping for 437
# --- 3.353520154953003 seconds ---
# 20fold 3-sigma clipping for 438
# --- 3.3729865550994873 seconds ---
# 20fold 3-sigma clipping for 439
# --- 3.3566408157348633 seconds ---
# 20fold 3-sigma clipping for 440
# --- 3.3133883476257324 seconds ---
# 20fold 3-sigma clipping for 441
# --- 3.3513598442077637 seconds ---
# 20fold 3-sigma clipping for 442
# --- 3.3619680404663086 seconds ---
# 20fold 3-sigma clipping for 443
# --- 3.3787121772766113 seconds ---
# 20fold 3-sigma clipping for 444
# --- 3.3577945232391357 seconds ---
# 20fold 3-sigma clipping for 445
# --- 3.3147826194763184 seconds ---
# 20fold 3-sigma clipping for 446
# --- 3.3565402030944824 seconds ---
# 20fold 3-sigma clipping for 447
# --- 3.365669012069702 seconds ---
# 20fold 3-sigma clipping for 448
# --- 3.3747568130493164 seconds ---
# 20fold 3-sigma clipping for 449
# --- 3.3564860820770264 seconds ---
# 20fold 3-sigma clipping for 450
# --- 3.3163015842437744 seconds ---
# 20fold 3-sigma clipping for 451
# --- 3.3514745235443115 seconds ---
# 20fold 3-sigma clipping for 452
# --- 3.360293388366699 seconds ---
# 20fold 3-sigma clipping for 453
# --- 3.3781490325927734 seconds ---
# 20fold 3-sigma clipping for 454
# --- 3.356292247772217 seconds ---
# 20fold 3-sigma clipping for 455
# --- 3.3097777366638184 seconds ---
# 20fold 3-sigma clipping for 456
# --- 3.3642897605895996 seconds ---
# 20fold 3-sigma clipping for 457
# --- 3.3667728900909424 seconds ---
# 20fold 3-sigma clipping for 458
# --- 3.3731322288513184 seconds ---
# 20fold 3-sigma clipping for 459
# --- 3.3653364181518555 seconds ---
# 20fold 3-sigma clipping for 460
# --- 3.306229829788208 seconds ---
# 20fold 3-sigma clipping for 461
# --- 3.3520450592041016 seconds ---
# 20fold 3-sigma clipping for 462
# --- 3.365335464477539 seconds ---
# 20fold 3-sigma clipping for 463
# --- 3.3730173110961914 seconds ---
# 20fold 3-sigma clipping for 464
# --- 3.3548128604888916 seconds ---
# 20fold 3-sigma clipping for 465
# --- 3.307644844055176 seconds ---
# 20fold 3-sigma clipping for 466
# --- 3.357428789138794 seconds ---
# 20fold 3-sigma clipping for 467
# --- 3.3642799854278564 seconds ---
# 20fold 3-sigma clipping for 468
# --- 3.373662233352661 seconds ---
# 20fold 3-sigma clipping for 469
# --- 3.3479955196380615 seconds ---
# 20fold 3-sigma clipping for 470
# --- 3.307528018951416 seconds ---
# 20fold 3-sigma clipping for 471
# --- 3.356612205505371 seconds ---
# 20fold 3-sigma clipping for 472
# --- 3.371232509613037 seconds ---
# 20fold 3-sigma clipping for 473
# --- 3.375213861465454 seconds ---
# 20fold 3-sigma clipping for 474
# --- 3.358720302581787 seconds ---
# 20fold 3-sigma clipping for 475
# --- 3.3112952709198 seconds ---
# 20fold 3-sigma clipping for 476
# --- 3.3548693656921387 seconds ---
# 20fold 3-sigma clipping for 477
# --- 3.3632876873016357 seconds ---
# 20fold 3-sigma clipping for 478
# --- 3.3871095180511475 seconds ---
# 20fold 3-sigma clipping for 479
# --- 3.3639979362487793 seconds ---
# 20fold 3-sigma clipping for 480
# --- 3.31415057182312 seconds ---
# 20fold 3-sigma clipping for 481
# --- 3.3490355014801025 seconds ---
# 20fold 3-sigma clipping for 482
# --- 3.3577768802642822 seconds ---
# 20fold 3-sigma clipping for 483
# --- 3.3709754943847656 seconds ---
# 20fold 3-sigma clipping for 484
# --- 3.3541643619537354 seconds ---
# 20fold 3-sigma clipping for 485
# --- 3.3036789894104004 seconds ---
# 20fold 3-sigma clipping for 486
# --- 3.3506760597229004 seconds ---
# 20fold 3-sigma clipping for 487
# --- 3.3637685775756836 seconds ---
# 20fold 3-sigma clipping for 488
# --- 3.3702454566955566 seconds ---
# 20fold 3-sigma clipping for 489
# --- 3.3579342365264893 seconds ---
# 20fold 3-sigma clipping for 490
# --- 3.316868782043457 seconds ---
# 20fold 3-sigma clipping for 491
# --- 3.366722345352173 seconds ---
# 20fold 3-sigma clipping for 492
# --- 3.364762544631958 seconds ---
# 20fold 3-sigma clipping for 493
# --- 3.3883280754089355 seconds ---
# 20fold 3-sigma clipping for 494
# --- 3.3767833709716797 seconds ---
# 20fold 3-sigma clipping for 495
# --- 3.324782371520996 seconds ---
# 20fold 3-sigma clipping for 496
# --- 3.3705782890319824 seconds ---
# 20fold 3-sigma clipping for 497
# --- 3.37874436378479 seconds ---
# 20fold 3-sigma clipping for 498
# --- 3.3960182666778564 seconds ---
# 20fold 3-sigma clipping for 499
# --- 3.373866081237793 seconds ---
# 20fold 3-sigma clipping for 500
# --- 3.324183940887451 seconds ---
# 20fold 3-sigma clipping for 501
# --- 3.363074541091919 seconds ---
# 20fold 3-sigma clipping for 502
# --- 3.3908512592315674 seconds ---
# 20fold 3-sigma clipping for 503
# --- 3.396519660949707 seconds ---
# 20fold 3-sigma clipping for 504
# --- 3.3702211380004883 seconds ---
# 20fold 3-sigma clipping for 505
# --- 3.328005313873291 seconds ---
# 20fold 3-sigma clipping for 506
# --- 3.3653564453125 seconds ---
# 20fold 3-sigma clipping for 507
# --- 3.386983871459961 seconds ---
# 20fold 3-sigma clipping for 508
# --- 3.3961844444274902 seconds ---
# 20fold 3-sigma clipping for 509
# --- 3.3706345558166504 seconds ---
# 20fold 3-sigma clipping for 510
# --- 3.318845272064209 seconds ---
# 20fold 3-sigma clipping for 511
# --- 3.3554205894470215 seconds ---
# 20fold 3-sigma clipping for 512
# --- 3.3739922046661377 seconds ---
# 20fold 3-sigma clipping for 513
# --- 3.377095937728882 seconds ---
# 20fold 3-sigma clipping for 514
# --- 3.3688371181488037 seconds ---
# 20fold 3-sigma clipping for 515
# --- 3.31459641456604 seconds ---
# 20fold 3-sigma clipping for 516
# --- 3.36214017868042 seconds ---
# 20fold 3-sigma clipping for 517
# --- 3.378269672393799 seconds ---
# 20fold 3-sigma clipping for 518
# --- 3.385610580444336 seconds ---
# 20fold 3-sigma clipping for 519
# --- 3.367445707321167 seconds ---
# 20fold 3-sigma clipping for 520
# --- 3.309572458267212 seconds ---
# 20fold 3-sigma clipping for 521
# --- 3.368242025375366 seconds ---
# 20fold 3-sigma clipping for 522
# --- 3.3789095878601074 seconds ---
# 20fold 3-sigma clipping for 523
# --- 3.3971710205078125 seconds ---
# 20fold 3-sigma clipping for 524
# --- 3.3726651668548584 seconds ---
# 20fold 3-sigma clipping for 525
# --- 3.326580762863159 seconds ---
# 20fold 3-sigma clipping for 526
# --- 3.3728079795837402 seconds ---
# 20fold 3-sigma clipping for 527
# --- 3.362971067428589 seconds ---
# 20fold 3-sigma clipping for 528
# --- 3.379394054412842 seconds ---
# 20fold 3-sigma clipping for 529
# --- 3.363657236099243 seconds ---
# 20fold 3-sigma clipping for 530
# --- 3.3111720085144043 seconds ---
# 20fold 3-sigma clipping for 531
# --- 3.357727289199829 seconds ---
# 20fold 3-sigma clipping for 532
# --- 3.3681044578552246 seconds ---
# 20fold 3-sigma clipping for 533
# --- 3.3848469257354736 seconds ---
# 20fold 3-sigma clipping for 534
# --- 3.3665599822998047 seconds ---
# 20fold 3-sigma clipping for 535
# --- 3.328124761581421 seconds ---
# 20fold 3-sigma clipping for 536
# --- 3.352871894836426 seconds ---
# 20fold 3-sigma clipping for 537
# --- 3.3647491931915283 seconds ---
# 20fold 3-sigma clipping for 538
# --- 3.372014045715332 seconds ---
# 20fold 3-sigma clipping for 539
# --- 3.361699342727661 seconds ---
# 20fold 3-sigma clipping for 540
# --- 3.315356731414795 seconds ---
# 20fold 3-sigma clipping for 541
# --- 3.364734411239624 seconds ---
# 20fold 3-sigma clipping for 542
# --- 3.374704122543335 seconds ---
# 20fold 3-sigma clipping for 543
# --- 3.3734688758850098 seconds ---
# 20fold 3-sigma clipping for 544
# --- 3.369016170501709 seconds ---
# 20fold 3-sigma clipping for 545
# --- 3.3162152767181396 seconds ---
# 20fold 3-sigma clipping for 546
# --- 3.3586456775665283 seconds ---
# 20fold 3-sigma clipping for 547
# --- 3.353297710418701 seconds ---
# 20fold 3-sigma clipping for 548
# --- 3.371354103088379 seconds ---
# 20fold 3-sigma clipping for 549
# --- 3.3569443225860596 seconds ---
# 20fold 3-sigma clipping for 550
# --- 3.326552391052246 seconds ---
# 20fold 3-sigma clipping for 551
# --- 3.3530242443084717 seconds ---
# 20fold 3-sigma clipping for 552
# --- 3.363231897354126 seconds ---
# 20fold 3-sigma clipping for 553
# --- 3.370826005935669 seconds ---
# 20fold 3-sigma clipping for 554
# --- 3.3473591804504395 seconds ---
# 20fold 3-sigma clipping for 555
# --- 3.307577133178711 seconds ---
# 20fold 3-sigma clipping for 556
# --- 3.3448846340179443 seconds ---
# 20fold 3-sigma clipping for 557
# --- 3.3570258617401123 seconds ---
# 20fold 3-sigma clipping for 558
# --- 3.374738931655884 seconds ---
# 20fold 3-sigma clipping for 559
# --- 3.3714828491210938 seconds ---
# 20fold 3-sigma clipping for 560
# --- 3.3167083263397217 seconds ---
# 20fold 3-sigma clipping for 561
# --- 3.3659298419952393 seconds ---
# 20fold 3-sigma clipping for 562
# --- 3.379063129425049 seconds ---
# 20fold 3-sigma clipping for 563
# --- 3.3846302032470703 seconds ---
# 20fold 3-sigma clipping for 564
# --- 3.362541675567627 seconds ---
# 20fold 3-sigma clipping for 565
# --- 3.305662155151367 seconds ---
# 20fold 3-sigma clipping for 566
# --- 3.357799768447876 seconds ---
# 20fold 3-sigma clipping for 567
# --- 3.3575241565704346 seconds ---
# 20fold 3-sigma clipping for 568
# --- 3.378464460372925 seconds ---
# 20fold 3-sigma clipping for 569
# --- 3.3566389083862305 seconds ---
# 20fold 3-sigma clipping for 570
# --- 3.302476167678833 seconds ---
# 20fold 3-sigma clipping for 571
# --- 3.346360683441162 seconds ---
# 20fold 3-sigma clipping for 572
# --- 3.367157459259033 seconds ---
# 20fold 3-sigma clipping for 573
# --- 3.3728268146514893 seconds ---
# 20fold 3-sigma clipping for 574
# --- 3.354580879211426 seconds ---
# 20fold 3-sigma clipping for 575
# --- 3.30863618850708 seconds ---
# 20fold 3-sigma clipping for 576
# --- 3.3501241207122803 seconds ---
# 20fold 3-sigma clipping for 577
# --- 3.360795736312866 seconds ---
# 20fold 3-sigma clipping for 578
# --- 3.3702609539031982 seconds ---
# 20fold 3-sigma clipping for 579
# --- 3.3459722995758057 seconds ---
# 20fold 3-sigma clipping for 580
# --- 3.2871830463409424 seconds ---
# 20fold 3-sigma clipping for 581
# --- 3.3306643962860107 seconds ---
# 20fold 3-sigma clipping for 582
# --- 3.3421080112457275 seconds ---
# 20fold 3-sigma clipping for 583
# --- 3.351407289505005 seconds ---
# 20fold 3-sigma clipping for 584
# --- 3.3385658264160156 seconds ---
# 20fold 3-sigma clipping for 585
# --- 3.300053119659424 seconds ---
# 20fold 3-sigma clipping for 586
# --- 3.3622844219207764 seconds ---
# 20fold 3-sigma clipping for 587
# --- 3.379319429397583 seconds ---
# 20fold 3-sigma clipping for 588
# --- 3.380906820297241 seconds ---
# 20fold 3-sigma clipping for 589
# --- 3.3642048835754395 seconds ---
# 20fold 3-sigma clipping for 590
# --- 3.3122670650482178 seconds ---
# 20fold 3-sigma clipping for 591
# --- 3.3611526489257812 seconds ---
# 20fold 3-sigma clipping for 592
# --- 3.35986065864563 seconds ---
# 20fold 3-sigma clipping for 593
# --- 3.385000467300415 seconds ---
# 20fold 3-sigma clipping for 594
# --- 3.3716721534729004 seconds ---
# 20fold 3-sigma clipping for 595
# --- 3.3170955181121826 seconds ---
# 20fold 3-sigma clipping for 596
# --- 3.3628342151641846 seconds ---
# 20fold 3-sigma clipping for 597
# --- 3.3510022163391113 seconds ---
# 20fold 3-sigma clipping for 598
# --- 3.38098406791687 seconds ---
# 20fold 3-sigma clipping for 599
# --- 3.3503048419952393 seconds ---
# 20fold 3-sigma clipping for 600
# --- 3.313321828842163 seconds ---
# 20fold 3-sigma clipping for 601
# --- 3.3521175384521484 seconds ---
# 20fold 3-sigma clipping for 602
# --- 3.355130672454834 seconds ---
# 20fold 3-sigma clipping for 603
# --- 3.358610153198242 seconds ---
# 20fold 3-sigma clipping for 604
# --- 3.355306625366211 seconds ---
# 20fold 3-sigma clipping for 605
# --- 3.3077452182769775 seconds ---
# 20fold 3-sigma clipping for 606
# --- 3.331106185913086 seconds ---
# 20fold 3-sigma clipping for 607
# --- 3.347907781600952 seconds ---
# 20fold 3-sigma clipping for 608
# --- 3.342463731765747 seconds ---
# 20fold 3-sigma clipping for 609
# --- 3.320706605911255 seconds ---
# 20fold 3-sigma clipping for 610
# --- 3.280789613723755 seconds ---
# 20fold 3-sigma clipping for 611
# --- 3.3217687606811523 seconds ---
# 20fold 3-sigma clipping for 612
# --- 3.3256940841674805 seconds ---
# 20fold 3-sigma clipping for 613
# --- 3.3506548404693604 seconds ---
# 20fold 3-sigma clipping for 614
# --- 3.329076051712036 seconds ---
# 20fold 3-sigma clipping for 615
# --- 3.2839348316192627 seconds ---
# 20fold 3-sigma clipping for 616
# --- 3.3230254650115967 seconds ---
# 20fold 3-sigma clipping for 617
# --- 3.3292043209075928 seconds ---
# 20fold 3-sigma clipping for 618
# --- 3.341038703918457 seconds ---
# 20fold 3-sigma clipping for 619
# --- 3.318411111831665 seconds ---
# 20fold 3-sigma clipping for 620
# --- 3.282430648803711 seconds ---
# 20fold 3-sigma clipping for 621
# --- 3.323291778564453 seconds ---
# 20fold 3-sigma clipping for 622
# --- 3.3407795429229736 seconds ---
# 20fold 3-sigma clipping for 623
# --- 3.3676743507385254 seconds ---
# 20fold 3-sigma clipping for 624
# --- 3.334702730178833 seconds ---
# 20fold 3-sigma clipping for 625
# --- 3.292668104171753 seconds ---
# 20fold 3-sigma clipping for 626
# --- 3.3379719257354736 seconds ---
# 20fold 3-sigma clipping for 627
# --- 3.3618760108947754 seconds ---
# 20fold 3-sigma clipping for 628
# --- 3.372856378555298 seconds ---
# 20fold 3-sigma clipping for 629
# --- 3.3510959148406982 seconds ---
# 20fold 3-sigma clipping for 630
# --- 3.3059639930725098 seconds ---
# 20fold 3-sigma clipping for 631
# --- 3.338933229446411 seconds ---
# 20fold 3-sigma clipping for 632
# --- 3.362597703933716 seconds ---
# 20fold 3-sigma clipping for 633
# --- 3.375562906265259 seconds ---
# 20fold 3-sigma clipping for 634
# --- 3.356840133666992 seconds ---
# 20fold 3-sigma clipping for 635
# --- 3.306060552597046 seconds ---
# 20fold 3-sigma clipping for 636
# --- 3.3510117530822754 seconds ---
# 20fold 3-sigma clipping for 637
# --- 3.352126359939575 seconds ---
# 20fold 3-sigma clipping for 638
# --- 3.2818498611450195 seconds ---
# 20fold 3-sigma clipping for 639
# --- 3.2442164421081543 seconds ---
# 20fold 3-sigma clipping for 640
# --- 3.1958274841308594 seconds ---
# 20fold 3-sigma clipping for 641
# --- 3.252681255340576 seconds ---
# 20fold 3-sigma clipping for 642
# --- 3.2584569454193115 seconds ---
# 20fold 3-sigma clipping for 643
# --- 3.264820098876953 seconds ---
# 20fold 3-sigma clipping for 644
# --- 3.2511394023895264 seconds ---
# 20fold 3-sigma clipping for 645
# --- 3.208956718444824 seconds ---
# 20fold 3-sigma clipping for 646
# --- 3.2409279346466064 seconds ---
# 20fold 3-sigma clipping for 647
# --- 3.241976261138916 seconds ---
# 20fold 3-sigma clipping for 648
# --- 3.248140573501587 seconds ---
# 20fold 3-sigma clipping for 649
# --- 3.2391626834869385 seconds ---
# 20fold 3-sigma clipping for 650
# --- 3.199017286300659 seconds ---
# 20fold 3-sigma clipping for 651
# --- 3.2395832538604736 seconds ---
# 20fold 3-sigma clipping for 652
# --- 3.2455391883850098 seconds ---
# 20fold 3-sigma clipping for 653
# --- 3.2504208087921143 seconds ---
# 20fold 3-sigma clipping for 654
# --- 3.239231586456299 seconds ---
# 20fold 3-sigma clipping for 655
# --- 3.1847825050354004 seconds ---
# 20fold 3-sigma clipping for 656
# --- 3.2365336418151855 seconds ---
# 20fold 3-sigma clipping for 657
# --- 3.258218765258789 seconds ---
# 20fold 3-sigma clipping for 658
# --- 3.2746243476867676 seconds ---
# 20fold 3-sigma clipping for 659
# --- 3.2502024173736572 seconds ---
# 20fold 3-sigma clipping for 660
# --- 3.200157642364502 seconds ---
# 20fold 3-sigma clipping for 661
# --- 3.2712199687957764 seconds ---
# 20fold 3-sigma clipping for 662
# --- 3.2606046199798584 seconds ---
# 20fold 3-sigma clipping for 663
# --- 3.2836990356445312 seconds ---
# 20fold 3-sigma clipping for 664
# --- 3.263895273208618 seconds ---
# 20fold 3-sigma clipping for 665
# --- 3.2338547706604004 seconds ---
# 20fold 3-sigma clipping for 666
# --- 3.261610507965088 seconds ---
# 20fold 3-sigma clipping for 667
# --- 3.268541097640991 seconds ---
# 20fold 3-sigma clipping for 668
# --- 3.264627695083618 seconds ---
# 20fold 3-sigma clipping for 669
# --- 3.2452728748321533 seconds ---
# 20fold 3-sigma clipping for 670
# --- 3.2037646770477295 seconds ---
# 20fold 3-sigma clipping for 671
# --- 3.2468435764312744 seconds ---
# 20fold 3-sigma clipping for 672
# --- 3.269474506378174 seconds ---
# 20fold 3-sigma clipping for 673
# --- 3.2761685848236084 seconds ---
# 20fold 3-sigma clipping for 674
# --- 3.2420308589935303 seconds ---
# 20fold 3-sigma clipping for 675
# --- 3.2163000106811523 seconds ---
# 20fold 3-sigma clipping for 676
# --- 3.2559492588043213 seconds ---
# 20fold 3-sigma clipping for 677
# --- 3.2507753372192383 seconds ---
# 20fold 3-sigma clipping for 678
# --- 3.2737855911254883 seconds ---
# 20fold 3-sigma clipping for 679
# --- 3.264376640319824 seconds ---
# 20fold 3-sigma clipping for 680
# --- 3.2053654193878174 seconds ---
# 20fold 3-sigma clipping for 681
# --- 3.25337553024292 seconds ---
# 20fold 3-sigma clipping for 682
# --- 3.273566961288452 seconds ---
# 20fold 3-sigma clipping for 683
# --- 3.2694523334503174 seconds ---
# 20fold 3-sigma clipping for 684
# --- 3.249134063720703 seconds ---
# 20fold 3-sigma clipping for 685
# --- 3.221705913543701 seconds ---
# 20fold 3-sigma clipping for 686
# --- 3.2611043453216553 seconds ---
# 20fold 3-sigma clipping for 687
# --- 3.2742111682891846 seconds ---
# 20fold 3-sigma clipping for 688
# --- 3.284104347229004 seconds ---
# 20fold 3-sigma clipping for 689
# --- 3.2538442611694336 seconds ---
# 20fold 3-sigma clipping for 690
# --- 3.2058629989624023 seconds ---
# 20fold 3-sigma clipping for 691
# --- 3.238560676574707 seconds ---
# 20fold 3-sigma clipping for 692
# --- 3.25305438041687 seconds ---
# 20fold 3-sigma clipping for 693
# --- 3.2728524208068848 seconds ---
# 20fold 3-sigma clipping for 694
# --- 3.271169662475586 seconds ---
# 20fold 3-sigma clipping for 695
# --- 3.208181142807007 seconds ---
# 20fold 3-sigma clipping for 696
# --- 3.2649550437927246 seconds ---
# 20fold 3-sigma clipping for 697
# --- 3.258904218673706 seconds ---
# 20fold 3-sigma clipping for 698
# --- 3.273470640182495 seconds ---
# 20fold 3-sigma clipping for 699
# --- 3.2309072017669678 seconds ---
# 20fold 3-sigma clipping for 700
# --- 3.2005884647369385 seconds ---
# 20fold 3-sigma clipping for 701
# --- 3.2535767555236816 seconds ---
# 20fold 3-sigma clipping for 702
# --- 3.259798765182495 seconds ---
# 20fold 3-sigma clipping for 703
# --- 3.296252965927124 seconds ---
# 20fold 3-sigma clipping for 704
# --- 3.2755048274993896 seconds ---
# 20fold 3-sigma clipping for 705
# --- 3.214226722717285 seconds ---
# 20fold 3-sigma clipping for 706
# --- 3.248800754547119 seconds ---
# 20fold 3-sigma clipping for 707
# --- 3.2552883625030518 seconds ---
# 20fold 3-sigma clipping for 708
# --- 3.2681005001068115 seconds ---
# 20fold 3-sigma clipping for 709
# --- 3.256685972213745 seconds ---
# 20fold 3-sigma clipping for 710
# --- 3.2145020961761475 seconds ---
# 20fold 3-sigma clipping for 711
# --- 3.2410929203033447 seconds ---
# 20fold 3-sigma clipping for 712
# --- 3.2531652450561523 seconds ---
# 20fold 3-sigma clipping for 713
# --- 3.2692205905914307 seconds ---
# 20fold 3-sigma clipping for 714
# --- 3.2484982013702393 seconds ---
# 20fold 3-sigma clipping for 715
# --- 3.2211976051330566 seconds ---
# 20fold 3-sigma clipping for 716
# --- 3.2756216526031494 seconds ---
# 20fold 3-sigma clipping for 717
# --- 3.2786076068878174 seconds ---
# 20fold 3-sigma clipping for 718
# --- 3.2926852703094482 seconds ---
# 20fold 3-sigma clipping for 719
# --- 3.270232915878296 seconds ---
# 20fold 3-sigma clipping for 720
# --- 3.242374897003174 seconds ---
# 20fold 3-sigma clipping for 721
# --- 3.2778267860412598 seconds ---
# 20fold 3-sigma clipping for 722
# --- 3.273167371749878 seconds ---
# 20fold 3-sigma clipping for 723
# --- 3.281672477722168 seconds ---
# 20fold 3-sigma clipping for 724
# --- 3.2645177841186523 seconds ---
# 20fold 3-sigma clipping for 725
# --- 3.225287437438965 seconds ---
# 20fold 3-sigma clipping for 726
# --- 3.250149965286255 seconds ---
# 20fold 3-sigma clipping for 727
# --- 3.266239881515503 seconds ---
# 20fold 3-sigma clipping for 728
# --- 3.2900547981262207 seconds ---
# 20fold 3-sigma clipping for 729
# --- 3.2811520099639893 seconds ---
# 20fold 3-sigma clipping for 730
# --- 3.2246646881103516 seconds ---
# 20fold 3-sigma clipping for 731
# --- 3.273426055908203 seconds ---
# 20fold 3-sigma clipping for 732
# --- 3.2871549129486084 seconds ---
# 20fold 3-sigma clipping for 733
# --- 3.3022632598876953 seconds ---
# 20fold 3-sigma clipping for 734
# --- 3.276798725128174 seconds ---
# 20fold 3-sigma clipping for 735
# --- 3.2437407970428467 seconds ---
# 20fold 3-sigma clipping for 736
# --- 3.2740108966827393 seconds ---
# 20fold 3-sigma clipping for 737
# --- 3.2759406566619873 seconds ---
# 20fold 3-sigma clipping for 738
# --- 3.2930052280426025 seconds ---
# 20fold 3-sigma clipping for 739
# --- 3.2765767574310303 seconds ---
# 20fold 3-sigma clipping for 740
# --- 3.231539249420166 seconds ---
# 20fold 3-sigma clipping for 741
# --- 3.269477367401123 seconds ---
# 20fold 3-sigma clipping for 742
# --- 3.2610583305358887 seconds ---
# 20fold 3-sigma clipping for 743
# --- 3.261258125305176 seconds ---
# 20fold 3-sigma clipping for 744
# --- 3.244737148284912 seconds ---
# 20fold 3-sigma clipping for 745
# --- 3.2227299213409424 seconds ---
# 20fold 3-sigma clipping for 746
# --- 3.270803451538086 seconds ---
# 20fold 3-sigma clipping for 747
# --- 3.2716352939605713 seconds ---
# 20fold 3-sigma clipping for 748
# --- 3.270160675048828 seconds ---
# 20fold 3-sigma clipping for 749
# --- 3.2657008171081543 seconds ---
# 20fold 3-sigma clipping for 750
# --- 3.236198902130127 seconds ---
# 20fold 3-sigma clipping for 751
# --- 3.2742438316345215 seconds ---
# 20fold 3-sigma clipping for 752
# --- 3.2838027477264404 seconds ---
# 20fold 3-sigma clipping for 753
# --- 3.2870051860809326 seconds ---
# 20fold 3-sigma clipping for 754
# --- 3.2744252681732178 seconds ---
# 20fold 3-sigma clipping for 755
# --- 3.2235984802246094 seconds ---
# 20fold 3-sigma clipping for 756
# --- 3.256199836730957 seconds ---
# 20fold 3-sigma clipping for 757
# --- 3.263211965560913 seconds ---
# 20fold 3-sigma clipping for 758
# --- 3.2734568119049072 seconds ---
# 20fold 3-sigma clipping for 759
# --- 3.253664493560791 seconds ---
# 20fold 3-sigma clipping for 760
# --- 3.2294821739196777 seconds ---
# 20fold 3-sigma clipping for 761
# --- 3.258315324783325 seconds ---
# 20fold 3-sigma clipping for 762
# --- 3.2576498985290527 seconds ---
# 20fold 3-sigma clipping for 763
# --- 3.268827438354492 seconds ---
# 20fold 3-sigma clipping for 764
# --- 3.2675464153289795 seconds ---
# 20fold 3-sigma clipping for 765
# --- 3.2181003093719482 seconds ---
# 20fold 3-sigma clipping for 766
# --- 3.256453514099121 seconds ---
# 20fold 3-sigma clipping for 767
# --- 3.2685515880584717 seconds ---
# 20fold 3-sigma clipping for 768
# --- 3.2814085483551025 seconds ---
# 20fold 3-sigma clipping for 769
# --- 3.254687547683716 seconds ---
# 20fold 3-sigma clipping for 770
# --- 3.227104663848877 seconds ---
# 20fold 3-sigma clipping for 771
# --- 3.2700703144073486 seconds ---
# 20fold 3-sigma clipping for 772
# --- 3.2647721767425537 seconds ---
# 20fold 3-sigma clipping for 773
# --- 3.2711455821990967 seconds ---
# 20fold 3-sigma clipping for 774
# --- 3.2471725940704346 seconds ---
# 20fold 3-sigma clipping for 775
# --- 3.2224631309509277 seconds ---
# 20fold 3-sigma clipping for 776
# --- 3.2520432472229004 seconds ---
# 20fold 3-sigma clipping for 777
# --- 3.2432096004486084 seconds ---
# 20fold 3-sigma clipping for 778
# --- 3.2724945545196533 seconds ---
# 20fold 3-sigma clipping for 779
# --- 3.243015766143799 seconds ---
# 20fold 3-sigma clipping for 780
# --- 3.190664529800415 seconds ---
# 20fold 3-sigma clipping for 781
# --- 3.2559566497802734 seconds ---
# 20fold 3-sigma clipping for 782
# --- 3.2604548931121826 seconds ---
# 20fold 3-sigma clipping for 783
# --- 3.259953260421753 seconds ---
# 20fold 3-sigma clipping for 784
# --- 3.2284107208251953 seconds ---
# 20fold 3-sigma clipping for 785
# --- 3.184568405151367 seconds ---
# 20fold 3-sigma clipping for 786
# --- 3.2203032970428467 seconds ---
# 20fold 3-sigma clipping for 787
# --- 3.228724241256714 seconds ---
# 20fold 3-sigma clipping for 788
# --- 3.2500808238983154 seconds ---
# 20fold 3-sigma clipping for 789
# --- 3.2673110961914062 seconds ---
# 20fold 3-sigma clipping for 790
# --- 3.215817451477051 seconds ---
# 20fold 3-sigma clipping for 791
# --- 3.271368980407715 seconds ---
# 20fold 3-sigma clipping for 792
# --- 3.2659568786621094 seconds ---
# 20fold 3-sigma clipping for 793
# --- 3.2710962295532227 seconds ---
# 20fold 3-sigma clipping for 794
# --- 3.2311530113220215 seconds ---
# 20fold 3-sigma clipping for 795
# --- 3.1858694553375244 seconds ---
# 20fold 3-sigma clipping for 796
# --- 3.234652519226074 seconds ---
# 20fold 3-sigma clipping for 797
# --- 3.280492067337036 seconds ---
# 20fold 3-sigma clipping for 798
# --- 3.2834227085113525 seconds ---
# 20fold 3-sigma clipping for 799
# --- 3.258521556854248 seconds ---
# 20fold 3-sigma clipping for 800
# --- 3.2104313373565674 seconds ---
# 20fold 3-sigma clipping for 801
# --- 3.245588779449463 seconds ---
# 20fold 3-sigma clipping for 802
# --- 3.2292799949645996 seconds ---
# 20fold 3-sigma clipping for 803
# --- 3.2307581901550293 seconds ---
# 20fold 3-sigma clipping for 804
# --- 3.242886543273926 seconds ---
# 20fold 3-sigma clipping for 805
# --- 3.203165292739868 seconds ---
# 20fold 3-sigma clipping for 806
# --- 3.238900661468506 seconds ---
# 20fold 3-sigma clipping for 807
# --- 3.2265820503234863 seconds ---
# 20fold 3-sigma clipping for 808
# --- 3.230142593383789 seconds ---
# 20fold 3-sigma clipping for 809
# --- 3.222196102142334 seconds ---
# 20fold 3-sigma clipping for 810
# --- 3.170013904571533 seconds ---
# 20fold 3-sigma clipping for 811
# --- 3.2244627475738525 seconds ---
# 20fold 3-sigma clipping for 812
# --- 3.2464592456817627 seconds ---
# 20fold 3-sigma clipping for 813
# --- 3.261648654937744 seconds ---
# 20fold 3-sigma clipping for 814
# --- 3.2242956161499023 seconds ---
# 20fold 3-sigma clipping for 815
# --- 3.180731773376465 seconds ---
# 20fold 3-sigma clipping for 816
# --- 3.2188546657562256 seconds ---
# 20fold 3-sigma clipping for 817
# --- 3.226611852645874 seconds ---
# 20fold 3-sigma clipping for 818
# --- 3.242516279220581 seconds ---
# 20fold 3-sigma clipping for 819
# --- 3.2497804164886475 seconds ---
# 20fold 3-sigma clipping for 820
# --- 3.204930543899536 seconds ---
# 20fold 3-sigma clipping for 821
# --- 3.2309751510620117 seconds ---
# 20fold 3-sigma clipping for 822
# --- 3.2248382568359375 seconds ---
# 20fold 3-sigma clipping for 823
# --- 3.2378997802734375 seconds ---
# 20fold 3-sigma clipping for 824
# --- 3.2382750511169434 seconds ---
# 20fold 3-sigma clipping for 825
# --- 3.205087184906006 seconds ---
# 20fold 3-sigma clipping for 826
# --- 3.274986505508423 seconds ---
# 20fold 3-sigma clipping for 827
# --- 3.2611796855926514 seconds ---
# 20fold 3-sigma clipping for 828
# --- 3.2875614166259766 seconds ---
# 20fold 3-sigma clipping for 829
# --- 3.265334367752075 seconds ---
# 20fold 3-sigma clipping for 830
# --- 3.229299783706665 seconds ---
# 20fold 3-sigma clipping for 831
# --- 3.2641704082489014 seconds ---
# 20fold 3-sigma clipping for 832
# --- 3.2516884803771973 seconds ---
# 20fold 3-sigma clipping for 833
# --- 3.2717087268829346 seconds ---
# 20fold 3-sigma clipping for 834
# --- 3.273404121398926 seconds ---
# 20fold 3-sigma clipping for 835
# --- 3.21372652053833 seconds ---
# 20fold 3-sigma clipping for 836
# --- 3.251826763153076 seconds ---
# 20fold 3-sigma clipping for 837
# --- 3.261237621307373 seconds ---
# 20fold 3-sigma clipping for 838
# --- 3.271339178085327 seconds ---
# 20fold 3-sigma clipping for 839
# --- 3.2444651126861572 seconds ---
# 20fold 3-sigma clipping for 840
# --- 3.2047789096832275 seconds ---
# 20fold 3-sigma clipping for 841
# --- 3.2665162086486816 seconds ---
# 20fold 3-sigma clipping for 842
# --- 3.2681283950805664 seconds ---
# 20fold 3-sigma clipping for 843
# --- 3.278815746307373 seconds ---
# 20fold 3-sigma clipping for 844
# --- 3.2623727321624756 seconds ---
# 20fold 3-sigma clipping for 845
# --- 3.2029833793640137 seconds ---
# 20fold 3-sigma clipping for 846
# --- 3.2368128299713135 seconds ---
# 20fold 3-sigma clipping for 847
# --- 3.2562990188598633 seconds ---
# 20fold 3-sigma clipping for 848
# --- 3.268209218978882 seconds ---
# 20fold 3-sigma clipping for 849
# --- 3.2814271450042725 seconds ---
# 20fold 3-sigma clipping for 850
# --- 3.22025990486145 seconds ---
# 20fold 3-sigma clipping for 851
# --- 3.245137929916382 seconds ---
# 20fold 3-sigma clipping for 852
# --- 3.2414939403533936 seconds ---
# 20fold 3-sigma clipping for 853
# --- 3.2588050365448 seconds ---
# 20fold 3-sigma clipping for 854
# --- 3.2235710620880127 seconds ---
# 20fold 3-sigma clipping for 855
# --- 3.193232774734497 seconds ---
# 20fold 3-sigma clipping for 856
# --- 3.2556848526000977 seconds ---
# 20fold 3-sigma clipping for 857
# --- 3.265822410583496 seconds ---
# 20fold 3-sigma clipping for 858
# --- 3.266277551651001 seconds ---
# 20fold 3-sigma clipping for 859
# --- 3.249868392944336 seconds ---
# 20fold 3-sigma clipping for 860
# --- 3.1974844932556152 seconds ---
# 20fold 3-sigma clipping for 861
# --- 3.241532802581787 seconds ---
# 20fold 3-sigma clipping for 862
# --- 3.2537343502044678 seconds ---
# 20fold 3-sigma clipping for 863
# --- 3.2947938442230225 seconds ---
# 20fold 3-sigma clipping for 864
# --- 3.2660200595855713 seconds ---
# 20fold 3-sigma clipping for 865
# --- 3.217900037765503 seconds ---
# 20fold 3-sigma clipping for 866
# --- 3.256970167160034 seconds ---
# 20fold 3-sigma clipping for 867
# --- 3.2510499954223633 seconds ---
# 20fold 3-sigma clipping for 868
# --- 3.2458670139312744 seconds ---
# 20fold 3-sigma clipping for 869
# --- 3.2258477210998535 seconds ---
# 20fold 3-sigma clipping for 870
# --- 3.1916489601135254 seconds ---
# 20fold 3-sigma clipping for 871
# --- 3.266646146774292 seconds ---

# %%
# -- apply 3-sigma clipping of HSI1
# -- read HSI1
cube1 = read_hyper(dpath1)
# Out:
# reading and parsing night_00000.hdr...
# reading night_00000.raw...

# %%
# -- data proprecessing for the image from row0 to row800
filtered_hsi1_half0 = sigma_clipping(cube1, "half0")
np.save("filtered_hsi1_half0.npy", filtered_hsi1_half0)

# %%
# -- data proprecessing for the image from row800 to row1600
filtered_hsi1_half1 = sigma_clipping(cube1, "half1")
# Out:
# 20fold 3-sigma clipping for 0
# --- 8.171499967575073 seconds ---
# 20fold 3-sigma clipping for 1
# --- 7.937376976013184 seconds ---
# 20fold 3-sigma clipping for 2
# --- 7.905690431594849 seconds ---
# 20fold 3-sigma clipping for 3
# --- 7.952996015548706 seconds ---
# 20fold 3-sigma clipping for 4
# --- 7.713855743408203 seconds ---
# 20fold 3-sigma clipping for 5
# --- 7.963889122009277 seconds ---
# 20fold 3-sigma clipping for 6
# --- 7.764651536941528 seconds ---
# 20fold 3-sigma clipping for 7
# --- 7.9657323360443115 seconds ---
# 20fold 3-sigma clipping for 8
# --- 7.833980321884155 seconds ---
# 20fold 3-sigma clipping for 9
# --- 7.82631254196167 seconds ---
# 20fold 3-sigma clipping for 10
# --- 7.984173059463501 seconds ---
# 20fold 3-sigma clipping for 11
# --- 8.006626844406128 seconds ---
# 20fold 3-sigma clipping for 12
# --- 7.82233190536499 seconds ---
# 20fold 3-sigma clipping for 13
# --- 7.979692220687866 seconds ---
# 20fold 3-sigma clipping for 14
# --- 7.884932279586792 seconds ---
# 20fold 3-sigma clipping for 15
# --- 7.946358919143677 seconds ---
# 20fold 3-sigma clipping for 16
# --- 7.910945415496826 seconds ---
# 20fold 3-sigma clipping for 17
# --- 7.785298109054565 seconds ---
# 20fold 3-sigma clipping for 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # -- data proprecessing for the image from row800 to row1600
# ----> 2 filtered_hsi1_half1 = sigma_clipping(cube1, "half1")
#
# Input In [5], in sigma_clipping(cubedata, half)
#      35 data_col = sig_clipping_col(data_row)
#      36 # -- row again
# ---> 37 data_row_2 = sig_clipping_row(data_col)
#      38 # -- another column
#      39 data_col_2 = sig_clipping_col(data_row_2)
#
# File ~/lighting-tech-changeover/ltco/hyss_util.py:117, in sig_clipping_row(arr)
#     112 loop_time = 0
#     114 while loop_time < 10:
#     115
#     116   # -- calculate the median value across the row
# --> 117   med = np.ma.median(arr, axis=0,  keepdims=True)
#     119   # -- calculate the sig across the row
#     120   sig = arr.std(axis=0,  keepdims=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/ma/extras.py:709, in median(a, axis, out, overwrite_input, keepdims)
#     706     else:
#     707         return m
# --> 709 r, k = _ureduce(a, func=_median, axis=axis, out=out,
#     710                 overwrite_input=overwrite_input)
#     711 if keepdims:
#     712     return r.reshape(k)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:3564, in _ureduce(a, func, **kwargs)
#    3561 else:
#    3562     keepdim = (1,) * a.ndim
# -> 3564 r = func(a, **kwargs)
#    3565 return r, keepdim
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/ma/extras.py:731, in _median(a, axis, out, overwrite_input)
#     729         asorted = a
#     730 else:
# --> 731     asorted = sort(a, axis=axis, fill_value=fill_value)
#     733 if axis is None:
#     734     axis = 0
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py:6904, in sort(a, axis, kind, order, endwith, fill_value)
#    6901     axis = 0
#    6903 if isinstance(a, MaskedArray):
# -> 6904     a.sort(axis=axis, kind=kind, order=order,
#    6905            endwith=endwith, fill_value=fill_value)
#    6906 else:
#    6907     a.sort(axis=axis, kind=kind, order=order)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py:5655, in MaskedArray.sort(self, axis, kind, order, endwith, fill_value)
#    5652 if self is masked:
#    5653     return
# -> 5655 sidx = self.argsort(axis=axis, kind=kind, order=order,
#    5656                     fill_value=fill_value, endwith=endwith)
#    5658 self[...] = np.take_along_axis(self, sidx, axis=axis)
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py:5493, in MaskedArray.argsort(self, axis, kind, order, endwith, fill_value)
#    5490         fill_value = maximum_fill_value(self)
#    5492 filled = self.filled(fill_value)
# -> 5493 return filled.argsort(axis=axis, kind=kind, order=order)
#
# KeyboardInterrupt:

# %%
np.save("filtered_hsi1_half1.npy", filtered_hsi1_half1)
