# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import dask.array as da
from hyss_util import *

# %%
# %matplotlib widget

# %%
# -- set mpl defaults
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gist_gray"
plt.rcParams["figure.figsize"] = (10, 5)

# %%
# -- set the data paths
dpath0 = os.path.join(os.environ["LTCO_HSI0"], "full frame 20ms faster_VNIR.raw")
dpath1 = os.path.join(os.environ["LTCO_HSI1"], "night_00000.raw")

# %%
# -- apply 3-sigma clipping of HSI0
# -- read HSI0
cube0 = read_hyper(dpath0)
# Out:
# reading and parsing full frame 20ms faster_VNIR.hdr...
# reading full frame 20ms faster_VNIR.raw...

# %%
shape = cube0.data.shape
shape
# Out:
# (872, 1600, 1560)

# %%
# -- apply 20 times 30sig clipping 
filtered_hsi0 = np.empty(shape = cube0.data.shape, dtype = "float64")
for i in range(len(cube0.data)):
    start_time = time.time()
    print("20fold 3-sigma clipping for {0}".format(i))
    # -- row first
    data_row = sig_clipping_row(cube0.data[i])
    # -- then column
    data_col = sig_clipping_col(data_row)
    # -- row again
    data_row_2 = sig_clipping_row(data_col)
    # -- another column
    data_col_2 = sig_clipping_col(data_row_2)
    print("--- %s seconds ---" % (time.time() - start_time))
    filtered_hsi0[i] = data_col_2
# Out:
# 20fold 3-sigma clipping for 0
# --- 7.0495827198028564 seconds ---
# 20fold 3-sigma clipping for 1
# --- 7.0528130531311035 seconds ---
# 20fold 3-sigma clipping for 2
# --- 7.069272994995117 seconds ---
# 20fold 3-sigma clipping for 3
# --- 7.027980327606201 seconds ---
# 20fold 3-sigma clipping for 4
# --- 6.969275951385498 seconds ---
# 20fold 3-sigma clipping for 5
# --- 7.039680004119873 seconds ---
# 20fold 3-sigma clipping for 6
# --- 7.059337615966797 seconds ---
# 20fold 3-sigma clipping for 7
# --- 7.06874680519104 seconds ---
# 20fold 3-sigma clipping for 8
# --- 7.059479236602783 seconds ---
# 20fold 3-sigma clipping for 9
# --- 6.997885704040527 seconds ---
# 20fold 3-sigma clipping for 10
# --- 7.072106838226318 seconds ---
# 20fold 3-sigma clipping for 11
# --- 7.069956541061401 seconds ---
# 20fold 3-sigma clipping for 12
# --- 7.076462030410767 seconds ---
# 20fold 3-sigma clipping for 13
# --- 7.054869174957275 seconds ---
# 20fold 3-sigma clipping for 14
# --- 7.002734422683716 seconds ---
# 20fold 3-sigma clipping for 15
# --- 7.079621076583862 seconds ---
# 20fold 3-sigma clipping for 16
# --- 7.0909693241119385 seconds ---
# 20fold 3-sigma clipping for 17
# --- 7.093827724456787 seconds ---
# 20fold 3-sigma clipping for 18
# --- 7.077288866043091 seconds ---
# 20fold 3-sigma clipping for 19
# --- 7.011087656021118 seconds ---
# 20fold 3-sigma clipping for 20
# --- 7.081459999084473 seconds ---
# 20fold 3-sigma clipping for 21
# --- 7.095765590667725 seconds ---
# 20fold 3-sigma clipping for 22
# --- 7.107752799987793 seconds ---
# 20fold 3-sigma clipping for 23
# --- 7.106015205383301 seconds ---
# 20fold 3-sigma clipping for 24
# --- 7.016935110092163 seconds ---
# 20fold 3-sigma clipping for 25
# --- 7.086256504058838 seconds ---
# 20fold 3-sigma clipping for 26
# --- 7.07815408706665 seconds ---
# 20fold 3-sigma clipping for 27
# --- 7.080370187759399 seconds ---
# 20fold 3-sigma clipping for 28
# --- 7.060423851013184 seconds ---
# 20fold 3-sigma clipping for 29
# --- 6.989384174346924 seconds ---
# 20fold 3-sigma clipping for 30
# --- 7.069212913513184 seconds ---
# 20fold 3-sigma clipping for 31
# --- 7.09488582611084 seconds ---
# 20fold 3-sigma clipping for 32
# --- 7.072445392608643 seconds ---
# 20fold 3-sigma clipping for 33
# --- 7.069433689117432 seconds ---
# 20fold 3-sigma clipping for 34
# --- 7.004809379577637 seconds ---
# 20fold 3-sigma clipping for 35
# --- 7.087658882141113 seconds ---
# 20fold 3-sigma clipping for 36
# --- 7.110085964202881 seconds ---
# 20fold 3-sigma clipping for 37
# --- 7.096463203430176 seconds ---
# 20fold 3-sigma clipping for 38
# --- 7.072160959243774 seconds ---
# 20fold 3-sigma clipping for 39
# --- 7.011106252670288 seconds ---
# 20fold 3-sigma clipping for 40
# --- 7.075018882751465 seconds ---
# 20fold 3-sigma clipping for 41
# --- 7.095046520233154 seconds ---
# 20fold 3-sigma clipping for 42
# --- 7.117582082748413 seconds ---
# 20fold 3-sigma clipping for 43
# --- 7.0894935131073 seconds ---
# 20fold 3-sigma clipping for 44
# --- 7.013897895812988 seconds ---
# 20fold 3-sigma clipping for 45
# --- 7.087998390197754 seconds ---
# 20fold 3-sigma clipping for 46
# --- 7.091592788696289 seconds ---
# 20fold 3-sigma clipping for 47
# --- 7.084819078445435 seconds ---
# 20fold 3-sigma clipping for 48
# --- 7.072664737701416 seconds ---
# 20fold 3-sigma clipping for 49
# --- 7.001241207122803 seconds ---
# 20fold 3-sigma clipping for 50
# --- 7.069257497787476 seconds ---
# 20fold 3-sigma clipping for 51
# --- 7.0902674198150635 seconds ---
# 20fold 3-sigma clipping for 52
# --- 7.107119083404541 seconds ---
# 20fold 3-sigma clipping for 53
# --- 7.071831226348877 seconds ---
# 20fold 3-sigma clipping for 54
# --- 7.0135486125946045 seconds ---
# 20fold 3-sigma clipping for 55
# --- 7.074398756027222 seconds ---
# 20fold 3-sigma clipping for 56
# --- 7.081111907958984 seconds ---
# 20fold 3-sigma clipping for 57
# --- 7.0852837562561035 seconds ---
# 20fold 3-sigma clipping for 58
# --- 7.07115912437439 seconds ---
# 20fold 3-sigma clipping for 59
# --- 7.022041320800781 seconds ---
# 20fold 3-sigma clipping for 60
# --- 7.080322980880737 seconds ---
# 20fold 3-sigma clipping for 61
# --- 7.093034029006958 seconds ---
# 20fold 3-sigma clipping for 62
# --- 7.103949785232544 seconds ---
# 20fold 3-sigma clipping for 63
# --- 7.079472064971924 seconds ---
# 20fold 3-sigma clipping for 64
# --- 7.013018369674683 seconds ---
# 20fold 3-sigma clipping for 65
# --- 7.065979957580566 seconds ---
# 20fold 3-sigma clipping for 66
# --- 7.068514347076416 seconds ---
# 20fold 3-sigma clipping for 67
# --- 7.086409091949463 seconds ---
# 20fold 3-sigma clipping for 68
# --- 7.069011688232422 seconds ---
# 20fold 3-sigma clipping for 69
# --- 7.014634847640991 seconds ---
# 20fold 3-sigma clipping for 70
# --- 7.088698863983154 seconds ---
# 20fold 3-sigma clipping for 71
# --- 7.11069917678833 seconds ---
# 20fold 3-sigma clipping for 72
# --- 7.114372968673706 seconds ---
# 20fold 3-sigma clipping for 73
# --- 7.094404220581055 seconds ---
# 20fold 3-sigma clipping for 74
# --- 7.030408620834351 seconds ---
# 20fold 3-sigma clipping for 75
# --- 7.099781274795532 seconds ---
# 20fold 3-sigma clipping for 76
# --- 7.095492124557495 seconds ---
# 20fold 3-sigma clipping for 77
# --- 7.107955694198608 seconds ---
# 20fold 3-sigma clipping for 78
# --- 7.0770263671875 seconds ---
# 20fold 3-sigma clipping for 79
# --- 7.005331039428711 seconds ---
# 20fold 3-sigma clipping for 80
# --- 7.069430589675903 seconds ---
# 20fold 3-sigma clipping for 81
# --- 7.083470821380615 seconds ---
# 20fold 3-sigma clipping for 82
# --- 7.091601371765137 seconds ---
# 20fold 3-sigma clipping for 83
# --- 7.069028615951538 seconds ---
# 20fold 3-sigma clipping for 84
# --- 6.982278347015381 seconds ---
# 20fold 3-sigma clipping for 85
# --- 7.068687200546265 seconds ---
# 20fold 3-sigma clipping for 86
# --- 7.079959392547607 seconds ---
# 20fold 3-sigma clipping for 87
# --- 7.104419708251953 seconds ---
# 20fold 3-sigma clipping for 88
# --- 7.081390142440796 seconds ---
# 20fold 3-sigma clipping for 89
# --- 7.003345251083374 seconds ---
# 20fold 3-sigma clipping for 90
# --- 7.0887908935546875 seconds ---
# 20fold 3-sigma clipping for 91
# --- 7.105799436569214 seconds ---
# 20fold 3-sigma clipping for 92
# --- 7.115048408508301 seconds ---
# 20fold 3-sigma clipping for 93
# --- 7.116508483886719 seconds ---
# 20fold 3-sigma clipping for 94
# --- 7.028073072433472 seconds ---
# 20fold 3-sigma clipping for 95
# --- 7.106146812438965 seconds ---
# 20fold 3-sigma clipping for 96
# --- 7.133478879928589 seconds ---
# 20fold 3-sigma clipping for 97
# --- 7.128607273101807 seconds ---
# 20fold 3-sigma clipping for 98
# --- 7.114828109741211 seconds ---
# 20fold 3-sigma clipping for 99
# --- 7.024390697479248 seconds ---
# 20fold 3-sigma clipping for 100
# --- 7.089536190032959 seconds ---
# 20fold 3-sigma clipping for 101
# --- 7.1197240352630615 seconds ---
# 20fold 3-sigma clipping for 102
# --- 7.101904392242432 seconds ---
# 20fold 3-sigma clipping for 103
# --- 7.058224678039551 seconds ---
# 20fold 3-sigma clipping for 104
# --- 6.989112377166748 seconds ---
# 20fold 3-sigma clipping for 105
# --- 7.062970876693726 seconds ---
# 20fold 3-sigma clipping for 106
# --- 7.075001955032349 seconds ---
# 20fold 3-sigma clipping for 107
# --- 7.064497709274292 seconds ---
# 20fold 3-sigma clipping for 108
# --- 7.057511806488037 seconds ---
# 20fold 3-sigma clipping for 109
# --- 7.017728805541992 seconds ---
# 20fold 3-sigma clipping for 110
# --- 7.100320100784302 seconds ---
# 20fold 3-sigma clipping for 111
# --- 7.095911979675293 seconds ---
# 20fold 3-sigma clipping for 112
# --- 7.079572439193726 seconds ---
# 20fold 3-sigma clipping for 113
# --- 7.068275213241577 seconds ---
# 20fold 3-sigma clipping for 114
# --- 6.98907995223999 seconds ---
# 20fold 3-sigma clipping for 115
# --- 7.068982124328613 seconds ---
# 20fold 3-sigma clipping for 116
# --- 7.075985908508301 seconds ---
# 20fold 3-sigma clipping for 117
# --- 7.110790491104126 seconds ---
# 20fold 3-sigma clipping for 118
# --- 7.084881067276001 seconds ---
# 20fold 3-sigma clipping for 119
# --- 6.998237371444702 seconds ---
# 20fold 3-sigma clipping for 120
# --- 7.069060564041138 seconds ---
# 20fold 3-sigma clipping for 121
# --- 7.101873397827148 seconds ---
# 20fold 3-sigma clipping for 122
# --- 7.097468137741089 seconds ---
# 20fold 3-sigma clipping for 123
# --- 7.0740203857421875 seconds ---
# 20fold 3-sigma clipping for 124
# --- 7.003910779953003 seconds ---
# 20fold 3-sigma clipping for 125
# --- 7.078994035720825 seconds ---
# 20fold 3-sigma clipping for 126
# --- 7.0817577838897705 seconds ---
# 20fold 3-sigma clipping for 127
# --- 7.0886571407318115 seconds ---
# 20fold 3-sigma clipping for 128
# --- 7.057130575180054 seconds ---
# 20fold 3-sigma clipping for 129
# --- 6.995159149169922 seconds ---
# 20fold 3-sigma clipping for 130
# --- 7.053912878036499 seconds ---
# 20fold 3-sigma clipping for 131
# --- 7.078178644180298 seconds ---
# 20fold 3-sigma clipping for 132
# --- 7.073820352554321 seconds ---
# 20fold 3-sigma clipping for 133
# --- 7.048835039138794 seconds ---
# 20fold 3-sigma clipping for 134
# --- 6.9937896728515625 seconds ---
# 20fold 3-sigma clipping for 135
# --- 7.037551403045654 seconds ---
# 20fold 3-sigma clipping for 136
# --- 7.05564022064209 seconds ---
# 20fold 3-sigma clipping for 137
# --- 7.079612493515015 seconds ---
# 20fold 3-sigma clipping for 138
# --- 7.042275905609131 seconds ---
# 20fold 3-sigma clipping for 139
# --- 6.986583232879639 seconds ---
# 20fold 3-sigma clipping for 140
# --- 7.072796106338501 seconds ---
# 20fold 3-sigma clipping for 141
# --- 7.078769207000732 seconds ---
# 20fold 3-sigma clipping for 142
# --- 7.0638604164123535 seconds ---
# 20fold 3-sigma clipping for 143
# --- 7.056161880493164 seconds ---
# 20fold 3-sigma clipping for 144
# --- 7.020574331283569 seconds ---
# 20fold 3-sigma clipping for 145
# --- 7.074766159057617 seconds ---
# 20fold 3-sigma clipping for 146
# --- 7.078431129455566 seconds ---
# 20fold 3-sigma clipping for 147
# --- 7.070790767669678 seconds ---
# 20fold 3-sigma clipping for 148
# --- 7.054176568984985 seconds ---
# 20fold 3-sigma clipping for 149
# --- 6.9846484661102295 seconds ---
# 20fold 3-sigma clipping for 150
# --- 7.053664684295654 seconds ---
# 20fold 3-sigma clipping for 151
# --- 7.066974878311157 seconds ---
# 20fold 3-sigma clipping for 152
# --- 7.055932998657227 seconds ---
# 20fold 3-sigma clipping for 153
# --- 7.041873931884766 seconds ---
# 20fold 3-sigma clipping for 154
# --- 6.998432636260986 seconds ---
# 20fold 3-sigma clipping for 155
# --- 7.041168451309204 seconds ---
# 20fold 3-sigma clipping for 156
# --- 7.058927536010742 seconds ---
# 20fold 3-sigma clipping for 157
# --- 7.080232620239258 seconds ---
# 20fold 3-sigma clipping for 158
# --- 7.0957067012786865 seconds ---
# 20fold 3-sigma clipping for 159
# --- 7.0221545696258545 seconds ---
# 20fold 3-sigma clipping for 160
# --- 7.086780548095703 seconds ---
# 20fold 3-sigma clipping for 161
# --- 7.099324703216553 seconds ---
# 20fold 3-sigma clipping for 162
# --- 7.101304531097412 seconds ---
# 20fold 3-sigma clipping for 163
# --- 7.094202756881714 seconds ---
# 20fold 3-sigma clipping for 164
# --- 7.037511110305786 seconds ---
# 20fold 3-sigma clipping for 165
# --- 7.112332105636597 seconds ---
# 20fold 3-sigma clipping for 166
# --- 7.118690252304077 seconds ---
# 20fold 3-sigma clipping for 167
# --- 7.106227159500122 seconds ---
# 20fold 3-sigma clipping for 168
# --- 7.095596075057983 seconds ---
# 20fold 3-sigma clipping for 169
# --- 7.043155908584595 seconds ---
# 20fold 3-sigma clipping for 170
# --- 7.1035096645355225 seconds ---
# 20fold 3-sigma clipping for 171
# --- 7.140036344528198 seconds ---
# 20fold 3-sigma clipping for 172
# --- 7.132983446121216 seconds ---
# 20fold 3-sigma clipping for 173
# --- 7.1012187004089355 seconds ---
# 20fold 3-sigma clipping for 174
# --- 7.041475057601929 seconds ---
# 20fold 3-sigma clipping for 175
# --- 7.119882106781006 seconds ---
# 20fold 3-sigma clipping for 176
# --- 7.095614671707153 seconds ---
# 20fold 3-sigma clipping for 177
# --- 7.100721836090088 seconds ---
# 20fold 3-sigma clipping for 178
# --- 7.104142189025879 seconds ---
# 20fold 3-sigma clipping for 179
# --- 7.013148784637451 seconds ---
# 20fold 3-sigma clipping for 180
# --- 7.087015151977539 seconds ---
# 20fold 3-sigma clipping for 181
# --- 7.104182720184326 seconds ---
# 20fold 3-sigma clipping for 182
# --- 7.109304666519165 seconds ---
# 20fold 3-sigma clipping for 183
# --- 7.0798375606536865 seconds ---
# 20fold 3-sigma clipping for 184
# --- 7.019596338272095 seconds ---
# 20fold 3-sigma clipping for 185
# --- 7.086337566375732 seconds ---
# 20fold 3-sigma clipping for 186
# --- 7.112010955810547 seconds ---
# 20fold 3-sigma clipping for 187
# --- 7.114080190658569 seconds ---
# 20fold 3-sigma clipping for 188
# --- 7.098625659942627 seconds ---
# 20fold 3-sigma clipping for 189
# --- 7.016346216201782 seconds ---
# 20fold 3-sigma clipping for 190
# --- 7.1136558055877686 seconds ---
# 20fold 3-sigma clipping for 191
# --- 7.139254570007324 seconds ---
# 20fold 3-sigma clipping for 192
# --- 7.128756284713745 seconds ---
# 20fold 3-sigma clipping for 193
# --- 7.098050117492676 seconds ---
# 20fold 3-sigma clipping for 194
# --- 7.053862810134888 seconds ---
# 20fold 3-sigma clipping for 195
# --- 7.120328903198242 seconds ---
# 20fold 3-sigma clipping for 196
# --- 7.143815994262695 seconds ---
# 20fold 3-sigma clipping for 197
# --- 7.121172666549683 seconds ---
# 20fold 3-sigma clipping for 198
# --- 7.106796503067017 seconds ---
# 20fold 3-sigma clipping for 199
# --- 7.036497592926025 seconds ---
# 20fold 3-sigma clipping for 200
# --- 7.121734142303467 seconds ---
# 20fold 3-sigma clipping for 201
# --- 7.123422622680664 seconds ---
# 20fold 3-sigma clipping for 202
# --- 7.135027170181274 seconds ---
# 20fold 3-sigma clipping for 203
# --- 7.098818778991699 seconds ---
# 20fold 3-sigma clipping for 204
# --- 7.027012825012207 seconds ---
# 20fold 3-sigma clipping for 205
# --- 7.1088316440582275 seconds ---
# 20fold 3-sigma clipping for 206
# --- 7.116125106811523 seconds ---
# 20fold 3-sigma clipping for 207
# --- 7.1197850704193115 seconds ---
# 20fold 3-sigma clipping for 208
# --- 7.0968732833862305 seconds ---
# 20fold 3-sigma clipping for 209
# --- 7.0290703773498535 seconds ---
# 20fold 3-sigma clipping for 210
# --- 7.084073543548584 seconds ---
# 20fold 3-sigma clipping for 211
# --- 7.098459005355835 seconds ---
# 20fold 3-sigma clipping for 212
# --- 7.104163885116577 seconds ---
# 20fold 3-sigma clipping for 213
# --- 7.083519697189331 seconds ---
# 20fold 3-sigma clipping for 214
# --- 7.0248496532440186 seconds ---
# 20fold 3-sigma clipping for 215
# --- 7.121421575546265 seconds ---
# 20fold 3-sigma clipping for 216
# --- 7.1320106983184814 seconds ---
# 20fold 3-sigma clipping for 217
# --- 7.145265817642212 seconds ---
# 20fold 3-sigma clipping for 218
# --- 7.139881610870361 seconds ---
# 20fold 3-sigma clipping for 219
# --- 7.054093360900879 seconds ---
# 20fold 3-sigma clipping for 220
# --- 7.103414297103882 seconds ---
# 20fold 3-sigma clipping for 221
# --- 7.130006551742554 seconds ---
# 20fold 3-sigma clipping for 222
# --- 7.14420485496521 seconds ---
# 20fold 3-sigma clipping for 223
# --- 7.120955467224121 seconds ---
# 20fold 3-sigma clipping for 224
# --- 7.0552685260772705 seconds ---
# 20fold 3-sigma clipping for 225
# --- 7.121886253356934 seconds ---
# 20fold 3-sigma clipping for 226
# --- 7.141685724258423 seconds ---
# 20fold 3-sigma clipping for 227
# --- 7.143514633178711 seconds ---
# 20fold 3-sigma clipping for 228
# --- 7.113518238067627 seconds ---
# 20fold 3-sigma clipping for 229
# --- 7.041609764099121 seconds ---
# 20fold 3-sigma clipping for 230
# --- 7.135426759719849 seconds ---
# 20fold 3-sigma clipping for 231
# --- 7.152325630187988 seconds ---
# 20fold 3-sigma clipping for 232
# --- 7.149868488311768 seconds ---
# 20fold 3-sigma clipping for 233
# --- 7.133335590362549 seconds ---
# 20fold 3-sigma clipping for 234
# --- 7.057634115219116 seconds ---
# 20fold 3-sigma clipping for 235
# --- 7.105095386505127 seconds ---
# 20fold 3-sigma clipping for 236
# --- 7.116730213165283 seconds ---
# 20fold 3-sigma clipping for 237
# --- 7.110420227050781 seconds ---
# 20fold 3-sigma clipping for 238
# --- 7.082464218139648 seconds ---
# 20fold 3-sigma clipping for 239
# --- 7.020922660827637 seconds ---
# 20fold 3-sigma clipping for 240
# --- 7.10744833946228 seconds ---
# 20fold 3-sigma clipping for 241
# --- 7.126660585403442 seconds ---
# 20fold 3-sigma clipping for 242
# --- 7.13063645362854 seconds ---
# 20fold 3-sigma clipping for 243
# --- 7.111395359039307 seconds ---
# 20fold 3-sigma clipping for 244
# --- 7.035895586013794 seconds ---
# 20fold 3-sigma clipping for 245
# --- 7.114436388015747 seconds ---
# 20fold 3-sigma clipping for 246
# --- 7.129178524017334 seconds ---
# 20fold 3-sigma clipping for 247
# --- 7.147005081176758 seconds ---
# 20fold 3-sigma clipping for 248
# --- 7.121376991271973 seconds ---
# 20fold 3-sigma clipping for 249
# --- 7.042171955108643 seconds ---
# 20fold 3-sigma clipping for 250
# --- 7.1319520473480225 seconds ---
# 20fold 3-sigma clipping for 251
# --- 7.17083740234375 seconds ---
# 20fold 3-sigma clipping for 252
# --- 7.1779866218566895 seconds ---
# 20fold 3-sigma clipping for 253
# --- 7.165234565734863 seconds ---
# 20fold 3-sigma clipping for 254
# --- 7.0690226554870605 seconds ---
# 20fold 3-sigma clipping for 255
# --- 7.15288782119751 seconds ---
# 20fold 3-sigma clipping for 256
# --- 7.149642705917358 seconds ---
# 20fold 3-sigma clipping for 257
# --- 7.158736944198608 seconds ---
# 20fold 3-sigma clipping for 258
# --- 7.129720687866211 seconds ---
# 20fold 3-sigma clipping for 259
# --- 7.071824789047241 seconds ---
# 20fold 3-sigma clipping for 260
# --- 7.120958089828491 seconds ---
# 20fold 3-sigma clipping for 261
# --- 7.140080213546753 seconds ---
# 20fold 3-sigma clipping for 262
# --- 7.3223772048950195 seconds ---
# 20fold 3-sigma clipping for 263
# --- 7.567246913909912 seconds ---
# 20fold 3-sigma clipping for 264
# --- 7.498548746109009 seconds ---
# 20fold 3-sigma clipping for 265
# --- 7.5446202754974365 seconds ---
# 20fold 3-sigma clipping for 266
# --- 7.565269470214844 seconds ---
# 20fold 3-sigma clipping for 267
# --- 7.57489538192749 seconds ---
# 20fold 3-sigma clipping for 268
# --- 7.556114196777344 seconds ---
# 20fold 3-sigma clipping for 269
# --- 7.46549654006958 seconds ---
# 20fold 3-sigma clipping for 270
# --- 7.575609445571899 seconds ---
# 20fold 3-sigma clipping for 271
# --- 7.598241090774536 seconds ---
# 20fold 3-sigma clipping for 272
# --- 7.560805559158325 seconds ---
# 20fold 3-sigma clipping for 273
# --- 7.553651332855225 seconds ---
# 20fold 3-sigma clipping for 274
# --- 7.477279186248779 seconds ---
# 20fold 3-sigma clipping for 275
# --- 7.5593578815460205 seconds ---
# 20fold 3-sigma clipping for 276
# --- 7.56445050239563 seconds ---
# 20fold 3-sigma clipping for 277
# --- 7.590331792831421 seconds ---
# 20fold 3-sigma clipping for 278
# --- 7.555967569351196 seconds ---
# 20fold 3-sigma clipping for 279
# --- 7.476863384246826 seconds ---
# 20fold 3-sigma clipping for 280
# --- 7.572360277175903 seconds ---
# 20fold 3-sigma clipping for 281
# --- 7.593516111373901 seconds ---
# 20fold 3-sigma clipping for 282
# --- 7.580069541931152 seconds ---
# 20fold 3-sigma clipping for 283
# --- 7.576954364776611 seconds ---
# 20fold 3-sigma clipping for 284
# --- 7.481502056121826 seconds ---
# 20fold 3-sigma clipping for 285
# --- 7.5545244216918945 seconds ---
# 20fold 3-sigma clipping for 286
# --- 7.568725347518921 seconds ---
# 20fold 3-sigma clipping for 287
# --- 7.584403991699219 seconds ---
# 20fold 3-sigma clipping for 288
# --- 7.565503358840942 seconds ---
# 20fold 3-sigma clipping for 289
# --- 7.470650911331177 seconds ---
# 20fold 3-sigma clipping for 290
# --- 7.558203458786011 seconds ---
# 20fold 3-sigma clipping for 291
# --- 7.565851211547852 seconds ---
# 20fold 3-sigma clipping for 292
# --- 7.574577331542969 seconds ---
# 20fold 3-sigma clipping for 293
# --- 7.553959369659424 seconds ---
# 20fold 3-sigma clipping for 294
# --- 7.45479416847229 seconds ---
# 20fold 3-sigma clipping for 295
# --- 7.527607202529907 seconds ---
# 20fold 3-sigma clipping for 296
# --- 7.545587778091431 seconds ---
# 20fold 3-sigma clipping for 297
# --- 7.547768831253052 seconds ---
# 20fold 3-sigma clipping for 298
# --- 7.521958351135254 seconds ---
# 20fold 3-sigma clipping for 299
# --- 7.466683626174927 seconds ---
# 20fold 3-sigma clipping for 300
# --- 7.557353973388672 seconds ---
# 20fold 3-sigma clipping for 301
# --- 7.56322455406189 seconds ---
# 20fold 3-sigma clipping for 302
# --- 7.547501087188721 seconds ---
# 20fold 3-sigma clipping for 303
# --- 7.512995719909668 seconds ---
# 20fold 3-sigma clipping for 304
# --- 7.434941053390503 seconds ---
# 20fold 3-sigma clipping for 305
# --- 7.531963109970093 seconds ---
# 20fold 3-sigma clipping for 306
# --- 7.543972015380859 seconds ---
# 20fold 3-sigma clipping for 307
# --- 7.561346769332886 seconds ---
# 20fold 3-sigma clipping for 308
# --- 7.521324872970581 seconds ---
# 20fold 3-sigma clipping for 309
# --- 7.438299894332886 seconds ---
# 20fold 3-sigma clipping for 310
# --- 7.512058973312378 seconds ---
# 20fold 3-sigma clipping for 311
# --- 7.523590564727783 seconds ---
# 20fold 3-sigma clipping for 312
# --- 7.523456811904907 seconds ---
# 20fold 3-sigma clipping for 313
# --- 7.522763252258301 seconds ---
# 20fold 3-sigma clipping for 314
# --- 7.460371017456055 seconds ---
# 20fold 3-sigma clipping for 315
# --- 7.567185878753662 seconds ---
# 20fold 3-sigma clipping for 316
# --- 7.578500270843506 seconds ---
# 20fold 3-sigma clipping for 317
# --- 7.603826522827148 seconds ---
# 20fold 3-sigma clipping for 318
# --- 7.560596227645874 seconds ---
# 20fold 3-sigma clipping for 319
# --- 7.4587037563323975 seconds ---
# 20fold 3-sigma clipping for 320
# --- 7.536007642745972 seconds ---
# 20fold 3-sigma clipping for 321
# --- 7.5519208908081055 seconds ---
# 20fold 3-sigma clipping for 322
# --- 7.540689945220947 seconds ---
# 20fold 3-sigma clipping for 323
# --- 7.5302112102508545 seconds ---
# 20fold 3-sigma clipping for 324
# --- 7.444592475891113 seconds ---
# 20fold 3-sigma clipping for 325
# --- 7.544613838195801 seconds ---
# 20fold 3-sigma clipping for 326
# --- 7.5508551597595215 seconds ---
# 20fold 3-sigma clipping for 327
# --- 7.5489771366119385 seconds ---
# 20fold 3-sigma clipping for 328
# --- 7.522433280944824 seconds ---
# 20fold 3-sigma clipping for 329
# --- 7.445662975311279 seconds ---
# 20fold 3-sigma clipping for 330
# --- 7.52920937538147 seconds ---
# 20fold 3-sigma clipping for 331
# --- 7.555527448654175 seconds ---
# 20fold 3-sigma clipping for 332
# --- 7.58707594871521 seconds ---
# 20fold 3-sigma clipping for 333
# --- 7.5553107261657715 seconds ---
# 20fold 3-sigma clipping for 334
# --- 7.48281192779541 seconds ---
# 20fold 3-sigma clipping for 335
# --- 7.547953367233276 seconds ---
# 20fold 3-sigma clipping for 336
# --- 7.5631818771362305 seconds ---
# 20fold 3-sigma clipping for 337
# --- 7.539254188537598 seconds ---
# 20fold 3-sigma clipping for 338
# --- 7.502655744552612 seconds ---
# 20fold 3-sigma clipping for 339
# --- 7.43252420425415 seconds ---
# 20fold 3-sigma clipping for 340
# --- 7.5108349323272705 seconds ---
# 20fold 3-sigma clipping for 341
# --- 7.543712377548218 seconds ---
# 20fold 3-sigma clipping for 342
# --- 7.565699815750122 seconds ---
# 20fold 3-sigma clipping for 343
# --- 7.537492513656616 seconds ---
# 20fold 3-sigma clipping for 344
# --- 7.462039232254028 seconds ---
# 20fold 3-sigma clipping for 345
# --- 7.539644002914429 seconds ---
# 20fold 3-sigma clipping for 346
# --- 7.576894521713257 seconds ---
# 20fold 3-sigma clipping for 347
# --- 7.61056923866272 seconds ---
# 20fold 3-sigma clipping for 348
# --- 7.541934251785278 seconds ---
# 20fold 3-sigma clipping for 349
# --- 7.487304449081421 seconds ---
# 20fold 3-sigma clipping for 350
# --- 7.559170961380005 seconds ---
# 20fold 3-sigma clipping for 351
# --- 7.571502685546875 seconds ---
# 20fold 3-sigma clipping for 352
# --- 7.574323892593384 seconds ---
# 20fold 3-sigma clipping for 353
# --- 7.53714394569397 seconds ---
# 20fold 3-sigma clipping for 354
# --- 7.463158845901489 seconds ---
# 20fold 3-sigma clipping for 355
# --- 7.540414571762085 seconds ---
# 20fold 3-sigma clipping for 356
# --- 7.549273729324341 seconds ---
# 20fold 3-sigma clipping for 357
# --- 7.560505390167236 seconds ---
# 20fold 3-sigma clipping for 358
# --- 7.529387712478638 seconds ---
# 20fold 3-sigma clipping for 359
# --- 7.453254222869873 seconds ---
# 20fold 3-sigma clipping for 360
# --- 7.542805910110474 seconds ---
# 20fold 3-sigma clipping for 361
# --- 7.536742448806763 seconds ---
# 20fold 3-sigma clipping for 362
# --- 7.558639764785767 seconds ---
# 20fold 3-sigma clipping for 363
# --- 7.540635824203491 seconds ---
# 20fold 3-sigma clipping for 364
# --- 7.456158638000488 seconds ---
# 20fold 3-sigma clipping for 365
# --- 7.521325349807739 seconds ---
# 20fold 3-sigma clipping for 366
# --- 7.529559135437012 seconds ---
# 20fold 3-sigma clipping for 367
# --- 7.552172422409058 seconds ---
# 20fold 3-sigma clipping for 368
# --- 7.520745754241943 seconds ---
# 20fold 3-sigma clipping for 369
# --- 7.44169545173645 seconds ---
# 20fold 3-sigma clipping for 370
# --- 7.526568651199341 seconds ---
# 20fold 3-sigma clipping for 371
# --- 7.549517869949341 seconds ---
# 20fold 3-sigma clipping for 372
# --- 7.556098937988281 seconds ---
# 20fold 3-sigma clipping for 373
# --- 7.518493413925171 seconds ---
# 20fold 3-sigma clipping for 374
# --- 7.418435096740723 seconds ---
# 20fold 3-sigma clipping for 375
# --- 7.502489805221558 seconds ---
# 20fold 3-sigma clipping for 376
# --- 7.521501541137695 seconds ---
# 20fold 3-sigma clipping for 377
# --- 7.5377233028411865 seconds ---
# 20fold 3-sigma clipping for 378
# --- 7.54120659828186 seconds ---
# 20fold 3-sigma clipping for 379
# --- 7.457088470458984 seconds ---
# 20fold 3-sigma clipping for 380
# --- 7.559661388397217 seconds ---
# 20fold 3-sigma clipping for 381
# --- 7.548961877822876 seconds ---
# 20fold 3-sigma clipping for 382
# --- 7.54999852180481 seconds ---
# 20fold 3-sigma clipping for 383
# --- 7.538085699081421 seconds ---
# 20fold 3-sigma clipping for 384
# --- 7.456488132476807 seconds ---
# 20fold 3-sigma clipping for 385
# --- 7.531503200531006 seconds ---
# 20fold 3-sigma clipping for 386
# --- 7.552806854248047 seconds ---
# 20fold 3-sigma clipping for 387
# --- 7.54578423500061 seconds ---
# 20fold 3-sigma clipping for 388
# --- 7.505580425262451 seconds ---
# 20fold 3-sigma clipping for 389
# --- 7.452559232711792 seconds ---
# 20fold 3-sigma clipping for 390
# --- 7.5128912925720215 seconds ---
# 20fold 3-sigma clipping for 391
# --- 7.534553050994873 seconds ---
# 20fold 3-sigma clipping for 392
# --- 7.548176288604736 seconds ---
# 20fold 3-sigma clipping for 393
# --- 7.53956937789917 seconds ---
# 20fold 3-sigma clipping for 394
# --- 7.466416597366333 seconds ---
# 20fold 3-sigma clipping for 395
# --- 7.530922889709473 seconds ---
# 20fold 3-sigma clipping for 396
# --- 7.548086643218994 seconds ---
# 20fold 3-sigma clipping for 397
# --- 7.544925928115845 seconds ---
# 20fold 3-sigma clipping for 398
# --- 7.531456470489502 seconds ---
# 20fold 3-sigma clipping for 399
# --- 7.460445165634155 seconds ---
# 20fold 3-sigma clipping for 400
# --- 7.533549547195435 seconds ---
# 20fold 3-sigma clipping for 401
# --- 7.548552989959717 seconds ---
# 20fold 3-sigma clipping for 402
# --- 7.555651426315308 seconds ---
# 20fold 3-sigma clipping for 403
# --- 7.526655197143555 seconds ---
# 20fold 3-sigma clipping for 404
# --- 7.432884931564331 seconds ---
# 20fold 3-sigma clipping for 405
# --- 7.527533054351807 seconds ---
# 20fold 3-sigma clipping for 406
# --- 7.54420018196106 seconds ---
# 20fold 3-sigma clipping for 407
# --- 7.547549724578857 seconds ---
# 20fold 3-sigma clipping for 408
# --- 7.529785394668579 seconds ---
# 20fold 3-sigma clipping for 409
# --- 7.4529643058776855 seconds ---
# 20fold 3-sigma clipping for 410
# --- 7.526132583618164 seconds ---
# 20fold 3-sigma clipping for 411
# --- 7.55406928062439 seconds ---
# 20fold 3-sigma clipping for 412
# --- 7.546361684799194 seconds ---
# 20fold 3-sigma clipping for 413
# --- 7.526413679122925 seconds ---
# 20fold 3-sigma clipping for 414
# --- 7.475611925125122 seconds ---
# 20fold 3-sigma clipping for 415
# --- 7.53921365737915 seconds ---
# 20fold 3-sigma clipping for 416
# --- 7.53403639793396 seconds ---
# 20fold 3-sigma clipping for 417
# --- 7.555016279220581 seconds ---
# 20fold 3-sigma clipping for 418
# --- 7.5317747592926025 seconds ---
# 20fold 3-sigma clipping for 419
# --- 7.454687118530273 seconds ---
# 20fold 3-sigma clipping for 420
# --- 7.524348735809326 seconds ---
# 20fold 3-sigma clipping for 421
# --- 7.537817478179932 seconds ---
# 20fold 3-sigma clipping for 422
# --- 7.5503926277160645 seconds ---
# 20fold 3-sigma clipping for 423
# --- 7.538147687911987 seconds ---
# 20fold 3-sigma clipping for 424
# --- 7.4639973640441895 seconds ---
# 20fold 3-sigma clipping for 425
# --- 7.5544962882995605 seconds ---
# 20fold 3-sigma clipping for 426
# --- 7.559527158737183 seconds ---
# 20fold 3-sigma clipping for 427
# --- 7.568158388137817 seconds ---
# 20fold 3-sigma clipping for 428
# --- 7.5529351234436035 seconds ---
# 20fold 3-sigma clipping for 429
# --- 7.4913294315338135 seconds ---
# 20fold 3-sigma clipping for 430
# --- 7.548908710479736 seconds ---
# 20fold 3-sigma clipping for 431
# --- 7.557961463928223 seconds ---
# 20fold 3-sigma clipping for 432
# --- 7.548327684402466 seconds ---
# 20fold 3-sigma clipping for 433
# --- 7.52485203742981 seconds ---
# 20fold 3-sigma clipping for 434
# --- 7.467198610305786 seconds ---
# 20fold 3-sigma clipping for 435
# --- 7.54419732093811 seconds ---
# 20fold 3-sigma clipping for 436
# --- 7.533081293106079 seconds ---
# 20fold 3-sigma clipping for 437
# --- 7.534135341644287 seconds ---
# 20fold 3-sigma clipping for 438
# --- 7.501557350158691 seconds ---
# 20fold 3-sigma clipping for 439
# --- 7.424411058425903 seconds ---
# 20fold 3-sigma clipping for 440
# --- 7.514578342437744 seconds ---
# 20fold 3-sigma clipping for 441
# --- 7.51516318321228 seconds ---
# 20fold 3-sigma clipping for 442
# --- 7.528500556945801 seconds ---
# 20fold 3-sigma clipping for 443
# --- 7.499049663543701 seconds ---
# 20fold 3-sigma clipping for 444
# --- 7.416677713394165 seconds ---
# 20fold 3-sigma clipping for 445
# --- 7.511923551559448 seconds ---
# 20fold 3-sigma clipping for 446
# --- 7.51734185218811 seconds ---
# 20fold 3-sigma clipping for 447
# --- 7.511859893798828 seconds ---
# 20fold 3-sigma clipping for 448
# --- 7.491111755371094 seconds ---
# 20fold 3-sigma clipping for 449
# --- 7.4243245124816895 seconds ---
# 20fold 3-sigma clipping for 450
# --- 7.537131071090698 seconds ---
# 20fold 3-sigma clipping for 451
# --- 7.530076265335083 seconds ---
# 20fold 3-sigma clipping for 452
# --- 7.544363975524902 seconds ---
# 20fold 3-sigma clipping for 453
# --- 7.51907205581665 seconds ---
# 20fold 3-sigma clipping for 454
# --- 7.445372104644775 seconds ---
# 20fold 3-sigma clipping for 455
# --- 7.538360595703125 seconds ---
# 20fold 3-sigma clipping for 456
# --- 7.536819219589233 seconds ---
# 20fold 3-sigma clipping for 457
# --- 7.530683755874634 seconds ---
# 20fold 3-sigma clipping for 458
# --- 7.509946823120117 seconds ---
# 20fold 3-sigma clipping for 459
# --- 7.439877271652222 seconds ---
# 20fold 3-sigma clipping for 460
# --- 7.51982855796814 seconds ---
# 20fold 3-sigma clipping for 461
# --- 7.524292707443237 seconds ---
# 20fold 3-sigma clipping for 462
# --- 7.536959886550903 seconds ---
# 20fold 3-sigma clipping for 463
# --- 7.5198187828063965 seconds ---
# 20fold 3-sigma clipping for 464
# --- 7.4330456256866455 seconds ---
# 20fold 3-sigma clipping for 465
# --- 7.509503602981567 seconds ---
# 20fold 3-sigma clipping for 466
# --- 7.528020143508911 seconds ---
# 20fold 3-sigma clipping for 467
# --- 7.536866188049316 seconds ---
# 20fold 3-sigma clipping for 468
# --- 7.530192136764526 seconds ---
# 20fold 3-sigma clipping for 469
# --- 7.433033227920532 seconds ---
# 20fold 3-sigma clipping for 470
# --- 7.516612529754639 seconds ---
# 20fold 3-sigma clipping for 471
# --- 7.527074337005615 seconds ---
# 20fold 3-sigma clipping for 472
# --- 7.543005466461182 seconds ---
# 20fold 3-sigma clipping for 473
# --- 7.535658597946167 seconds ---
# 20fold 3-sigma clipping for 474
# --- 7.451393127441406 seconds ---
# 20fold 3-sigma clipping for 475
# --- 7.528078556060791 seconds ---
# 20fold 3-sigma clipping for 476
# --- 7.540358543395996 seconds ---
# 20fold 3-sigma clipping for 477
# --- 7.54710841178894 seconds ---
# 20fold 3-sigma clipping for 478
# --- 7.51716160774231 seconds ---
# 20fold 3-sigma clipping for 479
# --- 7.445190668106079 seconds ---
# 20fold 3-sigma clipping for 480
# --- 7.525969982147217 seconds ---
# 20fold 3-sigma clipping for 481
# --- 7.5456202030181885 seconds ---
# 20fold 3-sigma clipping for 482
# --- 7.559569835662842 seconds ---
# 20fold 3-sigma clipping for 483
# --- 7.525047779083252 seconds ---
# 20fold 3-sigma clipping for 484
# --- 7.460049629211426 seconds ---
# 20fold 3-sigma clipping for 485
# --- 7.5471484661102295 seconds ---
# 20fold 3-sigma clipping for 486
# --- 7.5634379386901855 seconds ---
# 20fold 3-sigma clipping for 487
# --- 7.564185857772827 seconds ---
# 20fold 3-sigma clipping for 488
# --- 7.54779052734375 seconds ---
# 20fold 3-sigma clipping for 489
# --- 7.458456039428711 seconds ---
# 20fold 3-sigma clipping for 490
# --- 7.526360273361206 seconds ---
# 20fold 3-sigma clipping for 491
# --- 7.551774978637695 seconds ---
# 20fold 3-sigma clipping for 492
# --- 7.562574148178101 seconds ---
# 20fold 3-sigma clipping for 493
# --- 7.5246758460998535 seconds ---
# 20fold 3-sigma clipping for 494
# --- 7.461269378662109 seconds ---
# 20fold 3-sigma clipping for 495
# --- 7.5437233448028564 seconds ---
# 20fold 3-sigma clipping for 496
# --- 7.559962272644043 seconds ---
# 20fold 3-sigma clipping for 497
# --- 7.566891431808472 seconds ---
# 20fold 3-sigma clipping for 498
# --- 7.547492980957031 seconds ---
# 20fold 3-sigma clipping for 499
# --- 7.462895393371582 seconds ---
# 20fold 3-sigma clipping for 500
# --- 7.530178070068359 seconds ---
# 20fold 3-sigma clipping for 501
# --- 7.553277254104614 seconds ---
# 20fold 3-sigma clipping for 502
# --- 7.556818962097168 seconds ---
# 20fold 3-sigma clipping for 503
# --- 7.5313286781311035 seconds ---
# 20fold 3-sigma clipping for 504
# --- 7.475847244262695 seconds ---
# 20fold 3-sigma clipping for 505
# --- 7.552910089492798 seconds ---
# 20fold 3-sigma clipping for 506
# --- 7.546588182449341 seconds ---
# 20fold 3-sigma clipping for 507
# --- 7.558885335922241 seconds ---
# 20fold 3-sigma clipping for 508
# --- 7.539847373962402 seconds ---
# 20fold 3-sigma clipping for 509
# --- 7.4725775718688965 seconds ---
# 20fold 3-sigma clipping for 510
# --- 7.524051904678345 seconds ---
# 20fold 3-sigma clipping for 511
# --- 7.527800798416138 seconds ---
# 20fold 3-sigma clipping for 512
# --- 7.534423351287842 seconds ---
# 20fold 3-sigma clipping for 513
# --- 7.501481056213379 seconds ---
# 20fold 3-sigma clipping for 514
# --- 7.433325290679932 seconds ---
# 20fold 3-sigma clipping for 515
# --- 7.5377585887908936 seconds ---
# 20fold 3-sigma clipping for 516
# --- 7.5276219844818115 seconds ---
# 20fold 3-sigma clipping for 517
# --- 7.550926923751831 seconds ---
# 20fold 3-sigma clipping for 518
# --- 7.532617568969727 seconds ---
# 20fold 3-sigma clipping for 519
# --- 7.450613737106323 seconds ---
# 20fold 3-sigma clipping for 520
# --- 7.540132284164429 seconds ---
# 20fold 3-sigma clipping for 521
# --- 7.558790922164917 seconds ---
# 20fold 3-sigma clipping for 522
# --- 7.565514087677002 seconds ---
# 20fold 3-sigma clipping for 523
# --- 7.546197175979614 seconds ---
# 20fold 3-sigma clipping for 524
# --- 7.462368011474609 seconds ---
# 20fold 3-sigma clipping for 525
# --- 7.526655912399292 seconds ---
# 20fold 3-sigma clipping for 526
# --- 7.536478281021118 seconds ---
# 20fold 3-sigma clipping for 527
# --- 7.541812181472778 seconds ---
# 20fold 3-sigma clipping for 528
# --- 7.513094902038574 seconds ---
# 20fold 3-sigma clipping for 529
# --- 7.459619998931885 seconds ---
# 20fold 3-sigma clipping for 530
# --- 7.529063701629639 seconds ---
# 20fold 3-sigma clipping for 531
# --- 7.534462928771973 seconds ---
# 20fold 3-sigma clipping for 532
# --- 7.551562547683716 seconds ---
# 20fold 3-sigma clipping for 533
# --- 7.5213799476623535 seconds ---
# 20fold 3-sigma clipping for 534
# --- 7.466391086578369 seconds ---
# 20fold 3-sigma clipping for 535
# --- 7.540801048278809 seconds ---
# 20fold 3-sigma clipping for 536
# --- 7.544271230697632 seconds ---
# 20fold 3-sigma clipping for 537
# --- 7.33441162109375 seconds ---
# 20fold 3-sigma clipping for 538
# --- 7.100233793258667 seconds ---
# 20fold 3-sigma clipping for 539
# --- 7.023922920227051 seconds ---
# 20fold 3-sigma clipping for 540
# --- 7.0892109870910645 seconds ---
# 20fold 3-sigma clipping for 541
# --- 7.1091814041137695 seconds ---
# 20fold 3-sigma clipping for 542
# --- 7.122229814529419 seconds ---
# 20fold 3-sigma clipping for 543
# --- 7.092550992965698 seconds ---
# 20fold 3-sigma clipping for 544
# --- 7.110621929168701 seconds ---
# 20fold 3-sigma clipping for 545
# --- 7.27290678024292 seconds ---
# 20fold 3-sigma clipping for 546
# --- 7.281570196151733 seconds ---
# 20fold 3-sigma clipping for 547
# --- 7.296490907669067 seconds ---
# 20fold 3-sigma clipping for 548
# --- 7.260908603668213 seconds ---
# 20fold 3-sigma clipping for 549
# --- 7.18807315826416 seconds ---
# 20fold 3-sigma clipping for 550
# --- 7.26902961730957 seconds ---
# 20fold 3-sigma clipping for 551
# --- 7.282514810562134 seconds ---
# 20fold 3-sigma clipping for 552
# --- 7.288411378860474 seconds ---
# 20fold 3-sigma clipping for 553
# --- 7.241036415100098 seconds ---
# 20fold 3-sigma clipping for 554
# --- 7.183945178985596 seconds ---
# 20fold 3-sigma clipping for 555
# --- 7.270395040512085 seconds ---
# 20fold 3-sigma clipping for 556
# --- 7.255722761154175 seconds ---
# 20fold 3-sigma clipping for 557
# --- 7.2533183097839355 seconds ---
# 20fold 3-sigma clipping for 558
# --- 7.220277786254883 seconds ---
# 20fold 3-sigma clipping for 559
# --- 7.150071620941162 seconds ---
# 20fold 3-sigma clipping for 560
# --- 7.2240002155303955 seconds ---
# 20fold 3-sigma clipping for 561
# --- 7.256989002227783 seconds ---
# 20fold 3-sigma clipping for 562
# --- 7.232885122299194 seconds ---
# 20fold 3-sigma clipping for 563
# --- 7.187371253967285 seconds ---
# 20fold 3-sigma clipping for 564
# --- 7.122895240783691 seconds ---
# 20fold 3-sigma clipping for 565
# --- 7.194270372390747 seconds ---
# 20fold 3-sigma clipping for 566
# --- 7.208315372467041 seconds ---
# 20fold 3-sigma clipping for 567
# --- 7.2078118324279785 seconds ---
# 20fold 3-sigma clipping for 568
# --- 7.177060842514038 seconds ---
# 20fold 3-sigma clipping for 569
# --- 7.10031533241272 seconds ---
# 20fold 3-sigma clipping for 570
# --- 7.2118377685546875 seconds ---
# 20fold 3-sigma clipping for 571
# --- 7.199523687362671 seconds ---
# 20fold 3-sigma clipping for 572
# --- 7.197693586349487 seconds ---
# 20fold 3-sigma clipping for 573
# --- 7.185819149017334 seconds ---
# 20fold 3-sigma clipping for 574
# --- 7.107220888137817 seconds ---
# 20fold 3-sigma clipping for 575
# --- 7.19625186920166 seconds ---
# 20fold 3-sigma clipping for 576
# --- 7.205640554428101 seconds ---
# 20fold 3-sigma clipping for 577
# --- 7.2029454708099365 seconds ---
# 20fold 3-sigma clipping for 578
# --- 7.19047999382019 seconds ---
# 20fold 3-sigma clipping for 579
# --- 7.126241445541382 seconds ---
# 20fold 3-sigma clipping for 580
# --- 7.199554681777954 seconds ---
# 20fold 3-sigma clipping for 581
# --- 7.222055673599243 seconds ---
# 20fold 3-sigma clipping for 582
# --- 7.223674297332764 seconds ---
# 20fold 3-sigma clipping for 583
# --- 7.1930365562438965 seconds ---
# 20fold 3-sigma clipping for 584
# --- 7.123758316040039 seconds ---
# 20fold 3-sigma clipping for 585
# --- 7.2066075801849365 seconds ---
# 20fold 3-sigma clipping for 586
# --- 7.237046241760254 seconds ---
# 20fold 3-sigma clipping for 587
# --- 7.234561204910278 seconds ---
# 20fold 3-sigma clipping for 588
# --- 7.212666273117065 seconds ---
# 20fold 3-sigma clipping for 589
# --- 7.132038831710815 seconds ---
# 20fold 3-sigma clipping for 590
# --- 7.210133075714111 seconds ---
# 20fold 3-sigma clipping for 591
# --- 7.2118980884552 seconds ---
# 20fold 3-sigma clipping for 592
# --- 7.224806070327759 seconds ---
# 20fold 3-sigma clipping for 593
# --- 7.222405195236206 seconds ---
# 20fold 3-sigma clipping for 594
# --- 7.1389617919921875 seconds ---
# 20fold 3-sigma clipping for 595
# --- 7.199498414993286 seconds ---
# 20fold 3-sigma clipping for 596
# --- 7.199227809906006 seconds ---
# 20fold 3-sigma clipping for 597
# --- 7.206594228744507 seconds ---
# 20fold 3-sigma clipping for 598
# --- 7.212872505187988 seconds ---
# 20fold 3-sigma clipping for 599
# --- 7.125955820083618 seconds ---
# 20fold 3-sigma clipping for 600
# --- 7.188428163528442 seconds ---
# 20fold 3-sigma clipping for 601
# --- 7.19197678565979 seconds ---
# 20fold 3-sigma clipping for 602
# --- 7.18852972984314 seconds ---
# 20fold 3-sigma clipping for 603
# --- 7.166411399841309 seconds ---
# 20fold 3-sigma clipping for 604
# --- 7.100066184997559 seconds ---
# 20fold 3-sigma clipping for 605
# --- 7.171133279800415 seconds ---
# 20fold 3-sigma clipping for 606
# --- 7.204431772232056 seconds ---
# 20fold 3-sigma clipping for 607
# --- 7.209108829498291 seconds ---
# 20fold 3-sigma clipping for 608
# --- 7.197478294372559 seconds ---
# 20fold 3-sigma clipping for 609
# --- 7.1275413036346436 seconds ---
# 20fold 3-sigma clipping for 610
# --- 7.203061819076538 seconds ---
# 20fold 3-sigma clipping for 611
# --- 7.199864387512207 seconds ---
# 20fold 3-sigma clipping for 612
# --- 7.2135515213012695 seconds ---
# 20fold 3-sigma clipping for 613
# --- 7.196942090988159 seconds ---
# 20fold 3-sigma clipping for 614
# --- 7.122912168502808 seconds ---
# 20fold 3-sigma clipping for 615
# --- 7.178789138793945 seconds ---
# 20fold 3-sigma clipping for 616
# --- 7.195822477340698 seconds ---
# 20fold 3-sigma clipping for 617
# --- 7.19745135307312 seconds ---
# 20fold 3-sigma clipping for 618
# --- 7.182629108428955 seconds ---
# 20fold 3-sigma clipping for 619
# --- 7.13552451133728 seconds ---
# 20fold 3-sigma clipping for 620
# --- 7.188322305679321 seconds ---
# 20fold 3-sigma clipping for 621
# --- 7.223692178726196 seconds ---
# 20fold 3-sigma clipping for 622
# --- 7.212851524353027 seconds ---
# 20fold 3-sigma clipping for 623
# --- 7.181594371795654 seconds ---
# 20fold 3-sigma clipping for 624
# --- 7.1002748012542725 seconds ---
# 20fold 3-sigma clipping for 625
# --- 7.176588296890259 seconds ---
# 20fold 3-sigma clipping for 626
# --- 7.203210353851318 seconds ---
# 20fold 3-sigma clipping for 627
# --- 7.202703952789307 seconds ---
# 20fold 3-sigma clipping for 628
# --- 7.1912291049957275 seconds ---
# 20fold 3-sigma clipping for 629
# --- 7.107470750808716 seconds ---
# 20fold 3-sigma clipping for 630
# --- 7.188523769378662 seconds ---
# 20fold 3-sigma clipping for 631
# --- 7.190898895263672 seconds ---
# 20fold 3-sigma clipping for 632
# --- 7.201544284820557 seconds ---
# 20fold 3-sigma clipping for 633
# --- 7.1821630001068115 seconds ---
# 20fold 3-sigma clipping for 634
# --- 7.107933759689331 seconds ---
# 20fold 3-sigma clipping for 635
# --- 7.183417320251465 seconds ---
# 20fold 3-sigma clipping for 636
# --- 7.2119715213775635 seconds ---
# 20fold 3-sigma clipping for 637
# --- 7.202734708786011 seconds ---
# 20fold 3-sigma clipping for 638
# --- 7.172501802444458 seconds ---
# 20fold 3-sigma clipping for 639
# --- 7.126499652862549 seconds ---
# 20fold 3-sigma clipping for 640
# --- 7.179473400115967 seconds ---
# 20fold 3-sigma clipping for 641
# --- 7.18651556968689 seconds ---
# 20fold 3-sigma clipping for 642
# --- 7.199707746505737 seconds ---
# 20fold 3-sigma clipping for 643
# --- 7.177642583847046 seconds ---
# 20fold 3-sigma clipping for 644
# --- 7.126434087753296 seconds ---
# 20fold 3-sigma clipping for 645
# --- 7.207233667373657 seconds ---
# 20fold 3-sigma clipping for 646
# --- 7.208642244338989 seconds ---
# 20fold 3-sigma clipping for 647
# --- 7.212299823760986 seconds ---
# 20fold 3-sigma clipping for 648
# --- 7.188480854034424 seconds ---
# 20fold 3-sigma clipping for 649
# --- 7.109526634216309 seconds ---
# 20fold 3-sigma clipping for 650
# --- 7.19368839263916 seconds ---
# 20fold 3-sigma clipping for 651
# --- 7.204882383346558 seconds ---
# 20fold 3-sigma clipping for 652
# --- 7.243670701980591 seconds ---
# 20fold 3-sigma clipping for 653
# --- 7.2024219036102295 seconds ---
# 20fold 3-sigma clipping for 654
# --- 7.1359100341796875 seconds ---
# 20fold 3-sigma clipping for 655
# --- 7.2047882080078125 seconds ---
# 20fold 3-sigma clipping for 656
# --- 7.209035634994507 seconds ---
# 20fold 3-sigma clipping for 657
# --- 7.2160375118255615 seconds ---
# 20fold 3-sigma clipping for 658
# --- 7.2076873779296875 seconds ---
# 20fold 3-sigma clipping for 659
# --- 7.1440651416778564 seconds ---
# 20fold 3-sigma clipping for 660
# --- 7.216754674911499 seconds ---
# 20fold 3-sigma clipping for 661
# --- 7.227604627609253 seconds ---
# 20fold 3-sigma clipping for 662
# --- 7.235961198806763 seconds ---
# 20fold 3-sigma clipping for 663
# --- 7.182719469070435 seconds ---
# 20fold 3-sigma clipping for 664
# --- 7.090023040771484 seconds ---
# 20fold 3-sigma clipping for 665
# --- 7.171250820159912 seconds ---
# 20fold 3-sigma clipping for 666
# --- 7.176896810531616 seconds ---
# 20fold 3-sigma clipping for 667
# --- 7.189068794250488 seconds ---
# 20fold 3-sigma clipping for 668
# --- 7.164499044418335 seconds ---
# 20fold 3-sigma clipping for 669
# --- 7.10420036315918 seconds ---
# 20fold 3-sigma clipping for 670
# --- 7.173303842544556 seconds ---
# 20fold 3-sigma clipping for 671
# --- 7.193418502807617 seconds ---
# 20fold 3-sigma clipping for 672
# --- 7.232579231262207 seconds ---
# 20fold 3-sigma clipping for 673
# --- 7.214425086975098 seconds ---
# 20fold 3-sigma clipping for 674
# --- 7.139723539352417 seconds ---
# 20fold 3-sigma clipping for 675
# --- 7.2178754806518555 seconds ---
# 20fold 3-sigma clipping for 676
# --- 7.216746091842651 seconds ---
# 20fold 3-sigma clipping for 677
# --- 7.209505081176758 seconds ---
# 20fold 3-sigma clipping for 678
# --- 7.2051568031311035 seconds ---
# 20fold 3-sigma clipping for 679
# --- 7.135133743286133 seconds ---
# 20fold 3-sigma clipping for 680
# --- 7.233150959014893 seconds ---
# 20fold 3-sigma clipping for 681
# --- 7.236007452011108 seconds ---
# 20fold 3-sigma clipping for 682
# --- 7.199087381362915 seconds ---
# 20fold 3-sigma clipping for 683
# --- 7.175862550735474 seconds ---
# 20fold 3-sigma clipping for 684
# --- 7.102820873260498 seconds ---
# 20fold 3-sigma clipping for 685
# --- 7.171309471130371 seconds ---
# 20fold 3-sigma clipping for 686
# --- 7.192698240280151 seconds ---
# 20fold 3-sigma clipping for 687
# --- 7.204925775527954 seconds ---
# 20fold 3-sigma clipping for 688
# --- 7.176986455917358 seconds ---
# 20fold 3-sigma clipping for 689
# --- 7.110297918319702 seconds ---
# 20fold 3-sigma clipping for 690
# --- 7.1788856983184814 seconds ---
# 20fold 3-sigma clipping for 691
# --- 7.214385747909546 seconds ---
# 20fold 3-sigma clipping for 692
# --- 7.20909571647644 seconds ---
# 20fold 3-sigma clipping for 693
# --- 7.194900274276733 seconds ---
# 20fold 3-sigma clipping for 694
# --- 7.123856782913208 seconds ---
# 20fold 3-sigma clipping for 695
# --- 7.194143772125244 seconds ---
# 20fold 3-sigma clipping for 696
# --- 7.217599868774414 seconds ---
# 20fold 3-sigma clipping for 697
# --- 7.224755048751831 seconds ---
# 20fold 3-sigma clipping for 698
# --- 7.133658170700073 seconds ---
# 20fold 3-sigma clipping for 699
# --- 7.0002899169921875 seconds ---
# 20fold 3-sigma clipping for 700
# --- 7.076910495758057 seconds ---
# 20fold 3-sigma clipping for 701
# --- 7.073124647140503 seconds ---
# 20fold 3-sigma clipping for 702
# --- 7.104226112365723 seconds ---
# 20fold 3-sigma clipping for 703
# --- 7.05862283706665 seconds ---
# 20fold 3-sigma clipping for 704
# --- 6.97967791557312 seconds ---
# 20fold 3-sigma clipping for 705
# --- 7.073495388031006 seconds ---
# 20fold 3-sigma clipping for 706
# --- 7.0871288776397705 seconds ---
# 20fold 3-sigma clipping for 707
# --- 7.1014673709869385 seconds ---
# 20fold 3-sigma clipping for 708
# --- 7.0750367641448975 seconds ---
# 20fold 3-sigma clipping for 709
# --- 7.004534959793091 seconds ---
# 20fold 3-sigma clipping for 710
# --- 7.0875327587127686 seconds ---
# 20fold 3-sigma clipping for 711
# --- 7.111920118331909 seconds ---
# 20fold 3-sigma clipping for 712
# --- 7.135777950286865 seconds ---
# 20fold 3-sigma clipping for 713
# --- 7.095269203186035 seconds ---
# 20fold 3-sigma clipping for 714
# --- 7.008935213088989 seconds ---
# 20fold 3-sigma clipping for 715
# --- 7.0886640548706055 seconds ---
# 20fold 3-sigma clipping for 716
# --- 7.118865728378296 seconds ---
# 20fold 3-sigma clipping for 717
# --- 7.13861870765686 seconds ---
# 20fold 3-sigma clipping for 718
# --- 7.102793455123901 seconds ---
# 20fold 3-sigma clipping for 719
# --- 7.008366823196411 seconds ---
# 20fold 3-sigma clipping for 720
# --- 7.091050863265991 seconds ---
# 20fold 3-sigma clipping for 721
# --- 7.097437143325806 seconds ---
# 20fold 3-sigma clipping for 722
# --- 7.1089723110198975 seconds ---
# 20fold 3-sigma clipping for 723
# --- 7.088203430175781 seconds ---
# 20fold 3-sigma clipping for 724
# --- 7.017647743225098 seconds ---
# 20fold 3-sigma clipping for 725
# --- 7.109710216522217 seconds ---
# 20fold 3-sigma clipping for 726
# --- 7.113612174987793 seconds ---
# 20fold 3-sigma clipping for 727
# --- 7.114488363265991 seconds ---
# 20fold 3-sigma clipping for 728
# --- 7.102393388748169 seconds ---
# 20fold 3-sigma clipping for 729
# --- 7.010028600692749 seconds ---
# 20fold 3-sigma clipping for 730
# --- 7.101540803909302 seconds ---
# 20fold 3-sigma clipping for 731
# --- 7.10175085067749 seconds ---
# 20fold 3-sigma clipping for 732
# --- 7.101943731307983 seconds ---
# 20fold 3-sigma clipping for 733
# --- 7.0927650928497314 seconds ---
# 20fold 3-sigma clipping for 734
# --- 6.995992422103882 seconds ---
# 20fold 3-sigma clipping for 735
# --- 7.080348491668701 seconds ---
# 20fold 3-sigma clipping for 736
# --- 7.08291220664978 seconds ---
# 20fold 3-sigma clipping for 737
# --- 7.103648662567139 seconds ---
# 20fold 3-sigma clipping for 738
# --- 7.069492340087891 seconds ---
# 20fold 3-sigma clipping for 739
# --- 7.021494150161743 seconds ---
# 20fold 3-sigma clipping for 740
# --- 7.09190034866333 seconds ---
# 20fold 3-sigma clipping for 741
# --- 7.102549314498901 seconds ---
# 20fold 3-sigma clipping for 742
# --- 7.1025471687316895 seconds ---
# 20fold 3-sigma clipping for 743
# --- 7.083136558532715 seconds ---
# 20fold 3-sigma clipping for 744
# --- 7.019625902175903 seconds ---
# 20fold 3-sigma clipping for 745
# --- 7.075577735900879 seconds ---
# 20fold 3-sigma clipping for 746
# --- 7.0854268074035645 seconds ---
# 20fold 3-sigma clipping for 747
# --- 7.098615646362305 seconds ---
# 20fold 3-sigma clipping for 748
# --- 7.067789077758789 seconds ---
# 20fold 3-sigma clipping for 749
# --- 6.995555877685547 seconds ---
# 20fold 3-sigma clipping for 750
# --- 7.087637901306152 seconds ---
# 20fold 3-sigma clipping for 751
# --- 7.101191520690918 seconds ---
# 20fold 3-sigma clipping for 752
# --- 7.107022285461426 seconds ---
# 20fold 3-sigma clipping for 753
# --- 7.0876853466033936 seconds ---
# 20fold 3-sigma clipping for 754
# --- 7.033045768737793 seconds ---
# 20fold 3-sigma clipping for 755
# --- 7.118255853652954 seconds ---
# 20fold 3-sigma clipping for 756
# --- 7.140566825866699 seconds ---
# 20fold 3-sigma clipping for 757
# --- 7.1475419998168945 seconds ---
# 20fold 3-sigma clipping for 758
# --- 7.128894567489624 seconds ---
# 20fold 3-sigma clipping for 759
# --- 7.057331562042236 seconds ---
# 20fold 3-sigma clipping for 760
# --- 7.131784677505493 seconds ---
# 20fold 3-sigma clipping for 761
# --- 7.122327566146851 seconds ---
# 20fold 3-sigma clipping for 762
# --- 7.13077449798584 seconds ---
# 20fold 3-sigma clipping for 763
# --- 7.094549894332886 seconds ---
# 20fold 3-sigma clipping for 764
# --- 7.0328638553619385 seconds ---
# 20fold 3-sigma clipping for 765
# --- 7.1167685985565186 seconds ---
# 20fold 3-sigma clipping for 766
# --- 7.121348142623901 seconds ---
# 20fold 3-sigma clipping for 767
# --- 7.123278617858887 seconds ---
# 20fold 3-sigma clipping for 768
# --- 7.094885349273682 seconds ---
# 20fold 3-sigma clipping for 769
# --- 7.035590648651123 seconds ---
# 20fold 3-sigma clipping for 770
# --- 7.11223840713501 seconds ---
# 20fold 3-sigma clipping for 771
# --- 7.13102912902832 seconds ---
# 20fold 3-sigma clipping for 772
# --- 7.165488243103027 seconds ---
# 20fold 3-sigma clipping for 773
# --- 7.129166126251221 seconds ---
# 20fold 3-sigma clipping for 774
# --- 7.040350914001465 seconds ---
# 20fold 3-sigma clipping for 775
# --- 7.111127614974976 seconds ---
# 20fold 3-sigma clipping for 776
# --- 7.117572069168091 seconds ---
# 20fold 3-sigma clipping for 777
# --- 7.152267932891846 seconds ---
# 20fold 3-sigma clipping for 778
# --- 7.112718343734741 seconds ---
# 20fold 3-sigma clipping for 779
# --- 7.053447723388672 seconds ---
# 20fold 3-sigma clipping for 780
# --- 7.135322093963623 seconds ---
# 20fold 3-sigma clipping for 781
# --- 7.118165731430054 seconds ---
# 20fold 3-sigma clipping for 782
# --- 7.1376426219940186 seconds ---
# 20fold 3-sigma clipping for 783
# --- 7.1164937019348145 seconds ---
# 20fold 3-sigma clipping for 784
# --- 7.0533061027526855 seconds ---
# 20fold 3-sigma clipping for 785
# --- 7.128759860992432 seconds ---
# 20fold 3-sigma clipping for 786
# --- 7.1430463790893555 seconds ---
# 20fold 3-sigma clipping for 787
# --- 7.12974739074707 seconds ---
# 20fold 3-sigma clipping for 788
# --- 7.093605041503906 seconds ---
# 20fold 3-sigma clipping for 789
# --- 7.03980565071106 seconds ---
# 20fold 3-sigma clipping for 790
# --- 7.143035411834717 seconds ---
# 20fold 3-sigma clipping for 791
# --- 7.144825458526611 seconds ---
# 20fold 3-sigma clipping for 792
# --- 7.149533033370972 seconds ---
# 20fold 3-sigma clipping for 793
# --- 7.108891010284424 seconds ---
# 20fold 3-sigma clipping for 794
# --- 7.053941965103149 seconds ---
# 20fold 3-sigma clipping for 795
# --- 7.145266056060791 seconds ---
# 20fold 3-sigma clipping for 796
# --- 7.148493766784668 seconds ---
# 20fold 3-sigma clipping for 797
# --- 7.130850553512573 seconds ---
# 20fold 3-sigma clipping for 798
# --- 7.102956295013428 seconds ---
# 20fold 3-sigma clipping for 799
# --- 7.01903510093689 seconds ---
# 20fold 3-sigma clipping for 800
# --- 7.098376512527466 seconds ---
# 20fold 3-sigma clipping for 801
# --- 7.087164402008057 seconds ---
# 20fold 3-sigma clipping for 802
# --- 7.093068599700928 seconds ---
# 20fold 3-sigma clipping for 803
# --- 7.086969614028931 seconds ---
# 20fold 3-sigma clipping for 804
# --- 7.038078308105469 seconds ---
# 20fold 3-sigma clipping for 805
# --- 7.11781120300293 seconds ---
# 20fold 3-sigma clipping for 806
# --- 7.139285564422607 seconds ---
# 20fold 3-sigma clipping for 807
# --- 7.150194406509399 seconds ---
# 20fold 3-sigma clipping for 808
# --- 7.116934537887573 seconds ---
# 20fold 3-sigma clipping for 809
# --- 7.029124736785889 seconds ---
# 20fold 3-sigma clipping for 810
# --- 7.104535341262817 seconds ---
# 20fold 3-sigma clipping for 811
# --- 7.133468389511108 seconds ---
# 20fold 3-sigma clipping for 812
# --- 7.125226259231567 seconds ---
# 20fold 3-sigma clipping for 813
# --- 7.110802412033081 seconds ---
# 20fold 3-sigma clipping for 814
# --- 7.042731046676636 seconds ---
# 20fold 3-sigma clipping for 815
# --- 7.1167449951171875 seconds ---
# 20fold 3-sigma clipping for 816
# --- 7.1373090744018555 seconds ---
# 20fold 3-sigma clipping for 817
# --- 7.148972988128662 seconds ---
# 20fold 3-sigma clipping for 818
# --- 7.126567602157593 seconds ---
# 20fold 3-sigma clipping for 819
# --- 7.0651140213012695 seconds ---
# 20fold 3-sigma clipping for 820
# --- 7.118563652038574 seconds ---
# 20fold 3-sigma clipping for 821
# --- 7.121502161026001 seconds ---
# 20fold 3-sigma clipping for 822
# --- 7.147360563278198 seconds ---
# 20fold 3-sigma clipping for 823
# --- 7.11636757850647 seconds ---
# 20fold 3-sigma clipping for 824
# --- 7.02669095993042 seconds ---
# 20fold 3-sigma clipping for 825
# --- 7.114852428436279 seconds ---
# 20fold 3-sigma clipping for 826
# --- 7.142530679702759 seconds ---
# 20fold 3-sigma clipping for 827
# --- 7.146160364151001 seconds ---
# 20fold 3-sigma clipping for 828
# --- 7.127522945404053 seconds ---
# 20fold 3-sigma clipping for 829
# --- 7.0491156578063965 seconds ---
# 20fold 3-sigma clipping for 830
# --- 7.1250855922698975 seconds ---
# 20fold 3-sigma clipping for 831
# --- 7.145503997802734 seconds ---
# 20fold 3-sigma clipping for 832
# --- 7.1454174518585205 seconds ---
# 20fold 3-sigma clipping for 833
# --- 7.135664463043213 seconds ---
# 20fold 3-sigma clipping for 834
# --- 7.054109811782837 seconds ---
# 20fold 3-sigma clipping for 835
# --- 7.1426897048950195 seconds ---
# 20fold 3-sigma clipping for 836
# --- 7.156656980514526 seconds ---
# 20fold 3-sigma clipping for 837
# --- 7.14548921585083 seconds ---
# 20fold 3-sigma clipping for 838
# --- 7.125241279602051 seconds ---
# 20fold 3-sigma clipping for 839
# --- 7.052570581436157 seconds ---
# 20fold 3-sigma clipping for 840
# --- 7.13524317741394 seconds ---
# 20fold 3-sigma clipping for 841
# --- 7.16467809677124 seconds ---
# 20fold 3-sigma clipping for 842
# --- 7.159447908401489 seconds ---
# 20fold 3-sigma clipping for 843
# --- 7.090415954589844 seconds ---
# 20fold 3-sigma clipping for 844
# --- 7.00357460975647 seconds ---
# 20fold 3-sigma clipping for 845
# --- 7.08746600151062 seconds ---
# 20fold 3-sigma clipping for 846
# --- 7.1012163162231445 seconds ---
# 20fold 3-sigma clipping for 847
# --- 7.098398208618164 seconds ---
# 20fold 3-sigma clipping for 848
# --- 7.0680460929870605 seconds ---
# 20fold 3-sigma clipping for 849
# --- 7.006667613983154 seconds ---
# 20fold 3-sigma clipping for 850
# --- 7.109274387359619 seconds ---
# 20fold 3-sigma clipping for 851
# --- 7.1057448387146 seconds ---
# 20fold 3-sigma clipping for 852
# --- 7.106353282928467 seconds ---
# 20fold 3-sigma clipping for 853
# --- 7.082202672958374 seconds ---
# 20fold 3-sigma clipping for 854
# --- 6.987959623336792 seconds ---
# 20fold 3-sigma clipping for 855
# --- 7.089232444763184 seconds ---
# 20fold 3-sigma clipping for 856
# --- 7.0872156620025635 seconds ---
# 20fold 3-sigma clipping for 857
# --- 7.11398720741272 seconds ---
# 20fold 3-sigma clipping for 858
# --- 7.082469701766968 seconds ---
# 20fold 3-sigma clipping for 859
# --- 7.003291368484497 seconds ---
# 20fold 3-sigma clipping for 860
# --- 7.084283828735352 seconds ---
# 20fold 3-sigma clipping for 861
# --- 7.08340859413147 seconds ---
# 20fold 3-sigma clipping for 862
# --- 7.106395244598389 seconds ---
# 20fold 3-sigma clipping for 863
# --- 7.080236911773682 seconds ---
# 20fold 3-sigma clipping for 864
# --- 7.004616737365723 seconds ---
# 20fold 3-sigma clipping for 865
# --- 7.090562343597412 seconds ---
# 20fold 3-sigma clipping for 866
# --- 7.097980737686157 seconds ---
# 20fold 3-sigma clipping for 867
# --- 7.129856824874878 seconds ---
# 20fold 3-sigma clipping for 868
# --- 7.118082046508789 seconds ---
# 20fold 3-sigma clipping for 869
# --- 7.032598972320557 seconds ---
# 20fold 3-sigma clipping for 870
# --- 7.1070051193237305 seconds ---
# 20fold 3-sigma clipping for 871
# --- 7.120816707611084 seconds ---

# %%
np.save("filtered_hsi0.npy", filtered_hsi0)

# %%
# -- apply 3-sigma clipping of HSI1
# -- read HSI1
cube1 = read_hyper(dpath1)
# Out:
# reading and parsing night_00000.hdr...
# reading night_00000.raw...

# %%
shape = cube1.data.shape
shape
# Out:
# (848, 1600, 3195)

# %%
def sigma_clipping(cubedata):
    # -- apply 20 times 30sig clipping 
    filtered_hsi = np.empty(shape = cubedata.data.shape, dtype = "float64")
    for i in range(len(cubedata.data)):
        start_time = time.time()
        print("20fold 3-sigma clipping for {0}".format(i))
        # -- row first
        data_row = sig_clipping_row(cubedata.data[i])
        # -- then column
        data_col = sig_clipping_col(data_row)
        # -- row again
        data_row_2 = sig_clipping_row(data_col)
        # -- another column
        data_col_2 = sig_clipping_col(data_row_2)
        print("--- %s seconds ---" % (time.time() - start_time))
        filtered_hsi[i] = data_col_2
    return filtered_hsi

# %%
filtered_hsi1 = sigma_clipping(cube1)
# Out:
# 20fold 3-sigma clipping for 0
# --- 16.278308868408203 seconds ---
# 20fold 3-sigma clipping for 1
# --- 16.149247646331787 seconds ---
# 20fold 3-sigma clipping for 2
# --- 16.30854558944702 seconds ---
# 20fold 3-sigma clipping for 3
# --- 16.382644176483154 seconds ---
# 20fold 3-sigma clipping for 4
# --- 16.399495363235474 seconds ---
# 20fold 3-sigma clipping for 5
# --- 16.44141983985901 seconds ---
# 20fold 3-sigma clipping for 6
# --- 16.439237117767334 seconds ---
# 20fold 3-sigma clipping for 7
# --- 16.495246410369873 seconds ---
# 20fold 3-sigma clipping for 8
# --- 16.33535146713257 seconds ---
# 20fold 3-sigma clipping for 9
# --- 16.289705514907837 seconds ---
# 20fold 3-sigma clipping for 10
# --- 16.329031467437744 seconds ---
# 20fold 3-sigma clipping for 11
# --- 16.390137910842896 seconds ---
# 20fold 3-sigma clipping for 12
# --- 16.31299901008606 seconds ---
# 20fold 3-sigma clipping for 13
# --- 16.316306352615356 seconds ---
# 20fold 3-sigma clipping for 14
# --- 16.32303285598755 seconds ---
# 20fold 3-sigma clipping for 15
# --- 16.444621086120605 seconds ---
# 20fold 3-sigma clipping for 16
# --- 16.43362307548523 seconds ---
# 20fold 3-sigma clipping for 17
# --- 16.384647369384766 seconds ---
# 20fold 3-sigma clipping for 18
# --- 16.4997820854187 seconds ---
# 20fold 3-sigma clipping for 19
# --- 16.438966512680054 seconds ---
# 20fold 3-sigma clipping for 20
# --- 16.467328786849976 seconds ---
# 20fold 3-sigma clipping for 21
# --- 16.48779559135437 seconds ---
# 20fold 3-sigma clipping for 22
# --- 16.291975736618042 seconds ---
# 20fold 3-sigma clipping for 23
# --- 16.601891040802002 seconds ---
# 20fold 3-sigma clipping for 24
# --- 16.64012908935547 seconds ---
# 20fold 3-sigma clipping for 25
# --- 16.59635305404663 seconds ---
# 20fold 3-sigma clipping for 26
# --- 16.57612895965576 seconds ---
# 20fold 3-sigma clipping for 27
# --- 16.511793851852417 seconds ---
# 20fold 3-sigma clipping for 28
# --- 16.60540461540222 seconds ---
# 20fold 3-sigma clipping for 29
# --- 16.55106258392334 seconds ---
# 20fold 3-sigma clipping for 30
# --- 16.520421266555786 seconds ---
# 20fold 3-sigma clipping for 31
# --- 16.628384590148926 seconds ---
# 20fold 3-sigma clipping for 32
# --- 16.631581783294678 seconds ---
# 20fold 3-sigma clipping for 33
# --- 16.584869146347046 seconds ---
# 20fold 3-sigma clipping for 34
# --- 16.61132049560547 seconds ---
# 20fold 3-sigma clipping for 35
# --- 16.545751333236694 seconds ---
# 20fold 3-sigma clipping for 36
# --- 16.54336380958557 seconds ---
# 20fold 3-sigma clipping for 37
# --- 16.625419855117798 seconds ---
# 20fold 3-sigma clipping for 38
# --- 16.63501214981079 seconds ---
# 20fold 3-sigma clipping for 39
# --- 16.600735425949097 seconds ---
# 20fold 3-sigma clipping for 40
# --- 16.51103162765503 seconds ---
# 20fold 3-sigma clipping for 41
# --- 16.693901538848877 seconds ---
# 20fold 3-sigma clipping for 42
# --- 16.694120168685913 seconds ---
# 20fold 3-sigma clipping for 43
# --- 16.6244375705719 seconds ---
# 20fold 3-sigma clipping for 44
# --- 16.613439321517944 seconds ---
# 20fold 3-sigma clipping for 45
# --- 16.665273189544678 seconds ---
# 20fold 3-sigma clipping for 46
# --- 16.41725993156433 seconds ---
# 20fold 3-sigma clipping for 47
# --- 16.58725666999817 seconds ---
# 20fold 3-sigma clipping for 48
# --- 16.537930011749268 seconds ---
# 20fold 3-sigma clipping for 49
# --- 16.575355052947998 seconds ---
# 20fold 3-sigma clipping for 50
# --- 16.40772795677185 seconds ---
# 20fold 3-sigma clipping for 51
# --- 16.60257840156555 seconds ---
# 20fold 3-sigma clipping for 52
# --- 16.603954076766968 seconds ---
# 20fold 3-sigma clipping for 53
# --- 16.591468811035156 seconds ---
# 20fold 3-sigma clipping for 54
# --- 16.51678204536438 seconds ---
# 20fold 3-sigma clipping for 55
# --- 16.59678888320923 seconds ---
# 20fold 3-sigma clipping for 56
# --- 16.58094048500061 seconds ---
# 20fold 3-sigma clipping for 57
# --- 16.56760811805725 seconds ---
# 20fold 3-sigma clipping for 58
# --- 16.557153940200806 seconds ---
# 20fold 3-sigma clipping for 59
# --- 16.577068567276 seconds ---
# 20fold 3-sigma clipping for 60
# --- 16.713521242141724 seconds ---
# 20fold 3-sigma clipping for 61
# --- 16.689943313598633 seconds ---
# 20fold 3-sigma clipping for 62
# --- 16.586435317993164 seconds ---
# 20fold 3-sigma clipping for 63
# --- 16.567965745925903 seconds ---
# 20fold 3-sigma clipping for 64
# --- 16.672664165496826 seconds ---
# 20fold 3-sigma clipping for 65
# --- 16.56447148323059 seconds ---
# 20fold 3-sigma clipping for 66
# --- 16.67887783050537 seconds ---
# 20fold 3-sigma clipping for 67
# --- 16.449328660964966 seconds ---
# 20fold 3-sigma clipping for 68
# --- 16.60020899772644 seconds ---
# 20fold 3-sigma clipping for 69
# --- 16.45760178565979 seconds ---
# 20fold 3-sigma clipping for 70
# --- 16.577080726623535 seconds ---
# 20fold 3-sigma clipping for 71
# --- 16.595278024673462 seconds ---
# 20fold 3-sigma clipping for 72
# --- 16.625154495239258 seconds ---
# 20fold 3-sigma clipping for 73
# --- 16.58465838432312 seconds ---
# 20fold 3-sigma clipping for 74
# --- 16.55884289741516 seconds ---
# 20fold 3-sigma clipping for 75
# --- 16.6437885761261 seconds ---
# 20fold 3-sigma clipping for 76
# --- 16.53802466392517 seconds ---
# 20fold 3-sigma clipping for 77
# --- 16.61131238937378 seconds ---
# 20fold 3-sigma clipping for 78
# --- 16.62849473953247 seconds ---
# 20fold 3-sigma clipping for 79
# --- 16.628803491592407 seconds ---
# 20fold 3-sigma clipping for 80
# --- 16.666730403900146 seconds ---
# 20fold 3-sigma clipping for 81
# --- 16.562795162200928 seconds ---
# 20fold 3-sigma clipping for 82
# --- 16.639811754226685 seconds ---
# 20fold 3-sigma clipping for 83
# --- 16.65433955192566 seconds ---
# 20fold 3-sigma clipping for 84
# --- 16.676846265792847 seconds ---
# 20fold 3-sigma clipping for 85
# --- 16.589741230010986 seconds ---
# 20fold 3-sigma clipping for 86
# --- 16.687853813171387 seconds ---
# 20fold 3-sigma clipping for 87
# --- 16.66701030731201 seconds ---
# 20fold 3-sigma clipping for 88
# --- 16.65236735343933 seconds ---
# 20fold 3-sigma clipping for 89
# --- 16.583933115005493 seconds ---
# 20fold 3-sigma clipping for 90
# --- 16.663506507873535 seconds ---
# 20fold 3-sigma clipping for 91
# --- 16.678285121917725 seconds ---
# 20fold 3-sigma clipping for 92
# --- 16.614737510681152 seconds ---
# 20fold 3-sigma clipping for 93
# --- 16.428479433059692 seconds ---
# 20fold 3-sigma clipping for 94
# --- 16.611812114715576 seconds ---
# 20fold 3-sigma clipping for 95
# --- 16.558216333389282 seconds ---
# 20fold 3-sigma clipping for 96
# --- 16.524919748306274 seconds ---
# 20fold 3-sigma clipping for 97
# --- 16.578263521194458 seconds ---
# 20fold 3-sigma clipping for 98
# --- 16.48436450958252 seconds ---
# 20fold 3-sigma clipping for 99
# --- 16.503132820129395 seconds ---
# 20fold 3-sigma clipping for 100
# --- 16.662701845169067 seconds ---
# 20fold 3-sigma clipping for 101
# --- 16.495782613754272 seconds ---
# 20fold 3-sigma clipping for 102
# --- 16.55549716949463 seconds ---
# 20fold 3-sigma clipping for 103
# --- 16.624651193618774 seconds ---
# 20fold 3-sigma clipping for 104
# --- 16.669304609298706 seconds ---
# 20fold 3-sigma clipping for 105
# --- 16.49867296218872 seconds ---
# 20fold 3-sigma clipping for 106
# --- 16.611372232437134 seconds ---
# 20fold 3-sigma clipping for 107
# --- 16.663995265960693 seconds ---
# 20fold 3-sigma clipping for 108
# --- 16.536853075027466 seconds ---
# 20fold 3-sigma clipping for 109
# --- 16.652618408203125 seconds ---
# 20fold 3-sigma clipping for 110
# --- 16.602341413497925 seconds ---
# 20fold 3-sigma clipping for 111
# --- 16.52245044708252 seconds ---
# 20fold 3-sigma clipping for 112
# --- 16.45227551460266 seconds ---
# 20fold 3-sigma clipping for 113
# --- 16.493001461029053 seconds ---
# 20fold 3-sigma clipping for 114
# --- 16.63079285621643 seconds ---
# 20fold 3-sigma clipping for 115
# --- 16.53357720375061 seconds ---
# 20fold 3-sigma clipping for 116
# --- 16.499589204788208 seconds ---
# 20fold 3-sigma clipping for 117
# --- 16.57814073562622 seconds ---
# 20fold 3-sigma clipping for 118
# --- 16.582470417022705 seconds ---
# 20fold 3-sigma clipping for 119
# --- 16.595786809921265 seconds ---
# 20fold 3-sigma clipping for 120
# --- 16.618305444717407 seconds ---
# 20fold 3-sigma clipping for 121
# --- 16.422717571258545 seconds ---
# 20fold 3-sigma clipping for 122
# --- 16.55491042137146 seconds ---
# 20fold 3-sigma clipping for 123
# --- 16.65979504585266 seconds ---
# 20fold 3-sigma clipping for 124
# --- 16.71188449859619 seconds ---
# 20fold 3-sigma clipping for 125
# --- 16.698230743408203 seconds ---
# 20fold 3-sigma clipping for 126
# --- 16.65705418586731 seconds ---
# 20fold 3-sigma clipping for 127
# --- 16.66647982597351 seconds ---
# 20fold 3-sigma clipping for 128
# --- 16.61138391494751 seconds ---
# 20fold 3-sigma clipping for 129
# --- 16.541734218597412 seconds ---
# 20fold 3-sigma clipping for 130
# --- 16.553815603256226 seconds ---
# 20fold 3-sigma clipping for 131
# --- 16.57620930671692 seconds ---
# 20fold 3-sigma clipping for 132
# --- 16.453487873077393 seconds ---
# 20fold 3-sigma clipping for 133
# --- 16.576990842819214 seconds ---
# 20fold 3-sigma clipping for 134
# --- 16.543158531188965 seconds ---
# 20fold 3-sigma clipping for 135
# --- 16.455204963684082 seconds ---
# 20fold 3-sigma clipping for 136
# --- 16.44393253326416 seconds ---
# 20fold 3-sigma clipping for 137
# --- 16.61057209968567 seconds ---
# 20fold 3-sigma clipping for 138
# --- 16.57874369621277 seconds ---
# 20fold 3-sigma clipping for 139
# --- 16.618902921676636 seconds ---
# 20fold 3-sigma clipping for 140
# --- 16.639033317565918 seconds ---
# 20fold 3-sigma clipping for 141
# --- 16.638450622558594 seconds ---
# 20fold 3-sigma clipping for 142
# --- 16.682929039001465 seconds ---
# 20fold 3-sigma clipping for 143
# --- 16.626291036605835 seconds ---
# 20fold 3-sigma clipping for 144
# --- 16.61356210708618 seconds ---
# 20fold 3-sigma clipping for 145
# --- 16.70410132408142 seconds ---
# 20fold 3-sigma clipping for 146
# --- 16.61762762069702 seconds ---
# 20fold 3-sigma clipping for 147
# --- 16.6370267868042 seconds ---
# 20fold 3-sigma clipping for 148
# --- 16.660003185272217 seconds ---
# 20fold 3-sigma clipping for 149
# --- 16.584436893463135 seconds ---
# 20fold 3-sigma clipping for 150
# --- 16.70606565475464 seconds ---
# 20fold 3-sigma clipping for 151
# --- 16.659050464630127 seconds ---
# 20fold 3-sigma clipping for 152
# --- 16.70904850959778 seconds ---
# 20fold 3-sigma clipping for 153
# --- 16.698144912719727 seconds ---
# 20fold 3-sigma clipping for 154
# --- 16.691031455993652 seconds ---
# 20fold 3-sigma clipping for 155
# --- 16.742690801620483 seconds ---
# 20fold 3-sigma clipping for 156
# --- 16.65725803375244 seconds ---
# 20fold 3-sigma clipping for 157
# --- 16.648908138275146 seconds ---
# 20fold 3-sigma clipping for 158
# --- 16.60807991027832 seconds ---
# 20fold 3-sigma clipping for 159
# --- 16.6427321434021 seconds ---
# 20fold 3-sigma clipping for 160
# --- 16.706676483154297 seconds ---
# 20fold 3-sigma clipping for 161
# --- 16.554084300994873 seconds ---
# 20fold 3-sigma clipping for 162
# --- 16.588045358657837 seconds ---
# 20fold 3-sigma clipping for 163
# --- 16.640840530395508 seconds ---
# 20fold 3-sigma clipping for 164
# --- 16.70143175125122 seconds ---
# 20fold 3-sigma clipping for 165
# --- 16.65547204017639 seconds ---
# 20fold 3-sigma clipping for 166
# --- 16.513436794281006 seconds ---
# 20fold 3-sigma clipping for 167
# --- 16.639196395874023 seconds ---
# 20fold 3-sigma clipping for 168
# --- 16.64906406402588 seconds ---
# 20fold 3-sigma clipping for 169
# --- 16.575151681900024 seconds ---
# 20fold 3-sigma clipping for 170
# --- 16.539620637893677 seconds ---
# 20fold 3-sigma clipping for 171
# --- 16.486258029937744 seconds ---
# 20fold 3-sigma clipping for 172
# --- 16.64473843574524 seconds ---
# 20fold 3-sigma clipping for 173
# --- 16.627309560775757 seconds ---
# 20fold 3-sigma clipping for 174
# --- 16.572002172470093 seconds ---
# 20fold 3-sigma clipping for 175
# --- 16.557883501052856 seconds ---
# 20fold 3-sigma clipping for 176
# --- 16.59232759475708 seconds ---
# 20fold 3-sigma clipping for 177
# --- 16.58331871032715 seconds ---
# 20fold 3-sigma clipping for 178
# --- 16.613399982452393 seconds ---
# 20fold 3-sigma clipping for 179
# --- 16.64858341217041 seconds ---
# 20fold 3-sigma clipping for 180
# --- 16.581389665603638 seconds ---
# 20fold 3-sigma clipping for 181
# --- 16.58243465423584 seconds ---
# 20fold 3-sigma clipping for 182
# --- 16.613035917282104 seconds ---
# 20fold 3-sigma clipping for 183
# --- 16.475279808044434 seconds ---
# 20fold 3-sigma clipping for 184
# --- 16.592695474624634 seconds ---
# 20fold 3-sigma clipping for 185
# --- 16.62647271156311 seconds ---
# 20fold 3-sigma clipping for 186
# --- 16.635602712631226 seconds ---
# 20fold 3-sigma clipping for 187
# --- 16.576478719711304 seconds ---
# 20fold 3-sigma clipping for 188
# --- 16.590739727020264 seconds ---
# 20fold 3-sigma clipping for 189
# --- 16.618360996246338 seconds ---
# 20fold 3-sigma clipping for 190
# --- 16.574463605880737 seconds ---
# 20fold 3-sigma clipping for 191
# --- 16.611916303634644 seconds ---
# 20fold 3-sigma clipping for 192
# --- 16.569329977035522 seconds ---
# 20fold 3-sigma clipping for 193
# --- 16.636420249938965 seconds ---
# 20fold 3-sigma clipping for 194
# --- 16.68484878540039 seconds ---
# 20fold 3-sigma clipping for 195
# --- 16.65723490715027 seconds ---
# 20fold 3-sigma clipping for 196
# --- 16.56390619277954 seconds ---
# 20fold 3-sigma clipping for 197
# --- 16.585744380950928 seconds ---
# 20fold 3-sigma clipping for 198
# --- 16.665656328201294 seconds ---
# 20fold 3-sigma clipping for 199
# --- 16.717227935791016 seconds ---
# 20fold 3-sigma clipping for 200
# --- 16.67022156715393 seconds ---
# 20fold 3-sigma clipping for 201
# --- 16.693269729614258 seconds ---
# 20fold 3-sigma clipping for 202
# --- 16.559629201889038 seconds ---
# 20fold 3-sigma clipping for 203
# --- 16.613646268844604 seconds ---
# 20fold 3-sigma clipping for 204
# --- 16.643984079360962 seconds ---
# 20fold 3-sigma clipping for 205
# --- 16.57939887046814 seconds ---
# 20fold 3-sigma clipping for 206
# --- 16.64314603805542 seconds ---
# 20fold 3-sigma clipping for 207
# --- 16.563095331192017 seconds ---
# 20fold 3-sigma clipping for 208
# --- 16.658509731292725 seconds ---
# 20fold 3-sigma clipping for 209
# --- 16.65017557144165 seconds ---
# 20fold 3-sigma clipping for 210
# --- 16.69422698020935 seconds ---
# 20fold 3-sigma clipping for 211
# --- 16.701791763305664 seconds ---
# 20fold 3-sigma clipping for 212
# --- 16.645581483840942 seconds ---
# 20fold 3-sigma clipping for 213
# --- 16.560444116592407 seconds ---
# 20fold 3-sigma clipping for 214
# --- 16.637202739715576 seconds ---
# 20fold 3-sigma clipping for 215
# --- 16.616369485855103 seconds ---
# 20fold 3-sigma clipping for 216
# --- 16.56757164001465 seconds ---
# 20fold 3-sigma clipping for 217
# --- 16.64018201828003 seconds ---
# 20fold 3-sigma clipping for 218
# --- 16.63828682899475 seconds ---
# 20fold 3-sigma clipping for 219
# --- 16.62243103981018 seconds ---
# 20fold 3-sigma clipping for 220
# --- 16.611781358718872 seconds ---
# 20fold 3-sigma clipping for 221
# --- 16.609604120254517 seconds ---
# 20fold 3-sigma clipping for 222
# --- 16.561341524124146 seconds ---
# 20fold 3-sigma clipping for 223
# --- 16.569223165512085 seconds ---
# 20fold 3-sigma clipping for 224
# --- 16.647080898284912 seconds ---
# 20fold 3-sigma clipping for 225
# --- 16.6237633228302 seconds ---
# 20fold 3-sigma clipping for 226
# --- 16.54875946044922 seconds ---
# 20fold 3-sigma clipping for 227
# --- 16.61436629295349 seconds ---
# 20fold 3-sigma clipping for 228
# --- 16.598894834518433 seconds ---
# 20fold 3-sigma clipping for 229
# --- 16.51937508583069 seconds ---
# 20fold 3-sigma clipping for 230
# --- 16.524964809417725 seconds ---
# 20fold 3-sigma clipping for 231
# --- 16.715246438980103 seconds ---
# 20fold 3-sigma clipping for 232
# --- 16.685392141342163 seconds ---
# 20fold 3-sigma clipping for 233
# --- 16.565519094467163 seconds ---
# 20fold 3-sigma clipping for 234
# --- 16.599228382110596 seconds ---
# 20fold 3-sigma clipping for 235
# --- 16.69990372657776 seconds ---
# 20fold 3-sigma clipping for 236
# --- 16.67258620262146 seconds ---
# 20fold 3-sigma clipping for 237
# --- 16.693549394607544 seconds ---
# 20fold 3-sigma clipping for 238
# --- 16.718934535980225 seconds ---
# 20fold 3-sigma clipping for 239
# --- 16.74625563621521 seconds ---
# 20fold 3-sigma clipping for 240
# --- 16.729676246643066 seconds ---
# 20fold 3-sigma clipping for 241
# --- 16.54211401939392 seconds ---
# 20fold 3-sigma clipping for 242
# --- 16.72045922279358 seconds ---
# 20fold 3-sigma clipping for 243
# --- 16.680981159210205 seconds ---
# 20fold 3-sigma clipping for 244
# --- 16.71372151374817 seconds ---
# 20fold 3-sigma clipping for 245
# --- 16.626831531524658 seconds ---
# 20fold 3-sigma clipping for 246
# --- 16.689924001693726 seconds ---
# 20fold 3-sigma clipping for 247
# --- 16.73628306388855 seconds ---
# 20fold 3-sigma clipping for 248
# --- 16.620867013931274 seconds ---
# 20fold 3-sigma clipping for 249
# --- 16.687631845474243 seconds ---
# 20fold 3-sigma clipping for 250
# --- 16.55928063392639 seconds ---
# 20fold 3-sigma clipping for 251
# --- 16.59880828857422 seconds ---
# 20fold 3-sigma clipping for 252
# --- 16.67346477508545 seconds ---
# 20fold 3-sigma clipping for 253
# --- 16.643823862075806 seconds ---
# 20fold 3-sigma clipping for 254
# --- 16.68797779083252 seconds ---
# 20fold 3-sigma clipping for 255
# --- 16.659958124160767 seconds ---
# 20fold 3-sigma clipping for 256
# --- 16.666826963424683 seconds ---
# 20fold 3-sigma clipping for 257
# --- 16.657898426055908 seconds ---
# 20fold 3-sigma clipping for 258
# --- 16.64388155937195 seconds ---
# 20fold 3-sigma clipping for 259
# --- 16.590429544448853 seconds ---
# 20fold 3-sigma clipping for 260
# --- 16.63656497001648 seconds ---
# 20fold 3-sigma clipping for 261
# --- 16.69712996482849 seconds ---
# 20fold 3-sigma clipping for 262
# --- 16.651533126831055 seconds ---
# 20fold 3-sigma clipping for 263
# --- 16.618641138076782 seconds ---
# 20fold 3-sigma clipping for 264
# --- 16.534322500228882 seconds ---
# 20fold 3-sigma clipping for 265
# --- 16.55778217315674 seconds ---
# 20fold 3-sigma clipping for 266
# --- 16.642691612243652 seconds ---
# 20fold 3-sigma clipping for 267
# --- 16.6936776638031 seconds ---
# 20fold 3-sigma clipping for 268
# --- 16.613856315612793 seconds ---
# 20fold 3-sigma clipping for 269
# --- 16.673961639404297 seconds ---
# 20fold 3-sigma clipping for 270
# --- 16.681308269500732 seconds ---
# 20fold 3-sigma clipping for 271
# --- 16.58025574684143 seconds ---
# 20fold 3-sigma clipping for 272
# --- 16.594646692276 seconds ---
# 20fold 3-sigma clipping for 273
# --- 16.66187357902527 seconds ---
# 20fold 3-sigma clipping for 274
# --- 16.682661294937134 seconds ---
# 20fold 3-sigma clipping for 275
# --- 16.693601846694946 seconds ---
# 20fold 3-sigma clipping for 276
# --- 16.65482521057129 seconds ---
# 20fold 3-sigma clipping for 277
# --- 16.505447149276733 seconds ---
# 20fold 3-sigma clipping for 278
# --- 16.65249729156494 seconds ---
# 20fold 3-sigma clipping for 279
# --- 16.64740490913391 seconds ---
# 20fold 3-sigma clipping for 280
# --- 16.665640830993652 seconds ---
# 20fold 3-sigma clipping for 281
# --- 16.67783522605896 seconds ---
# 20fold 3-sigma clipping for 282
# --- 16.562196731567383 seconds ---
# 20fold 3-sigma clipping for 283
# --- 16.550253868103027 seconds ---
# 20fold 3-sigma clipping for 284
# --- 16.539714097976685 seconds ---
# 20fold 3-sigma clipping for 285
# --- 16.667309522628784 seconds ---
# 20fold 3-sigma clipping for 286
# --- 16.606306791305542 seconds ---
# 20fold 3-sigma clipping for 287
# --- 16.602067232131958 seconds ---
# 20fold 3-sigma clipping for 288
# --- 16.676579475402832 seconds ---
# 20fold 3-sigma clipping for 289
# --- 16.69383668899536 seconds ---
# 20fold 3-sigma clipping for 290
# --- 16.66912341117859 seconds ---
# 20fold 3-sigma clipping for 291
# --- 16.61280131340027 seconds ---
# 20fold 3-sigma clipping for 292
# --- 16.679418802261353 seconds ---
# 20fold 3-sigma clipping for 293
# --- 16.706103324890137 seconds ---
# 20fold 3-sigma clipping for 294
# --- 16.733060836791992 seconds ---
# 20fold 3-sigma clipping for 295
# --- 16.75086998939514 seconds ---
# 20fold 3-sigma clipping for 296
# --- 16.724531650543213 seconds ---
# 20fold 3-sigma clipping for 297
# --- 16.562949895858765 seconds ---
# 20fold 3-sigma clipping for 298
# --- 16.694546937942505 seconds ---
# 20fold 3-sigma clipping for 299
# --- 16.675138235092163 seconds ---
# 20fold 3-sigma clipping for 300
# --- 16.719008922576904 seconds ---
# 20fold 3-sigma clipping for 301
# --- 16.684263467788696 seconds ---
# 20fold 3-sigma clipping for 302
# --- 16.602107763290405 seconds ---
# 20fold 3-sigma clipping for 303
# --- 16.717557668685913 seconds ---
# 20fold 3-sigma clipping for 304
# --- 16.536982774734497 seconds ---
# 20fold 3-sigma clipping for 305
# --- 16.6154682636261 seconds ---
# 20fold 3-sigma clipping for 306
# --- 16.707977294921875 seconds ---
# 20fold 3-sigma clipping for 307
# --- 16.588207244873047 seconds ---
# 20fold 3-sigma clipping for 308
# --- 16.620298147201538 seconds ---
# 20fold 3-sigma clipping for 309
# --- 16.55908226966858 seconds ---
# 20fold 3-sigma clipping for 310
# --- 16.708975315093994 seconds ---
# 20fold 3-sigma clipping for 311
# --- 16.637505531311035 seconds ---
# 20fold 3-sigma clipping for 312
# --- 16.595343351364136 seconds ---
# 20fold 3-sigma clipping for 313
# --- 16.617246627807617 seconds ---
# 20fold 3-sigma clipping for 314
# --- 16.699485063552856 seconds ---
# 20fold 3-sigma clipping for 315
# --- 16.682583570480347 seconds ---
# 20fold 3-sigma clipping for 316
# --- 16.662374258041382 seconds ---
# 20fold 3-sigma clipping for 317
# --- 16.711124658584595 seconds ---
# 20fold 3-sigma clipping for 318
# --- 16.537187337875366 seconds ---
# 20fold 3-sigma clipping for 319
# --- 16.677541494369507 seconds ---
# 20fold 3-sigma clipping for 320
# --- 16.5797598361969 seconds ---
# 20fold 3-sigma clipping for 321
# --- 16.650378227233887 seconds ---
# 20fold 3-sigma clipping for 322
# --- 16.692654609680176 seconds ---
# 20fold 3-sigma clipping for 323
# --- 16.692147254943848 seconds ---
# 20fold 3-sigma clipping for 324
# --- 16.674742698669434 seconds ---
# 20fold 3-sigma clipping for 325
# --- 16.684338808059692 seconds ---
# 20fold 3-sigma clipping for 326
# --- 16.652977228164673 seconds ---
# 20fold 3-sigma clipping for 327
# --- 16.5355167388916 seconds ---
# 20fold 3-sigma clipping for 328
# --- 16.66162657737732 seconds ---
# 20fold 3-sigma clipping for 329
# --- 16.532564640045166 seconds ---
# 20fold 3-sigma clipping for 330
# --- 16.69664168357849 seconds ---
# 20fold 3-sigma clipping for 331
# --- 16.56761598587036 seconds ---
# 20fold 3-sigma clipping for 332
# --- 16.699878454208374 seconds ---
# 20fold 3-sigma clipping for 333
# --- 16.655245304107666 seconds ---
# 20fold 3-sigma clipping for 334
# --- 16.66101598739624 seconds ---
# 20fold 3-sigma clipping for 335
# --- 16.622767686843872 seconds ---
# 20fold 3-sigma clipping for 336
# --- 16.615875005722046 seconds ---
# 20fold 3-sigma clipping for 337
# --- 16.715091228485107 seconds ---
# 20fold 3-sigma clipping for 338
# --- 16.61315083503723 seconds ---
# 20fold 3-sigma clipping for 339
# --- 16.644866704940796 seconds ---
# 20fold 3-sigma clipping for 340
# --- 16.685309886932373 seconds ---
# 20fold 3-sigma clipping for 341
# --- 16.638147830963135 seconds ---
# 20fold 3-sigma clipping for 342
# --- 16.562563180923462 seconds ---
# 20fold 3-sigma clipping for 343
# --- 16.720005989074707 seconds ---
# 20fold 3-sigma clipping for 344
# --- 16.710613250732422 seconds ---
# 20fold 3-sigma clipping for 345
# --- 16.734572649002075 seconds ---
# 20fold 3-sigma clipping for 346
# --- 16.6840341091156 seconds ---
# 20fold 3-sigma clipping for 347
# --- 16.680060148239136 seconds ---
# 20fold 3-sigma clipping for 348
# --- 16.62508511543274 seconds ---
# 20fold 3-sigma clipping for 349
# --- 16.73485255241394 seconds ---
# 20fold 3-sigma clipping for 350
# --- 16.499340772628784 seconds ---
# 20fold 3-sigma clipping for 351
# --- 16.619616985321045 seconds ---
# 20fold 3-sigma clipping for 352
# --- 16.68223214149475 seconds ---
# 20fold 3-sigma clipping for 353
# --- 16.674680948257446 seconds ---
# 20fold 3-sigma clipping for 354
# --- 16.62308955192566 seconds ---
# 20fold 3-sigma clipping for 355
# --- 16.688103914260864 seconds ---
# 20fold 3-sigma clipping for 356
# --- 16.470641374588013 seconds ---
# 20fold 3-sigma clipping for 357
# --- 16.560594081878662 seconds ---
# 20fold 3-sigma clipping for 358
# --- 16.721977472305298 seconds ---
# 20fold 3-sigma clipping for 359
# --- 16.53743290901184 seconds ---
# 20fold 3-sigma clipping for 360
# --- 16.636234760284424 seconds ---
# 20fold 3-sigma clipping for 361
# --- 16.708513975143433 seconds ---
# 20fold 3-sigma clipping for 362
# --- 16.731123208999634 seconds ---
# 20fold 3-sigma clipping for 363
# --- 16.668563842773438 seconds ---
# 20fold 3-sigma clipping for 364
# --- 16.682189226150513 seconds ---
# 20fold 3-sigma clipping for 365
# --- 16.701768398284912 seconds ---
# 20fold 3-sigma clipping for 366
# --- 16.736076593399048 seconds ---
# 20fold 3-sigma clipping for 367
# --- 16.68771719932556 seconds ---
# 20fold 3-sigma clipping for 368
# --- 16.585994482040405 seconds ---
# 20fold 3-sigma clipping for 369
# --- 16.697814464569092 seconds ---
# 20fold 3-sigma clipping for 370
# --- 16.682048559188843 seconds ---
# 20fold 3-sigma clipping for 371
# --- 16.714768648147583 seconds ---
# 20fold 3-sigma clipping for 372
# --- 16.747446537017822 seconds ---
# 20fold 3-sigma clipping for 373
# --- 16.53320860862732 seconds ---
# 20fold 3-sigma clipping for 374
# --- 16.558335065841675 seconds ---
# 20fold 3-sigma clipping for 375
# --- 16.614885807037354 seconds ---
# 20fold 3-sigma clipping for 376
# --- 16.501781225204468 seconds ---
# 20fold 3-sigma clipping for 377
# --- 16.663336992263794 seconds ---
# 20fold 3-sigma clipping for 378
# --- 16.700005292892456 seconds ---
# 20fold 3-sigma clipping for 379
# --- 16.589580297470093 seconds ---
# 20fold 3-sigma clipping for 380
# --- 16.513976335525513 seconds ---
# 20fold 3-sigma clipping for 381
# --- 16.70318078994751 seconds ---
# 20fold 3-sigma clipping for 382
# --- 16.571601629257202 seconds ---
# 20fold 3-sigma clipping for 383
# --- 16.74489140510559 seconds ---
# 20fold 3-sigma clipping for 384
# --- 16.75714111328125 seconds ---
# 20fold 3-sigma clipping for 385
# --- 16.736793756484985 seconds ---
# 20fold 3-sigma clipping for 386
# --- 16.714105367660522 seconds ---
# 20fold 3-sigma clipping for 387
# --- 16.745121002197266 seconds ---
# 20fold 3-sigma clipping for 388
# --- 16.784472942352295 seconds ---
# 20fold 3-sigma clipping for 389
# --- 16.673767805099487 seconds ---
# 20fold 3-sigma clipping for 390
# --- 16.639201641082764 seconds ---
# 20fold 3-sigma clipping for 391
# --- 16.751445531845093 seconds ---
# 20fold 3-sigma clipping for 392
# --- 16.77348041534424 seconds ---
# 20fold 3-sigma clipping for 393
# --- 16.63873839378357 seconds ---
# 20fold 3-sigma clipping for 394
# --- 16.74867296218872 seconds ---
# 20fold 3-sigma clipping for 395
# --- 16.642252445220947 seconds ---
# 20fold 3-sigma clipping for 396
# --- 16.748740434646606 seconds ---
# 20fold 3-sigma clipping for 397
# --- 16.5467529296875 seconds ---
# 20fold 3-sigma clipping for 398
# --- 16.76825189590454 seconds ---
# 20fold 3-sigma clipping for 399
# --- 16.519611835479736 seconds ---
# 20fold 3-sigma clipping for 400
# --- 16.563709020614624 seconds ---
# 20fold 3-sigma clipping for 401
# --- 16.587314128875732 seconds ---
# 20fold 3-sigma clipping for 402
# --- 16.66465425491333 seconds ---
# 20fold 3-sigma clipping for 403
# --- 16.532039642333984 seconds ---
# 20fold 3-sigma clipping for 404
# --- 16.531489849090576 seconds ---
# 20fold 3-sigma clipping for 405
# --- 16.707783699035645 seconds ---
# 20fold 3-sigma clipping for 406
# --- 16.746211290359497 seconds ---
# 20fold 3-sigma clipping for 407
# --- 16.65008807182312 seconds ---
# 20fold 3-sigma clipping for 408
# --- 16.69913125038147 seconds ---
# 20fold 3-sigma clipping for 409
# --- 16.75333547592163 seconds ---
# 20fold 3-sigma clipping for 410
# --- 16.665340423583984 seconds ---
# 20fold 3-sigma clipping for 411
# --- 16.76988387107849 seconds ---
# 20fold 3-sigma clipping for 412
# --- 16.581865072250366 seconds ---
# 20fold 3-sigma clipping for 413
# --- 16.64548110961914 seconds ---
# 20fold 3-sigma clipping for 414
# --- 16.768842458724976 seconds ---
# 20fold 3-sigma clipping for 415
# --- 16.813904762268066 seconds ---
# 20fold 3-sigma clipping for 416
# --- 16.665627241134644 seconds ---
# 20fold 3-sigma clipping for 417
# --- 16.733067274093628 seconds ---
# 20fold 3-sigma clipping for 418
# --- 16.729693174362183 seconds ---
# 20fold 3-sigma clipping for 419
# --- 16.677224159240723 seconds ---
# 20fold 3-sigma clipping for 420
# --- 16.647216081619263 seconds ---
# 20fold 3-sigma clipping for 421
# --- 16.675732135772705 seconds ---
# 20fold 3-sigma clipping for 422
# --- 16.68311381340027 seconds ---
# 20fold 3-sigma clipping for 423
# --- 16.77240562438965 seconds ---
# 20fold 3-sigma clipping for 424
# --- 16.601831436157227 seconds ---
# 20fold 3-sigma clipping for 425
# --- 16.629602909088135 seconds ---
# 20fold 3-sigma clipping for 426
# --- 16.795238256454468 seconds ---
# 20fold 3-sigma clipping for 427
# --- 16.777756214141846 seconds ---
# 20fold 3-sigma clipping for 428
# --- 16.736990928649902 seconds ---
# 20fold 3-sigma clipping for 429
# --- 16.80575680732727 seconds ---
# 20fold 3-sigma clipping for 430
# --- 16.685159921646118 seconds ---
# 20fold 3-sigma clipping for 431
# --- 16.72882604598999 seconds ---
# 20fold 3-sigma clipping for 432
# --- 16.74704909324646 seconds ---
# 20fold 3-sigma clipping for 433
# --- 16.602689027786255 seconds ---
# 20fold 3-sigma clipping for 434
# --- 16.716547966003418 seconds ---
# 20fold 3-sigma clipping for 435
# --- 16.703548192977905 seconds ---
# 20fold 3-sigma clipping for 436
# --- 16.62920570373535 seconds ---
# 20fold 3-sigma clipping for 437
# --- 16.652194023132324 seconds ---
# 20fold 3-sigma clipping for 438
# --- 16.52178406715393 seconds ---
# 20fold 3-sigma clipping for 439
# --- 16.74126648902893 seconds ---
# 20fold 3-sigma clipping for 440
# --- 16.63101315498352 seconds ---
# 20fold 3-sigma clipping for 441
# --- 16.744433403015137 seconds ---
# 20fold 3-sigma clipping for 442
# --- 16.707611560821533 seconds ---
# 20fold 3-sigma clipping for 443
# --- 16.653136730194092 seconds ---
# 20fold 3-sigma clipping for 444
# --- 16.68257761001587 seconds ---
# 20fold 3-sigma clipping for 445
# --- 16.574912548065186 seconds ---
# 20fold 3-sigma clipping for 446
# --- 16.62187671661377 seconds ---
# 20fold 3-sigma clipping for 447
# --- 16.76426601409912 seconds ---
# 20fold 3-sigma clipping for 448
# --- 16.728434562683105 seconds ---
# 20fold 3-sigma clipping for 449
# --- 16.637821435928345 seconds ---
# 20fold 3-sigma clipping for 450
# --- 16.62370777130127 seconds ---
# 20fold 3-sigma clipping for 451
# --- 16.68617606163025 seconds ---
# 20fold 3-sigma clipping for 452
# --- 16.69471788406372 seconds ---
# 20fold 3-sigma clipping for 453
# --- 16.46370768547058 seconds ---
# 20fold 3-sigma clipping for 454
# --- 16.748941898345947 seconds ---
# 20fold 3-sigma clipping for 455
# --- 16.71319270133972 seconds ---
# 20fold 3-sigma clipping for 456
# --- 16.647828340530396 seconds ---
# 20fold 3-sigma clipping for 457
# --- 16.693801641464233 seconds ---
# 20fold 3-sigma clipping for 458
# --- 16.715399742126465 seconds ---
# 20fold 3-sigma clipping for 459
# --- 16.648156881332397 seconds ---
# 20fold 3-sigma clipping for 460
# --- 16.774973392486572 seconds ---
# 20fold 3-sigma clipping for 461
# --- 16.71125054359436 seconds ---
# 20fold 3-sigma clipping for 462
# --- 16.626636266708374 seconds ---
# 20fold 3-sigma clipping for 463
# --- 16.738605499267578 seconds ---
# 20fold 3-sigma clipping for 464
# --- 16.690728664398193 seconds ---
# 20fold 3-sigma clipping for 465
# --- 16.73615026473999 seconds ---
# 20fold 3-sigma clipping for 466
# --- 16.67275857925415 seconds ---
# 20fold 3-sigma clipping for 467
# --- 16.555555820465088 seconds ---
# 20fold 3-sigma clipping for 468
# --- 16.725234270095825 seconds ---
# 20fold 3-sigma clipping for 469
# --- 16.620421886444092 seconds ---
# 20fold 3-sigma clipping for 470
# --- 16.721611976623535 seconds ---
# 20fold 3-sigma clipping for 471
# --- 16.742113828659058 seconds ---
# 20fold 3-sigma clipping for 472
# --- 16.738872051239014 seconds ---
# 20fold 3-sigma clipping for 473
# --- 16.67489194869995 seconds ---
# 20fold 3-sigma clipping for 474
# --- 16.615967273712158 seconds ---
# 20fold 3-sigma clipping for 475
# --- 16.677767515182495 seconds ---
# 20fold 3-sigma clipping for 476
# --- 16.574864149093628 seconds ---
# 20fold 3-sigma clipping for 477
# --- 16.532888412475586 seconds ---
# 20fold 3-sigma clipping for 478
# --- 16.619624614715576 seconds ---
# 20fold 3-sigma clipping for 479
# --- 16.517504692077637 seconds ---
# 20fold 3-sigma clipping for 480
# --- 16.65433979034424 seconds ---
# 20fold 3-sigma clipping for 481
# --- 16.510493278503418 seconds ---
# 20fold 3-sigma clipping for 482
# --- 16.603710651397705 seconds ---
# 20fold 3-sigma clipping for 483
# --- 16.42609930038452 seconds ---
# 20fold 3-sigma clipping for 484
# --- 16.719287633895874 seconds ---
# 20fold 3-sigma clipping for 485
# --- 16.74314260482788 seconds ---
# 20fold 3-sigma clipping for 486
# --- 16.57965087890625 seconds ---
# 20fold 3-sigma clipping for 487
# --- 16.648902654647827 seconds ---
# 20fold 3-sigma clipping for 488
# --- 16.675079107284546 seconds ---
# 20fold 3-sigma clipping for 489
# --- 16.507599592208862 seconds ---
# 20fold 3-sigma clipping for 490
# --- 16.529898643493652 seconds ---
# 20fold 3-sigma clipping for 491
# --- 16.627437829971313 seconds ---
# 20fold 3-sigma clipping for 492
# --- 16.73634362220764 seconds ---
# 20fold 3-sigma clipping for 493
# --- 16.741199016571045 seconds ---
# 20fold 3-sigma clipping for 494
# --- 16.559260368347168 seconds ---
# 20fold 3-sigma clipping for 495
# --- 16.698572874069214 seconds ---
# 20fold 3-sigma clipping for 496
# --- 16.682878732681274 seconds ---
# 20fold 3-sigma clipping for 497
# --- 16.518370389938354 seconds ---
# 20fold 3-sigma clipping for 498
# --- 16.74231743812561 seconds ---
# 20fold 3-sigma clipping for 499
# --- 16.713929414749146 seconds ---
# 20fold 3-sigma clipping for 500
# --- 16.728153228759766 seconds ---
# 20fold 3-sigma clipping for 501
# --- 16.740703582763672 seconds ---
# 20fold 3-sigma clipping for 502
# --- 16.79074740409851 seconds ---
# 20fold 3-sigma clipping for 503
# --- 16.752060651779175 seconds ---
# 20fold 3-sigma clipping for 504
# --- 16.500468254089355 seconds ---
# 20fold 3-sigma clipping for 505
# --- 16.656643867492676 seconds ---
# 20fold 3-sigma clipping for 506
# --- 16.682199954986572 seconds ---
# 20fold 3-sigma clipping for 507
# --- 16.56720232963562 seconds ---
# 20fold 3-sigma clipping for 508
# --- 16.624616146087646 seconds ---
# 20fold 3-sigma clipping for 509
# --- 16.69052267074585 seconds ---
# 20fold 3-sigma clipping for 510
# --- 16.547602891921997 seconds ---
# 20fold 3-sigma clipping for 511
# --- 16.552553415298462 seconds ---
# 20fold 3-sigma clipping for 512
# --- 16.659895658493042 seconds ---
# 20fold 3-sigma clipping for 513
# --- 16.616810083389282 seconds ---
# 20fold 3-sigma clipping for 514
# --- 16.56457495689392 seconds ---
# 20fold 3-sigma clipping for 515
# --- 16.481449842453003 seconds ---
# 20fold 3-sigma clipping for 516
# --- 16.6686270236969 seconds ---
# 20fold 3-sigma clipping for 517
# --- 16.636619806289673 seconds ---
# 20fold 3-sigma clipping for 518
# --- 16.61362099647522 seconds ---
# 20fold 3-sigma clipping for 519
# --- 16.622291088104248 seconds ---
# 20fold 3-sigma clipping for 520
# --- 16.645198583602905 seconds ---
# 20fold 3-sigma clipping for 521
# --- 16.66368317604065 seconds ---
# 20fold 3-sigma clipping for 522
# --- 16.5674090385437 seconds ---
# 20fold 3-sigma clipping for 523
# --- 16.515372276306152 seconds ---
# 20fold 3-sigma clipping for 524
# --- 16.639877557754517 seconds ---
# 20fold 3-sigma clipping for 525
# --- 16.471410274505615 seconds ---
# 20fold 3-sigma clipping for 526
# --- 16.668744564056396 seconds ---
# 20fold 3-sigma clipping for 527
# --- 16.665433883666992 seconds ---
# 20fold 3-sigma clipping for 528
# --- 16.599716186523438 seconds ---
# 20fold 3-sigma clipping for 529
# --- 16.500351190567017 seconds ---
# 20fold 3-sigma clipping for 530
# --- 16.671846389770508 seconds ---
# 20fold 3-sigma clipping for 531
# --- 16.496818780899048 seconds ---
# 20fold 3-sigma clipping for 532
# --- 16.632654428482056 seconds ---
# 20fold 3-sigma clipping for 533
# --- 16.526834726333618 seconds ---
# 20fold 3-sigma clipping for 534
# --- 16.750385999679565 seconds ---
# 20fold 3-sigma clipping for 535
# --- 16.666866540908813 seconds ---
# 20fold 3-sigma clipping for 536
# --- 16.66384196281433 seconds ---
# 20fold 3-sigma clipping for 537
# --- 16.629368782043457 seconds ---
# 20fold 3-sigma clipping for 538
# --- 16.554664850234985 seconds ---
# 20fold 3-sigma clipping for 539
# --- 16.71260118484497 seconds ---
# 20fold 3-sigma clipping for 540
# --- 16.7401180267334 seconds ---
# 20fold 3-sigma clipping for 541
# --- 16.62210178375244 seconds ---
# 20fold 3-sigma clipping for 542
# --- 16.45578908920288 seconds ---
# 20fold 3-sigma clipping for 543
# --- 16.695512056350708 seconds ---
# 20fold 3-sigma clipping for 544
# --- 16.57684063911438 seconds ---
# 20fold 3-sigma clipping for 545
# --- 16.52104616165161 seconds ---
# 20fold 3-sigma clipping for 546
# --- 16.741493225097656 seconds ---
# 20fold 3-sigma clipping for 547
# --- 16.46080732345581 seconds ---
# 20fold 3-sigma clipping for 548
# --- 16.69876003265381 seconds ---
# 20fold 3-sigma clipping for 549
# --- 16.517993211746216 seconds ---
# 20fold 3-sigma clipping for 550
# --- 16.68847393989563 seconds ---
# 20fold 3-sigma clipping for 551
# --- 16.61560845375061 seconds ---
# 20fold 3-sigma clipping for 552
# --- 16.621854305267334 seconds ---
# 20fold 3-sigma clipping for 553
# --- 16.388009786605835 seconds ---
# 20fold 3-sigma clipping for 554
# --- 16.640703678131104 seconds ---
# 20fold 3-sigma clipping for 555
# --- 16.566967487335205 seconds ---
# 20fold 3-sigma clipping for 556
# --- 16.45700716972351 seconds ---
# 20fold 3-sigma clipping for 557
# --- 16.562439918518066 seconds ---
# 20fold 3-sigma clipping for 558
# --- 16.651772260665894 seconds ---
# 20fold 3-sigma clipping for 559
# --- 16.402252912521362 seconds ---
# 20fold 3-sigma clipping for 560
# --- 16.539106845855713 seconds ---
# 20fold 3-sigma clipping for 561
# --- 16.668522834777832 seconds ---
# 20fold 3-sigma clipping for 562
# --- 16.72218894958496 seconds ---
# 20fold 3-sigma clipping for 563
# --- 16.761741638183594 seconds ---
# 20fold 3-sigma clipping for 564
# --- 16.76317262649536 seconds ---
# 20fold 3-sigma clipping for 565
# --- 16.67064380645752 seconds ---
# 20fold 3-sigma clipping for 566
# --- 16.648098707199097 seconds ---
# 20fold 3-sigma clipping for 567
# --- 16.730491399765015 seconds ---
# 20fold 3-sigma clipping for 568
# --- 16.57909083366394 seconds ---
# 20fold 3-sigma clipping for 569
# --- 16.697537183761597 seconds ---
# 20fold 3-sigma clipping for 570
# --- 16.55901002883911 seconds ---
# 20fold 3-sigma clipping for 571
# --- 16.655545473098755 seconds ---
# 20fold 3-sigma clipping for 572
# --- 16.722942113876343 seconds ---
# 20fold 3-sigma clipping for 573
# --- 16.672770738601685 seconds ---
# 20fold 3-sigma clipping for 574
# --- 16.654667139053345 seconds ---
# 20fold 3-sigma clipping for 575
# --- 16.55891489982605 seconds ---
# 20fold 3-sigma clipping for 576
# --- 16.447389125823975 seconds ---
# 20fold 3-sigma clipping for 577
# --- 16.591826915740967 seconds ---
# 20fold 3-sigma clipping for 578
# --- 16.777565717697144 seconds ---
# 20fold 3-sigma clipping for 579
# --- 16.68249273300171 seconds ---
# 20fold 3-sigma clipping for 580
# --- 16.594547033309937 seconds ---
# 20fold 3-sigma clipping for 581
# --- 16.588968753814697 seconds ---
# 20fold 3-sigma clipping for 582
# --- 16.627404928207397 seconds ---
# 20fold 3-sigma clipping for 583
# --- 16.634116649627686 seconds ---
# 20fold 3-sigma clipping for 584
# --- 16.54761242866516 seconds ---
# 20fold 3-sigma clipping for 585
# --- 16.7123384475708 seconds ---
# 20fold 3-sigma clipping for 586
# --- 16.599978923797607 seconds ---
# 20fold 3-sigma clipping for 587
# --- 16.665273427963257 seconds ---
# 20fold 3-sigma clipping for 588
# --- 16.600215911865234 seconds ---
# 20fold 3-sigma clipping for 589
# --- 16.67715048789978 seconds ---
# 20fold 3-sigma clipping for 590
# --- 16.729522705078125 seconds ---
# 20fold 3-sigma clipping for 591
# --- 16.61758041381836 seconds ---
# 20fold 3-sigma clipping for 592
# --- 16.61914348602295 seconds ---
# 20fold 3-sigma clipping for 593
# --- 16.51304054260254 seconds ---
# 20fold 3-sigma clipping for 594
# --- 16.69543719291687 seconds ---
# 20fold 3-sigma clipping for 595
# --- 16.72668719291687 seconds ---
# 20fold 3-sigma clipping for 596
# --- 16.660864114761353 seconds ---
# 20fold 3-sigma clipping for 597
# --- 16.68321180343628 seconds ---
# 20fold 3-sigma clipping for 598
# --- 16.658220052719116 seconds ---
# 20fold 3-sigma clipping for 599
# --- 16.686697959899902 seconds ---
# 20fold 3-sigma clipping for 600
# --- 16.768040895462036 seconds ---
# 20fold 3-sigma clipping for 601
# --- 16.69049596786499 seconds ---
# 20fold 3-sigma clipping for 602
# --- 16.751433610916138 seconds ---
# 20fold 3-sigma clipping for 603
# --- 16.749964475631714 seconds ---
# 20fold 3-sigma clipping for 604
# --- 16.60111141204834 seconds ---
# 20fold 3-sigma clipping for 605
# --- 16.79139018058777 seconds ---
# 20fold 3-sigma clipping for 606
# --- 16.68073058128357 seconds ---
# 20fold 3-sigma clipping for 607
# --- 16.75626802444458 seconds ---
# 20fold 3-sigma clipping for 608
# --- 16.796926021575928 seconds ---
# 20fold 3-sigma clipping for 609
# --- 16.767237663269043 seconds ---
# 20fold 3-sigma clipping for 610
# --- 16.80454111099243 seconds ---
# 20fold 3-sigma clipping for 611
# --- 16.795443296432495 seconds ---
# 20fold 3-sigma clipping for 612
# --- 16.70610547065735 seconds ---
# 20fold 3-sigma clipping for 613
# --- 16.680330991744995 seconds ---
# 20fold 3-sigma clipping for 614
# --- 16.58837366104126 seconds ---
# 20fold 3-sigma clipping for 615
# --- 16.7130765914917 seconds ---
# 20fold 3-sigma clipping for 616
# --- 16.629284858703613 seconds ---
# 20fold 3-sigma clipping for 617
# --- 16.707663536071777 seconds ---
# 20fold 3-sigma clipping for 618
# --- 16.699174165725708 seconds ---
# 20fold 3-sigma clipping for 619
# --- 16.618303775787354 seconds ---
# 20fold 3-sigma clipping for 620
# --- 16.574861526489258 seconds ---
# 20fold 3-sigma clipping for 621
# --- 16.689731121063232 seconds ---
# 20fold 3-sigma clipping for 622
# --- 16.622409343719482 seconds ---
# 20fold 3-sigma clipping for 623
# --- 16.574169158935547 seconds ---
# 20fold 3-sigma clipping for 624
# --- 16.669464349746704 seconds ---
# 20fold 3-sigma clipping for 625
# --- 16.4871346950531 seconds ---
# 20fold 3-sigma clipping for 626
# --- 16.661340475082397 seconds ---
# 20fold 3-sigma clipping for 627
# --- 16.64800763130188 seconds ---
# 20fold 3-sigma clipping for 628
# --- 16.605475187301636 seconds ---
# 20fold 3-sigma clipping for 629
# --- 16.55848240852356 seconds ---
# 20fold 3-sigma clipping for 630
# --- 16.644200563430786 seconds ---
# 20fold 3-sigma clipping for 631
# --- 16.595415115356445 seconds ---
# 20fold 3-sigma clipping for 632
# --- 16.70848798751831 seconds ---
# 20fold 3-sigma clipping for 633
# --- 16.641329050064087 seconds ---
# 20fold 3-sigma clipping for 634
# --- 16.661999464035034 seconds ---
# 20fold 3-sigma clipping for 635
# --- 16.72325849533081 seconds ---
# 20fold 3-sigma clipping for 636
# --- 16.644943714141846 seconds ---
# 20fold 3-sigma clipping for 637
# --- 16.679218292236328 seconds ---
# 20fold 3-sigma clipping for 638
# --- 16.739386796951294 seconds ---
# 20fold 3-sigma clipping for 639
# --- 16.691208362579346 seconds ---
# 20fold 3-sigma clipping for 640
# --- 16.74811339378357 seconds ---
# 20fold 3-sigma clipping for 641
# --- 16.508534908294678 seconds ---
# 20fold 3-sigma clipping for 642
# --- 16.48711323738098 seconds ---
# 20fold 3-sigma clipping for 643
# --- 16.639454126358032 seconds ---
# 20fold 3-sigma clipping for 644
# --- 16.681474208831787 seconds ---
# 20fold 3-sigma clipping for 645
# --- 16.69249415397644 seconds ---
# 20fold 3-sigma clipping for 646
# --- 16.622510194778442 seconds ---
# 20fold 3-sigma clipping for 647
# --- 16.57858443260193 seconds ---
# 20fold 3-sigma clipping for 648
# --- 16.482755184173584 seconds ---
# 20fold 3-sigma clipping for 649
# --- 16.43229579925537 seconds ---
# 20fold 3-sigma clipping for 650
# --- 16.004714727401733 seconds ---
# 20fold 3-sigma clipping for 651
# --- 16.09950041770935 seconds ---
# 20fold 3-sigma clipping for 652
# --- 16.09729266166687 seconds ---
# 20fold 3-sigma clipping for 653
# --- 16.137083053588867 seconds ---
# 20fold 3-sigma clipping for 654
# --- 15.943514347076416 seconds ---
# 20fold 3-sigma clipping for 655
# --- 16.19526696205139 seconds ---
# 20fold 3-sigma clipping for 656
# --- 16.133875608444214 seconds ---
# 20fold 3-sigma clipping for 657
# --- 16.088550567626953 seconds ---
# 20fold 3-sigma clipping for 658
# --- 16.092748880386353 seconds ---
# 20fold 3-sigma clipping for 659
# --- 16.103403091430664 seconds ---
# 20fold 3-sigma clipping for 660
# --- 16.081209421157837 seconds ---
# 20fold 3-sigma clipping for 661
# --- 15.973362922668457 seconds ---
# 20fold 3-sigma clipping for 662
# --- 16.033410787582397 seconds ---
# 20fold 3-sigma clipping for 663
# --- 15.990213632583618 seconds ---
# 20fold 3-sigma clipping for 664
# --- 15.913602828979492 seconds ---
# 20fold 3-sigma clipping for 665
# --- 16.11754846572876 seconds ---
# 20fold 3-sigma clipping for 666
# --- 16.03091549873352 seconds ---
# 20fold 3-sigma clipping for 667
# --- 16.071869134902954 seconds ---
# 20fold 3-sigma clipping for 668
# --- 16.095604181289673 seconds ---
# 20fold 3-sigma clipping for 669
# --- 16.1004958152771 seconds ---
# 20fold 3-sigma clipping for 670
# --- 16.06267738342285 seconds ---
# 20fold 3-sigma clipping for 671
# --- 16.057072162628174 seconds ---
# 20fold 3-sigma clipping for 672
# --- 16.170125007629395 seconds ---
# 20fold 3-sigma clipping for 673
# --- 16.014933824539185 seconds ---
# 20fold 3-sigma clipping for 674
# --- 16.028486490249634 seconds ---
# 20fold 3-sigma clipping for 675
# --- 16.21102786064148 seconds ---
# 20fold 3-sigma clipping for 676
# --- 15.966996192932129 seconds ---
# 20fold 3-sigma clipping for 677
# --- 16.082863807678223 seconds ---
# 20fold 3-sigma clipping for 678
# --- 16.104454040527344 seconds ---
# 20fold 3-sigma clipping for 679
# --- 16.188180208206177 seconds ---
# 20fold 3-sigma clipping for 680
# --- 16.073229789733887 seconds ---
# 20fold 3-sigma clipping for 681
# --- 16.139030933380127 seconds ---
# 20fold 3-sigma clipping for 682
# --- 16.216400384902954 seconds ---
# 20fold 3-sigma clipping for 683
# --- 16.018131256103516 seconds ---
# 20fold 3-sigma clipping for 684
# --- 15.977636814117432 seconds ---
# 20fold 3-sigma clipping for 685
# --- 16.23263907432556 seconds ---
# 20fold 3-sigma clipping for 686
# --- 16.045313596725464 seconds ---
# 20fold 3-sigma clipping for 687
# --- 16.037761688232422 seconds ---
# 20fold 3-sigma clipping for 688
# --- 16.0476713180542 seconds ---
# 20fold 3-sigma clipping for 689
# --- 16.099674224853516 seconds ---
# 20fold 3-sigma clipping for 690
# --- 16.15071439743042 seconds ---
# 20fold 3-sigma clipping for 691
# --- 16.15762972831726 seconds ---
# 20fold 3-sigma clipping for 692
# --- 16.086573839187622 seconds ---
# 20fold 3-sigma clipping for 693
# --- 16.095994234085083 seconds ---
# 20fold 3-sigma clipping for 694
# --- 16.201897382736206 seconds ---
# 20fold 3-sigma clipping for 695
# --- 16.193782091140747 seconds ---
# 20fold 3-sigma clipping for 696
# --- 16.09747886657715 seconds ---
# 20fold 3-sigma clipping for 697
# --- 16.072190761566162 seconds ---
# 20fold 3-sigma clipping for 698
# --- 16.079082012176514 seconds ---
# 20fold 3-sigma clipping for 699
# --- 16.162272453308105 seconds ---
# 20fold 3-sigma clipping for 700
# --- 16.020549297332764 seconds ---
# 20fold 3-sigma clipping for 701
# --- 16.058865070343018 seconds ---
# 20fold 3-sigma clipping for 702
# --- 16.06521773338318 seconds ---
# 20fold 3-sigma clipping for 703
# --- 15.999320983886719 seconds ---
# 20fold 3-sigma clipping for 704
# --- 15.997976779937744 seconds ---
# 20fold 3-sigma clipping for 705
# --- 16.07821750640869 seconds ---
# 20fold 3-sigma clipping for 706
# --- 16.060400009155273 seconds ---
# 20fold 3-sigma clipping for 707
# --- 16.09341335296631 seconds ---
# 20fold 3-sigma clipping for 708
# --- 16.13878297805786 seconds ---
# 20fold 3-sigma clipping for 709
# --- 16.123209238052368 seconds ---
# 20fold 3-sigma clipping for 710
# --- 16.26607060432434 seconds ---
# 20fold 3-sigma clipping for 711
# --- 16.340585470199585 seconds ---
# 20fold 3-sigma clipping for 712
# --- 16.291109561920166 seconds ---
# 20fold 3-sigma clipping for 713
# --- 16.34544801712036 seconds ---
# 20fold 3-sigma clipping for 714
# --- 16.267969369888306 seconds ---
# 20fold 3-sigma clipping for 715
# --- 16.30520796775818 seconds ---
# 20fold 3-sigma clipping for 716
# --- 16.178311347961426 seconds ---
# 20fold 3-sigma clipping for 717
# --- 16.300195455551147 seconds ---
# 20fold 3-sigma clipping for 718
# --- 16.33955693244934 seconds ---
# 20fold 3-sigma clipping for 719
# --- 16.398675441741943 seconds ---
# 20fold 3-sigma clipping for 720
# --- 16.264942407608032 seconds ---
# 20fold 3-sigma clipping for 721
# --- 16.256978750228882 seconds ---
# 20fold 3-sigma clipping for 722
# --- 16.31637144088745 seconds ---
# 20fold 3-sigma clipping for 723
# --- 16.297702312469482 seconds ---
# 20fold 3-sigma clipping for 724
# --- 16.149613857269287 seconds ---
# 20fold 3-sigma clipping for 725
# --- 16.190422773361206 seconds ---
# 20fold 3-sigma clipping for 726
# --- 16.13495182991028 seconds ---
# 20fold 3-sigma clipping for 727
# --- 16.084899425506592 seconds ---
# 20fold 3-sigma clipping for 728
# --- 16.31590175628662 seconds ---
# 20fold 3-sigma clipping for 729
# --- 16.628124475479126 seconds ---
# 20fold 3-sigma clipping for 730
# --- 16.68502640724182 seconds ---
# 20fold 3-sigma clipping for 731
# --- 16.64199995994568 seconds ---
# 20fold 3-sigma clipping for 732
# --- 16.673826694488525 seconds ---
# 20fold 3-sigma clipping for 733
# --- 16.655866146087646 seconds ---
# 20fold 3-sigma clipping for 734
# --- 16.757753610610962 seconds ---
# 20fold 3-sigma clipping for 735
# --- 16.705530643463135 seconds ---
# 20fold 3-sigma clipping for 736
# --- 16.555419921875 seconds ---
# 20fold 3-sigma clipping for 737
# --- 16.592029809951782 seconds ---
# 20fold 3-sigma clipping for 738
# --- 16.588150024414062 seconds ---
# 20fold 3-sigma clipping for 739
# --- 16.56926202774048 seconds ---
# 20fold 3-sigma clipping for 740
# --- 16.573873043060303 seconds ---
# 20fold 3-sigma clipping for 741
# --- 16.654964208602905 seconds ---
# 20fold 3-sigma clipping for 742
# --- 16.490832805633545 seconds ---
# 20fold 3-sigma clipping for 743
# --- 16.72191095352173 seconds ---
# 20fold 3-sigma clipping for 744
# --- 16.677741527557373 seconds ---
# 20fold 3-sigma clipping for 745
# --- 16.542821407318115 seconds ---
# 20fold 3-sigma clipping for 746
# --- 16.629937887191772 seconds ---
# 20fold 3-sigma clipping for 747
# --- 16.65678644180298 seconds ---
# 20fold 3-sigma clipping for 748
# --- 16.683911323547363 seconds ---
# 20fold 3-sigma clipping for 749
# --- 16.541112422943115 seconds ---
# 20fold 3-sigma clipping for 750
# --- 16.447694301605225 seconds ---
# 20fold 3-sigma clipping for 751
# --- 16.572636365890503 seconds ---
# 20fold 3-sigma clipping for 752
# --- 16.51488733291626 seconds ---
# 20fold 3-sigma clipping for 753
# --- 16.604323863983154 seconds ---
# 20fold 3-sigma clipping for 754
# --- 16.563122749328613 seconds ---
# 20fold 3-sigma clipping for 755
# --- 16.542418479919434 seconds ---
# 20fold 3-sigma clipping for 756
# --- 16.521891832351685 seconds ---
# 20fold 3-sigma clipping for 757
# --- 16.690389156341553 seconds ---
# 20fold 3-sigma clipping for 758
# --- 16.672486305236816 seconds ---
# 20fold 3-sigma clipping for 759
# --- 16.65385675430298 seconds ---
# 20fold 3-sigma clipping for 760
# --- 16.486796617507935 seconds ---
# 20fold 3-sigma clipping for 761
# --- 16.5556378364563 seconds ---
# 20fold 3-sigma clipping for 762
# --- 16.66854214668274 seconds ---
# 20fold 3-sigma clipping for 763
# --- 16.666531085968018 seconds ---
# 20fold 3-sigma clipping for 764
# --- 16.682887315750122 seconds ---
# 20fold 3-sigma clipping for 765
# --- 16.690715312957764 seconds ---
# 20fold 3-sigma clipping for 766
# --- 16.686224222183228 seconds ---
# 20fold 3-sigma clipping for 767
# --- 16.68586230278015 seconds ---
# 20fold 3-sigma clipping for 768
# --- 16.663671731948853 seconds ---
# 20fold 3-sigma clipping for 769
# --- 16.557533502578735 seconds ---
# 20fold 3-sigma clipping for 770
# --- 16.735681533813477 seconds ---
# 20fold 3-sigma clipping for 771
# --- 16.66502070426941 seconds ---
# 20fold 3-sigma clipping for 772
# --- 16.607508182525635 seconds ---
# 20fold 3-sigma clipping for 773
# --- 16.47825264930725 seconds ---
# 20fold 3-sigma clipping for 774
# --- 16.584740161895752 seconds ---
# 20fold 3-sigma clipping for 775
# --- 16.688636302947998 seconds ---
# 20fold 3-sigma clipping for 776
# --- 16.683533430099487 seconds ---
# 20fold 3-sigma clipping for 777
# --- 16.775094747543335 seconds ---
# 20fold 3-sigma clipping for 778
# --- 16.69638729095459 seconds ---
# 20fold 3-sigma clipping for 779
# --- 16.704277753829956 seconds ---
# 20fold 3-sigma clipping for 780
# --- 16.63795495033264 seconds ---
# 20fold 3-sigma clipping for 781
# --- 16.728225708007812 seconds ---
# 20fold 3-sigma clipping for 782
# --- 16.712430953979492 seconds ---
# 20fold 3-sigma clipping for 783
# --- 16.6630437374115 seconds ---
# 20fold 3-sigma clipping for 784
# --- 16.7627432346344 seconds ---
# 20fold 3-sigma clipping for 785
# --- 16.7871675491333 seconds ---
# 20fold 3-sigma clipping for 786
# --- 16.764070749282837 seconds ---
# 20fold 3-sigma clipping for 787
# --- 16.60829758644104 seconds ---
# 20fold 3-sigma clipping for 788
# --- 16.49207091331482 seconds ---
# 20fold 3-sigma clipping for 789
# --- 16.742538690567017 seconds ---
# 20fold 3-sigma clipping for 790
# --- 16.659430742263794 seconds ---
# 20fold 3-sigma clipping for 791
# --- 16.455695390701294 seconds ---
# 20fold 3-sigma clipping for 792
# --- 16.669666051864624 seconds ---
# 20fold 3-sigma clipping for 793
# --- 16.658491134643555 seconds ---
# 20fold 3-sigma clipping for 794
# --- 16.68750524520874 seconds ---
# 20fold 3-sigma clipping for 795
# --- 16.60252332687378 seconds ---
# 20fold 3-sigma clipping for 796
# --- 16.6506564617157 seconds ---
# 20fold 3-sigma clipping for 797
# --- 16.664170742034912 seconds ---
# 20fold 3-sigma clipping for 798
# --- 16.67309856414795 seconds ---
# 20fold 3-sigma clipping for 799
# --- 16.646949291229248 seconds ---
# 20fold 3-sigma clipping for 800
# --- 16.72146201133728 seconds ---
# 20fold 3-sigma clipping for 801
# --- 16.67171549797058 seconds ---
# 20fold 3-sigma clipping for 802
# --- 16.71172833442688 seconds ---
# 20fold 3-sigma clipping for 803
# --- 16.653884649276733 seconds ---
# 20fold 3-sigma clipping for 804
# --- 16.747164964675903 seconds ---
# 20fold 3-sigma clipping for 805
# --- 16.660775661468506 seconds ---
# 20fold 3-sigma clipping for 806
# --- 16.679704427719116 seconds ---
# 20fold 3-sigma clipping for 807
# --- 16.667428255081177 seconds ---
# 20fold 3-sigma clipping for 808
# --- 16.677961587905884 seconds ---
# 20fold 3-sigma clipping for 809
# --- 16.657238721847534 seconds ---
# 20fold 3-sigma clipping for 810
# --- 16.64693832397461 seconds ---
# 20fold 3-sigma clipping for 811
# --- 16.6005437374115 seconds ---
# 20fold 3-sigma clipping for 812
# --- 16.46708917617798 seconds ---
# 20fold 3-sigma clipping for 813
# --- 16.50518560409546 seconds ---
# 20fold 3-sigma clipping for 814
# --- 16.709128856658936 seconds ---
# 20fold 3-sigma clipping for 815
# --- 16.64997911453247 seconds ---
# 20fold 3-sigma clipping for 816
# --- 16.554170846939087 seconds ---
# 20fold 3-sigma clipping for 817
# --- 16.73398756980896 seconds ---
# 20fold 3-sigma clipping for 818
# --- 16.671135187149048 seconds ---
# 20fold 3-sigma clipping for 819
# --- 16.611619472503662 seconds ---
# 20fold 3-sigma clipping for 820
# --- 16.688682317733765 seconds ---
# 20fold 3-sigma clipping for 821
# --- 16.63725733757019 seconds ---
# 20fold 3-sigma clipping for 822
# --- 16.713632822036743 seconds ---
# 20fold 3-sigma clipping for 823
# --- 16.73342537879944 seconds ---
# 20fold 3-sigma clipping for 824
# --- 16.76966142654419 seconds ---
# 20fold 3-sigma clipping for 825
# --- 16.617729425430298 seconds ---
# 20fold 3-sigma clipping for 826
# --- 16.782817840576172 seconds ---
# 20fold 3-sigma clipping for 827
# --- 16.54426383972168 seconds ---
# 20fold 3-sigma clipping for 828
# --- 16.70776343345642 seconds ---
# 20fold 3-sigma clipping for 829
# --- 16.70842409133911 seconds ---
# 20fold 3-sigma clipping for 830
# --- 16.531837701797485 seconds ---
# 20fold 3-sigma clipping for 831
# --- 16.646155834197998 seconds ---
# 20fold 3-sigma clipping for 832
# --- 16.656561851501465 seconds ---
# 20fold 3-sigma clipping for 833
# --- 16.60103750228882 seconds ---
# 20fold 3-sigma clipping for 834
# --- 16.739994525909424 seconds ---
# 20fold 3-sigma clipping for 835
# --- 16.57170057296753 seconds ---
# 20fold 3-sigma clipping for 836
# --- 16.70638418197632 seconds ---
# 20fold 3-sigma clipping for 837
# --- 16.583205461502075 seconds ---
# 20fold 3-sigma clipping for 838
# --- 16.64134430885315 seconds ---
# 20fold 3-sigma clipping for 839
# --- 16.708487510681152 seconds ---
# 20fold 3-sigma clipping for 840
# --- 16.70842146873474 seconds ---
# 20fold 3-sigma clipping for 841
# --- 16.709914922714233 seconds ---
# 20fold 3-sigma clipping for 842
# --- 16.785327672958374 seconds ---
# 20fold 3-sigma clipping for 843
# --- 16.671169757843018 seconds ---
# 20fold 3-sigma clipping for 844
# --- 16.67979335784912 seconds ---
# 20fold 3-sigma clipping for 845
# --- 16.560354709625244 seconds ---
# 20fold 3-sigma clipping for 846
# --- 16.76942205429077 seconds ---
# 20fold 3-sigma clipping for 847
# --- 16.671859979629517 seconds ---

# %%
np.save("filtered_hsi1.npy", filtered_hsi1)

# %%
filteres_hsi1.shape
# Out:
# (848, 1600, 3195)
