# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt
import dask.array as da
from hyss_util import *

# %%
# %matplotlib widget

# %%
# -- set mpl defaults
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gist_gray"
plt.rcParams["figure.figsize"] = (10, 5)

# %%
# -- set the data paths
dpath0 = os.path.join(os.environ["LTCO_HSI0"], "full frame 20ms faster_VNIR.raw")
dpath1 = os.path.join(os.environ["LTCO_HSI1"], "night_00000.raw")

# %%
# -- apply 3-sigma clipping of HSI0
# -- read HSI0
cube0 = read_hyper(dpath0)
# Out:
# reading and parsing full frame 20ms faster_VNIR.hdr...
# reading full frame 20ms faster_VNIR.raw...

# %%
def sigma_clipping(cubedata, half):
    
    """ 
  Read half of the raw data and then clean it 

  Parameters:
  ----------

    cubedata: data cube 
  three dimentional array
  
    half: str   


  Returns：
  -------
  A three dimentional numpy array

    """  

    if half == "half0":
        spec = cubedata.data[:, :800, :]
    else:
        spec = cubedata.data[:, 800:1600, :]
        
        
    # -- apply 20 times 30sig clipping 
    filtered_hsi = np.empty(shape = spec.shape, dtype = "float64")
    for i in range(len(spec)):
        start_time = time.time()
        print("20fold 3-sigma clipping for {0}".format(i))
        # -- row first
        data_row = sig_clipping_row(spec[i])
        # -- then column
        data_col = sig_clipping_col(data_row)
        # -- row again
        data_row_2 = sig_clipping_row(data_col)
        # -- another column
        data_col_2 = sig_clipping_col(data_row_2)
        print("--- %s seconds ---" % (time.time() - start_time))
        filtered_hsi[i] = data_col_2
    return filtered_hsi

# %%
np.save("filtered_hsi0.npy", filtered_hsi0)

# %%
# -- apply 3-sigma clipping of HSI1
# -- read HSI1
cube1 = read_hyper(dpath1)
# Out:
# reading and parsing night_00000.hdr...
# reading night_00000.raw...

# %%
# -- data proprecessing for the image from row0 to row800
filtered_hsi1_half0 = sigma_clipping(cube1, "half0")
np.save("filtered_hsi1_half0.npy", filtered_hsi1_half0)

# %%
np.save("filtered_hsi1_half0.npy", filtered_hsi1_half0)

# %%
# -- data proprecessing for the image from row800 to row1600
filtered_hsi1_half1 = sigma_clipping(cube1, "half1")
# Out:
# 20fold 3-sigma clipping for 0
# --- 8.294332027435303 seconds ---
# 20fold 3-sigma clipping for 1
# --- 8.104199409484863 seconds ---
# 20fold 3-sigma clipping for 2
# --- 8.182462692260742 seconds ---
# 20fold 3-sigma clipping for 3
# --- 8.174302577972412 seconds ---
# 20fold 3-sigma clipping for 4
# --- 8.016351699829102 seconds ---
# 20fold 3-sigma clipping for 5
# --- 7.965640068054199 seconds ---
# 20fold 3-sigma clipping for 6
# --- 8.14137053489685 seconds ---
# 20fold 3-sigma clipping for 7
# --- 8.188476800918579 seconds ---
# 20fold 3-sigma clipping for 8
# --- 8.15904426574707 seconds ---
# 20fold 3-sigma clipping for 9
# --- 8.056303262710571 seconds ---
# 20fold 3-sigma clipping for 10
# --- 8.005744457244873 seconds ---
# 20fold 3-sigma clipping for 11
# --- 8.204275846481323 seconds ---
# 20fold 3-sigma clipping for 12
# --- 8.184917449951172 seconds ---
# 20fold 3-sigma clipping for 13
# --- 8.162922859191895 seconds ---
# 20fold 3-sigma clipping for 14
# --- 8.07371711730957 seconds ---
# 20fold 3-sigma clipping for 15
# --- 7.944909572601318 seconds ---
# 20fold 3-sigma clipping for 16
# --- 8.169275522232056 seconds ---
# 20fold 3-sigma clipping for 17
# --- 8.172078609466553 seconds ---
# 20fold 3-sigma clipping for 18
# --- 8.156850337982178 seconds ---
# 20fold 3-sigma clipping for 19
# --- 8.014859676361084 seconds ---
# 20fold 3-sigma clipping for 20
# --- 7.9423229694366455 seconds ---
# 20fold 3-sigma clipping for 21
# --- 8.20037293434143 seconds ---
# 20fold 3-sigma clipping for 22
# --- 8.216125011444092 seconds ---
# 20fold 3-sigma clipping for 23
# --- 8.173491477966309 seconds ---
# 20fold 3-sigma clipping for 24
# --- 8.032293796539307 seconds ---
# 20fold 3-sigma clipping for 25
# --- 7.96630334854126 seconds ---
# 20fold 3-sigma clipping for 26
# --- 8.128037452697754 seconds ---
# 20fold 3-sigma clipping for 27
# --- 8.140552282333374 seconds ---
# 20fold 3-sigma clipping for 28
# --- 8.188327550888062 seconds ---
# 20fold 3-sigma clipping for 29
# --- 8.043992042541504 seconds ---
# 20fold 3-sigma clipping for 30
# --- 7.774479866027832 seconds ---
# 20fold 3-sigma clipping for 31
# --- 7.731722593307495 seconds ---
# 20fold 3-sigma clipping for 32
# --- 7.75356125831604 seconds ---
# 20fold 3-sigma clipping for 33
# --- 7.773501873016357 seconds ---
# 20fold 3-sigma clipping for 34
# --- 7.630415439605713 seconds ---
# 20fold 3-sigma clipping for 35
# --- 7.617269515991211 seconds ---
# 20fold 3-sigma clipping for 36
# --- 7.8030805587768555 seconds ---
# 20fold 3-sigma clipping for 37
# --- 7.877660274505615 seconds ---
# 20fold 3-sigma clipping for 38
# --- 7.793121576309204 seconds ---
# 20fold 3-sigma clipping for 39
# --- 7.637523889541626 seconds ---
# 20fold 3-sigma clipping for 40
# --- 7.567320108413696 seconds ---
# 20fold 3-sigma clipping for 41
# --- 7.761736154556274 seconds ---
# 20fold 3-sigma clipping for 42
# --- 7.769032001495361 seconds ---
# 20fold 3-sigma clipping for 43
# --- 7.788546800613403 seconds ---
# 20fold 3-sigma clipping for 44
# --- 7.6762683391571045 seconds ---
# 20fold 3-sigma clipping for 45
# --- 7.591271877288818 seconds ---
# 20fold 3-sigma clipping for 46
# --- 7.792195081710815 seconds ---
# 20fold 3-sigma clipping for 47
# --- 7.837803840637207 seconds ---
# 20fold 3-sigma clipping for 48
# --- 7.8334245681762695 seconds ---
# 20fold 3-sigma clipping for 49
# --- 7.698753833770752 seconds ---
# 20fold 3-sigma clipping for 50
# --- 7.614017486572266 seconds ---
# 20fold 3-sigma clipping for 51
# --- 7.803240537643433 seconds ---
# 20fold 3-sigma clipping for 52
# --- 7.8146843910217285 seconds ---
# 20fold 3-sigma clipping for 53
# --- 7.82517409324646 seconds ---
# 20fold 3-sigma clipping for 54
# --- 7.704983472824097 seconds ---
# 20fold 3-sigma clipping for 55
# --- 7.604051113128662 seconds ---
# 20fold 3-sigma clipping for 56
# --- 7.810214042663574 seconds ---
# 20fold 3-sigma clipping for 57
# --- 7.771696090698242 seconds ---
# 20fold 3-sigma clipping for 58
# --- 7.831460952758789 seconds ---
# 20fold 3-sigma clipping for 59
# --- 7.691432237625122 seconds ---
# 20fold 3-sigma clipping for 60
# --- 7.623877763748169 seconds ---
# 20fold 3-sigma clipping for 61
# --- 7.786678791046143 seconds ---
# 20fold 3-sigma clipping for 62
# --- 7.806211709976196 seconds ---
# 20fold 3-sigma clipping for 63
# --- 7.831739664077759 seconds ---
# 20fold 3-sigma clipping for 64
# --- 7.717909574508667 seconds ---
# 20fold 3-sigma clipping for 65
# --- 7.648630857467651 seconds ---
# 20fold 3-sigma clipping for 66
# --- 7.816036701202393 seconds ---
# 20fold 3-sigma clipping for 67
# --- 7.926837205886841 seconds ---
# 20fold 3-sigma clipping for 68
# --- 7.816315174102783 seconds ---
# 20fold 3-sigma clipping for 69
# --- 7.706620454788208 seconds ---
# 20fold 3-sigma clipping for 70
# --- 7.610271215438843 seconds ---
# 20fold 3-sigma clipping for 71
# --- 7.777899265289307 seconds ---
# 20fold 3-sigma clipping for 72
# --- 7.830087900161743 seconds ---
# 20fold 3-sigma clipping for 73
# --- 7.8479273319244385 seconds ---
# 20fold 3-sigma clipping for 74
# --- 7.743408918380737 seconds ---
# 20fold 3-sigma clipping for 75
# --- 7.641866445541382 seconds ---
# 20fold 3-sigma clipping for 76
# --- 7.831305503845215 seconds ---
# 20fold 3-sigma clipping for 77
# --- 7.833775281906128 seconds ---
# 20fold 3-sigma clipping for 78
# --- 7.834048509597778 seconds ---
# 20fold 3-sigma clipping for 79
# --- 8.11178183555603 seconds ---
# 20fold 3-sigma clipping for 80
# --- 7.991790056228638 seconds ---
# 20fold 3-sigma clipping for 81
# --- 8.243049621582031 seconds ---
# 20fold 3-sigma clipping for 82
# --- 7.801640033721924 seconds ---
# 20fold 3-sigma clipping for 83
# --- 7.813429832458496 seconds ---
# 20fold 3-sigma clipping for 84
# --- 7.692387342453003 seconds ---
# 20fold 3-sigma clipping for 85
# --- 7.635377645492554 seconds ---
# 20fold 3-sigma clipping for 86
# --- 7.807709693908691 seconds ---
# 20fold 3-sigma clipping for 87
# --- 7.830083131790161 seconds ---
# 20fold 3-sigma clipping for 88
# --- 7.787532329559326 seconds ---
# 20fold 3-sigma clipping for 89
# --- 7.6998045444488525 seconds ---
# 20fold 3-sigma clipping for 90
# --- 7.633533477783203 seconds ---
# 20fold 3-sigma clipping for 91
# --- 7.794232130050659 seconds ---
# 20fold 3-sigma clipping for 92
# --- 7.801611423492432 seconds ---
# 20fold 3-sigma clipping for 93
# --- 7.809298276901245 seconds ---
# 20fold 3-sigma clipping for 94
# --- 7.663277626037598 seconds ---
# 20fold 3-sigma clipping for 95
# --- 7.632592678070068 seconds ---
# 20fold 3-sigma clipping for 96
# --- 7.779554843902588 seconds ---
# 20fold 3-sigma clipping for 97
# --- 7.824808120727539 seconds ---
# 20fold 3-sigma clipping for 98
# --- 7.804340124130249 seconds ---
# 20fold 3-sigma clipping for 99
# --- 7.669672012329102 seconds ---
# 20fold 3-sigma clipping for 100
# --- 7.6140546798706055 seconds ---
# 20fold 3-sigma clipping for 101
# --- 7.793552875518799 seconds ---
# 20fold 3-sigma clipping for 102
# --- 7.818657636642456 seconds ---
# 20fold 3-sigma clipping for 103
# --- 7.797295808792114 seconds ---
# 20fold 3-sigma clipping for 104
# --- 7.681373834609985 seconds ---
# 20fold 3-sigma clipping for 105
# --- 7.618841171264648 seconds ---
# 20fold 3-sigma clipping for 106
# --- 7.785839080810547 seconds ---
# 20fold 3-sigma clipping for 107
# --- 7.814411878585815 seconds ---
# 20fold 3-sigma clipping for 108
# --- 7.8266236782073975 seconds ---
# 20fold 3-sigma clipping for 109
# --- 7.6881866455078125 seconds ---
# 20fold 3-sigma clipping for 110
# --- 7.629040479660034 seconds ---
# 20fold 3-sigma clipping for 111
# --- 7.746143341064453 seconds ---
# 20fold 3-sigma clipping for 112
# --- 7.797536134719849 seconds ---
# 20fold 3-sigma clipping for 113
# --- 7.7868359088897705 seconds ---
# 20fold 3-sigma clipping for 114
# --- 7.630599021911621 seconds ---
# 20fold 3-sigma clipping for 115
# --- 7.591169595718384 seconds ---
# 20fold 3-sigma clipping for 116
# --- 7.768008470535278 seconds ---
# 20fold 3-sigma clipping for 117
# --- 7.771214723587036 seconds ---
# 20fold 3-sigma clipping for 118
# --- 7.737717390060425 seconds ---
# 20fold 3-sigma clipping for 119
# --- 7.643723487854004 seconds ---
# 20fold 3-sigma clipping for 120
# --- 7.5029213428497314 seconds ---
# 20fold 3-sigma clipping for 121
# --- 7.565852880477905 seconds ---
# 20fold 3-sigma clipping for 122
# --- 7.5727832317352295 seconds ---
# 20fold 3-sigma clipping for 123
# --- 7.572452783584595 seconds ---
# 20fold 3-sigma clipping for 124
# --- 7.451432228088379 seconds ---
# 20fold 3-sigma clipping for 125
# --- 7.411792278289795 seconds ---
# 20fold 3-sigma clipping for 126
# --- 7.535226345062256 seconds ---
# 20fold 3-sigma clipping for 127
# --- 7.588239669799805 seconds ---
# 20fold 3-sigma clipping for 128
# --- 7.599076986312866 seconds ---
# 20fold 3-sigma clipping for 129
# --- 7.477090835571289 seconds ---
# 20fold 3-sigma clipping for 130
# --- 7.392984390258789 seconds ---
# 20fold 3-sigma clipping for 131
# --- 7.592428684234619 seconds ---
# 20fold 3-sigma clipping for 132
# --- 7.585731029510498 seconds ---
# 20fold 3-sigma clipping for 133
# --- 7.603375196456909 seconds ---
# 20fold 3-sigma clipping for 134
# --- 7.504746913909912 seconds ---
# 20fold 3-sigma clipping for 135
# --- 7.425293922424316 seconds ---
# 20fold 3-sigma clipping for 136
# --- 7.5860395431518555 seconds ---
# 20fold 3-sigma clipping for 137
# --- 7.588762044906616 seconds ---
# 20fold 3-sigma clipping for 138
# --- 7.620635747909546 seconds ---
# 20fold 3-sigma clipping for 139
# --- 7.510874509811401 seconds ---
# 20fold 3-sigma clipping for 140
# --- 7.4601967334747314 seconds ---
# 20fold 3-sigma clipping for 141
# --- 7.602599143981934 seconds ---
# 20fold 3-sigma clipping for 142
# --- 7.672905206680298 seconds ---
# 20fold 3-sigma clipping for 143
# --- 7.6550257205963135 seconds ---
# 20fold 3-sigma clipping for 144
# --- 7.516700029373169 seconds ---
# 20fold 3-sigma clipping for 145
# --- 7.465298652648926 seconds ---
# 20fold 3-sigma clipping for 146
# --- 7.640281915664673 seconds ---
# 20fold 3-sigma clipping for 147
# --- 7.6533684730529785 seconds ---
# 20fold 3-sigma clipping for 148
# --- 7.6447975635528564 seconds ---
# 20fold 3-sigma clipping for 149
# --- 7.527458906173706 seconds ---
# 20fold 3-sigma clipping for 150
# --- 7.47673487663269 seconds ---
# 20fold 3-sigma clipping for 151
# --- 7.653431177139282 seconds ---
# 20fold 3-sigma clipping for 152
# --- 7.6551194190979 seconds ---
# 20fold 3-sigma clipping for 153
# --- 7.644114017486572 seconds ---
# 20fold 3-sigma clipping for 154
# --- 7.489557981491089 seconds ---
# 20fold 3-sigma clipping for 155
# --- 7.436310052871704 seconds ---
# 20fold 3-sigma clipping for 156
# --- 7.591559648513794 seconds ---
# 20fold 3-sigma clipping for 157
# --- 7.609022617340088 seconds ---
# 20fold 3-sigma clipping for 158
# --- 7.64342474937439 seconds ---
# 20fold 3-sigma clipping for 159
# --- 7.4971230030059814 seconds ---
# 20fold 3-sigma clipping for 160
# --- 7.462201833724976 seconds ---
# 20fold 3-sigma clipping for 161
# --- 7.611980199813843 seconds ---
# 20fold 3-sigma clipping for 162
# --- 7.646547079086304 seconds ---
# 20fold 3-sigma clipping for 163
# --- 7.628385305404663 seconds ---
# 20fold 3-sigma clipping for 164
# --- 7.485098123550415 seconds ---
# 20fold 3-sigma clipping for 165
# --- 7.447070360183716 seconds ---
# 20fold 3-sigma clipping for 166
# --- 7.574533462524414 seconds ---
# 20fold 3-sigma clipping for 167
# --- 7.578457593917847 seconds ---
# 20fold 3-sigma clipping for 168
# --- 7.587894916534424 seconds ---
# 20fold 3-sigma clipping for 169
# --- 7.496638536453247 seconds ---
# 20fold 3-sigma clipping for 170
# --- 7.428354263305664 seconds ---
# 20fold 3-sigma clipping for 171
# --- 7.542949199676514 seconds ---
# 20fold 3-sigma clipping for 172
# --- 7.596147775650024 seconds ---
# 20fold 3-sigma clipping for 173
# --- 7.59360933303833 seconds ---
# 20fold 3-sigma clipping for 174
# --- 7.477378606796265 seconds ---
# 20fold 3-sigma clipping for 175
# --- 7.43800163269043 seconds ---
# 20fold 3-sigma clipping for 176
# --- 7.6210973262786865 seconds ---
# 20fold 3-sigma clipping for 177
# --- 7.612499237060547 seconds ---
# 20fold 3-sigma clipping for 178
# --- 7.818962574005127 seconds ---
# 20fold 3-sigma clipping for 179
# --- 7.73196005821228 seconds ---
# 20fold 3-sigma clipping for 180
# --- 7.676670074462891 seconds ---
# 20fold 3-sigma clipping for 181
# --- 7.839353799819946 seconds ---
# 20fold 3-sigma clipping for 182
# --- 7.813428640365601 seconds ---
# 20fold 3-sigma clipping for 183
# --- 7.847979545593262 seconds ---
# 20fold 3-sigma clipping for 184
# --- 7.731364488601685 seconds ---
# 20fold 3-sigma clipping for 185
# --- 7.6479480266571045 seconds ---
# 20fold 3-sigma clipping for 186
# --- 7.819810152053833 seconds ---
# 20fold 3-sigma clipping for 187
# --- 7.846200942993164 seconds ---
# 20fold 3-sigma clipping for 188
# --- 7.847817659378052 seconds ---
# 20fold 3-sigma clipping for 189
# --- 7.747681617736816 seconds ---
# 20fold 3-sigma clipping for 190
# --- 7.6715264320373535 seconds ---
# 20fold 3-sigma clipping for 191
# --- 7.823648452758789 seconds ---
# 20fold 3-sigma clipping for 192
# --- 7.8608081340789795 seconds ---
# 20fold 3-sigma clipping for 193
# --- 7.856494665145874 seconds ---
# 20fold 3-sigma clipping for 194
# --- 7.7460455894470215 seconds ---
# 20fold 3-sigma clipping for 195
# --- 7.688178539276123 seconds ---
# 20fold 3-sigma clipping for 196
# --- 7.806671380996704 seconds ---
# 20fold 3-sigma clipping for 197
# --- 7.876949787139893 seconds ---
# 20fold 3-sigma clipping for 198
# --- 7.862462043762207 seconds ---
# 20fold 3-sigma clipping for 199
# --- 7.75328516960144 seconds ---
# 20fold 3-sigma clipping for 200
# --- 7.6656174659729 seconds ---
# 20fold 3-sigma clipping for 201
# --- 7.827774524688721 seconds ---
# 20fold 3-sigma clipping for 202
# --- 7.844473600387573 seconds ---
# 20fold 3-sigma clipping for 203
# --- 7.848535537719727 seconds ---
# 20fold 3-sigma clipping for 204
# --- 7.764613151550293 seconds ---
# 20fold 3-sigma clipping for 205
# --- 7.674015998840332 seconds ---
# 20fold 3-sigma clipping for 206
# --- 7.8246705532073975 seconds ---
# 20fold 3-sigma clipping for 207
# --- 7.880608797073364 seconds ---
# 20fold 3-sigma clipping for 208
# --- 7.88152289390564 seconds ---
# 20fold 3-sigma clipping for 209
# --- 7.721630573272705 seconds ---
# 20fold 3-sigma clipping for 210
# --- 7.704615831375122 seconds ---
# 20fold 3-sigma clipping for 211
# --- 7.848587274551392 seconds ---
# 20fold 3-sigma clipping for 212
# --- 7.8776185512542725 seconds ---
# 20fold 3-sigma clipping for 213
# --- 7.8721184730529785 seconds ---
# 20fold 3-sigma clipping for 214
# --- 7.74843692779541 seconds ---
# 20fold 3-sigma clipping for 215
# --- 7.690011978149414 seconds ---
# 20fold 3-sigma clipping for 216
# --- 7.81363582611084 seconds ---
# 20fold 3-sigma clipping for 217
# --- 7.877335071563721 seconds ---
# 20fold 3-sigma clipping for 218
# --- 7.895059585571289 seconds ---
# 20fold 3-sigma clipping for 219
# --- 7.7711944580078125 seconds ---
# 20fold 3-sigma clipping for 220
# --- 7.701853275299072 seconds ---
# 20fold 3-sigma clipping for 221
# --- 7.870506763458252 seconds ---
# 20fold 3-sigma clipping for 222
# --- 7.913299322128296 seconds ---
# 20fold 3-sigma clipping for 223
# --- 7.88140082359314 seconds ---
# 20fold 3-sigma clipping for 224
# --- 7.752521276473999 seconds ---
# 20fold 3-sigma clipping for 225
# --- 7.703057765960693 seconds ---
# 20fold 3-sigma clipping for 226
# --- 7.8023011684417725 seconds ---
# 20fold 3-sigma clipping for 227
# --- 7.8844521045684814 seconds ---
# 20fold 3-sigma clipping for 228
# --- 7.895580291748047 seconds ---
# 20fold 3-sigma clipping for 229
# --- 7.7707085609436035 seconds ---
# 20fold 3-sigma clipping for 230
# --- 7.698369026184082 seconds ---
# 20fold 3-sigma clipping for 231
# --- 7.845395565032959 seconds ---
# 20fold 3-sigma clipping for 232
# --- 7.895542621612549 seconds ---
# 20fold 3-sigma clipping for 233
# --- 7.898082494735718 seconds ---
# 20fold 3-sigma clipping for 234
# --- 7.7502264976501465 seconds ---
# 20fold 3-sigma clipping for 235
# --- 7.678290367126465 seconds ---
# 20fold 3-sigma clipping for 236
# --- 7.8371422290802 seconds ---
# 20fold 3-sigma clipping for 237
# --- 7.889759302139282 seconds ---
# 20fold 3-sigma clipping for 238
# --- 7.808100700378418 seconds ---
# 20fold 3-sigma clipping for 239
# --- 7.613023281097412 seconds ---
# 20fold 3-sigma clipping for 240
# --- 7.554413557052612 seconds ---
# 20fold 3-sigma clipping for 241
# --- 7.7128682136535645 seconds ---
# 20fold 3-sigma clipping for 242
# --- 7.792892932891846 seconds ---
# 20fold 3-sigma clipping for 243
# --- 7.759544372558594 seconds ---
# 20fold 3-sigma clipping for 244
# --- 7.619170904159546 seconds ---
# 20fold 3-sigma clipping for 245
# --- 7.547487258911133 seconds ---
# 20fold 3-sigma clipping for 246
# --- 7.747494697570801 seconds ---
# 20fold 3-sigma clipping for 247
# --- 7.678587913513184 seconds ---
# 20fold 3-sigma clipping for 248
# --- 7.642407417297363 seconds ---
# 20fold 3-sigma clipping for 249
# --- 7.482139587402344 seconds ---
# 20fold 3-sigma clipping for 250
# --- 7.447624206542969 seconds ---
# 20fold 3-sigma clipping for 251
# --- 7.596936941146851 seconds ---
# 20fold 3-sigma clipping for 252
# --- 7.6059346199035645 seconds ---
# 20fold 3-sigma clipping for 253
# --- 7.629719257354736 seconds ---
# 20fold 3-sigma clipping for 254
# --- 7.510393857955933 seconds ---
# 20fold 3-sigma clipping for 255
# --- 7.421665906906128 seconds ---
# 20fold 3-sigma clipping for 256
# --- 7.5986223220825195 seconds ---
# 20fold 3-sigma clipping for 257
# --- 7.636835336685181 seconds ---
# 20fold 3-sigma clipping for 258
# --- 7.617990016937256 seconds ---
# 20fold 3-sigma clipping for 259
# --- 7.5052008628845215 seconds ---
# 20fold 3-sigma clipping for 260
# --- 7.460628509521484 seconds ---
# 20fold 3-sigma clipping for 261
# --- 7.64241623878479 seconds ---
# 20fold 3-sigma clipping for 262
# --- 7.658198833465576 seconds ---
# 20fold 3-sigma clipping for 263
# --- 7.638158082962036 seconds ---
# 20fold 3-sigma clipping for 264
# --- 7.526747465133667 seconds ---
# 20fold 3-sigma clipping for 265
# --- 7.457292556762695 seconds ---
# 20fold 3-sigma clipping for 266
# --- 7.638448238372803 seconds ---
# 20fold 3-sigma clipping for 267
# --- 7.660253286361694 seconds ---
# 20fold 3-sigma clipping for 268
# --- 7.668982982635498 seconds ---
# 20fold 3-sigma clipping for 269
# --- 7.538417816162109 seconds ---
# 20fold 3-sigma clipping for 270
# --- 7.474986791610718 seconds ---
# 20fold 3-sigma clipping for 271
# --- 7.637493371963501 seconds ---
# 20fold 3-sigma clipping for 272
# --- 7.650346279144287 seconds ---
# 20fold 3-sigma clipping for 273
# --- 7.68224310874939 seconds ---
# 20fold 3-sigma clipping for 274
# --- 7.559319972991943 seconds ---
# 20fold 3-sigma clipping for 275
# --- 7.491638898849487 seconds ---
# 20fold 3-sigma clipping for 276
# --- 7.6295788288116455 seconds ---
# 20fold 3-sigma clipping for 277
# --- 7.657564640045166 seconds ---
# 20fold 3-sigma clipping for 278
# --- 7.642228841781616 seconds ---
# 20fold 3-sigma clipping for 279
# --- 7.55892276763916 seconds ---
# 20fold 3-sigma clipping for 280
# --- 7.4657511711120605 seconds ---
# 20fold 3-sigma clipping for 281
# --- 7.641052484512329 seconds ---
# 20fold 3-sigma clipping for 282
# --- 7.665889263153076 seconds ---
# 20fold 3-sigma clipping for 283
# --- 7.68143630027771 seconds ---
# 20fold 3-sigma clipping for 284
# --- 7.5587968826293945 seconds ---
# 20fold 3-sigma clipping for 285
# --- 7.480428457260132 seconds ---
# 20fold 3-sigma clipping for 286
# --- 7.63637900352478 seconds ---
# 20fold 3-sigma clipping for 287
# --- 7.64694619178772 seconds ---
# 20fold 3-sigma clipping for 288
# --- 7.642196416854858 seconds ---
# 20fold 3-sigma clipping for 289
# --- 7.551893949508667 seconds ---
# 20fold 3-sigma clipping for 290
# --- 7.462302207946777 seconds ---
# 20fold 3-sigma clipping for 291
# --- 7.640891075134277 seconds ---
# 20fold 3-sigma clipping for 292
# --- 7.656066417694092 seconds ---
# 20fold 3-sigma clipping for 293
# --- 7.658232927322388 seconds ---
# 20fold 3-sigma clipping for 294
# --- 7.528995037078857 seconds ---
# 20fold 3-sigma clipping for 295
# --- 7.469590425491333 seconds ---
# 20fold 3-sigma clipping for 296
# --- 7.632081508636475 seconds ---
# 20fold 3-sigma clipping for 297
# --- 7.656357049942017 seconds ---
# 20fold 3-sigma clipping for 298
# --- 7.661773204803467 seconds ---
# 20fold 3-sigma clipping for 299
# --- 7.517197132110596 seconds ---
# 20fold 3-sigma clipping for 300
# --- 7.447088241577148 seconds ---
# 20fold 3-sigma clipping for 301
# --- 7.616406679153442 seconds ---
# 20fold 3-sigma clipping for 302
# --- 7.657465934753418 seconds ---
# 20fold 3-sigma clipping for 303
# --- 7.659888982772827 seconds ---
# 20fold 3-sigma clipping for 304
# --- 7.529582262039185 seconds ---
# 20fold 3-sigma clipping for 305
# --- 7.466944456100464 seconds ---
# 20fold 3-sigma clipping for 306
# --- 7.6528894901275635 seconds ---
# 20fold 3-sigma clipping for 307
# --- 7.6860575675964355 seconds ---
# 20fold 3-sigma clipping for 308
# --- 7.673230886459351 seconds ---
# 20fold 3-sigma clipping for 309
# --- 7.553068161010742 seconds ---
# 20fold 3-sigma clipping for 310
# --- 7.480103254318237 seconds ---
# 20fold 3-sigma clipping for 311
# --- 7.641972780227661 seconds ---
# 20fold 3-sigma clipping for 312
# --- 7.676807165145874 seconds ---
# 20fold 3-sigma clipping for 313
# --- 7.677152633666992 seconds ---
# 20fold 3-sigma clipping for 314
# --- 7.540597915649414 seconds ---
# 20fold 3-sigma clipping for 315
# --- 7.461807012557983 seconds ---
# 20fold 3-sigma clipping for 316
# --- 7.640474557876587 seconds ---
# 20fold 3-sigma clipping for 317
# --- 7.668701887130737 seconds ---
# 20fold 3-sigma clipping for 318
# --- 7.654769420623779 seconds ---
# 20fold 3-sigma clipping for 319
# --- 8.445375204086304 seconds ---
# 20fold 3-sigma clipping for 320
# --- 8.614742279052734 seconds ---
# 20fold 3-sigma clipping for 321
# --- 8.805697441101074 seconds ---
# 20fold 3-sigma clipping for 322
# --- 7.6349852085113525 seconds ---
# 20fold 3-sigma clipping for 323
# --- 7.643481969833374 seconds ---
# 20fold 3-sigma clipping for 324
# --- 7.766116142272949 seconds ---
# 20fold 3-sigma clipping for 325
# --- 7.8783118724823 seconds ---
# 20fold 3-sigma clipping for 326
# --- 11.646155595779419 seconds ---
# 20fold 3-sigma clipping for 327
# --- 8.856973886489868 seconds ---
# 20fold 3-sigma clipping for 328
# --- 7.754591226577759 seconds ---
# 20fold 3-sigma clipping for 329
# --- 7.7354912757873535 seconds ---
# 20fold 3-sigma clipping for 330
# --- 7.597142934799194 seconds ---
# 20fold 3-sigma clipping for 331
# --- 7.739079475402832 seconds ---
# 20fold 3-sigma clipping for 332
# --- 7.750948905944824 seconds ---
# 20fold 3-sigma clipping for 333
# --- 7.799849271774292 seconds ---
# 20fold 3-sigma clipping for 334
# --- 7.798987150192261 seconds ---
# 20fold 3-sigma clipping for 335
# --- 7.611206531524658 seconds ---
# 20fold 3-sigma clipping for 336
# --- 7.758771181106567 seconds ---
# 20fold 3-sigma clipping for 337
# --- 7.780324459075928 seconds ---
# 20fold 3-sigma clipping for 338
# --- 7.776498079299927 seconds ---
# 20fold 3-sigma clipping for 339
# --- 7.822752952575684 seconds ---
# 20fold 3-sigma clipping for 340
# --- 7.635657072067261 seconds ---
# 20fold 3-sigma clipping for 341
# --- 7.773475170135498 seconds ---
# 20fold 3-sigma clipping for 342
# --- 7.7798686027526855 seconds ---
# 20fold 3-sigma clipping for 343
# --- 7.7956483364105225 seconds ---
# 20fold 3-sigma clipping for 344
# --- 7.795388221740723 seconds ---
# 20fold 3-sigma clipping for 345
# --- 7.598339319229126 seconds ---
# 20fold 3-sigma clipping for 346
# --- 7.760812759399414 seconds ---
# 20fold 3-sigma clipping for 347
# --- 7.746826887130737 seconds ---
# 20fold 3-sigma clipping for 348
# --- 7.779700756072998 seconds ---
# 20fold 3-sigma clipping for 349
# --- 7.755285739898682 seconds ---
# 20fold 3-sigma clipping for 350
# --- 7.606983423233032 seconds ---
# 20fold 3-sigma clipping for 351
# --- 7.810511350631714 seconds ---
# 20fold 3-sigma clipping for 352
# --- 7.722877502441406 seconds ---
# 20fold 3-sigma clipping for 353
# --- 7.76708197593689 seconds ---
# 20fold 3-sigma clipping for 354
# --- 7.738145112991333 seconds ---
# 20fold 3-sigma clipping for 355
# --- 7.591265916824341 seconds ---
# 20fold 3-sigma clipping for 356
# --- 7.716953754425049 seconds ---
# 20fold 3-sigma clipping for 357
# --- 7.7496747970581055 seconds ---
# 20fold 3-sigma clipping for 358
# --- 7.762495994567871 seconds ---
# 20fold 3-sigma clipping for 359
# --- 7.754268169403076 seconds ---
# 20fold 3-sigma clipping for 360
# --- 7.600131034851074 seconds ---
# 20fold 3-sigma clipping for 361
# --- 7.737115144729614 seconds ---
# 20fold 3-sigma clipping for 362
# --- 7.769817590713501 seconds ---
# 20fold 3-sigma clipping for 363
# --- 7.803368091583252 seconds ---
# 20fold 3-sigma clipping for 364
# --- 7.754374027252197 seconds ---
# 20fold 3-sigma clipping for 365
# --- 7.59818696975708 seconds ---
# 20fold 3-sigma clipping for 366
# --- 7.749173641204834 seconds ---
# 20fold 3-sigma clipping for 367
# --- 7.729105710983276 seconds ---
# 20fold 3-sigma clipping for 368
# --- 7.772305727005005 seconds ---
# 20fold 3-sigma clipping for 369
# --- 7.767387628555298 seconds ---
# 20fold 3-sigma clipping for 370
# --- 7.6246657371521 seconds ---
# 20fold 3-sigma clipping for 371
# --- 7.745378017425537 seconds ---
# 20fold 3-sigma clipping for 372
# --- 7.740720748901367 seconds ---
# 20fold 3-sigma clipping for 373
# --- 7.776656866073608 seconds ---
# 20fold 3-sigma clipping for 374
# --- 7.7626190185546875 seconds ---
# 20fold 3-sigma clipping for 375
# --- 7.6069934368133545 seconds ---
# 20fold 3-sigma clipping for 376
# --- 7.726718187332153 seconds ---
# 20fold 3-sigma clipping for 377
# --- 7.7202582359313965 seconds ---
# 20fold 3-sigma clipping for 378
# --- 7.771597385406494 seconds ---
# 20fold 3-sigma clipping for 379
# --- 7.747185468673706 seconds ---
# 20fold 3-sigma clipping for 380
# --- 7.588536739349365 seconds ---
# 20fold 3-sigma clipping for 381
# --- 7.730167388916016 seconds ---
# 20fold 3-sigma clipping for 382
# --- 7.770468473434448 seconds ---
# 20fold 3-sigma clipping for 383
# --- 7.784894704818726 seconds ---
# 20fold 3-sigma clipping for 384
# --- 7.846555948257446 seconds ---
# 20fold 3-sigma clipping for 385
# --- 7.644422292709351 seconds ---
# 20fold 3-sigma clipping for 386
# --- 7.769671678543091 seconds ---
# 20fold 3-sigma clipping for 387
# --- 7.775879859924316 seconds ---
# 20fold 3-sigma clipping for 388
# --- 7.803498029708862 seconds ---
# 20fold 3-sigma clipping for 389
# --- 7.772007942199707 seconds ---
# 20fold 3-sigma clipping for 390
# --- 7.605212211608887 seconds ---
# 20fold 3-sigma clipping for 391
# --- 7.769811153411865 seconds ---
# 20fold 3-sigma clipping for 392
# --- 7.800574541091919 seconds ---
# 20fold 3-sigma clipping for 393
# --- 7.814360618591309 seconds ---
# 20fold 3-sigma clipping for 394
# --- 7.808665990829468 seconds ---
# 20fold 3-sigma clipping for 395
# --- 7.630713701248169 seconds ---
# 20fold 3-sigma clipping for 396
# --- 7.784839391708374 seconds ---
# 20fold 3-sigma clipping for 397
# --- 7.7803053855896 seconds ---
# 20fold 3-sigma clipping for 398
# --- 7.7978973388671875 seconds ---
# 20fold 3-sigma clipping for 399
# --- 7.7801148891448975 seconds ---
# 20fold 3-sigma clipping for 400
# --- 7.618531942367554 seconds ---
# 20fold 3-sigma clipping for 401
# --- 7.757375478744507 seconds ---
# 20fold 3-sigma clipping for 402
# --- 7.76945161819458 seconds ---
# 20fold 3-sigma clipping for 403
# --- 7.798565626144409 seconds ---
# 20fold 3-sigma clipping for 404
# --- 7.777147054672241 seconds ---
# 20fold 3-sigma clipping for 405
# --- 7.6334228515625 seconds ---
# 20fold 3-sigma clipping for 406
# --- 7.755737066268921 seconds ---
# 20fold 3-sigma clipping for 407
# --- 7.760626316070557 seconds ---
# 20fold 3-sigma clipping for 408
# --- 7.7761054039001465 seconds ---
# 20fold 3-sigma clipping for 409
# --- 7.764491558074951 seconds ---
# 20fold 3-sigma clipping for 410
# --- 7.621697902679443 seconds ---
# 20fold 3-sigma clipping for 411
# --- 7.746532917022705 seconds ---
# 20fold 3-sigma clipping for 412
# --- 7.772177696228027 seconds ---
# 20fold 3-sigma clipping for 413
# --- 7.78290319442749 seconds ---
# 20fold 3-sigma clipping for 414
# --- 7.750131130218506 seconds ---
# 20fold 3-sigma clipping for 415
# --- 7.611223936080933 seconds ---
# 20fold 3-sigma clipping for 416
# --- 7.751236200332642 seconds ---
# 20fold 3-sigma clipping for 417
# --- 7.752625465393066 seconds ---
# 20fold 3-sigma clipping for 418
# --- 7.7668492794036865 seconds ---
# 20fold 3-sigma clipping for 419
# --- 7.7773356437683105 seconds ---
# 20fold 3-sigma clipping for 420
# --- 7.610695838928223 seconds ---
# 20fold 3-sigma clipping for 421
# --- 7.768842935562134 seconds ---
# 20fold 3-sigma clipping for 422
# --- 7.757879257202148 seconds ---
# 20fold 3-sigma clipping for 423
# --- 7.783918857574463 seconds ---
# 20fold 3-sigma clipping for 424
# --- 7.758584976196289 seconds ---
# 20fold 3-sigma clipping for 425
# --- 7.589479684829712 seconds ---
# 20fold 3-sigma clipping for 426
# --- 7.74854302406311 seconds ---
# 20fold 3-sigma clipping for 427
# --- 7.7280755043029785 seconds ---
# 20fold 3-sigma clipping for 428
# --- 7.7556374073028564 seconds ---
# 20fold 3-sigma clipping for 429
# --- 7.722767114639282 seconds ---
# 20fold 3-sigma clipping for 430
# --- 7.5826194286346436 seconds ---
# 20fold 3-sigma clipping for 431
# --- 7.721960544586182 seconds ---
# 20fold 3-sigma clipping for 432
# --- 7.734510898590088 seconds ---
# 20fold 3-sigma clipping for 433
# --- 7.790914058685303 seconds ---
# 20fold 3-sigma clipping for 434
# --- 7.756586313247681 seconds ---
# 20fold 3-sigma clipping for 435
# --- 7.5930335521698 seconds ---
# 20fold 3-sigma clipping for 436
# --- 7.733479976654053 seconds ---
# 20fold 3-sigma clipping for 437
# --- 7.762261629104614 seconds ---
# 20fold 3-sigma clipping for 438
# --- 7.749155759811401 seconds ---
# 20fold 3-sigma clipping for 439
# --- 7.742603540420532 seconds ---
# 20fold 3-sigma clipping for 440
# --- 7.581202268600464 seconds ---
# 20fold 3-sigma clipping for 441
# --- 7.73425817489624 seconds ---
# 20fold 3-sigma clipping for 442
# --- 7.751703262329102 seconds ---
# 20fold 3-sigma clipping for 443
# --- 7.7619805335998535 seconds ---
# 20fold 3-sigma clipping for 444
# --- 7.756913185119629 seconds ---
# 20fold 3-sigma clipping for 445
# --- 7.600549221038818 seconds ---
# 20fold 3-sigma clipping for 446
# --- 7.740794658660889 seconds ---
# 20fold 3-sigma clipping for 447
# --- 7.728670120239258 seconds ---
# 20fold 3-sigma clipping for 448
# --- 7.788628578186035 seconds ---
# 20fold 3-sigma clipping for 449
# --- 7.783786296844482 seconds ---
# 20fold 3-sigma clipping for 450
# --- 7.606595754623413 seconds ---
# 20fold 3-sigma clipping for 451
# --- 7.7133708000183105 seconds ---
# 20fold 3-sigma clipping for 452
# --- 7.746647596359253 seconds ---
# 20fold 3-sigma clipping for 453
# --- 7.767375469207764 seconds ---
# 20fold 3-sigma clipping for 454
# --- 7.745010852813721 seconds ---
# 20fold 3-sigma clipping for 455
# --- 7.622889280319214 seconds ---
# 20fold 3-sigma clipping for 456
# --- 7.7573018074035645 seconds ---
# 20fold 3-sigma clipping for 457
# --- 7.757684230804443 seconds ---
# 20fold 3-sigma clipping for 458
# --- 7.78645920753479 seconds ---
# 20fold 3-sigma clipping for 459
# --- 7.727433204650879 seconds ---
# 20fold 3-sigma clipping for 460
# --- 7.5856945514678955 seconds ---
# 20fold 3-sigma clipping for 461
# --- 7.74970555305481 seconds ---
# 20fold 3-sigma clipping for 462
# --- 7.751006603240967 seconds ---
# 20fold 3-sigma clipping for 463
# --- 7.768015623092651 seconds ---
# 20fold 3-sigma clipping for 464
# --- 7.758106708526611 seconds ---
# 20fold 3-sigma clipping for 465
# --- 7.55554461479187 seconds ---
# 20fold 3-sigma clipping for 466
# --- 7.732016324996948 seconds ---
# 20fold 3-sigma clipping for 467
# --- 7.739322185516357 seconds ---
# 20fold 3-sigma clipping for 468
# --- 7.775862455368042 seconds ---
# 20fold 3-sigma clipping for 469
# --- 7.76195216178894 seconds ---
# 20fold 3-sigma clipping for 470
# --- 7.606997489929199 seconds ---
# 20fold 3-sigma clipping for 471
# --- 7.750306129455566 seconds ---
# 20fold 3-sigma clipping for 472
# --- 7.741258859634399 seconds ---
# 20fold 3-sigma clipping for 473
# --- 7.751797437667847 seconds ---
# 20fold 3-sigma clipping for 474
# --- 7.751760244369507 seconds ---
# 20fold 3-sigma clipping for 475
# --- 7.5816004276275635 seconds ---
# 20fold 3-sigma clipping for 476
# --- 7.738395690917969 seconds ---
# 20fold 3-sigma clipping for 477
# --- 7.747679710388184 seconds ---
# 20fold 3-sigma clipping for 478
# --- 7.75389552116394 seconds ---
# 20fold 3-sigma clipping for 479
# --- 7.748422384262085 seconds ---
# 20fold 3-sigma clipping for 480
# --- 7.613131761550903 seconds ---
# 20fold 3-sigma clipping for 481
# --- 7.747006416320801 seconds ---
# 20fold 3-sigma clipping for 482
# --- 7.749118328094482 seconds ---
# 20fold 3-sigma clipping for 483
# --- 7.791114330291748 seconds ---
# 20fold 3-sigma clipping for 484
# --- 7.751118421554565 seconds ---
# 20fold 3-sigma clipping for 485
# --- 7.599841833114624 seconds ---
# 20fold 3-sigma clipping for 486
# --- 7.73877477645874 seconds ---
# 20fold 3-sigma clipping for 487
# --- 7.748701572418213 seconds ---
# 20fold 3-sigma clipping for 488
# --- 7.785588979721069 seconds ---
# 20fold 3-sigma clipping for 489
# --- 7.746079206466675 seconds ---
# 20fold 3-sigma clipping for 490
# --- 7.589579820632935 seconds ---
# 20fold 3-sigma clipping for 491
# --- 7.729939937591553 seconds ---
# 20fold 3-sigma clipping for 492
# --- 7.757779359817505 seconds ---
# 20fold 3-sigma clipping for 493
# --- 7.774100303649902 seconds ---
# 20fold 3-sigma clipping for 494
# --- 7.772927284240723 seconds ---
# 20fold 3-sigma clipping for 495
# --- 7.6011035442352295 seconds ---
# 20fold 3-sigma clipping for 496
# --- 7.754434823989868 seconds ---
# 20fold 3-sigma clipping for 497
# --- 7.77018666267395 seconds ---
# 20fold 3-sigma clipping for 498
# --- 7.761798143386841 seconds ---
# 20fold 3-sigma clipping for 499
# --- 7.7652587890625 seconds ---
# 20fold 3-sigma clipping for 500
# --- 7.597686290740967 seconds ---
# 20fold 3-sigma clipping for 501
# --- 7.754267930984497 seconds ---
# 20fold 3-sigma clipping for 502
# --- 7.756195545196533 seconds ---
# 20fold 3-sigma clipping for 503
# --- 7.780524492263794 seconds ---
# 20fold 3-sigma clipping for 504
# --- 7.772530555725098 seconds ---
# 20fold 3-sigma clipping for 505
# --- 7.606752157211304 seconds ---
# 20fold 3-sigma clipping for 506
# --- 7.74880576133728 seconds ---
# 20fold 3-sigma clipping for 507
# --- 7.748493909835815 seconds ---
# 20fold 3-sigma clipping for 508
# --- 7.787612676620483 seconds ---
# 20fold 3-sigma clipping for 509
# --- 7.755346059799194 seconds ---
# 20fold 3-sigma clipping for 510
# --- 7.597736597061157 seconds ---
# 20fold 3-sigma clipping for 511
# --- 7.770265102386475 seconds ---
# 20fold 3-sigma clipping for 512
# --- 7.806180477142334 seconds ---
# 20fold 3-sigma clipping for 513
# --- 7.81126070022583 seconds ---
# 20fold 3-sigma clipping for 514
# --- 7.775001764297485 seconds ---
# 20fold 3-sigma clipping for 515
# --- 7.614049434661865 seconds ---
# 20fold 3-sigma clipping for 516
# --- 7.751356840133667 seconds ---
# 20fold 3-sigma clipping for 517
# --- 7.783918619155884 seconds ---
# 20fold 3-sigma clipping for 518
# --- 7.804877519607544 seconds ---
# 20fold 3-sigma clipping for 519
# --- 7.80603814125061 seconds ---
# 20fold 3-sigma clipping for 520
# --- 7.638021230697632 seconds ---
# 20fold 3-sigma clipping for 521
# --- 7.779987812042236 seconds ---
# 20fold 3-sigma clipping for 522
# --- 7.7857794761657715 seconds ---
# 20fold 3-sigma clipping for 523
# --- 7.8131561279296875 seconds ---
# 20fold 3-sigma clipping for 524
# --- 7.776061773300171 seconds ---
# 20fold 3-sigma clipping for 525
# --- 7.602893829345703 seconds ---
# 20fold 3-sigma clipping for 526
# --- 7.739418268203735 seconds ---
# 20fold 3-sigma clipping for 527
# --- 7.75193452835083 seconds ---
# 20fold 3-sigma clipping for 528
# --- 7.788747310638428 seconds ---
# 20fold 3-sigma clipping for 529
# --- 7.766156435012817 seconds ---
# 20fold 3-sigma clipping for 530
# --- 7.603918075561523 seconds ---
# 20fold 3-sigma clipping for 531
# --- 7.761126279830933 seconds ---
# 20fold 3-sigma clipping for 532
# --- 7.757867813110352 seconds ---
# 20fold 3-sigma clipping for 533
# --- 7.781064748764038 seconds ---
# 20fold 3-sigma clipping for 534
# --- 7.755442142486572 seconds ---
# 20fold 3-sigma clipping for 535
# --- 7.599696636199951 seconds ---
# 20fold 3-sigma clipping for 536
# --- 7.745062589645386 seconds ---
# 20fold 3-sigma clipping for 537
# --- 7.762418508529663 seconds ---
# 20fold 3-sigma clipping for 538
# --- 7.823788166046143 seconds ---
# 20fold 3-sigma clipping for 539
# --- 7.769322156906128 seconds ---
# 20fold 3-sigma clipping for 540
# --- 7.625243425369263 seconds ---
# 20fold 3-sigma clipping for 541
# --- 7.754128694534302 seconds ---
# 20fold 3-sigma clipping for 542
# --- 7.757354497909546 seconds ---
# 20fold 3-sigma clipping for 543
# --- 7.79722785949707 seconds ---
# 20fold 3-sigma clipping for 544
# --- 7.762775897979736 seconds ---
# 20fold 3-sigma clipping for 545
# --- 7.615872859954834 seconds ---
# 20fold 3-sigma clipping for 546
# --- 7.7633209228515625 seconds ---
# 20fold 3-sigma clipping for 547
# --- 7.763076305389404 seconds ---
# 20fold 3-sigma clipping for 548
# --- 7.756105899810791 seconds ---
# 20fold 3-sigma clipping for 549
# --- 7.747328519821167 seconds ---
# 20fold 3-sigma clipping for 550
# --- 7.586877822875977 seconds ---
# 20fold 3-sigma clipping for 551
# --- 7.739756345748901 seconds ---
# 20fold 3-sigma clipping for 552
# --- 7.7461230754852295 seconds ---
# 20fold 3-sigma clipping for 553
# --- 7.7878851890563965 seconds ---
# 20fold 3-sigma clipping for 554
# --- 7.74109411239624 seconds ---
# 20fold 3-sigma clipping for 555
# --- 7.586585760116577 seconds ---
# 20fold 3-sigma clipping for 556
# --- 7.734330415725708 seconds ---
# 20fold 3-sigma clipping for 557
# --- 7.717664957046509 seconds ---
# 20fold 3-sigma clipping for 558
# --- 7.773885250091553 seconds ---
# 20fold 3-sigma clipping for 559
# --- 7.748500823974609 seconds ---
# 20fold 3-sigma clipping for 560
# --- 7.575031995773315 seconds ---
# 20fold 3-sigma clipping for 561
# --- 7.742485284805298 seconds ---
# 20fold 3-sigma clipping for 562
# --- 7.757398843765259 seconds ---
# 20fold 3-sigma clipping for 563
# --- 7.789953708648682 seconds ---
# 20fold 3-sigma clipping for 564
# --- 7.7507405281066895 seconds ---
# 20fold 3-sigma clipping for 565
# --- 7.577257871627808 seconds ---
# 20fold 3-sigma clipping for 566
# --- 7.740103006362915 seconds ---
# 20fold 3-sigma clipping for 567
# --- 7.755575656890869 seconds ---
# 20fold 3-sigma clipping for 568
# --- 7.774157762527466 seconds ---
# 20fold 3-sigma clipping for 569
# --- 7.761126279830933 seconds ---
# 20fold 3-sigma clipping for 570
# --- 7.605954170227051 seconds ---
# 20fold 3-sigma clipping for 571
# --- 7.751835823059082 seconds ---
# 20fold 3-sigma clipping for 572
# --- 7.757810831069946 seconds ---
# 20fold 3-sigma clipping for 573
# --- 7.780592441558838 seconds ---
# 20fold 3-sigma clipping for 574
# --- 7.757124423980713 seconds ---
# 20fold 3-sigma clipping for 575
# --- 7.605169057846069 seconds ---
# 20fold 3-sigma clipping for 576
# --- 7.76165509223938 seconds ---
# 20fold 3-sigma clipping for 577
# --- 7.753737926483154 seconds ---
# 20fold 3-sigma clipping for 578
# --- 7.789507150650024 seconds ---
# 20fold 3-sigma clipping for 579
# --- 7.769901752471924 seconds ---
# 20fold 3-sigma clipping for 580
# --- 7.59899377822876 seconds ---
# 20fold 3-sigma clipping for 581
# --- 7.770141124725342 seconds ---
# 20fold 3-sigma clipping for 582
# --- 7.801473379135132 seconds ---
# 20fold 3-sigma clipping for 583
# --- 7.791400909423828 seconds ---
# 20fold 3-sigma clipping for 584
# --- 7.76633358001709 seconds ---
# 20fold 3-sigma clipping for 585
# --- 7.6132731437683105 seconds ---
# 20fold 3-sigma clipping for 586
# --- 7.789198875427246 seconds ---
# 20fold 3-sigma clipping for 587
# --- 7.790892601013184 seconds ---
# 20fold 3-sigma clipping for 588
# --- 7.778458118438721 seconds ---
# 20fold 3-sigma clipping for 589
# --- 7.734246730804443 seconds ---
# 20fold 3-sigma clipping for 590
# --- 7.611870527267456 seconds ---
# 20fold 3-sigma clipping for 591
# --- 7.765239000320435 seconds ---
# 20fold 3-sigma clipping for 592
# --- 7.759087085723877 seconds ---
# 20fold 3-sigma clipping for 593
# --- 7.776098966598511 seconds ---
# 20fold 3-sigma clipping for 594
# --- 7.755342245101929 seconds ---
# 20fold 3-sigma clipping for 595
# --- 7.567738771438599 seconds ---
# 20fold 3-sigma clipping for 596
# --- 7.603045463562012 seconds ---
# 20fold 3-sigma clipping for 597
# --- 7.620555877685547 seconds ---
# 20fold 3-sigma clipping for 598
# --- 7.640766859054565 seconds ---
# 20fold 3-sigma clipping for 599
# --- 7.617326498031616 seconds ---
# 20fold 3-sigma clipping for 600
# --- 7.482319116592407 seconds ---
# 20fold 3-sigma clipping for 601
# --- 7.624967813491821 seconds ---
# 20fold 3-sigma clipping for 602
# --- 7.60400128364563 seconds ---
# 20fold 3-sigma clipping for 603
# --- 7.631937026977539 seconds ---
# 20fold 3-sigma clipping for 604
# --- 7.6173951625823975 seconds ---
# 20fold 3-sigma clipping for 605
# --- 7.487541437149048 seconds ---
# 20fold 3-sigma clipping for 606
# --- 7.60242772102356 seconds ---
# 20fold 3-sigma clipping for 607
# --- 7.631648302078247 seconds ---
# 20fold 3-sigma clipping for 608
# --- 7.635437488555908 seconds ---
# 20fold 3-sigma clipping for 609
# --- 7.6121649742126465 seconds ---
# 20fold 3-sigma clipping for 610
# --- 7.47686505317688 seconds ---
# 20fold 3-sigma clipping for 611
# --- 7.614776849746704 seconds ---
# 20fold 3-sigma clipping for 612
# --- 7.617918014526367 seconds ---
# 20fold 3-sigma clipping for 613
# --- 7.648665189743042 seconds ---
# 20fold 3-sigma clipping for 614
# --- 7.590181827545166 seconds ---
# 20fold 3-sigma clipping for 615
# --- 7.465883493423462 seconds ---
# 20fold 3-sigma clipping for 616
# --- 7.599839210510254 seconds ---
# 20fold 3-sigma clipping for 617
# --- 7.601533651351929 seconds ---
# 20fold 3-sigma clipping for 618
# --- 7.636847972869873 seconds ---
# 20fold 3-sigma clipping for 619
# --- 7.614795207977295 seconds ---
# 20fold 3-sigma clipping for 620
# --- 7.462955713272095 seconds ---
# 20fold 3-sigma clipping for 621
# --- 7.622851133346558 seconds ---
# 20fold 3-sigma clipping for 622
# --- 7.628246784210205 seconds ---
# 20fold 3-sigma clipping for 623
# --- 7.639535903930664 seconds ---
# 20fold 3-sigma clipping for 624
# --- 7.625460386276245 seconds ---
# 20fold 3-sigma clipping for 625
# --- 7.49558687210083 seconds ---
# 20fold 3-sigma clipping for 626
# --- 7.615485191345215 seconds ---
# 20fold 3-sigma clipping for 627
# --- 7.611891269683838 seconds ---
# 20fold 3-sigma clipping for 628
# --- 7.628456115722656 seconds ---
# 20fold 3-sigma clipping for 629
# --- 7.622072219848633 seconds ---
# 20fold 3-sigma clipping for 630
# --- 7.463188886642456 seconds ---
# 20fold 3-sigma clipping for 631
# --- 7.599546432495117 seconds ---
# 20fold 3-sigma clipping for 632
# --- 7.6088478565216064 seconds ---
# 20fold 3-sigma clipping for 633
# --- 7.634347677230835 seconds ---
# 20fold 3-sigma clipping for 634
# --- 7.627835512161255 seconds ---
# 20fold 3-sigma clipping for 635
# --- 7.4580442905426025 seconds ---
# 20fold 3-sigma clipping for 636
# --- 7.59431791305542 seconds ---
# 20fold 3-sigma clipping for 637
# --- 7.605915784835815 seconds ---
# 20fold 3-sigma clipping for 638
# --- 7.649409532546997 seconds ---
# 20fold 3-sigma clipping for 639
# --- 7.630784273147583 seconds ---
# 20fold 3-sigma clipping for 640
# --- 7.468060493469238 seconds ---
# 20fold 3-sigma clipping for 641
# --- 7.612870454788208 seconds ---
# 20fold 3-sigma clipping for 642
# --- 7.6171555519104 seconds ---
# 20fold 3-sigma clipping for 643
# --- 7.624664306640625 seconds ---
# 20fold 3-sigma clipping for 644
# --- 7.625909090042114 seconds ---
# 20fold 3-sigma clipping for 645
# --- 7.482471942901611 seconds ---
# 20fold 3-sigma clipping for 646
# --- 7.603837251663208 seconds ---
# 20fold 3-sigma clipping for 647
# --- 7.630213975906372 seconds ---
# 20fold 3-sigma clipping for 648
# --- 7.645540714263916 seconds ---
# 20fold 3-sigma clipping for 649
# --- 7.624799728393555 seconds ---
# 20fold 3-sigma clipping for 650
# --- 7.475665092468262 seconds ---
# 20fold 3-sigma clipping for 651
# --- 7.624709606170654 seconds ---
# 20fold 3-sigma clipping for 652
# --- 7.634458303451538 seconds ---
# 20fold 3-sigma clipping for 653
# --- 7.6485607624053955 seconds ---
# 20fold 3-sigma clipping for 654
# --- 7.639882564544678 seconds ---
# 20fold 3-sigma clipping for 655
# --- 7.485163450241089 seconds ---
# 20fold 3-sigma clipping for 656
# --- 7.599606275558472 seconds ---
# 20fold 3-sigma clipping for 657
# --- 7.611745595932007 seconds ---
# 20fold 3-sigma clipping for 658
# --- 7.620062828063965 seconds ---
# 20fold 3-sigma clipping for 659
# --- 7.618531703948975 seconds ---
# 20fold 3-sigma clipping for 660
# --- 7.468043327331543 seconds ---
# 20fold 3-sigma clipping for 661
# --- 7.6157066822052 seconds ---
# 20fold 3-sigma clipping for 662
# --- 7.598694562911987 seconds ---
# 20fold 3-sigma clipping for 663
# --- 7.633335590362549 seconds ---
# 20fold 3-sigma clipping for 664
# --- 7.623671293258667 seconds ---
# 20fold 3-sigma clipping for 665
# --- 7.446928262710571 seconds ---
# 20fold 3-sigma clipping for 666
# --- 7.609898805618286 seconds ---
# 20fold 3-sigma clipping for 667
# --- 7.611196041107178 seconds ---
# 20fold 3-sigma clipping for 668
# --- 7.626775503158569 seconds ---
# 20fold 3-sigma clipping for 669
# --- 7.608330488204956 seconds ---
# 20fold 3-sigma clipping for 670
# --- 7.465024471282959 seconds ---
# 20fold 3-sigma clipping for 671
# --- 7.596773386001587 seconds ---
# 20fold 3-sigma clipping for 672
# --- 7.606950521469116 seconds ---
# 20fold 3-sigma clipping for 673
# --- 7.62385630607605 seconds ---
# 20fold 3-sigma clipping for 674
# --- 7.608505487442017 seconds ---
# 20fold 3-sigma clipping for 675
# --- 7.447911500930786 seconds ---
# 20fold 3-sigma clipping for 676
# --- 7.588292598724365 seconds ---
# 20fold 3-sigma clipping for 677
# --- 7.6215925216674805 seconds ---
# 20fold 3-sigma clipping for 678
# --- 7.621321678161621 seconds ---
# 20fold 3-sigma clipping for 679
# --- 7.5867760181427 seconds ---
# 20fold 3-sigma clipping for 680
# --- 7.452255010604858 seconds ---
# 20fold 3-sigma clipping for 681
# --- 7.597646713256836 seconds ---
# 20fold 3-sigma clipping for 682
# --- 7.6051857471466064 seconds ---
# 20fold 3-sigma clipping for 683
# --- 7.614301443099976 seconds ---
# 20fold 3-sigma clipping for 684
# --- 7.599014520645142 seconds ---
# 20fold 3-sigma clipping for 685
# --- 7.429142713546753 seconds ---
# 20fold 3-sigma clipping for 686
# --- 7.585488557815552 seconds ---
# 20fold 3-sigma clipping for 687
# --- 7.603742837905884 seconds ---
# 20fold 3-sigma clipping for 688
# --- 7.617254257202148 seconds ---
# 20fold 3-sigma clipping for 689
# --- 7.617462396621704 seconds ---
# 20fold 3-sigma clipping for 690
# --- 7.453113079071045 seconds ---
# 20fold 3-sigma clipping for 691
# --- 7.611301422119141 seconds ---
# 20fold 3-sigma clipping for 692
# --- 7.592216491699219 seconds ---
# 20fold 3-sigma clipping for 693
# --- 7.615004301071167 seconds ---
# 20fold 3-sigma clipping for 694
# --- 7.609209060668945 seconds ---
# 20fold 3-sigma clipping for 695
# --- 7.464226961135864 seconds ---
# 20fold 3-sigma clipping for 696
# --- 7.623176336288452 seconds ---
# 20fold 3-sigma clipping for 697
# --- 7.611911773681641 seconds ---
# 20fold 3-sigma clipping for 698
# --- 7.633896827697754 seconds ---
# 20fold 3-sigma clipping for 699
# --- 7.5956621170043945 seconds ---
# 20fold 3-sigma clipping for 700
# --- 7.443118095397949 seconds ---
# 20fold 3-sigma clipping for 701
# --- 7.6047961711883545 seconds ---
# 20fold 3-sigma clipping for 702
# --- 7.613383531570435 seconds ---
# 20fold 3-sigma clipping for 703
# --- 7.616932392120361 seconds ---
# 20fold 3-sigma clipping for 704
# --- 7.610896110534668 seconds ---
# 20fold 3-sigma clipping for 705
# --- 7.469053506851196 seconds ---
# 20fold 3-sigma clipping for 706
# --- 7.609245300292969 seconds ---
# 20fold 3-sigma clipping for 707
# --- 7.611797332763672 seconds ---
# 20fold 3-sigma clipping for 708
# --- 7.638812780380249 seconds ---
# 20fold 3-sigma clipping for 709
# --- 7.627640962600708 seconds ---
# 20fold 3-sigma clipping for 710
# --- 7.484425067901611 seconds ---
# 20fold 3-sigma clipping for 711
# --- 7.631325721740723 seconds ---
# 20fold 3-sigma clipping for 712
# --- 7.616044521331787 seconds ---
# 20fold 3-sigma clipping for 713
# --- 7.638378858566284 seconds ---
# 20fold 3-sigma clipping for 714
# --- 7.6257545948028564 seconds ---
# 20fold 3-sigma clipping for 715
# --- 7.463105916976929 seconds ---
# 20fold 3-sigma clipping for 716
# --- 7.630186319351196 seconds ---
# 20fold 3-sigma clipping for 717
# --- 7.631550312042236 seconds ---
# 20fold 3-sigma clipping for 718
# --- 7.637337923049927 seconds ---
# 20fold 3-sigma clipping for 719
# --- 7.622519016265869 seconds ---
# 20fold 3-sigma clipping for 720
# --- 7.474865436553955 seconds ---
# 20fold 3-sigma clipping for 721
# --- 7.625607013702393 seconds ---
# 20fold 3-sigma clipping for 722
# --- 7.61435079574585 seconds ---
# 20fold 3-sigma clipping for 723
# --- 7.652097225189209 seconds ---
# 20fold 3-sigma clipping for 724
# --- 7.637597560882568 seconds ---
# 20fold 3-sigma clipping for 725
# --- 7.444492816925049 seconds ---
# 20fold 3-sigma clipping for 726
# --- 7.597806215286255 seconds ---
# 20fold 3-sigma clipping for 727
# --- 7.625958681106567 seconds ---
# 20fold 3-sigma clipping for 728
# --- 7.643582105636597 seconds ---
# 20fold 3-sigma clipping for 729
# --- 7.637224197387695 seconds ---
# 20fold 3-sigma clipping for 730
# --- 7.501842498779297 seconds ---
# 20fold 3-sigma clipping for 731
# --- 7.624065399169922 seconds ---
# 20fold 3-sigma clipping for 732
# --- 7.617164850234985 seconds ---
# 20fold 3-sigma clipping for 733
# --- 7.604203701019287 seconds ---
# 20fold 3-sigma clipping for 734
# --- 7.60804557800293 seconds ---
# 20fold 3-sigma clipping for 735
# --- 7.4902870655059814 seconds ---
# 20fold 3-sigma clipping for 736
# --- 7.610741138458252 seconds ---
# 20fold 3-sigma clipping for 737
# --- 7.627708673477173 seconds ---
# 20fold 3-sigma clipping for 738
# --- 7.641958236694336 seconds ---
# 20fold 3-sigma clipping for 739
# --- 7.629636764526367 seconds ---
# 20fold 3-sigma clipping for 740
# --- 7.498122692108154 seconds ---
# 20fold 3-sigma clipping for 741
# --- 7.643701791763306 seconds ---
# 20fold 3-sigma clipping for 742
# --- 7.635117769241333 seconds ---
# 20fold 3-sigma clipping for 743
# --- 7.642786741256714 seconds ---
# 20fold 3-sigma clipping for 744
# --- 7.629437208175659 seconds ---
# 20fold 3-sigma clipping for 745
# --- 7.473919868469238 seconds ---
# 20fold 3-sigma clipping for 746
# --- 7.6197521686553955 seconds ---
# 20fold 3-sigma clipping for 747
# --- 7.614053249359131 seconds ---
# 20fold 3-sigma clipping for 748
# --- 7.672130584716797 seconds ---
# 20fold 3-sigma clipping for 749
# --- 7.639442205429077 seconds ---
# 20fold 3-sigma clipping for 750
# --- 7.473252534866333 seconds ---
# 20fold 3-sigma clipping for 751
# --- 7.608654260635376 seconds ---
# 20fold 3-sigma clipping for 752
# --- 7.626063823699951 seconds ---
# 20fold 3-sigma clipping for 753
# --- 7.645345211029053 seconds ---
# 20fold 3-sigma clipping for 754
# --- 7.622481107711792 seconds ---
# 20fold 3-sigma clipping for 755
# --- 7.505927085876465 seconds ---
# 20fold 3-sigma clipping for 756
# --- 7.625593900680542 seconds ---
# 20fold 3-sigma clipping for 757
# --- 7.635282516479492 seconds ---
# 20fold 3-sigma clipping for 758
# --- 7.652923345565796 seconds ---
# 20fold 3-sigma clipping for 759
# --- 7.645533800125122 seconds ---
# 20fold 3-sigma clipping for 760
# --- 7.463414669036865 seconds ---
# 20fold 3-sigma clipping for 761
# --- 7.617961168289185 seconds ---
# 20fold 3-sigma clipping for 762
# --- 7.615463733673096 seconds ---
# 20fold 3-sigma clipping for 763
# --- 7.655834674835205 seconds ---
# 20fold 3-sigma clipping for 764
# --- 7.6287713050842285 seconds ---
# 20fold 3-sigma clipping for 765
# --- 7.478033542633057 seconds ---
# 20fold 3-sigma clipping for 766
# --- 7.617539405822754 seconds ---
# 20fold 3-sigma clipping for 767
# --- 7.637349605560303 seconds ---
# 20fold 3-sigma clipping for 768
# --- 7.63451886177063 seconds ---
# 20fold 3-sigma clipping for 769
# --- 7.622044563293457 seconds ---
# 20fold 3-sigma clipping for 770
# --- 7.467094659805298 seconds ---
# 20fold 3-sigma clipping for 771
# --- 7.620045185089111 seconds ---
# 20fold 3-sigma clipping for 772
# --- 7.604663372039795 seconds ---
# 20fold 3-sigma clipping for 773
# --- 7.637941598892212 seconds ---
# 20fold 3-sigma clipping for 774
# --- 7.633415222167969 seconds ---
# 20fold 3-sigma clipping for 775
# --- 7.487592935562134 seconds ---
# 20fold 3-sigma clipping for 776
# --- 7.617627143859863 seconds ---
# 20fold 3-sigma clipping for 777
# --- 7.637815952301025 seconds ---
# 20fold 3-sigma clipping for 778
# --- 7.6755218505859375 seconds ---
# 20fold 3-sigma clipping for 779
# --- 7.6289660930633545 seconds ---
# 20fold 3-sigma clipping for 780
# --- 7.511655330657959 seconds ---
# 20fold 3-sigma clipping for 781
# --- 7.658585786819458 seconds ---
# 20fold 3-sigma clipping for 782
# --- 7.657544374465942 seconds ---
# 20fold 3-sigma clipping for 783
# --- 7.660710573196411 seconds ---
# 20fold 3-sigma clipping for 784
# --- 7.627198934555054 seconds ---
# 20fold 3-sigma clipping for 785
# --- 7.502055644989014 seconds ---
# 20fold 3-sigma clipping for 786
# --- 7.644394397735596 seconds ---
# 20fold 3-sigma clipping for 787
# --- 7.645674705505371 seconds ---
# 20fold 3-sigma clipping for 788
# --- 7.6631760597229 seconds ---
# 20fold 3-sigma clipping for 789
# --- 7.652997970581055 seconds ---
# 20fold 3-sigma clipping for 790
# --- 7.505625009536743 seconds ---
# 20fold 3-sigma clipping for 791
# --- 7.651881217956543 seconds ---
# 20fold 3-sigma clipping for 792
# --- 7.646653890609741 seconds ---
# 20fold 3-sigma clipping for 793
# --- 7.685391902923584 seconds ---
# 20fold 3-sigma clipping for 794
# --- 7.677933692932129 seconds ---
# 20fold 3-sigma clipping for 795
# --- 7.488129377365112 seconds ---
# 20fold 3-sigma clipping for 796
# --- 7.67223334312439 seconds ---
# 20fold 3-sigma clipping for 797
# --- 7.672457695007324 seconds ---
# 20fold 3-sigma clipping for 798
# --- 7.681509733200073 seconds ---
# 20fold 3-sigma clipping for 799
# --- 7.675755023956299 seconds ---
# 20fold 3-sigma clipping for 800
# --- 7.503058433532715 seconds ---
# 20fold 3-sigma clipping for 801
# --- 7.640499114990234 seconds ---
# 20fold 3-sigma clipping for 802
# --- 7.648796081542969 seconds ---
# 20fold 3-sigma clipping for 803
# --- 7.7026026248931885 seconds ---
# 20fold 3-sigma clipping for 804
# --- 7.689665079116821 seconds ---
# 20fold 3-sigma clipping for 805
# --- 7.499671220779419 seconds ---
# 20fold 3-sigma clipping for 806
# --- 7.644786596298218 seconds ---
# 20fold 3-sigma clipping for 807
# --- 7.6478657722473145 seconds ---
# 20fold 3-sigma clipping for 808
# --- 7.664222717285156 seconds ---
# 20fold 3-sigma clipping for 809
# --- 7.646340608596802 seconds ---
# 20fold 3-sigma clipping for 810
# --- 7.49520468711853 seconds ---
# 20fold 3-sigma clipping for 811
# --- 7.641106367111206 seconds ---
# 20fold 3-sigma clipping for 812
# --- 7.6727399826049805 seconds ---
# 20fold 3-sigma clipping for 813
# --- 7.693050146102905 seconds ---
# 20fold 3-sigma clipping for 814
# --- 7.661340713500977 seconds ---
# 20fold 3-sigma clipping for 815
# --- 7.501199245452881 seconds ---
# 20fold 3-sigma clipping for 816
# --- 7.655827522277832 seconds ---
# 20fold 3-sigma clipping for 817
# --- 7.651028871536255 seconds ---
# 20fold 3-sigma clipping for 818
# --- 7.684322834014893 seconds ---
# 20fold 3-sigma clipping for 819
# --- 7.698385238647461 seconds ---
# 20fold 3-sigma clipping for 820
# --- 7.531051397323608 seconds ---
# 20fold 3-sigma clipping for 821
# --- 7.666752815246582 seconds ---
# 20fold 3-sigma clipping for 822
# --- 7.6638994216918945 seconds ---
# 20fold 3-sigma clipping for 823
# --- 7.67558479309082 seconds ---
# 20fold 3-sigma clipping for 824
# --- 7.659046173095703 seconds ---
# 20fold 3-sigma clipping for 825
# --- 7.513084173202515 seconds ---
# 20fold 3-sigma clipping for 826
# --- 7.665986776351929 seconds ---
# 20fold 3-sigma clipping for 827
# --- 7.723951578140259 seconds ---
# 20fold 3-sigma clipping for 828
# --- 7.7914042472839355 seconds ---
# 20fold 3-sigma clipping for 829
# --- 7.775982618331909 seconds ---
# 20fold 3-sigma clipping for 830
# --- 7.619481563568115 seconds ---
# 20fold 3-sigma clipping for 831
# --- 7.766049385070801 seconds ---
# 20fold 3-sigma clipping for 832
# --- 7.76218843460083 seconds ---
# 20fold 3-sigma clipping for 833
# --- 7.8056159019470215 seconds ---
# 20fold 3-sigma clipping for 834
# --- 7.77073860168457 seconds ---
# 20fold 3-sigma clipping for 835
# --- 7.618225812911987 seconds ---
# 20fold 3-sigma clipping for 836
# --- 7.782151460647583 seconds ---
# 20fold 3-sigma clipping for 837
# --- 7.76480770111084 seconds ---
# 20fold 3-sigma clipping for 838
# --- 7.794832468032837 seconds ---
# 20fold 3-sigma clipping for 839
# --- 7.760907411575317 seconds ---
# 20fold 3-sigma clipping for 840
# --- 7.593100070953369 seconds ---
# 20fold 3-sigma clipping for 841
# --- 7.751193523406982 seconds ---
# 20fold 3-sigma clipping for 842
# --- 7.7596869468688965 seconds ---
# 20fold 3-sigma clipping for 843
# --- 7.754028558731079 seconds ---
# 20fold 3-sigma clipping for 844
# --- 7.747546911239624 seconds ---
# 20fold 3-sigma clipping for 845
# --- 7.604745864868164 seconds ---
# 20fold 3-sigma clipping for 846
# --- 7.764790058135986 seconds ---
# 20fold 3-sigma clipping for 847
# --- 7.777356147766113 seconds ---

# %%
np.save("filtered_hsi1_half1.npy", filtered_hsi1_half1)

# %%
# -- data proprecessing for the image from row0 to row800
filtered_hsi0_half0 = sigma_clipping(cube0, "half0")
np.save("filtered_hsi0_half0.npy", filtered_hsi0_half0)
# Out:
# 20fold 3-sigma clipping for 0
# --- 3.1479082107543945 seconds ---
# 20fold 3-sigma clipping for 1
# --- 3.130420684814453 seconds ---
# 20fold 3-sigma clipping for 2
# --- 3.14082407951355 seconds ---
# 20fold 3-sigma clipping for 3
# --- 3.126542568206787 seconds ---
# 20fold 3-sigma clipping for 4
# --- 3.1207473278045654 seconds ---
# 20fold 3-sigma clipping for 5
# --- 3.1332802772521973 seconds ---
# 20fold 3-sigma clipping for 6
# --- 3.1427855491638184 seconds ---
# 20fold 3-sigma clipping for 7
# --- 3.1217403411865234 seconds ---
# 20fold 3-sigma clipping for 8
# --- 3.121967077255249 seconds ---
# 20fold 3-sigma clipping for 9
# --- 3.1327321529388428 seconds ---
# 20fold 3-sigma clipping for 10
# --- 3.1491165161132812 seconds ---
# 20fold 3-sigma clipping for 11
# --- 3.116382122039795 seconds ---
# 20fold 3-sigma clipping for 12
# --- 3.1172902584075928 seconds ---
# 20fold 3-sigma clipping for 13
# --- 3.1293771266937256 seconds ---
# 20fold 3-sigma clipping for 14
# --- 3.146739959716797 seconds ---
# 20fold 3-sigma clipping for 15
# --- 3.1197702884674072 seconds ---
# 20fold 3-sigma clipping for 16
# --- 3.122478485107422 seconds ---
# 20fold 3-sigma clipping for 17
# --- 3.134671688079834 seconds ---
# 20fold 3-sigma clipping for 18
# --- 3.1456847190856934 seconds ---
# 20fold 3-sigma clipping for 19
# --- 3.1207334995269775 seconds ---
# 20fold 3-sigma clipping for 20
# --- 3.1186094284057617 seconds ---
# 20fold 3-sigma clipping for 21
# --- 3.137681722640991 seconds ---
# 20fold 3-sigma clipping for 22
# --- 3.145118474960327 seconds ---
# 20fold 3-sigma clipping for 23
# --- 3.1190454959869385 seconds ---
# 20fold 3-sigma clipping for 24
# --- 3.1341536045074463 seconds ---
# 20fold 3-sigma clipping for 25
# --- 3.1347389221191406 seconds ---
# 20fold 3-sigma clipping for 26
# --- 3.185699939727783 seconds ---
# 20fold 3-sigma clipping for 27
# --- 3.1840875148773193 seconds ---
# 20fold 3-sigma clipping for 28
# --- 3.189621925354004 seconds ---
# 20fold 3-sigma clipping for 29
# --- 3.2007806301116943 seconds ---
# 20fold 3-sigma clipping for 30
# --- 3.2120089530944824 seconds ---
# 20fold 3-sigma clipping for 31
# --- 3.1864306926727295 seconds ---
# 20fold 3-sigma clipping for 32
# --- 3.1934638023376465 seconds ---
# 20fold 3-sigma clipping for 33
# --- 3.2074661254882812 seconds ---
# 20fold 3-sigma clipping for 34
# --- 3.2188313007354736 seconds ---
# 20fold 3-sigma clipping for 35
# --- 3.1882593631744385 seconds ---
# 20fold 3-sigma clipping for 36
# --- 3.1825428009033203 seconds ---
# 20fold 3-sigma clipping for 37
# --- 3.1893887519836426 seconds ---
# 20fold 3-sigma clipping for 38
# --- 3.2038869857788086 seconds ---
# 20fold 3-sigma clipping for 39
# --- 3.1806886196136475 seconds ---
# 20fold 3-sigma clipping for 40
# --- 3.1753973960876465 seconds ---
# 20fold 3-sigma clipping for 41
# --- 3.184190511703491 seconds ---
# 20fold 3-sigma clipping for 42
# --- 3.2050225734710693 seconds ---
# 20fold 3-sigma clipping for 43
# --- 3.1827120780944824 seconds ---
# 20fold 3-sigma clipping for 44
# --- 3.1843461990356445 seconds ---
# 20fold 3-sigma clipping for 45
# --- 3.201547861099243 seconds ---
# 20fold 3-sigma clipping for 46
# --- 3.19939923286438 seconds ---
# 20fold 3-sigma clipping for 47
# --- 3.1736133098602295 seconds ---
# 20fold 3-sigma clipping for 48
# --- 3.174616575241089 seconds ---
# 20fold 3-sigma clipping for 49
# --- 3.201131820678711 seconds ---
# 20fold 3-sigma clipping for 50
# --- 3.2140655517578125 seconds ---
# 20fold 3-sigma clipping for 51
# --- 3.1858620643615723 seconds ---
# 20fold 3-sigma clipping for 52
# --- 3.1786410808563232 seconds ---
# 20fold 3-sigma clipping for 53
# --- 3.1877055168151855 seconds ---
# 20fold 3-sigma clipping for 54
# --- 3.2153565883636475 seconds ---
# 20fold 3-sigma clipping for 55
# --- 3.1763877868652344 seconds ---
# 20fold 3-sigma clipping for 56
# --- 3.1841237545013428 seconds ---
# 20fold 3-sigma clipping for 57
# --- 3.194916009902954 seconds ---
# 20fold 3-sigma clipping for 58
# --- 3.206300735473633 seconds ---
# 20fold 3-sigma clipping for 59
# --- 3.2017061710357666 seconds ---
# 20fold 3-sigma clipping for 60
# --- 3.177417039871216 seconds ---
# 20fold 3-sigma clipping for 61
# --- 3.2048518657684326 seconds ---
# 20fold 3-sigma clipping for 62
# --- 3.206190347671509 seconds ---
# 20fold 3-sigma clipping for 63
# --- 3.1945667266845703 seconds ---
# 20fold 3-sigma clipping for 64
# --- 3.1965503692626953 seconds ---
# 20fold 3-sigma clipping for 65
# --- 3.208087205886841 seconds ---
# 20fold 3-sigma clipping for 66
# --- 3.209705352783203 seconds ---
# 20fold 3-sigma clipping for 67
# --- 3.182312250137329 seconds ---
# 20fold 3-sigma clipping for 68
# --- 3.190791130065918 seconds ---
# 20fold 3-sigma clipping for 69
# --- 3.1832404136657715 seconds ---
# 20fold 3-sigma clipping for 70
# --- 3.2071430683135986 seconds ---
# 20fold 3-sigma clipping for 71
# --- 3.163926124572754 seconds ---
# 20fold 3-sigma clipping for 72
# --- 3.1716363430023193 seconds ---
# 20fold 3-sigma clipping for 73
# --- 3.1793172359466553 seconds ---
# 20fold 3-sigma clipping for 74
# --- 3.2134618759155273 seconds ---
# 20fold 3-sigma clipping for 75
# --- 3.1734893321990967 seconds ---
# 20fold 3-sigma clipping for 76
# --- 3.178447723388672 seconds ---
# 20fold 3-sigma clipping for 77
# --- 3.200253486633301 seconds ---
# 20fold 3-sigma clipping for 78
# --- 3.204923629760742 seconds ---
# 20fold 3-sigma clipping for 79
# --- 3.18280291557312 seconds ---
# 20fold 3-sigma clipping for 80
# --- 3.1836280822753906 seconds ---
# 20fold 3-sigma clipping for 81
# --- 3.195704698562622 seconds ---
# 20fold 3-sigma clipping for 82
# --- 3.212580680847168 seconds ---
# 20fold 3-sigma clipping for 83
# --- 3.1844491958618164 seconds ---
# 20fold 3-sigma clipping for 84
# --- 3.191434621810913 seconds ---
# 20fold 3-sigma clipping for 85
# --- 3.195582866668701 seconds ---
# 20fold 3-sigma clipping for 86
# --- 3.219352960586548 seconds ---
# 20fold 3-sigma clipping for 87
# --- 3.1913068294525146 seconds ---
# 20fold 3-sigma clipping for 88
# --- 3.2055461406707764 seconds ---
# 20fold 3-sigma clipping for 89
# --- 3.194699764251709 seconds ---
# 20fold 3-sigma clipping for 90
# --- 3.2196781635284424 seconds ---
# 20fold 3-sigma clipping for 91
# --- 3.1837146282196045 seconds ---
# 20fold 3-sigma clipping for 92
# --- 3.1996707916259766 seconds ---
# 20fold 3-sigma clipping for 93
# --- 3.209710121154785 seconds ---
# 20fold 3-sigma clipping for 94
# --- 3.2418253421783447 seconds ---
# 20fold 3-sigma clipping for 95
# --- 3.215808868408203 seconds ---
# 20fold 3-sigma clipping for 96
# --- 3.207676649093628 seconds ---
# 20fold 3-sigma clipping for 97
# --- 3.221588373184204 seconds ---
# 20fold 3-sigma clipping for 98
# --- 3.2355358600616455 seconds ---
# 20fold 3-sigma clipping for 99
# --- 3.2262418270111084 seconds ---
# 20fold 3-sigma clipping for 100
# --- 3.205859661102295 seconds ---
# 20fold 3-sigma clipping for 101
# --- 3.2211720943450928 seconds ---
# 20fold 3-sigma clipping for 102
# --- 3.212362289428711 seconds ---
# 20fold 3-sigma clipping for 103
# --- 3.1962051391601562 seconds ---
# 20fold 3-sigma clipping for 104
# --- 3.2104744911193848 seconds ---
# 20fold 3-sigma clipping for 105
# --- 3.224313735961914 seconds ---
# 20fold 3-sigma clipping for 106
# --- 3.2379560470581055 seconds ---
# 20fold 3-sigma clipping for 107
# --- 3.2044920921325684 seconds ---
# 20fold 3-sigma clipping for 108
# --- 3.205345630645752 seconds ---
# 20fold 3-sigma clipping for 109
# --- 3.202072858810425 seconds ---
# 20fold 3-sigma clipping for 110
# --- 3.2310104370117188 seconds ---
# 20fold 3-sigma clipping for 111
# --- 3.1904892921447754 seconds ---
# 20fold 3-sigma clipping for 112
# --- 3.205739974975586 seconds ---
# 20fold 3-sigma clipping for 113
# --- 3.2164387702941895 seconds ---
# 20fold 3-sigma clipping for 114
# --- 3.2360126972198486 seconds ---
# 20fold 3-sigma clipping for 115
# --- 3.2035863399505615 seconds ---
# 20fold 3-sigma clipping for 116
# --- 3.2023305892944336 seconds ---
# 20fold 3-sigma clipping for 117
# --- 3.2144901752471924 seconds ---
# 20fold 3-sigma clipping for 118
# --- 3.2312612533569336 seconds ---
# 20fold 3-sigma clipping for 119
# --- 3.2007555961608887 seconds ---
# 20fold 3-sigma clipping for 120
# --- 3.205519437789917 seconds ---
# 20fold 3-sigma clipping for 121
# --- 3.2080633640289307 seconds ---
# 20fold 3-sigma clipping for 122
# --- 3.22355580329895 seconds ---
# 20fold 3-sigma clipping for 123
# --- 3.1946604251861572 seconds ---
# 20fold 3-sigma clipping for 124
# --- 3.201981782913208 seconds ---
# 20fold 3-sigma clipping for 125
# --- 3.218675374984741 seconds ---
# 20fold 3-sigma clipping for 126
# --- 3.2361679077148438 seconds ---
# 20fold 3-sigma clipping for 127
# --- 3.198103666305542 seconds ---
# 20fold 3-sigma clipping for 128
# --- 3.21270751953125 seconds ---
# 20fold 3-sigma clipping for 129
# --- 3.2214291095733643 seconds ---
# 20fold 3-sigma clipping for 130
# --- 3.220879077911377 seconds ---
# 20fold 3-sigma clipping for 131
# --- 3.208785057067871 seconds ---
# 20fold 3-sigma clipping for 132
# --- 3.1908819675445557 seconds ---
# 20fold 3-sigma clipping for 133
# --- 3.212355136871338 seconds ---
# 20fold 3-sigma clipping for 134
# --- 3.218863010406494 seconds ---
# 20fold 3-sigma clipping for 135
# --- 3.210092306137085 seconds ---
# 20fold 3-sigma clipping for 136
# --- 3.215815544128418 seconds ---
# 20fold 3-sigma clipping for 137
# --- 3.2233383655548096 seconds ---
# 20fold 3-sigma clipping for 138
# --- 3.232896327972412 seconds ---
# 20fold 3-sigma clipping for 139
# --- 3.1908183097839355 seconds ---
# 20fold 3-sigma clipping for 140
# --- 3.202425718307495 seconds ---
# 20fold 3-sigma clipping for 141
# --- 3.2108473777770996 seconds ---
# 20fold 3-sigma clipping for 142
# --- 3.213521718978882 seconds ---
# 20fold 3-sigma clipping for 143
# --- 3.197150230407715 seconds ---
# 20fold 3-sigma clipping for 144
# --- 3.1948187351226807 seconds ---
# 20fold 3-sigma clipping for 145
# --- 3.218020439147949 seconds ---
# 20fold 3-sigma clipping for 146
# --- 3.2308132648468018 seconds ---
# 20fold 3-sigma clipping for 147
# --- 3.194775342941284 seconds ---
# 20fold 3-sigma clipping for 148
# --- 3.196441173553467 seconds ---
# 20fold 3-sigma clipping for 149
# --- 3.1981401443481445 seconds ---
# 20fold 3-sigma clipping for 150
# --- 3.2166473865509033 seconds ---
# 20fold 3-sigma clipping for 151
# --- 3.1960558891296387 seconds ---
# 20fold 3-sigma clipping for 152
# --- 3.2005677223205566 seconds ---
# 20fold 3-sigma clipping for 153
# --- 3.209709882736206 seconds ---
# 20fold 3-sigma clipping for 154
# --- 3.2137296199798584 seconds ---
# 20fold 3-sigma clipping for 155
# --- 3.2012531757354736 seconds ---
# 20fold 3-sigma clipping for 156
# --- 3.205489158630371 seconds ---
# 20fold 3-sigma clipping for 157
# --- 3.219573974609375 seconds ---
# 20fold 3-sigma clipping for 158
# --- 3.2137768268585205 seconds ---
# 20fold 3-sigma clipping for 159
# --- 3.215477228164673 seconds ---
# 20fold 3-sigma clipping for 160
# --- 3.1987597942352295 seconds ---
# 20fold 3-sigma clipping for 161
# --- 3.219223737716675 seconds ---
# 20fold 3-sigma clipping for 162
# --- 3.215505838394165 seconds ---
# 20fold 3-sigma clipping for 163
# --- 3.203315496444702 seconds ---
# 20fold 3-sigma clipping for 164
# --- 3.1979293823242188 seconds ---
# 20fold 3-sigma clipping for 165
# --- 3.210869312286377 seconds ---
# 20fold 3-sigma clipping for 166
# --- 3.244389295578003 seconds ---
# 20fold 3-sigma clipping for 167
# --- 3.2022156715393066 seconds ---
# 20fold 3-sigma clipping for 168
# --- 3.204895496368408 seconds ---
# 20fold 3-sigma clipping for 169
# --- 3.2112631797790527 seconds ---
# 20fold 3-sigma clipping for 170
# --- 3.2297732830047607 seconds ---
# 20fold 3-sigma clipping for 171
# --- 3.2134499549865723 seconds ---
# 20fold 3-sigma clipping for 172
# --- 3.2075417041778564 seconds ---
# 20fold 3-sigma clipping for 173
# --- 3.2180211544036865 seconds ---
# 20fold 3-sigma clipping for 174
# --- 3.223845958709717 seconds ---
# 20fold 3-sigma clipping for 175
# --- 3.194446325302124 seconds ---
# 20fold 3-sigma clipping for 176
# --- 3.200572967529297 seconds ---
# 20fold 3-sigma clipping for 177
# --- 3.205183982849121 seconds ---
# 20fold 3-sigma clipping for 178
# --- 3.2182607650756836 seconds ---
# 20fold 3-sigma clipping for 179
# --- 3.1948463916778564 seconds ---
# 20fold 3-sigma clipping for 180
# --- 3.193455696105957 seconds ---
# 20fold 3-sigma clipping for 181
# --- 3.1947555541992188 seconds ---
# 20fold 3-sigma clipping for 182
# --- 3.2066900730133057 seconds ---
# 20fold 3-sigma clipping for 183
# --- 3.191716432571411 seconds ---
# 20fold 3-sigma clipping for 184
# --- 3.1976735591888428 seconds ---
# 20fold 3-sigma clipping for 185
# --- 3.2115023136138916 seconds ---
# 20fold 3-sigma clipping for 186
# --- 3.2192795276641846 seconds ---
# 20fold 3-sigma clipping for 187
# --- 3.1915650367736816 seconds ---
# 20fold 3-sigma clipping for 188
# --- 3.1808629035949707 seconds ---
# 20fold 3-sigma clipping for 189
# --- 3.1918301582336426 seconds ---
# 20fold 3-sigma clipping for 190
# --- 3.2069668769836426 seconds ---
# 20fold 3-sigma clipping for 191
# --- 3.1819252967834473 seconds ---
# 20fold 3-sigma clipping for 192
# --- 3.1727335453033447 seconds ---
# 20fold 3-sigma clipping for 193
# --- 3.188939094543457 seconds ---
# 20fold 3-sigma clipping for 194
# --- 3.2023699283599854 seconds ---
# 20fold 3-sigma clipping for 195
# --- 3.179905414581299 seconds ---
# 20fold 3-sigma clipping for 196
# --- 3.1818857192993164 seconds ---
# 20fold 3-sigma clipping for 197
# --- 3.2081353664398193 seconds ---
# 20fold 3-sigma clipping for 198
# --- 3.223525285720825 seconds ---
# 20fold 3-sigma clipping for 199
# --- 3.1966371536254883 seconds ---
# 20fold 3-sigma clipping for 200
# --- 3.198206901550293 seconds ---
# 20fold 3-sigma clipping for 201
# --- 3.203631639480591 seconds ---
# 20fold 3-sigma clipping for 202
# --- 3.2265210151672363 seconds ---
# 20fold 3-sigma clipping for 203
# --- 3.1815273761749268 seconds ---
# 20fold 3-sigma clipping for 204
# --- 3.1979687213897705 seconds ---
# 20fold 3-sigma clipping for 205
# --- 3.189469814300537 seconds ---
# 20fold 3-sigma clipping for 206
# --- 3.2152135372161865 seconds ---
# 20fold 3-sigma clipping for 207
# --- 3.1793243885040283 seconds ---
# 20fold 3-sigma clipping for 208
# --- 3.195228338241577 seconds ---
# 20fold 3-sigma clipping for 209
# --- 3.2028534412384033 seconds ---
# 20fold 3-sigma clipping for 210
# --- 3.211538791656494 seconds ---
# 20fold 3-sigma clipping for 211
# --- 3.188052177429199 seconds ---
# 20fold 3-sigma clipping for 212
# --- 3.1816978454589844 seconds ---
# 20fold 3-sigma clipping for 213
# --- 3.1999001502990723 seconds ---
# 20fold 3-sigma clipping for 214
# --- 3.205500364303589 seconds ---
# 20fold 3-sigma clipping for 215
# --- 3.1817829608917236 seconds ---
# 20fold 3-sigma clipping for 216
# --- 3.181835412979126 seconds ---
# 20fold 3-sigma clipping for 217
# --- 3.2012670040130615 seconds ---
# 20fold 3-sigma clipping for 218
# --- 3.2150115966796875 seconds ---
# 20fold 3-sigma clipping for 219
# --- 3.201281785964966 seconds ---
# 20fold 3-sigma clipping for 220
# --- 3.209672212600708 seconds ---
# 20fold 3-sigma clipping for 221
# --- 3.206808090209961 seconds ---
# 20fold 3-sigma clipping for 222
# --- 3.2120795249938965 seconds ---
# 20fold 3-sigma clipping for 223
# --- 3.189176559448242 seconds ---
# 20fold 3-sigma clipping for 224
# --- 3.190382719039917 seconds ---
# 20fold 3-sigma clipping for 225
# --- 3.2034285068511963 seconds ---
# 20fold 3-sigma clipping for 226
# --- 3.2200112342834473 seconds ---
# 20fold 3-sigma clipping for 227
# --- 3.195600748062134 seconds ---
# 20fold 3-sigma clipping for 228
# --- 3.2163138389587402 seconds ---
# 20fold 3-sigma clipping for 229
# --- 3.215593099594116 seconds ---
# 20fold 3-sigma clipping for 230
# --- 3.233915090560913 seconds ---
# 20fold 3-sigma clipping for 231
# --- 3.2015762329101562 seconds ---
# 20fold 3-sigma clipping for 232
# --- 3.179152011871338 seconds ---
# 20fold 3-sigma clipping for 233
# --- 3.1964645385742188 seconds ---
# 20fold 3-sigma clipping for 234
# --- 3.2125446796417236 seconds ---
# 20fold 3-sigma clipping for 235
# --- 3.1864874362945557 seconds ---
# 20fold 3-sigma clipping for 236
# --- 3.1929428577423096 seconds ---
# 20fold 3-sigma clipping for 237
# --- 3.2064497470855713 seconds ---
# 20fold 3-sigma clipping for 238
# --- 3.225614070892334 seconds ---
# 20fold 3-sigma clipping for 239
# --- 3.1980133056640625 seconds ---
# 20fold 3-sigma clipping for 240
# --- 3.186196804046631 seconds ---
# 20fold 3-sigma clipping for 241
# --- 3.196554183959961 seconds ---
# 20fold 3-sigma clipping for 242
# --- 3.213156223297119 seconds ---
# 20fold 3-sigma clipping for 243
# --- 3.186797618865967 seconds ---
# 20fold 3-sigma clipping for 244
# --- 3.189289093017578 seconds ---
# 20fold 3-sigma clipping for 245
# --- 3.1938188076019287 seconds ---
# 20fold 3-sigma clipping for 246
# --- 3.205508232116699 seconds ---
# 20fold 3-sigma clipping for 247
# --- 3.1986682415008545 seconds ---
# 20fold 3-sigma clipping for 248
# --- 3.1887917518615723 seconds ---
# 20fold 3-sigma clipping for 249
# --- 3.2083797454833984 seconds ---
# 20fold 3-sigma clipping for 250
# --- 3.2224676609039307 seconds ---
# 20fold 3-sigma clipping for 251
# --- 3.186295747756958 seconds ---
# 20fold 3-sigma clipping for 252
# --- 3.191955804824829 seconds ---
# 20fold 3-sigma clipping for 253
# --- 3.206904411315918 seconds ---
# 20fold 3-sigma clipping for 254
# --- 3.2188363075256348 seconds ---
# 20fold 3-sigma clipping for 255
# --- 3.1947009563446045 seconds ---
# 20fold 3-sigma clipping for 256
# --- 3.189589500427246 seconds ---
# 20fold 3-sigma clipping for 257
# --- 3.202848434448242 seconds ---
# 20fold 3-sigma clipping for 258
# --- 3.219651937484741 seconds ---
# 20fold 3-sigma clipping for 259
# --- 3.1972484588623047 seconds ---
# 20fold 3-sigma clipping for 260
# --- 3.1901564598083496 seconds ---
# 20fold 3-sigma clipping for 261
# --- 3.1899523735046387 seconds ---
# 20fold 3-sigma clipping for 262
# --- 3.22737193107605 seconds ---
# 20fold 3-sigma clipping for 263
# --- 3.195712089538574 seconds ---
# 20fold 3-sigma clipping for 264
# --- 3.2146408557891846 seconds ---
# 20fold 3-sigma clipping for 265
# --- 3.220409870147705 seconds ---
# 20fold 3-sigma clipping for 266
# --- 3.2320361137390137 seconds ---
# 20fold 3-sigma clipping for 267
# --- 3.1867477893829346 seconds ---
# 20fold 3-sigma clipping for 268
# --- 3.195932626724243 seconds ---
# 20fold 3-sigma clipping for 269
# --- 3.210836410522461 seconds ---
# 20fold 3-sigma clipping for 270
# --- 3.225253105163574 seconds ---
# 20fold 3-sigma clipping for 271
# --- 3.1973071098327637 seconds ---
# 20fold 3-sigma clipping for 272
# --- 3.1863207817077637 seconds ---
# 20fold 3-sigma clipping for 273
# --- 3.214967966079712 seconds ---
# 20fold 3-sigma clipping for 274
# --- 3.2297298908233643 seconds ---
# 20fold 3-sigma clipping for 275
# --- 3.198478937149048 seconds ---
# 20fold 3-sigma clipping for 276
# --- 3.189568281173706 seconds ---
# 20fold 3-sigma clipping for 277
# --- 3.2154626846313477 seconds ---
# 20fold 3-sigma clipping for 278
# --- 3.216226100921631 seconds ---
# 20fold 3-sigma clipping for 279
# --- 3.1946778297424316 seconds ---
# 20fold 3-sigma clipping for 280
# --- 3.1949758529663086 seconds ---
# 20fold 3-sigma clipping for 281
# --- 3.209327220916748 seconds ---
# 20fold 3-sigma clipping for 282
# --- 3.2218971252441406 seconds ---
# 20fold 3-sigma clipping for 283
# --- 3.198727607727051 seconds ---
# 20fold 3-sigma clipping for 284
# --- 3.198284387588501 seconds ---
# 20fold 3-sigma clipping for 285
# --- 3.2087128162384033 seconds ---
# 20fold 3-sigma clipping for 286
# --- 3.219663143157959 seconds ---
# 20fold 3-sigma clipping for 287
# --- 3.1879639625549316 seconds ---
# 20fold 3-sigma clipping for 288
# --- 3.1898751258850098 seconds ---
# 20fold 3-sigma clipping for 289
# --- 3.206650733947754 seconds ---
# 20fold 3-sigma clipping for 290
# --- 3.2238123416900635 seconds ---
# 20fold 3-sigma clipping for 291
# --- 3.204930305480957 seconds ---
# 20fold 3-sigma clipping for 292
# --- 3.20181941986084 seconds ---
# 20fold 3-sigma clipping for 293
# --- 3.2263777256011963 seconds ---
# 20fold 3-sigma clipping for 294
# --- 3.2348477840423584 seconds ---
# 20fold 3-sigma clipping for 295
# --- 3.2173826694488525 seconds ---
# 20fold 3-sigma clipping for 296
# --- 3.2222366333007812 seconds ---
# 20fold 3-sigma clipping for 297
# --- 3.2335829734802246 seconds ---
# 20fold 3-sigma clipping for 298
# --- 3.228386878967285 seconds ---
# 20fold 3-sigma clipping for 299
# --- 3.212334156036377 seconds ---
# 20fold 3-sigma clipping for 300
# --- 3.228417158126831 seconds ---
# 20fold 3-sigma clipping for 301
# --- 3.2179653644561768 seconds ---
# 20fold 3-sigma clipping for 302
# --- 3.2497737407684326 seconds ---
# 20fold 3-sigma clipping for 303
# --- 3.2010393142700195 seconds ---
# 20fold 3-sigma clipping for 304
# --- 3.200364828109741 seconds ---
# 20fold 3-sigma clipping for 305
# --- 3.218035936355591 seconds ---
# 20fold 3-sigma clipping for 306
# --- 3.212003231048584 seconds ---
# 20fold 3-sigma clipping for 307
# --- 3.190645456314087 seconds ---
# 20fold 3-sigma clipping for 308
# --- 3.1884987354278564 seconds ---
# 20fold 3-sigma clipping for 309
# --- 3.2191548347473145 seconds ---
# 20fold 3-sigma clipping for 310
# --- 3.214437246322632 seconds ---
# 20fold 3-sigma clipping for 311
# --- 3.205653190612793 seconds ---
# 20fold 3-sigma clipping for 312
# --- 3.200448751449585 seconds ---
# 20fold 3-sigma clipping for 313
# --- 3.219688892364502 seconds ---
# 20fold 3-sigma clipping for 314
# --- 3.233553171157837 seconds ---
# 20fold 3-sigma clipping for 315
# --- 3.204740524291992 seconds ---
# 20fold 3-sigma clipping for 316
# --- 3.205573081970215 seconds ---
# 20fold 3-sigma clipping for 317
# --- 3.2218921184539795 seconds ---
# 20fold 3-sigma clipping for 318
# --- 3.2266879081726074 seconds ---
# 20fold 3-sigma clipping for 319
# --- 3.1872591972351074 seconds ---
# 20fold 3-sigma clipping for 320
# --- 3.1946029663085938 seconds ---
# 20fold 3-sigma clipping for 321
# --- 3.1943576335906982 seconds ---
# 20fold 3-sigma clipping for 322
# --- 3.2177834510803223 seconds ---
# 20fold 3-sigma clipping for 323
# --- 3.190182685852051 seconds ---
# 20fold 3-sigma clipping for 324
# --- 3.188483715057373 seconds ---
# 20fold 3-sigma clipping for 325
# --- 3.1991689205169678 seconds ---
# 20fold 3-sigma clipping for 326
# --- 3.2202742099761963 seconds ---
# 20fold 3-sigma clipping for 327
# --- 3.199589729309082 seconds ---
# 20fold 3-sigma clipping for 328
# --- 3.1860694885253906 seconds ---
# 20fold 3-sigma clipping for 329
# --- 3.2047393321990967 seconds ---
# 20fold 3-sigma clipping for 330
# --- 3.2123942375183105 seconds ---
# 20fold 3-sigma clipping for 331
# --- 3.2008752822875977 seconds ---
# 20fold 3-sigma clipping for 332
# --- 3.205324411392212 seconds ---
# 20fold 3-sigma clipping for 333
# --- 3.2039997577667236 seconds ---
# 20fold 3-sigma clipping for 334
# --- 3.2165207862854004 seconds ---
# 20fold 3-sigma clipping for 335
# --- 3.1958489418029785 seconds ---
# 20fold 3-sigma clipping for 336
# --- 3.196714162826538 seconds ---
# 20fold 3-sigma clipping for 337
# --- 3.2007997035980225 seconds ---
# 20fold 3-sigma clipping for 338
# --- 3.227349281311035 seconds ---
# 20fold 3-sigma clipping for 339
# --- 3.1920461654663086 seconds ---
# 20fold 3-sigma clipping for 340
# --- 3.206475257873535 seconds ---
# 20fold 3-sigma clipping for 341
# --- 3.205683469772339 seconds ---
# 20fold 3-sigma clipping for 342
# --- 3.2206032276153564 seconds ---
# 20fold 3-sigma clipping for 343
# --- 3.204894542694092 seconds ---
# 20fold 3-sigma clipping for 344
# --- 3.203159809112549 seconds ---
# 20fold 3-sigma clipping for 345
# --- 3.2203409671783447 seconds ---
# 20fold 3-sigma clipping for 346
# --- 3.223363161087036 seconds ---
# 20fold 3-sigma clipping for 347
# --- 3.204146146774292 seconds ---
# 20fold 3-sigma clipping for 348
# --- 3.197375774383545 seconds ---
# 20fold 3-sigma clipping for 349
# --- 3.2067182064056396 seconds ---
# 20fold 3-sigma clipping for 350
# --- 3.224682569503784 seconds ---
# 20fold 3-sigma clipping for 351
# --- 3.203636884689331 seconds ---
# 20fold 3-sigma clipping for 352
# --- 3.1897358894348145 seconds ---
# 20fold 3-sigma clipping for 353
# --- 3.2116103172302246 seconds ---
# 20fold 3-sigma clipping for 354
# --- 3.2196898460388184 seconds ---
# 20fold 3-sigma clipping for 355
# --- 3.1903250217437744 seconds ---
# 20fold 3-sigma clipping for 356
# --- 3.19268798828125 seconds ---
# 20fold 3-sigma clipping for 357
# --- 3.1994450092315674 seconds ---
# 20fold 3-sigma clipping for 358
# --- 3.210721015930176 seconds ---
# 20fold 3-sigma clipping for 359
# --- 3.183018922805786 seconds ---
# 20fold 3-sigma clipping for 360
# --- 3.1975531578063965 seconds ---
# 20fold 3-sigma clipping for 361
# --- 3.1976170539855957 seconds ---
# 20fold 3-sigma clipping for 362
# --- 3.2186336517333984 seconds ---
# 20fold 3-sigma clipping for 363
# --- 3.193328380584717 seconds ---
# 20fold 3-sigma clipping for 364
# --- 3.197266101837158 seconds ---
# 20fold 3-sigma clipping for 365
# --- 3.198603630065918 seconds ---
# 20fold 3-sigma clipping for 366
# --- 3.2134339809417725 seconds ---
# 20fold 3-sigma clipping for 367
# --- 3.1938226222991943 seconds ---
# 20fold 3-sigma clipping for 368
# --- 3.1915557384490967 seconds ---
# 20fold 3-sigma clipping for 369
# --- 3.2051024436950684 seconds ---
# 20fold 3-sigma clipping for 370
# --- 3.228792667388916 seconds ---
# 20fold 3-sigma clipping for 371
# --- 3.200828790664673 seconds ---
# 20fold 3-sigma clipping for 372
# --- 3.207555055618286 seconds ---
# 20fold 3-sigma clipping for 373
# --- 3.2201104164123535 seconds ---
# 20fold 3-sigma clipping for 374
# --- 3.2354907989501953 seconds ---
# 20fold 3-sigma clipping for 375
# --- 3.2078402042388916 seconds ---
# 20fold 3-sigma clipping for 376
# --- 3.2060747146606445 seconds ---
# 20fold 3-sigma clipping for 377
# --- 3.2022862434387207 seconds ---
# 20fold 3-sigma clipping for 378
# --- 3.2036385536193848 seconds ---
# 20fold 3-sigma clipping for 379
# --- 3.183861255645752 seconds ---
# 20fold 3-sigma clipping for 380
# --- 3.191668748855591 seconds ---
# 20fold 3-sigma clipping for 381
# --- 3.217085599899292 seconds ---
# 20fold 3-sigma clipping for 382
# --- 3.2343990802764893 seconds ---
# 20fold 3-sigma clipping for 383
# --- 3.211322784423828 seconds ---
# 20fold 3-sigma clipping for 384
# --- 3.1949610710144043 seconds ---
# 20fold 3-sigma clipping for 385
# --- 3.21950101852417 seconds ---
# 20fold 3-sigma clipping for 386
# --- 3.2202866077423096 seconds ---
# 20fold 3-sigma clipping for 387
# --- 3.1932642459869385 seconds ---
# 20fold 3-sigma clipping for 388
# --- 3.1903326511383057 seconds ---
# 20fold 3-sigma clipping for 389
# --- 3.2032668590545654 seconds ---
# 20fold 3-sigma clipping for 390
# --- 3.2250595092773438 seconds ---
# 20fold 3-sigma clipping for 391
# --- 3.200643539428711 seconds ---
# 20fold 3-sigma clipping for 392
# --- 3.1988320350646973 seconds ---
# 20fold 3-sigma clipping for 393
# --- 3.196124315261841 seconds ---
# 20fold 3-sigma clipping for 394
# --- 3.227140188217163 seconds ---
# 20fold 3-sigma clipping for 395
# --- 3.1870384216308594 seconds ---
# 20fold 3-sigma clipping for 396
# --- 3.195103883743286 seconds ---
# 20fold 3-sigma clipping for 397
# --- 3.199436902999878 seconds ---
# 20fold 3-sigma clipping for 398
# --- 3.2200300693511963 seconds ---
# 20fold 3-sigma clipping for 399
# --- 3.1808366775512695 seconds ---
# 20fold 3-sigma clipping for 400
# --- 3.194251775741577 seconds ---
# 20fold 3-sigma clipping for 401
# --- 3.2029895782470703 seconds ---
# 20fold 3-sigma clipping for 402
# --- 3.219661235809326 seconds ---
# 20fold 3-sigma clipping for 403
# --- 3.2018206119537354 seconds ---
# 20fold 3-sigma clipping for 404
# --- 3.200727701187134 seconds ---
# 20fold 3-sigma clipping for 405
# --- 3.2074639797210693 seconds ---
# 20fold 3-sigma clipping for 406
# --- 3.2260396480560303 seconds ---
# 20fold 3-sigma clipping for 407
# --- 3.209566354751587 seconds ---
# 20fold 3-sigma clipping for 408
# --- 3.2120091915130615 seconds ---
# 20fold 3-sigma clipping for 409
# --- 3.227597236633301 seconds ---
# 20fold 3-sigma clipping for 410
# --- 3.242906093597412 seconds ---
# 20fold 3-sigma clipping for 411
# --- 3.2166872024536133 seconds ---
# 20fold 3-sigma clipping for 412
# --- 3.205960988998413 seconds ---
# 20fold 3-sigma clipping for 413
# --- 3.227222442626953 seconds ---
# 20fold 3-sigma clipping for 414
# --- 3.2349586486816406 seconds ---
# 20fold 3-sigma clipping for 415
# --- 3.2012476921081543 seconds ---
# 20fold 3-sigma clipping for 416
# --- 3.205838680267334 seconds ---
# 20fold 3-sigma clipping for 417
# --- 3.2037346363067627 seconds ---
# 20fold 3-sigma clipping for 418
# --- 3.225083827972412 seconds ---
# 20fold 3-sigma clipping for 419
# --- 3.187166690826416 seconds ---
# 20fold 3-sigma clipping for 420
# --- 3.192563533782959 seconds ---
# 20fold 3-sigma clipping for 421
# --- 3.2059688568115234 seconds ---
# 20fold 3-sigma clipping for 422
# --- 3.220792293548584 seconds ---
# 20fold 3-sigma clipping for 423
# --- 3.1872215270996094 seconds ---
# 20fold 3-sigma clipping for 424
# --- 3.210244655609131 seconds ---
# 20fold 3-sigma clipping for 425
# --- 3.215379238128662 seconds ---
# 20fold 3-sigma clipping for 426
# --- 3.2246181964874268 seconds ---
# 20fold 3-sigma clipping for 427
# --- 3.1971826553344727 seconds ---
# 20fold 3-sigma clipping for 428
# --- 3.203519821166992 seconds ---
# 20fold 3-sigma clipping for 429
# --- 3.2047369480133057 seconds ---
# 20fold 3-sigma clipping for 430
# --- 3.201505184173584 seconds ---
# 20fold 3-sigma clipping for 431
# --- 3.1906514167785645 seconds ---
# 20fold 3-sigma clipping for 432
# --- 3.2012786865234375 seconds ---
# 20fold 3-sigma clipping for 433
# --- 3.2161529064178467 seconds ---
# 20fold 3-sigma clipping for 434
# --- 3.233214855194092 seconds ---
# 20fold 3-sigma clipping for 435
# --- 3.2017438411712646 seconds ---
# 20fold 3-sigma clipping for 436
# --- 3.210747480392456 seconds ---
# 20fold 3-sigma clipping for 437
# --- 3.2262778282165527 seconds ---
# 20fold 3-sigma clipping for 438
# --- 3.24324107170105 seconds ---
# 20fold 3-sigma clipping for 439
# --- 3.2049992084503174 seconds ---
# 20fold 3-sigma clipping for 440
# --- 3.2005443572998047 seconds ---
# 20fold 3-sigma clipping for 441
# --- 3.2192606925964355 seconds ---
# 20fold 3-sigma clipping for 442
# --- 3.2182745933532715 seconds ---
# 20fold 3-sigma clipping for 443
# --- 3.182525396347046 seconds ---
# 20fold 3-sigma clipping for 444
# --- 3.1852364540100098 seconds ---
# 20fold 3-sigma clipping for 445
# --- 3.2038216590881348 seconds ---
# 20fold 3-sigma clipping for 446
# --- 3.2190372943878174 seconds ---
# 20fold 3-sigma clipping for 447
# --- 3.2082576751708984 seconds ---
# 20fold 3-sigma clipping for 448
# --- 3.1958889961242676 seconds ---
# 20fold 3-sigma clipping for 449
# --- 3.2162036895751953 seconds ---
# 20fold 3-sigma clipping for 450
# --- 3.218756914138794 seconds ---
# 20fold 3-sigma clipping for 451
# --- 3.195160150527954 seconds ---
# 20fold 3-sigma clipping for 452
# --- 3.1923415660858154 seconds ---
# 20fold 3-sigma clipping for 453
# --- 3.2056570053100586 seconds ---
# 20fold 3-sigma clipping for 454
# --- 3.211198329925537 seconds ---
# 20fold 3-sigma clipping for 455
# --- 3.1883606910705566 seconds ---
# 20fold 3-sigma clipping for 456
# --- 3.197333335876465 seconds ---
# 20fold 3-sigma clipping for 457
# --- 3.2086641788482666 seconds ---
# 20fold 3-sigma clipping for 458
# --- 3.220762252807617 seconds ---
# 20fold 3-sigma clipping for 459
# --- 3.1926333904266357 seconds ---
# 20fold 3-sigma clipping for 460
# --- 3.1981091499328613 seconds ---
# 20fold 3-sigma clipping for 461
# --- 3.20560884475708 seconds ---
# 20fold 3-sigma clipping for 462
# --- 3.2347607612609863 seconds ---
# 20fold 3-sigma clipping for 463
# --- 3.1982171535491943 seconds ---
# 20fold 3-sigma clipping for 464
# --- 3.196688413619995 seconds ---
# 20fold 3-sigma clipping for 465
# --- 3.211397647857666 seconds ---
# 20fold 3-sigma clipping for 466
# --- 3.2220051288604736 seconds ---
# 20fold 3-sigma clipping for 467
# --- 3.2041714191436768 seconds ---
# 20fold 3-sigma clipping for 468
# --- 3.1986656188964844 seconds ---
# 20fold 3-sigma clipping for 469
# --- 3.2035603523254395 seconds ---
# 20fold 3-sigma clipping for 470
# --- 3.216029167175293 seconds ---
# 20fold 3-sigma clipping for 471
# --- 3.1807894706726074 seconds ---
# 20fold 3-sigma clipping for 472
# --- 3.18563175201416 seconds ---
# 20fold 3-sigma clipping for 473
# --- 3.1941895484924316 seconds ---
# 20fold 3-sigma clipping for 474
# --- 3.215022087097168 seconds ---
# 20fold 3-sigma clipping for 475
# --- 3.1947004795074463 seconds ---
# 20fold 3-sigma clipping for 476
# --- 3.206777811050415 seconds ---
# 20fold 3-sigma clipping for 477
# --- 3.219047784805298 seconds ---
# 20fold 3-sigma clipping for 478
# --- 3.225579261779785 seconds ---
# 20fold 3-sigma clipping for 479
# --- 3.196972131729126 seconds ---
# 20fold 3-sigma clipping for 480
# --- 3.182579755783081 seconds ---
# 20fold 3-sigma clipping for 481
# --- 3.1965200901031494 seconds ---
# 20fold 3-sigma clipping for 482
# --- 3.203627109527588 seconds ---
# 20fold 3-sigma clipping for 483
# --- 3.170456647872925 seconds ---
# 20fold 3-sigma clipping for 484
# --- 3.1822264194488525 seconds ---
# 20fold 3-sigma clipping for 485
# --- 3.204288959503174 seconds ---
# 20fold 3-sigma clipping for 486
# --- 3.224587917327881 seconds ---
# 20fold 3-sigma clipping for 487
# --- 3.1898350715637207 seconds ---
# 20fold 3-sigma clipping for 488
# --- 3.204360246658325 seconds ---
# 20fold 3-sigma clipping for 489
# --- 3.2045044898986816 seconds ---
# 20fold 3-sigma clipping for 490
# --- 3.2118396759033203 seconds ---
# 20fold 3-sigma clipping for 491
# --- 3.186032295227051 seconds ---
# 20fold 3-sigma clipping for 492
# --- 3.19347882270813 seconds ---
# 20fold 3-sigma clipping for 493
# --- 3.2073113918304443 seconds ---
# 20fold 3-sigma clipping for 494
# --- 3.209887742996216 seconds ---
# 20fold 3-sigma clipping for 495
# --- 3.192033290863037 seconds ---
# 20fold 3-sigma clipping for 496
# --- 3.197920083999634 seconds ---
# 20fold 3-sigma clipping for 497
# --- 3.2134017944335938 seconds ---
# 20fold 3-sigma clipping for 498
# --- 3.2236504554748535 seconds ---
# 20fold 3-sigma clipping for 499
# --- 3.2004759311676025 seconds ---
# 20fold 3-sigma clipping for 500
# --- 3.1965420246124268 seconds ---
# 20fold 3-sigma clipping for 501
# --- 3.198931932449341 seconds ---
# 20fold 3-sigma clipping for 502
# --- 3.2173781394958496 seconds ---
# 20fold 3-sigma clipping for 503
# --- 3.1945040225982666 seconds ---
# 20fold 3-sigma clipping for 504
# --- 3.2026240825653076 seconds ---
# 20fold 3-sigma clipping for 505
# --- 3.2011489868164062 seconds ---
# 20fold 3-sigma clipping for 506
# --- 3.2362751960754395 seconds ---
# 20fold 3-sigma clipping for 507
# --- 3.203669786453247 seconds ---
# 20fold 3-sigma clipping for 508
# --- 3.210559844970703 seconds ---
# 20fold 3-sigma clipping for 509
# --- 3.213468074798584 seconds ---
# 20fold 3-sigma clipping for 510
# --- 3.240549325942993 seconds ---
# 20fold 3-sigma clipping for 511
# --- 3.202664613723755 seconds ---
# 20fold 3-sigma clipping for 512
# --- 3.206266403198242 seconds ---
# 20fold 3-sigma clipping for 513
# --- 3.2167999744415283 seconds ---
# 20fold 3-sigma clipping for 514
# --- 3.208961009979248 seconds ---
# 20fold 3-sigma clipping for 515
# --- 3.1975045204162598 seconds ---
# 20fold 3-sigma clipping for 516
# --- 3.1948037147521973 seconds ---
# 20fold 3-sigma clipping for 517
# --- 3.2129852771759033 seconds ---
# 20fold 3-sigma clipping for 518
# --- 3.218022584915161 seconds ---
# 20fold 3-sigma clipping for 519
# --- 3.1898245811462402 seconds ---
# 20fold 3-sigma clipping for 520
# --- 3.1946425437927246 seconds ---
# 20fold 3-sigma clipping for 521
# --- 3.205280303955078 seconds ---
# 20fold 3-sigma clipping for 522
# --- 3.225113868713379 seconds ---
# 20fold 3-sigma clipping for 523
# --- 3.193967819213867 seconds ---
# 20fold 3-sigma clipping for 524
# --- 3.2045164108276367 seconds ---
# 20fold 3-sigma clipping for 525
# --- 3.198690414428711 seconds ---
# 20fold 3-sigma clipping for 526
# --- 3.2149312496185303 seconds ---
# 20fold 3-sigma clipping for 527
# --- 3.1834075450897217 seconds ---
# 20fold 3-sigma clipping for 528
# --- 3.1908791065216064 seconds ---
# 20fold 3-sigma clipping for 529
# --- 3.205435276031494 seconds ---
# 20fold 3-sigma clipping for 530
# --- 3.2093212604522705 seconds ---
# 20fold 3-sigma clipping for 531
# --- 3.1891825199127197 seconds ---
# 20fold 3-sigma clipping for 532
# --- 3.200930595397949 seconds ---
# 20fold 3-sigma clipping for 533
# --- 3.212470054626465 seconds ---
# 20fold 3-sigma clipping for 534
# --- 3.2001631259918213 seconds ---
# 20fold 3-sigma clipping for 535
# --- 3.186851978302002 seconds ---
# 20fold 3-sigma clipping for 536
# --- 3.183283805847168 seconds ---
# 20fold 3-sigma clipping for 537
# --- 3.200693130493164 seconds ---
# 20fold 3-sigma clipping for 538
# --- 3.220646381378174 seconds ---
# 20fold 3-sigma clipping for 539
# --- 3.1870601177215576 seconds ---
# 20fold 3-sigma clipping for 540
# --- 3.188554048538208 seconds ---
# 20fold 3-sigma clipping for 541
# --- 3.1921613216400146 seconds ---
# 20fold 3-sigma clipping for 542
# --- 3.2137868404388428 seconds ---
# 20fold 3-sigma clipping for 543
# --- 3.18438982963562 seconds ---
# 20fold 3-sigma clipping for 544
# --- 3.201425790786743 seconds ---
# 20fold 3-sigma clipping for 545
# --- 3.22119402885437 seconds ---
# 20fold 3-sigma clipping for 546
# --- 3.225191593170166 seconds ---
# 20fold 3-sigma clipping for 547
# --- 3.193265438079834 seconds ---
# 20fold 3-sigma clipping for 548
# --- 3.2006335258483887 seconds ---
# 20fold 3-sigma clipping for 549
# --- 3.2132647037506104 seconds ---
# 20fold 3-sigma clipping for 550
# --- 3.233309268951416 seconds ---
# 20fold 3-sigma clipping for 551
# --- 3.187307357788086 seconds ---
# 20fold 3-sigma clipping for 552
# --- 3.202643871307373 seconds ---
# 20fold 3-sigma clipping for 553
# --- 3.198878765106201 seconds ---
# 20fold 3-sigma clipping for 554
# --- 3.2130446434020996 seconds ---
# 20fold 3-sigma clipping for 555
# --- 3.181068181991577 seconds ---
# 20fold 3-sigma clipping for 556
# --- 3.195129156112671 seconds ---
# 20fold 3-sigma clipping for 557
# --- 3.192638635635376 seconds ---
# 20fold 3-sigma clipping for 558
# --- 3.2008049488067627 seconds ---
# 20fold 3-sigma clipping for 559
# --- 3.1786365509033203 seconds ---
# 20fold 3-sigma clipping for 560
# --- 3.178637981414795 seconds ---
# 20fold 3-sigma clipping for 561
# --- 3.194572925567627 seconds ---
# 20fold 3-sigma clipping for 562
# --- 3.2178943157196045 seconds ---
# 20fold 3-sigma clipping for 563
# --- 3.184067487716675 seconds ---
# 20fold 3-sigma clipping for 564
# --- 3.1831188201904297 seconds ---
# 20fold 3-sigma clipping for 565
# --- 3.197049617767334 seconds ---
# 20fold 3-sigma clipping for 566
# --- 3.215424060821533 seconds ---
# 20fold 3-sigma clipping for 567
# --- 3.1785149574279785 seconds ---
# 20fold 3-sigma clipping for 568
# --- 3.183863639831543 seconds ---
# 20fold 3-sigma clipping for 569
# --- 3.200652837753296 seconds ---
# 20fold 3-sigma clipping for 570
# --- 3.2145700454711914 seconds ---
# 20fold 3-sigma clipping for 571
# --- 3.1851234436035156 seconds ---
# 20fold 3-sigma clipping for 572
# --- 3.176548957824707 seconds ---
# 20fold 3-sigma clipping for 573
# --- 3.1982715129852295 seconds ---
# 20fold 3-sigma clipping for 574
# --- 3.2176473140716553 seconds ---
# 20fold 3-sigma clipping for 575
# --- 3.1746859550476074 seconds ---
# 20fold 3-sigma clipping for 576
# --- 3.191068410873413 seconds ---
# 20fold 3-sigma clipping for 577
# --- 3.1926090717315674 seconds ---
# 20fold 3-sigma clipping for 578
# --- 3.210892915725708 seconds ---
# 20fold 3-sigma clipping for 579
# --- 3.1776437759399414 seconds ---
# 20fold 3-sigma clipping for 580
# --- 3.1879608631134033 seconds ---
# 20fold 3-sigma clipping for 581
# --- 3.192622661590576 seconds ---
# 20fold 3-sigma clipping for 582
# --- 3.2162153720855713 seconds ---
# 20fold 3-sigma clipping for 583
# --- 3.1860735416412354 seconds ---
# 20fold 3-sigma clipping for 584
# --- 3.1903786659240723 seconds ---
# 20fold 3-sigma clipping for 585
# --- 3.209648847579956 seconds ---
# 20fold 3-sigma clipping for 586
# --- 3.2271244525909424 seconds ---
# 20fold 3-sigma clipping for 587
# --- 3.189107656478882 seconds ---
# 20fold 3-sigma clipping for 588
# --- 3.1867923736572266 seconds ---
# 20fold 3-sigma clipping for 589
# --- 3.2074897289276123 seconds ---
# 20fold 3-sigma clipping for 590
# --- 3.2136547565460205 seconds ---
# 20fold 3-sigma clipping for 591
# --- 3.192598819732666 seconds ---
# 20fold 3-sigma clipping for 592
# --- 3.198237180709839 seconds ---
# 20fold 3-sigma clipping for 593
# --- 3.203950881958008 seconds ---
# 20fold 3-sigma clipping for 594
# --- 3.2144293785095215 seconds ---
# 20fold 3-sigma clipping for 595
# --- 3.1801674365997314 seconds ---
# 20fold 3-sigma clipping for 596
# --- 3.177063465118408 seconds ---
# 20fold 3-sigma clipping for 597
# --- 3.1922757625579834 seconds ---
# 20fold 3-sigma clipping for 598
# --- 3.198641061782837 seconds ---
# 20fold 3-sigma clipping for 599
# --- 3.174952268600464 seconds ---
# 20fold 3-sigma clipping for 600
# --- 3.179277181625366 seconds ---
# 20fold 3-sigma clipping for 601
# --- 3.194930076599121 seconds ---
# 20fold 3-sigma clipping for 602
# --- 3.2100815773010254 seconds ---
# 20fold 3-sigma clipping for 603
# --- 3.1891918182373047 seconds ---
# 20fold 3-sigma clipping for 604
# --- 3.194694757461548 seconds ---
# 20fold 3-sigma clipping for 605
# --- 3.1925249099731445 seconds ---
# 20fold 3-sigma clipping for 606
# --- 3.2123045921325684 seconds ---
# 20fold 3-sigma clipping for 607
# --- 3.1748645305633545 seconds ---
# 20fold 3-sigma clipping for 608
# --- 3.195655345916748 seconds ---
# 20fold 3-sigma clipping for 609
# --- 3.1471126079559326 seconds ---
# 20fold 3-sigma clipping for 610
# --- 3.148592233657837 seconds ---
# 20fold 3-sigma clipping for 611
# --- 3.1287639141082764 seconds ---
# 20fold 3-sigma clipping for 612
# --- 3.118389844894409 seconds ---
# 20fold 3-sigma clipping for 613
# --- 3.135456085205078 seconds ---
# 20fold 3-sigma clipping for 614
# --- 3.1416850090026855 seconds ---
# 20fold 3-sigma clipping for 615
# --- 3.118410348892212 seconds ---
# 20fold 3-sigma clipping for 616
# --- 3.1276981830596924 seconds ---
# 20fold 3-sigma clipping for 617
# --- 3.1297788619995117 seconds ---
# 20fold 3-sigma clipping for 618
# --- 3.1452999114990234 seconds ---
# 20fold 3-sigma clipping for 619
# --- 3.115036964416504 seconds ---
# 20fold 3-sigma clipping for 620
# --- 3.118896007537842 seconds ---
# 20fold 3-sigma clipping for 621
# --- 3.1324026584625244 seconds ---
# 20fold 3-sigma clipping for 622
# --- 3.151581048965454 seconds ---
# 20fold 3-sigma clipping for 623
# --- 3.1216928958892822 seconds ---
# 20fold 3-sigma clipping for 624
# --- 3.1233878135681152 seconds ---
# 20fold 3-sigma clipping for 625
# --- 3.1338717937469482 seconds ---
# 20fold 3-sigma clipping for 626
# --- 3.1470742225646973 seconds ---
# 20fold 3-sigma clipping for 627
# --- 3.1274759769439697 seconds ---
# 20fold 3-sigma clipping for 628
# --- 3.124696969985962 seconds ---
# 20fold 3-sigma clipping for 629
# --- 3.132786750793457 seconds ---
# 20fold 3-sigma clipping for 630
# --- 3.1442997455596924 seconds ---
# 20fold 3-sigma clipping for 631
# --- 3.120389223098755 seconds ---
# 20fold 3-sigma clipping for 632
# --- 3.1228833198547363 seconds ---
# 20fold 3-sigma clipping for 633
# --- 3.139350175857544 seconds ---
# 20fold 3-sigma clipping for 634
# --- 3.153909921646118 seconds ---
# 20fold 3-sigma clipping for 635
# --- 3.1226284503936768 seconds ---
# 20fold 3-sigma clipping for 636
# --- 3.1266555786132812 seconds ---
# 20fold 3-sigma clipping for 637
# --- 3.131072998046875 seconds ---
# 20fold 3-sigma clipping for 638
# --- 3.151094436645508 seconds ---
# 20fold 3-sigma clipping for 639
# --- 3.1225008964538574 seconds ---
# 20fold 3-sigma clipping for 640
# --- 3.1288561820983887 seconds ---
# 20fold 3-sigma clipping for 641
# --- 3.1315760612487793 seconds ---
# 20fold 3-sigma clipping for 642
# --- 3.153841733932495 seconds ---
# 20fold 3-sigma clipping for 643
# --- 3.1204731464385986 seconds ---
# 20fold 3-sigma clipping for 644
# --- 3.1191701889038086 seconds ---
# 20fold 3-sigma clipping for 645
# --- 3.1342687606811523 seconds ---
# 20fold 3-sigma clipping for 646
# --- 3.150421142578125 seconds ---
# 20fold 3-sigma clipping for 647
# --- 3.1246557235717773 seconds ---
# 20fold 3-sigma clipping for 648
# --- 3.1310765743255615 seconds ---
# 20fold 3-sigma clipping for 649
# --- 3.1412065029144287 seconds ---
# 20fold 3-sigma clipping for 650
# --- 3.138537883758545 seconds ---
# 20fold 3-sigma clipping for 651
# --- 3.1182780265808105 seconds ---
# 20fold 3-sigma clipping for 652
# --- 3.114370346069336 seconds ---
# 20fold 3-sigma clipping for 653
# --- 3.1282923221588135 seconds ---
# 20fold 3-sigma clipping for 654
# --- 3.146437644958496 seconds ---
# 20fold 3-sigma clipping for 655
# --- 3.117208242416382 seconds ---
# 20fold 3-sigma clipping for 656
# --- 3.118696689605713 seconds ---
# 20fold 3-sigma clipping for 657
# --- 3.131298303604126 seconds ---
# 20fold 3-sigma clipping for 658
# --- 3.141140937805176 seconds ---
# 20fold 3-sigma clipping for 659
# --- 3.1171393394470215 seconds ---
# 20fold 3-sigma clipping for 660
# --- 3.1163620948791504 seconds ---
# 20fold 3-sigma clipping for 661
# --- 3.12990140914917 seconds ---
# 20fold 3-sigma clipping for 662
# --- 3.1371841430664062 seconds ---
# 20fold 3-sigma clipping for 663
# --- 3.127807140350342 seconds ---
# 20fold 3-sigma clipping for 664
# --- 3.1156108379364014 seconds ---
# 20fold 3-sigma clipping for 665
# --- 3.136536121368408 seconds ---
# 20fold 3-sigma clipping for 666
# --- 3.1494390964508057 seconds ---
# 20fold 3-sigma clipping for 667
# --- 3.123652219772339 seconds ---
# 20fold 3-sigma clipping for 668
# --- 3.1226706504821777 seconds ---
# 20fold 3-sigma clipping for 669
# --- 3.129551410675049 seconds ---
# 20fold 3-sigma clipping for 670
# --- 3.147554636001587 seconds ---
# 20fold 3-sigma clipping for 671
# --- 3.117957353591919 seconds ---
# 20fold 3-sigma clipping for 672
# --- 3.117194414138794 seconds ---
# 20fold 3-sigma clipping for 673
# --- 3.133739709854126 seconds ---
# 20fold 3-sigma clipping for 674
# --- 3.161313533782959 seconds ---
# 20fold 3-sigma clipping for 675
# --- 3.1226367950439453 seconds ---
# 20fold 3-sigma clipping for 676
# --- 3.1269590854644775 seconds ---
# 20fold 3-sigma clipping for 677
# --- 3.130674123764038 seconds ---
# 20fold 3-sigma clipping for 678
# --- 3.1459152698516846 seconds ---
# 20fold 3-sigma clipping for 679
# --- 3.1094138622283936 seconds ---
# 20fold 3-sigma clipping for 680
# --- 3.1147656440734863 seconds ---
# 20fold 3-sigma clipping for 681
# --- 3.122723340988159 seconds ---
# 20fold 3-sigma clipping for 682
# --- 3.1345579624176025 seconds ---
# 20fold 3-sigma clipping for 683
# --- 3.114440441131592 seconds ---
# 20fold 3-sigma clipping for 684
# --- 3.1175942420959473 seconds ---
# 20fold 3-sigma clipping for 685
# --- 3.1286520957946777 seconds ---
# 20fold 3-sigma clipping for 686
# --- 3.153031826019287 seconds ---
# 20fold 3-sigma clipping for 687
# --- 3.115652084350586 seconds ---
# 20fold 3-sigma clipping for 688
# --- 3.1173646450042725 seconds ---
# 20fold 3-sigma clipping for 689
# --- 3.134782314300537 seconds ---
# 20fold 3-sigma clipping for 690
# --- 3.1484344005584717 seconds ---
# 20fold 3-sigma clipping for 691
# --- 3.1198883056640625 seconds ---
# 20fold 3-sigma clipping for 692
# --- 3.122238874435425 seconds ---
# 20fold 3-sigma clipping for 693
# --- 3.1330533027648926 seconds ---
# 20fold 3-sigma clipping for 694
# --- 3.1450717449188232 seconds ---
# 20fold 3-sigma clipping for 695
# --- 3.128990650177002 seconds ---
# 20fold 3-sigma clipping for 696
# --- 3.121565818786621 seconds ---
# 20fold 3-sigma clipping for 697
# --- 3.1520485877990723 seconds ---
# 20fold 3-sigma clipping for 698
# --- 3.1551828384399414 seconds ---
# 20fold 3-sigma clipping for 699
# --- 3.1260898113250732 seconds ---
# 20fold 3-sigma clipping for 700
# --- 3.119112253189087 seconds ---
# 20fold 3-sigma clipping for 701
# --- 3.1337788105010986 seconds ---
# 20fold 3-sigma clipping for 702
# --- 3.1488959789276123 seconds ---
# 20fold 3-sigma clipping for 703
# --- 3.1199862957000732 seconds ---
# 20fold 3-sigma clipping for 704
# --- 3.1156482696533203 seconds ---
# 20fold 3-sigma clipping for 705
# --- 3.1399285793304443 seconds ---
# 20fold 3-sigma clipping for 706
# --- 3.1446263790130615 seconds ---
# 20fold 3-sigma clipping for 707
# --- 3.1225314140319824 seconds ---
# 20fold 3-sigma clipping for 708
# --- 3.12424898147583 seconds ---
# 20fold 3-sigma clipping for 709
# --- 3.14994478225708 seconds ---
# 20fold 3-sigma clipping for 710
# --- 3.155280590057373 seconds ---
# 20fold 3-sigma clipping for 711
# --- 3.112229108810425 seconds ---
# 20fold 3-sigma clipping for 712
# --- 3.1192398071289062 seconds ---
# 20fold 3-sigma clipping for 713
# --- 3.143923044204712 seconds ---
# 20fold 3-sigma clipping for 714
# --- 3.150438070297241 seconds ---
# 20fold 3-sigma clipping for 715
# --- 3.1199593544006348 seconds ---
# 20fold 3-sigma clipping for 716
# --- 3.1376399993896484 seconds ---
# 20fold 3-sigma clipping for 717
# --- 3.141792058944702 seconds ---
# 20fold 3-sigma clipping for 718
# --- 3.162219762802124 seconds ---
# 20fold 3-sigma clipping for 719
# --- 3.132446050643921 seconds ---
# 20fold 3-sigma clipping for 720
# --- 3.132551908493042 seconds ---
# 20fold 3-sigma clipping for 721
# --- 3.15034556388855 seconds ---
# 20fold 3-sigma clipping for 722
# --- 3.156223773956299 seconds ---
# 20fold 3-sigma clipping for 723
# --- 3.137730598449707 seconds ---
# 20fold 3-sigma clipping for 724
# --- 3.1373369693756104 seconds ---
# 20fold 3-sigma clipping for 725
# --- 3.153088331222534 seconds ---
# 20fold 3-sigma clipping for 726
# --- 3.1672704219818115 seconds ---
# 20fold 3-sigma clipping for 727
# --- 3.1393439769744873 seconds ---
# 20fold 3-sigma clipping for 728
# --- 3.1603596210479736 seconds ---
# 20fold 3-sigma clipping for 729
# --- 3.1514289379119873 seconds ---
# 20fold 3-sigma clipping for 730
# --- 3.1733224391937256 seconds ---
# 20fold 3-sigma clipping for 731
# --- 3.1340372562408447 seconds ---
# 20fold 3-sigma clipping for 732
# --- 3.1400914192199707 seconds ---
# 20fold 3-sigma clipping for 733
# --- 3.1543235778808594 seconds ---
# 20fold 3-sigma clipping for 734
# --- 3.170874834060669 seconds ---
# 20fold 3-sigma clipping for 735
# --- 3.122331380844116 seconds ---
# 20fold 3-sigma clipping for 736
# --- 3.131692886352539 seconds ---
# 20fold 3-sigma clipping for 737
# --- 3.152056932449341 seconds ---
# 20fold 3-sigma clipping for 738
# --- 3.1705808639526367 seconds ---
# 20fold 3-sigma clipping for 739
# --- 3.1341216564178467 seconds ---
# 20fold 3-sigma clipping for 740
# --- 3.1433663368225098 seconds ---
# 20fold 3-sigma clipping for 741
# --- 3.1545486450195312 seconds ---
# 20fold 3-sigma clipping for 742
# --- 3.166541576385498 seconds ---
# 20fold 3-sigma clipping for 743
# --- 3.1289069652557373 seconds ---
# 20fold 3-sigma clipping for 744
# --- 3.1356828212738037 seconds ---
# 20fold 3-sigma clipping for 745
# --- 3.142899513244629 seconds ---
# 20fold 3-sigma clipping for 746
# --- 3.159223794937134 seconds ---
# 20fold 3-sigma clipping for 747
# --- 3.1390953063964844 seconds ---
# 20fold 3-sigma clipping for 748
# --- 3.1416983604431152 seconds ---
# 20fold 3-sigma clipping for 749
# --- 3.1544322967529297 seconds ---
# 20fold 3-sigma clipping for 750
# --- 3.15568208694458 seconds ---
# 20fold 3-sigma clipping for 751
# --- 3.1396782398223877 seconds ---
# 20fold 3-sigma clipping for 752
# --- 3.138242483139038 seconds ---
# 20fold 3-sigma clipping for 753
# --- 3.1601219177246094 seconds ---
# 20fold 3-sigma clipping for 754
# --- 3.1589298248291016 seconds ---
# 20fold 3-sigma clipping for 755
# --- 3.1442689895629883 seconds ---
# 20fold 3-sigma clipping for 756
# --- 3.1354968547821045 seconds ---
# 20fold 3-sigma clipping for 757
# --- 3.1473546028137207 seconds ---
# 20fold 3-sigma clipping for 758
# --- 3.1735639572143555 seconds ---
# 20fold 3-sigma clipping for 759
# --- 3.150116443634033 seconds ---
# 20fold 3-sigma clipping for 760
# --- 3.138617515563965 seconds ---
# 20fold 3-sigma clipping for 761
# --- 3.161747694015503 seconds ---
# 20fold 3-sigma clipping for 762
# --- 3.16517972946167 seconds ---
# 20fold 3-sigma clipping for 763
# --- 3.1366841793060303 seconds ---
# 20fold 3-sigma clipping for 764
# --- 3.1370415687561035 seconds ---
# 20fold 3-sigma clipping for 765
# --- 3.154632329940796 seconds ---
# 20fold 3-sigma clipping for 766
# --- 3.1683316230773926 seconds ---
# 20fold 3-sigma clipping for 767
# --- 3.1357452869415283 seconds ---
# 20fold 3-sigma clipping for 768
# --- 3.1488704681396484 seconds ---
# 20fold 3-sigma clipping for 769
# --- 3.1536240577697754 seconds ---
# 20fold 3-sigma clipping for 770
# --- 3.162522792816162 seconds ---
# 20fold 3-sigma clipping for 771
# --- 3.12611722946167 seconds ---
# 20fold 3-sigma clipping for 772
# --- 3.1459386348724365 seconds ---
# 20fold 3-sigma clipping for 773
# --- 3.149570941925049 seconds ---
# 20fold 3-sigma clipping for 774
# --- 3.169511079788208 seconds ---
# 20fold 3-sigma clipping for 775
# --- 3.1447486877441406 seconds ---
# 20fold 3-sigma clipping for 776
# --- 3.1443521976470947 seconds ---
# 20fold 3-sigma clipping for 777
# --- 3.147961378097534 seconds ---
# 20fold 3-sigma clipping for 778
# --- 3.1664223670959473 seconds ---
# 20fold 3-sigma clipping for 779
# --- 3.1415092945098877 seconds ---
# 20fold 3-sigma clipping for 780
# --- 3.1447510719299316 seconds ---
# 20fold 3-sigma clipping for 781
# --- 3.1463119983673096 seconds ---
# 20fold 3-sigma clipping for 782
# --- 3.1656270027160645 seconds ---
# 20fold 3-sigma clipping for 783
# --- 3.137547492980957 seconds ---
# 20fold 3-sigma clipping for 784
# --- 3.1494197845458984 seconds ---
# 20fold 3-sigma clipping for 785
# --- 3.154163360595703 seconds ---
# 20fold 3-sigma clipping for 786
# --- 3.1670286655426025 seconds ---
# 20fold 3-sigma clipping for 787
# --- 3.1450445652008057 seconds ---
# 20fold 3-sigma clipping for 788
# --- 3.131075859069824 seconds ---
# 20fold 3-sigma clipping for 789
# --- 3.1427197456359863 seconds ---
# 20fold 3-sigma clipping for 790
# --- 3.176748514175415 seconds ---
# 20fold 3-sigma clipping for 791
# --- 3.1531975269317627 seconds ---
# 20fold 3-sigma clipping for 792
# --- 3.1482934951782227 seconds ---
# 20fold 3-sigma clipping for 793
# --- 3.158196210861206 seconds ---
# 20fold 3-sigma clipping for 794
# --- 3.170238971710205 seconds ---
# 20fold 3-sigma clipping for 795
# --- 3.1357805728912354 seconds ---
# 20fold 3-sigma clipping for 796
# --- 3.1303369998931885 seconds ---
# 20fold 3-sigma clipping for 797
# --- 3.146395444869995 seconds ---
# 20fold 3-sigma clipping for 798
# --- 3.1674721240997314 seconds ---
# 20fold 3-sigma clipping for 799
# --- 3.143237352371216 seconds ---
# 20fold 3-sigma clipping for 800
# --- 3.1544857025146484 seconds ---
# 20fold 3-sigma clipping for 801
# --- 3.1690409183502197 seconds ---
# 20fold 3-sigma clipping for 802
# --- 3.173910617828369 seconds ---
# 20fold 3-sigma clipping for 803
# --- 3.137968063354492 seconds ---
# 20fold 3-sigma clipping for 804
# --- 3.1293463706970215 seconds ---
# 20fold 3-sigma clipping for 805
# --- 3.1555185317993164 seconds ---
# 20fold 3-sigma clipping for 806
# --- 3.1735856533050537 seconds ---
# 20fold 3-sigma clipping for 807
# --- 3.146501064300537 seconds ---
# 20fold 3-sigma clipping for 808
# --- 3.1391289234161377 seconds ---
# 20fold 3-sigma clipping for 809
# --- 3.155730962753296 seconds ---
# 20fold 3-sigma clipping for 810
# --- 3.15964937210083 seconds ---
# 20fold 3-sigma clipping for 811
# --- 3.150912284851074 seconds ---
# 20fold 3-sigma clipping for 812
# --- 3.143219470977783 seconds ---
# 20fold 3-sigma clipping for 813
# --- 3.1571314334869385 seconds ---
# 20fold 3-sigma clipping for 814
# --- 3.172585964202881 seconds ---
# 20fold 3-sigma clipping for 815
# --- 3.1362085342407227 seconds ---
# 20fold 3-sigma clipping for 816
# --- 3.1395604610443115 seconds ---
# 20fold 3-sigma clipping for 817
# --- 3.150862693786621 seconds ---
# 20fold 3-sigma clipping for 818
# --- 3.1672003269195557 seconds ---
# 20fold 3-sigma clipping for 819
# --- 3.1269986629486084 seconds ---
# 20fold 3-sigma clipping for 820
# --- 3.130758285522461 seconds ---
# 20fold 3-sigma clipping for 821
# --- 3.15665864944458 seconds ---
# 20fold 3-sigma clipping for 822
# --- 3.1655657291412354 seconds ---
# 20fold 3-sigma clipping for 823
# --- 3.13958477973938 seconds ---
# 20fold 3-sigma clipping for 824
# --- 3.1374197006225586 seconds ---
# 20fold 3-sigma clipping for 825
# --- 3.157130718231201 seconds ---
# 20fold 3-sigma clipping for 826
# --- 3.1595938205718994 seconds ---
# 20fold 3-sigma clipping for 827
# --- 3.1422765254974365 seconds ---
# 20fold 3-sigma clipping for 828
# --- 3.1415443420410156 seconds ---
# 20fold 3-sigma clipping for 829
# --- 3.1469125747680664 seconds ---
# 20fold 3-sigma clipping for 830
# --- 3.1627092361450195 seconds ---
# 20fold 3-sigma clipping for 831
# --- 3.132253885269165 seconds ---
# 20fold 3-sigma clipping for 832
# --- 3.1347811222076416 seconds ---
# 20fold 3-sigma clipping for 833
# --- 3.1522088050842285 seconds ---
# 20fold 3-sigma clipping for 834
# --- 3.173621654510498 seconds ---
# 20fold 3-sigma clipping for 835
# --- 3.143019199371338 seconds ---
# 20fold 3-sigma clipping for 836
# --- 3.128174066543579 seconds ---
# 20fold 3-sigma clipping for 837
# --- 3.1519410610198975 seconds ---
# 20fold 3-sigma clipping for 838
# --- 3.1672894954681396 seconds ---
# 20fold 3-sigma clipping for 839
# --- 3.137918472290039 seconds ---
# 20fold 3-sigma clipping for 840
# --- 3.13847279548645 seconds ---
# 20fold 3-sigma clipping for 841
# --- 3.1519522666931152 seconds ---
# 20fold 3-sigma clipping for 842
# --- 3.170806884765625 seconds ---
# 20fold 3-sigma clipping for 843
# --- 3.13706636428833 seconds ---
# 20fold 3-sigma clipping for 844
# --- 3.145120859146118 seconds ---
# 20fold 3-sigma clipping for 845
# --- 3.1457955837249756 seconds ---
# 20fold 3-sigma clipping for 846
# --- 3.1728761196136475 seconds ---
# 20fold 3-sigma clipping for 847
# --- 3.1403722763061523 seconds ---
# 20fold 3-sigma clipping for 848
# --- 3.134648561477661 seconds ---
# 20fold 3-sigma clipping for 849
# --- 3.1472384929656982 seconds ---
# 20fold 3-sigma clipping for 850
# --- 3.1595141887664795 seconds ---
# 20fold 3-sigma clipping for 851
# --- 3.1274893283843994 seconds ---
# 20fold 3-sigma clipping for 852
# --- 3.1443705558776855 seconds ---
# 20fold 3-sigma clipping for 853
# --- 3.162071466445923 seconds ---
# 20fold 3-sigma clipping for 854
# --- 3.1695501804351807 seconds ---
# 20fold 3-sigma clipping for 855
# --- 3.141737699508667 seconds ---
# 20fold 3-sigma clipping for 856
# --- 3.1539275646209717 seconds ---
# 20fold 3-sigma clipping for 857
# --- 3.1623613834381104 seconds ---
# 20fold 3-sigma clipping for 858
# --- 3.1754941940307617 seconds ---
# 20fold 3-sigma clipping for 859
# --- 3.148853063583374 seconds ---
# 20fold 3-sigma clipping for 860
# --- 3.1458005905151367 seconds ---
# 20fold 3-sigma clipping for 861
# --- 3.160048484802246 seconds ---
# 20fold 3-sigma clipping for 862
# --- 3.1721832752227783 seconds ---
# 20fold 3-sigma clipping for 863
# --- 3.144254684448242 seconds ---
# 20fold 3-sigma clipping for 864
# --- 3.160781145095825 seconds ---
# 20fold 3-sigma clipping for 865
# --- 3.1522088050842285 seconds ---
# 20fold 3-sigma clipping for 866
# --- 3.172642230987549 seconds ---
# 20fold 3-sigma clipping for 867
# --- 3.136969566345215 seconds ---
# 20fold 3-sigma clipping for 868
# --- 3.15148663520813 seconds ---
# 20fold 3-sigma clipping for 869
# --- 3.162777900695801 seconds ---
# 20fold 3-sigma clipping for 870
# --- 3.1757190227508545 seconds ---
# 20fold 3-sigma clipping for 871
# --- 3.1430370807647705 seconds ---

# %%
# -- data proprecessing for the image from row0 to row800
filtered_hsi0_half1 = sigma_clipping(cube0, "half1")
np.save("filtered_hsi0_half1.npy", filtered_hsi0_half1)
# Out:
# 20fold 3-sigma clipping for 0
# --- 3.186441421508789 seconds ---
# 20fold 3-sigma clipping for 1
# --- 3.1622979640960693 seconds ---
# 20fold 3-sigma clipping for 2
# --- 3.1699509620666504 seconds ---
# 20fold 3-sigma clipping for 3
# --- 3.1476449966430664 seconds ---
# 20fold 3-sigma clipping for 4
# --- 3.1399669647216797 seconds ---
# 20fold 3-sigma clipping for 5
# --- 3.161386728286743 seconds ---
# 20fold 3-sigma clipping for 6
# --- 3.170823097229004 seconds ---
# 20fold 3-sigma clipping for 7
# --- 3.14776611328125 seconds ---
# 20fold 3-sigma clipping for 8
# --- 3.1494879722595215 seconds ---
# 20fold 3-sigma clipping for 9
# --- 3.1618974208831787 seconds ---
# 20fold 3-sigma clipping for 10
# --- 3.1744296550750732 seconds ---
# 20fold 3-sigma clipping for 11
# --- 3.1531496047973633 seconds ---
# 20fold 3-sigma clipping for 12
# --- 3.1533358097076416 seconds ---
# 20fold 3-sigma clipping for 13
# --- 3.166187047958374 seconds ---
# 20fold 3-sigma clipping for 14
# --- 3.17922043800354 seconds ---
# 20fold 3-sigma clipping for 15
# --- 3.149932622909546 seconds ---
# 20fold 3-sigma clipping for 16
# --- 3.1527013778686523 seconds ---
# 20fold 3-sigma clipping for 17
# --- 3.1668336391448975 seconds ---
# 20fold 3-sigma clipping for 18
# --- 3.179185628890991 seconds ---
# 20fold 3-sigma clipping for 19
# --- 3.1516618728637695 seconds ---
# 20fold 3-sigma clipping for 20
# --- 3.154475450515747 seconds ---
# 20fold 3-sigma clipping for 21
# --- 3.1653807163238525 seconds ---
# 20fold 3-sigma clipping for 22
# --- 3.188113212585449 seconds ---
# 20fold 3-sigma clipping for 23
# --- 3.1660146713256836 seconds ---
# 20fold 3-sigma clipping for 24
# --- 3.1533544063568115 seconds ---
# 20fold 3-sigma clipping for 25
# --- 3.157839775085449 seconds ---
# 20fold 3-sigma clipping for 26
# --- 3.1887218952178955 seconds ---
# 20fold 3-sigma clipping for 27
# --- 3.139834403991699 seconds ---
# 20fold 3-sigma clipping for 28
# --- 3.142035961151123 seconds ---
# 20fold 3-sigma clipping for 29
# --- 3.160200595855713 seconds ---
# 20fold 3-sigma clipping for 30
# --- 3.169619560241699 seconds ---
# 20fold 3-sigma clipping for 31
# --- 3.1587283611297607 seconds ---
# 20fold 3-sigma clipping for 32
# --- 3.148287534713745 seconds ---
# 20fold 3-sigma clipping for 33
# --- 3.166888952255249 seconds ---
# 20fold 3-sigma clipping for 34
# --- 3.1732826232910156 seconds ---
# 20fold 3-sigma clipping for 35
# --- 3.1363580226898193 seconds ---
# 20fold 3-sigma clipping for 36
# --- 3.130682945251465 seconds ---
# 20fold 3-sigma clipping for 37
# --- 3.152726411819458 seconds ---
# 20fold 3-sigma clipping for 38
# --- 3.170198678970337 seconds ---
# 20fold 3-sigma clipping for 39
# --- 3.13582706451416 seconds ---
# 20fold 3-sigma clipping for 40
# --- 3.1388864517211914 seconds ---
# 20fold 3-sigma clipping for 41
# --- 3.155182123184204 seconds ---
# 20fold 3-sigma clipping for 42
# --- 3.1814920902252197 seconds ---
# 20fold 3-sigma clipping for 43
# --- 3.146239995956421 seconds ---
# 20fold 3-sigma clipping for 44
# --- 3.1519689559936523 seconds ---
# 20fold 3-sigma clipping for 45
# --- 3.1657590866088867 seconds ---
# 20fold 3-sigma clipping for 46
# --- 3.165318489074707 seconds ---
# 20fold 3-sigma clipping for 47
# --- 3.143674850463867 seconds ---
# 20fold 3-sigma clipping for 48
# --- 3.1366403102874756 seconds ---
# 20fold 3-sigma clipping for 49
# --- 3.138531446456909 seconds ---
# 20fold 3-sigma clipping for 50
# --- 3.1632208824157715 seconds ---
# 20fold 3-sigma clipping for 51
# --- 3.1364316940307617 seconds ---
# 20fold 3-sigma clipping for 52
# --- 3.141162157058716 seconds ---
# 20fold 3-sigma clipping for 53
# --- 3.1470751762390137 seconds ---
# 20fold 3-sigma clipping for 54
# --- 3.1713709831237793 seconds ---
# 20fold 3-sigma clipping for 55
# --- 3.1448264122009277 seconds ---
# 20fold 3-sigma clipping for 56
# --- 3.1510276794433594 seconds ---
# 20fold 3-sigma clipping for 57
# --- 3.1528916358947754 seconds ---
# 20fold 3-sigma clipping for 58
# --- 3.1659278869628906 seconds ---
# 20fold 3-sigma clipping for 59
# --- 3.1358206272125244 seconds ---
# 20fold 3-sigma clipping for 60
# --- 3.1348772048950195 seconds ---
# 20fold 3-sigma clipping for 61
# --- 3.1443419456481934 seconds ---
# 20fold 3-sigma clipping for 62
# --- 3.17016863822937 seconds ---
# 20fold 3-sigma clipping for 63
# --- 3.142972707748413 seconds ---
# 20fold 3-sigma clipping for 64
# --- 3.139077663421631 seconds ---
# 20fold 3-sigma clipping for 65
# --- 3.1436710357666016 seconds ---
# 20fold 3-sigma clipping for 66
# --- 3.1624372005462646 seconds ---
# 20fold 3-sigma clipping for 67
# --- 3.1237003803253174 seconds ---
# 20fold 3-sigma clipping for 68
# --- 3.1340277194976807 seconds ---
# 20fold 3-sigma clipping for 69
# --- 3.150827407836914 seconds ---
# 20fold 3-sigma clipping for 70
# --- 3.1643855571746826 seconds ---
# 20fold 3-sigma clipping for 71
# --- 3.1327970027923584 seconds ---
# 20fold 3-sigma clipping for 72
# --- 3.1303412914276123 seconds ---
# 20fold 3-sigma clipping for 73
# --- 3.150675058364868 seconds ---
# 20fold 3-sigma clipping for 74
# --- 3.1641504764556885 seconds ---
# 20fold 3-sigma clipping for 75
# --- 3.1391093730926514 seconds ---
# 20fold 3-sigma clipping for 76
# --- 3.1375081539154053 seconds ---
# 20fold 3-sigma clipping for 77
# --- 3.164702892303467 seconds ---
# 20fold 3-sigma clipping for 78
# --- 3.1648154258728027 seconds ---
# 20fold 3-sigma clipping for 79
# --- 3.141911506652832 seconds ---
# 20fold 3-sigma clipping for 80
# --- 3.124450445175171 seconds ---
# 20fold 3-sigma clipping for 81
# --- 3.1500401496887207 seconds ---
# 20fold 3-sigma clipping for 82
# --- 3.163423776626587 seconds ---
# 20fold 3-sigma clipping for 83
# --- 3.136686086654663 seconds ---
# 20fold 3-sigma clipping for 84
# --- 3.149409532546997 seconds ---
# 20fold 3-sigma clipping for 85
# --- 3.164548873901367 seconds ---
# 20fold 3-sigma clipping for 86
# --- 3.174875497817993 seconds ---
# 20fold 3-sigma clipping for 87
# --- 3.1411287784576416 seconds ---
# 20fold 3-sigma clipping for 88
# --- 3.1386053562164307 seconds ---
# 20fold 3-sigma clipping for 89
# --- 3.1504769325256348 seconds ---
# 20fold 3-sigma clipping for 90
# --- 3.156022310256958 seconds ---
# 20fold 3-sigma clipping for 91
# --- 3.132216215133667 seconds ---
# 20fold 3-sigma clipping for 92
# --- 3.1370882987976074 seconds ---
# 20fold 3-sigma clipping for 93
# --- 3.152454376220703 seconds ---
# 20fold 3-sigma clipping for 94
# --- 3.177664279937744 seconds ---
# 20fold 3-sigma clipping for 95
# --- 3.1442580223083496 seconds ---
# 20fold 3-sigma clipping for 96
# --- 3.142730236053467 seconds ---
# 20fold 3-sigma clipping for 97
# --- 3.1534852981567383 seconds ---
# 20fold 3-sigma clipping for 98
# --- 3.1638762950897217 seconds ---
# 20fold 3-sigma clipping for 99
# --- 3.1325087547302246 seconds ---
# 20fold 3-sigma clipping for 100
# --- 3.143566608428955 seconds ---
# 20fold 3-sigma clipping for 101
# --- 3.1527717113494873 seconds ---
# 20fold 3-sigma clipping for 102
# --- 3.1709177494049072 seconds ---
# 20fold 3-sigma clipping for 103
# --- 3.138662576675415 seconds ---
# 20fold 3-sigma clipping for 104
# --- 3.1435470581054688 seconds ---
# 20fold 3-sigma clipping for 105
# --- 3.1602530479431152 seconds ---
# 20fold 3-sigma clipping for 106
# --- 3.1761012077331543 seconds ---
# 20fold 3-sigma clipping for 107
# --- 3.1401774883270264 seconds ---
# 20fold 3-sigma clipping for 108
# --- 3.131301164627075 seconds ---
# 20fold 3-sigma clipping for 109
# --- 3.134916305541992 seconds ---
# 20fold 3-sigma clipping for 110
# --- 3.16245174407959 seconds ---
# 20fold 3-sigma clipping for 111
# --- 3.120858669281006 seconds ---
# 20fold 3-sigma clipping for 112
# --- 3.124882459640503 seconds ---
# 20fold 3-sigma clipping for 113
# --- 3.141698122024536 seconds ---
# 20fold 3-sigma clipping for 114
# --- 3.151841878890991 seconds ---
# 20fold 3-sigma clipping for 115
# --- 3.1294562816619873 seconds ---
# 20fold 3-sigma clipping for 116
# --- 3.1356260776519775 seconds ---
# 20fold 3-sigma clipping for 117
# --- 3.1475539207458496 seconds ---
# 20fold 3-sigma clipping for 118
# --- 3.1660239696502686 seconds ---
# 20fold 3-sigma clipping for 119
# --- 3.127261161804199 seconds ---
# 20fold 3-sigma clipping for 120
# --- 3.1298036575317383 seconds ---
# 20fold 3-sigma clipping for 121
# --- 3.1413400173187256 seconds ---
# 20fold 3-sigma clipping for 122
# --- 3.1587040424346924 seconds ---
# 20fold 3-sigma clipping for 123
# --- 3.1270253658294678 seconds ---
# 20fold 3-sigma clipping for 124
# --- 3.1263883113861084 seconds ---
# 20fold 3-sigma clipping for 125
# --- 3.1560275554656982 seconds ---
# 20fold 3-sigma clipping for 126
# --- 3.1705851554870605 seconds ---
# 20fold 3-sigma clipping for 127
# --- 3.1295979022979736 seconds ---
# 20fold 3-sigma clipping for 128
# --- 3.1232216358184814 seconds ---
# 20fold 3-sigma clipping for 129
# --- 3.138561487197876 seconds ---
# 20fold 3-sigma clipping for 130
# --- 3.157559871673584 seconds ---
# 20fold 3-sigma clipping for 131
# --- 3.130788564682007 seconds ---
# 20fold 3-sigma clipping for 132
# --- 3.12955641746521 seconds ---
# 20fold 3-sigma clipping for 133
# --- 3.1452102661132812 seconds ---
# 20fold 3-sigma clipping for 134
# --- 3.1629250049591064 seconds ---
# 20fold 3-sigma clipping for 135
# --- 3.12813663482666 seconds ---
# 20fold 3-sigma clipping for 136
# --- 3.1535720825195312 seconds ---
# 20fold 3-sigma clipping for 137
# --- 3.1523499488830566 seconds ---
# 20fold 3-sigma clipping for 138
# --- 3.174630641937256 seconds ---
# 20fold 3-sigma clipping for 139
# --- 3.147965669631958 seconds ---
# 20fold 3-sigma clipping for 140
# --- 3.151768445968628 seconds ---
# 20fold 3-sigma clipping for 141
# --- 3.1638758182525635 seconds ---
# 20fold 3-sigma clipping for 142
# --- 3.1843223571777344 seconds ---
# 20fold 3-sigma clipping for 143
# --- 3.1377615928649902 seconds ---
# 20fold 3-sigma clipping for 144
# --- 3.140878200531006 seconds ---
# 20fold 3-sigma clipping for 145
# --- 3.1467576026916504 seconds ---
# 20fold 3-sigma clipping for 146
# --- 3.174037218093872 seconds ---
# 20fold 3-sigma clipping for 147
# --- 3.1546380519866943 seconds ---
# 20fold 3-sigma clipping for 148
# --- 3.1562681198120117 seconds ---
# 20fold 3-sigma clipping for 149
# --- 3.1688051223754883 seconds ---
# 20fold 3-sigma clipping for 150
# --- 3.184623956680298 seconds ---
# 20fold 3-sigma clipping for 151
# --- 3.149374008178711 seconds ---
# 20fold 3-sigma clipping for 152
# --- 3.1515920162200928 seconds ---
# 20fold 3-sigma clipping for 153
# --- 3.166388750076294 seconds ---
# 20fold 3-sigma clipping for 154
# --- 3.175894260406494 seconds ---
# 20fold 3-sigma clipping for 155
# --- 3.1490936279296875 seconds ---
# 20fold 3-sigma clipping for 156
# --- 3.156172275543213 seconds ---
# 20fold 3-sigma clipping for 157
# --- 3.1713457107543945 seconds ---
# 20fold 3-sigma clipping for 158
# --- 3.178542137145996 seconds ---
# 20fold 3-sigma clipping for 159
# --- 3.1536169052124023 seconds ---
# 20fold 3-sigma clipping for 160
# --- 3.142916679382324 seconds ---
# 20fold 3-sigma clipping for 161
# --- 3.172640562057495 seconds ---
# 20fold 3-sigma clipping for 162
# --- 3.1838929653167725 seconds ---
# 20fold 3-sigma clipping for 163
# --- 3.144718647003174 seconds ---
# 20fold 3-sigma clipping for 164
# --- 3.145155906677246 seconds ---
# 20fold 3-sigma clipping for 165
# --- 3.1531622409820557 seconds ---
# 20fold 3-sigma clipping for 166
# --- 3.1618971824645996 seconds ---
# 20fold 3-sigma clipping for 167
# --- 3.140897274017334 seconds ---
# 20fold 3-sigma clipping for 168
# --- 3.137349843978882 seconds ---
# 20fold 3-sigma clipping for 169
# --- 3.1512160301208496 seconds ---
# 20fold 3-sigma clipping for 170
# --- 3.1853644847869873 seconds ---
# 20fold 3-sigma clipping for 171
# --- 3.146258592605591 seconds ---
# 20fold 3-sigma clipping for 172
# --- 3.1561477184295654 seconds ---
# 20fold 3-sigma clipping for 173
# --- 3.1585729122161865 seconds ---
# 20fold 3-sigma clipping for 174
# --- 3.171314001083374 seconds ---
# 20fold 3-sigma clipping for 175
# --- 3.142889976501465 seconds ---
# 20fold 3-sigma clipping for 176
# --- 3.14982533454895 seconds ---
# 20fold 3-sigma clipping for 177
# --- 3.159512519836426 seconds ---
# 20fold 3-sigma clipping for 178
# --- 3.176666498184204 seconds ---
# 20fold 3-sigma clipping for 179
# --- 3.1446259021759033 seconds ---
# 20fold 3-sigma clipping for 180
# --- 3.1566643714904785 seconds ---
# 20fold 3-sigma clipping for 181
# --- 3.164522171020508 seconds ---
# 20fold 3-sigma clipping for 182
# --- 3.1752727031707764 seconds ---
# 20fold 3-sigma clipping for 183
# --- 3.148405075073242 seconds ---
# 20fold 3-sigma clipping for 184
# --- 3.1506965160369873 seconds ---
# 20fold 3-sigma clipping for 185
# --- 3.164978265762329 seconds ---
# 20fold 3-sigma clipping for 186
# --- 3.169301748275757 seconds ---
# 20fold 3-sigma clipping for 187
# --- 3.141725540161133 seconds ---
# 20fold 3-sigma clipping for 188
# --- 3.1459884643554688 seconds ---
# 20fold 3-sigma clipping for 189
# --- 3.150644302368164 seconds ---
# 20fold 3-sigma clipping for 190
# --- 3.1789395809173584 seconds ---
# 20fold 3-sigma clipping for 191
# --- 3.156754970550537 seconds ---
# 20fold 3-sigma clipping for 192
# --- 3.144557237625122 seconds ---
# 20fold 3-sigma clipping for 193
# --- 3.167881727218628 seconds ---
# 20fold 3-sigma clipping for 194
# --- 3.1716630458831787 seconds ---
# 20fold 3-sigma clipping for 195
# --- 3.140907049179077 seconds ---
# 20fold 3-sigma clipping for 196
# --- 3.138787031173706 seconds ---
# 20fold 3-sigma clipping for 197
# --- 3.1527819633483887 seconds ---
# 20fold 3-sigma clipping for 198
# --- 3.176632881164551 seconds ---
# 20fold 3-sigma clipping for 199
# --- 3.161794424057007 seconds ---
# 20fold 3-sigma clipping for 200
# --- 3.1490137577056885 seconds ---
# 20fold 3-sigma clipping for 201
# --- 3.1680006980895996 seconds ---
# 20fold 3-sigma clipping for 202
# --- 3.1820857524871826 seconds ---
# 20fold 3-sigma clipping for 203
# --- 3.152026414871216 seconds ---
# 20fold 3-sigma clipping for 204
# --- 3.1498312950134277 seconds ---
# 20fold 3-sigma clipping for 205
# --- 3.1564218997955322 seconds ---
# 20fold 3-sigma clipping for 206
# --- 3.185556173324585 seconds ---
# 20fold 3-sigma clipping for 207
# --- 3.15077543258667 seconds ---
# 20fold 3-sigma clipping for 208
# --- 3.1511893272399902 seconds ---
# 20fold 3-sigma clipping for 209
# --- 3.1672050952911377 seconds ---
# 20fold 3-sigma clipping for 210
# --- 3.18686842918396 seconds ---
# 20fold 3-sigma clipping for 211
# --- 3.161172389984131 seconds ---
# 20fold 3-sigma clipping for 212
# --- 3.1441237926483154 seconds ---
# 20fold 3-sigma clipping for 213
# --- 3.1684141159057617 seconds ---
# 20fold 3-sigma clipping for 214
# --- 3.1812922954559326 seconds ---
# 20fold 3-sigma clipping for 215
# --- 3.1515674591064453 seconds ---
# 20fold 3-sigma clipping for 216
# --- 3.133256673812866 seconds ---
# 20fold 3-sigma clipping for 217
# --- 3.1512904167175293 seconds ---
# 20fold 3-sigma clipping for 218
# --- 3.153726577758789 seconds ---
# 20fold 3-sigma clipping for 219
# --- 3.1239583492279053 seconds ---
# 20fold 3-sigma clipping for 220
# --- 3.1306872367858887 seconds ---
# 20fold 3-sigma clipping for 221
# --- 3.167052984237671 seconds ---
# 20fold 3-sigma clipping for 222
# --- 3.166713237762451 seconds ---
# 20fold 3-sigma clipping for 223
# --- 3.142238140106201 seconds ---
# 20fold 3-sigma clipping for 224
# --- 3.141740560531616 seconds ---
# 20fold 3-sigma clipping for 225
# --- 3.1468520164489746 seconds ---
# 20fold 3-sigma clipping for 226
# --- 3.159668207168579 seconds ---
# 20fold 3-sigma clipping for 227
# --- 3.1418442726135254 seconds ---
# 20fold 3-sigma clipping for 228
# --- 3.1373093128204346 seconds ---
# 20fold 3-sigma clipping for 229
# --- 3.1551146507263184 seconds ---
# 20fold 3-sigma clipping for 230
# --- 3.169816493988037 seconds ---
# 20fold 3-sigma clipping for 231
# --- 3.1459200382232666 seconds ---
# 20fold 3-sigma clipping for 232
# --- 3.1375770568847656 seconds ---
# 20fold 3-sigma clipping for 233
# --- 3.147646427154541 seconds ---
# 20fold 3-sigma clipping for 234
# --- 3.159235715866089 seconds ---
# 20fold 3-sigma clipping for 235
# --- 3.126699447631836 seconds ---
# 20fold 3-sigma clipping for 236
# --- 3.1454713344573975 seconds ---
# 20fold 3-sigma clipping for 237
# --- 3.1686081886291504 seconds ---
# 20fold 3-sigma clipping for 238
# --- 3.1825692653656006 seconds ---
# 20fold 3-sigma clipping for 239
# --- 3.1602823734283447 seconds ---
# 20fold 3-sigma clipping for 240
# --- 3.151628017425537 seconds ---
# 20fold 3-sigma clipping for 241
# --- 3.1616735458374023 seconds ---
# 20fold 3-sigma clipping for 242
# --- 3.1738216876983643 seconds ---
# 20fold 3-sigma clipping for 243
# --- 3.1368799209594727 seconds ---
# 20fold 3-sigma clipping for 244
# --- 3.1655521392822266 seconds ---
# 20fold 3-sigma clipping for 245
# --- 3.1788127422332764 seconds ---
# 20fold 3-sigma clipping for 246
# --- 3.1869540214538574 seconds ---
# 20fold 3-sigma clipping for 247
# --- 3.1721110343933105 seconds ---
# 20fold 3-sigma clipping for 248
# --- 3.1500306129455566 seconds ---
# 20fold 3-sigma clipping for 249
# --- 3.155045747756958 seconds ---
# 20fold 3-sigma clipping for 250
# --- 3.1743602752685547 seconds ---
# 20fold 3-sigma clipping for 251
# --- 3.15262508392334 seconds ---
# 20fold 3-sigma clipping for 252
# --- 3.171027660369873 seconds ---
# 20fold 3-sigma clipping for 253
# --- 3.163557767868042 seconds ---
# 20fold 3-sigma clipping for 254
# --- 3.1689255237579346 seconds ---
# 20fold 3-sigma clipping for 255
# --- 3.130673408508301 seconds ---
# 20fold 3-sigma clipping for 256
# --- 3.119276285171509 seconds ---
# 20fold 3-sigma clipping for 257
# --- 3.1384682655334473 seconds ---
# 20fold 3-sigma clipping for 258
# --- 3.1593973636627197 seconds ---
# 20fold 3-sigma clipping for 259
# --- 3.146317958831787 seconds ---
# 20fold 3-sigma clipping for 260
# --- 3.1550405025482178 seconds ---
# 20fold 3-sigma clipping for 261
# --- 3.1553900241851807 seconds ---
# 20fold 3-sigma clipping for 262
# --- 3.168565034866333 seconds ---
# 20fold 3-sigma clipping for 263
# --- 3.1349592208862305 seconds ---
# 20fold 3-sigma clipping for 264
# --- 3.131014347076416 seconds ---
# 20fold 3-sigma clipping for 265
# --- 3.1443700790405273 seconds ---
# 20fold 3-sigma clipping for 266
# --- 3.1574580669403076 seconds ---
# 20fold 3-sigma clipping for 267
# --- 3.158477544784546 seconds ---
# 20fold 3-sigma clipping for 268
# --- 3.1491003036499023 seconds ---
# 20fold 3-sigma clipping for 269
# --- 3.1452689170837402 seconds ---
# 20fold 3-sigma clipping for 270
# --- 3.155090808868408 seconds ---
# 20fold 3-sigma clipping for 271
# --- 3.128807306289673 seconds ---
# 20fold 3-sigma clipping for 272
# --- 3.142895221710205 seconds ---
# 20fold 3-sigma clipping for 273
# --- 3.148562431335449 seconds ---
# 20fold 3-sigma clipping for 274
# --- 3.1789052486419678 seconds ---
# 20fold 3-sigma clipping for 275
# --- 3.1592047214508057 seconds ---
# 20fold 3-sigma clipping for 276
# --- 3.1587984561920166 seconds ---
# 20fold 3-sigma clipping for 277
# --- 3.167428493499756 seconds ---
# 20fold 3-sigma clipping for 278
# --- 3.1831741333007812 seconds ---
# 20fold 3-sigma clipping for 279
# --- 3.138593912124634 seconds ---
# 20fold 3-sigma clipping for 280
# --- 3.1319081783294678 seconds ---
# 20fold 3-sigma clipping for 281
# --- 3.156259536743164 seconds ---
# 20fold 3-sigma clipping for 282
# --- 3.1950817108154297 seconds ---
# 20fold 3-sigma clipping for 283
# --- 3.156902313232422 seconds ---
# 20fold 3-sigma clipping for 284
# --- 3.1483330726623535 seconds ---
# 20fold 3-sigma clipping for 285
# --- 3.1664621829986572 seconds ---
# 20fold 3-sigma clipping for 286
# --- 3.169376850128174 seconds ---
# 20fold 3-sigma clipping for 287
# --- 3.138188600540161 seconds ---
# 20fold 3-sigma clipping for 288
# --- 3.129662036895752 seconds ---
# 20fold 3-sigma clipping for 289
# --- 3.148750066757202 seconds ---
# 20fold 3-sigma clipping for 290
# --- 3.1678550243377686 seconds ---
# 20fold 3-sigma clipping for 291
# --- 3.1398203372955322 seconds ---
# 20fold 3-sigma clipping for 292
# --- 3.1399011611938477 seconds ---
# 20fold 3-sigma clipping for 293
# --- 3.148970365524292 seconds ---
# 20fold 3-sigma clipping for 294
# --- 3.167689085006714 seconds ---
# 20fold 3-sigma clipping for 295
# --- 3.13835072517395 seconds ---
# 20fold 3-sigma clipping for 296
# --- 3.1501619815826416 seconds ---
# 20fold 3-sigma clipping for 297
# --- 3.17969012260437 seconds ---
# 20fold 3-sigma clipping for 298
# --- 3.184676170349121 seconds ---
# 20fold 3-sigma clipping for 299
# --- 3.1494805812835693 seconds ---
# 20fold 3-sigma clipping for 300
# --- 3.152381420135498 seconds ---
# 20fold 3-sigma clipping for 301
# --- 3.1561155319213867 seconds ---
# 20fold 3-sigma clipping for 302
# --- 3.1754095554351807 seconds ---
# 20fold 3-sigma clipping for 303
# --- 3.170975685119629 seconds ---
# 20fold 3-sigma clipping for 304
# --- 3.1525633335113525 seconds ---
# 20fold 3-sigma clipping for 305
# --- 3.1819746494293213 seconds ---
# 20fold 3-sigma clipping for 306
# --- 3.1802659034729004 seconds ---
# 20fold 3-sigma clipping for 307
# --- 3.152524948120117 seconds ---
# 20fold 3-sigma clipping for 308
# --- 3.144681453704834 seconds ---
# 20fold 3-sigma clipping for 309
# --- 3.1514532566070557 seconds ---
# 20fold 3-sigma clipping for 310
# --- 3.170290231704712 seconds ---
# 20fold 3-sigma clipping for 311
# --- 3.1433358192443848 seconds ---
# 20fold 3-sigma clipping for 312
# --- 3.163914442062378 seconds ---
# 20fold 3-sigma clipping for 313
# --- 3.187464952468872 seconds ---
# 20fold 3-sigma clipping for 314
# --- 3.194133758544922 seconds ---
# 20fold 3-sigma clipping for 315
# --- 3.1714982986450195 seconds ---
# 20fold 3-sigma clipping for 316
# --- 3.1511526107788086 seconds ---
# 20fold 3-sigma clipping for 317
# --- 3.1708900928497314 seconds ---
# 20fold 3-sigma clipping for 318
# --- 3.1763734817504883 seconds ---
# 20fold 3-sigma clipping for 319
# --- 3.140671968460083 seconds ---
# 20fold 3-sigma clipping for 320
# --- 3.1519699096679688 seconds ---
# 20fold 3-sigma clipping for 321
# --- 3.1796092987060547 seconds ---
# 20fold 3-sigma clipping for 322
# --- 3.1808700561523438 seconds ---
# 20fold 3-sigma clipping for 323
# --- 3.147747278213501 seconds ---
# 20fold 3-sigma clipping for 324
# --- 3.1444616317749023 seconds ---
# 20fold 3-sigma clipping for 325
# --- 3.147986650466919 seconds ---
# 20fold 3-sigma clipping for 326
# --- 3.1724202632904053 seconds ---
# 20fold 3-sigma clipping for 327
# --- 3.1548562049865723 seconds ---
# 20fold 3-sigma clipping for 328
# --- 3.1707828044891357 seconds ---
# 20fold 3-sigma clipping for 329
# --- 3.1677234172821045 seconds ---
# 20fold 3-sigma clipping for 330
# --- 3.1821470260620117 seconds ---
# 20fold 3-sigma clipping for 331
# --- 3.1422128677368164 seconds ---
# 20fold 3-sigma clipping for 332
# --- 3.1424834728240967 seconds ---
# 20fold 3-sigma clipping for 333
# --- 3.161463975906372 seconds ---
# 20fold 3-sigma clipping for 334
# --- 3.177013635635376 seconds ---
# 20fold 3-sigma clipping for 335
# --- 3.162508249282837 seconds ---
# 20fold 3-sigma clipping for 336
# --- 3.1620945930480957 seconds ---
# 20fold 3-sigma clipping for 337
# --- 3.162855625152588 seconds ---
# 20fold 3-sigma clipping for 338
# --- 3.17803955078125 seconds ---
# 20fold 3-sigma clipping for 339
# --- 3.1360154151916504 seconds ---
# 20fold 3-sigma clipping for 340
# --- 3.1388397216796875 seconds ---
# 20fold 3-sigma clipping for 341
# --- 3.157465696334839 seconds ---
# 20fold 3-sigma clipping for 342
# --- 3.1690757274627686 seconds ---
# 20fold 3-sigma clipping for 343
# --- 3.163469076156616 seconds ---
# 20fold 3-sigma clipping for 344
# --- 3.1576595306396484 seconds ---
# 20fold 3-sigma clipping for 345
# --- 3.155538558959961 seconds ---
# 20fold 3-sigma clipping for 346
# --- 3.1763641834259033 seconds ---
# 20fold 3-sigma clipping for 347
# --- 3.1412763595581055 seconds ---
# 20fold 3-sigma clipping for 348
# --- 3.145045042037964 seconds ---
# 20fold 3-sigma clipping for 349
# --- 3.147662401199341 seconds ---
# 20fold 3-sigma clipping for 350
# --- 3.168640613555908 seconds ---
# 20fold 3-sigma clipping for 351
# --- 3.14308762550354 seconds ---
# 20fold 3-sigma clipping for 352
# --- 3.150822401046753 seconds ---
# 20fold 3-sigma clipping for 353
# --- 3.1721980571746826 seconds ---
# 20fold 3-sigma clipping for 354
# --- 3.192601442337036 seconds ---
# 20fold 3-sigma clipping for 355
# --- 3.1600003242492676 seconds ---
# 20fold 3-sigma clipping for 356
# --- 3.1503217220306396 seconds ---
# 20fold 3-sigma clipping for 357
# --- 3.1570394039154053 seconds ---
# 20fold 3-sigma clipping for 358
# --- 3.1838784217834473 seconds ---
# 20fold 3-sigma clipping for 359
# --- 3.1518237590789795 seconds ---
# 20fold 3-sigma clipping for 360
# --- 3.15554141998291 seconds ---
# 20fold 3-sigma clipping for 361
# --- 3.1563775539398193 seconds ---
# 20fold 3-sigma clipping for 362
# --- 3.1753785610198975 seconds ---
# 20fold 3-sigma clipping for 363
# --- 3.1442573070526123 seconds ---
# 20fold 3-sigma clipping for 364
# --- 3.14018177986145 seconds ---
# 20fold 3-sigma clipping for 365
# --- 3.1599512100219727 seconds ---
# 20fold 3-sigma clipping for 366
# --- 3.1805734634399414 seconds ---
# 20fold 3-sigma clipping for 367
# --- 3.152109384536743 seconds ---
# 20fold 3-sigma clipping for 368
# --- 3.1334760189056396 seconds ---
# 20fold 3-sigma clipping for 369
# --- 3.1667983531951904 seconds ---
# 20fold 3-sigma clipping for 370
# --- 3.17301607131958 seconds ---
# 20fold 3-sigma clipping for 371
# --- 3.150069236755371 seconds ---
# 20fold 3-sigma clipping for 372
# --- 3.1424074172973633 seconds ---
# 20fold 3-sigma clipping for 373
# --- 3.174177885055542 seconds ---
# 20fold 3-sigma clipping for 374
# --- 3.1866111755371094 seconds ---
# 20fold 3-sigma clipping for 375
# --- 3.1550681591033936 seconds ---
# 20fold 3-sigma clipping for 376
# --- 3.140106439590454 seconds ---
# 20fold 3-sigma clipping for 377
# --- 3.154029130935669 seconds ---
# 20fold 3-sigma clipping for 378
# --- 3.166670322418213 seconds ---
# 20fold 3-sigma clipping for 379
# --- 3.1390044689178467 seconds ---
# 20fold 3-sigma clipping for 380
# --- 3.1462724208831787 seconds ---
# 20fold 3-sigma clipping for 381
# --- 3.1690876483917236 seconds ---
# 20fold 3-sigma clipping for 382
# --- 3.1748905181884766 seconds ---
# 20fold 3-sigma clipping for 383
# --- 3.151352643966675 seconds ---
# 20fold 3-sigma clipping for 384
# --- 3.141507148742676 seconds ---
# 20fold 3-sigma clipping for 385
# --- 3.1622841358184814 seconds ---
# 20fold 3-sigma clipping for 386
# --- 3.1761863231658936 seconds ---
# 20fold 3-sigma clipping for 387
# --- 3.1444802284240723 seconds ---
# 20fold 3-sigma clipping for 388
# --- 3.151165008544922 seconds ---
# 20fold 3-sigma clipping for 389
# --- 3.1660287380218506 seconds ---
# 20fold 3-sigma clipping for 390
# --- 3.178192138671875 seconds ---
# 20fold 3-sigma clipping for 391
# --- 3.1482629776000977 seconds ---
# 20fold 3-sigma clipping for 392
# --- 3.1500914096832275 seconds ---
# 20fold 3-sigma clipping for 393
# --- 3.160851001739502 seconds ---
# 20fold 3-sigma clipping for 394
# --- 3.1692771911621094 seconds ---
# 20fold 3-sigma clipping for 395
# --- 3.13228702545166 seconds ---
# 20fold 3-sigma clipping for 396
# --- 3.150218963623047 seconds ---
# 20fold 3-sigma clipping for 397
# --- 3.1644628047943115 seconds ---
# 20fold 3-sigma clipping for 398
# --- 3.1694741249084473 seconds ---
# 20fold 3-sigma clipping for 399
# --- 3.139036178588867 seconds ---
# 20fold 3-sigma clipping for 400
# --- 3.135272979736328 seconds ---
# 20fold 3-sigma clipping for 401
# --- 3.149068593978882 seconds ---
# 20fold 3-sigma clipping for 402
# --- 3.1620748043060303 seconds ---
# 20fold 3-sigma clipping for 403
# --- 3.1410303115844727 seconds ---
# 20fold 3-sigma clipping for 404
# --- 3.141275405883789 seconds ---
# 20fold 3-sigma clipping for 405
# --- 3.1578197479248047 seconds ---
# 20fold 3-sigma clipping for 406
# --- 3.168836832046509 seconds ---
# 20fold 3-sigma clipping for 407
# --- 3.1415789127349854 seconds ---
# 20fold 3-sigma clipping for 408
# --- 3.126469850540161 seconds ---
# 20fold 3-sigma clipping for 409
# --- 3.1489181518554688 seconds ---
# 20fold 3-sigma clipping for 410
# --- 3.165111780166626 seconds ---
# 20fold 3-sigma clipping for 411
# --- 3.152466058731079 seconds ---
# 20fold 3-sigma clipping for 412
# --- 3.1492159366607666 seconds ---
# 20fold 3-sigma clipping for 413
# --- 3.1668789386749268 seconds ---
# 20fold 3-sigma clipping for 414
# --- 3.159528970718384 seconds ---
# 20fold 3-sigma clipping for 415
# --- 3.141226291656494 seconds ---
# 20fold 3-sigma clipping for 416
# --- 3.1377053260803223 seconds ---
# 20fold 3-sigma clipping for 417
# --- 3.1588730812072754 seconds ---
# 20fold 3-sigma clipping for 418
# --- 3.168916702270508 seconds ---
# 20fold 3-sigma clipping for 419
# --- 3.146585464477539 seconds ---
# 20fold 3-sigma clipping for 420
# --- 3.1511917114257812 seconds ---
# 20fold 3-sigma clipping for 421
# --- 3.1597559452056885 seconds ---
# 20fold 3-sigma clipping for 422
# --- 3.1701269149780273 seconds ---
# 20fold 3-sigma clipping for 423
# --- 3.1424453258514404 seconds ---
# 20fold 3-sigma clipping for 424
# --- 3.136413335800171 seconds ---
# 20fold 3-sigma clipping for 425
# --- 3.1476540565490723 seconds ---
# 20fold 3-sigma clipping for 426
# --- 3.1764700412750244 seconds ---
# 20fold 3-sigma clipping for 427
# --- 3.156404733657837 seconds ---
# 20fold 3-sigma clipping for 428
# --- 3.1641056537628174 seconds ---
# 20fold 3-sigma clipping for 429
# --- 3.188772678375244 seconds ---
# 20fold 3-sigma clipping for 430
# --- 3.210404872894287 seconds ---
# 20fold 3-sigma clipping for 431
# --- 3.174684762954712 seconds ---
# 20fold 3-sigma clipping for 432
# --- 3.163841962814331 seconds ---
# 20fold 3-sigma clipping for 433
# --- 3.1923227310180664 seconds ---
# 20fold 3-sigma clipping for 434
# --- 3.2304840087890625 seconds ---
# 20fold 3-sigma clipping for 435
# --- 3.20564341545105 seconds ---
# 20fold 3-sigma clipping for 436
# --- 3.2018916606903076 seconds ---
# 20fold 3-sigma clipping for 437
# --- 3.2087278366088867 seconds ---
# 20fold 3-sigma clipping for 438
# --- 3.213193655014038 seconds ---
# 20fold 3-sigma clipping for 439
# --- 3.177340030670166 seconds ---
# 20fold 3-sigma clipping for 440
# --- 3.169828414916992 seconds ---
# 20fold 3-sigma clipping for 441
# --- 3.1965601444244385 seconds ---
# 20fold 3-sigma clipping for 442
# --- 3.205805540084839 seconds ---
# 20fold 3-sigma clipping for 443
# --- 3.1828019618988037 seconds ---
# 20fold 3-sigma clipping for 444
# --- 3.186951160430908 seconds ---
# 20fold 3-sigma clipping for 445
# --- 3.204439640045166 seconds ---
# 20fold 3-sigma clipping for 446
# --- 3.2287678718566895 seconds ---
# 20fold 3-sigma clipping for 447
# --- 3.1896302700042725 seconds ---
# 20fold 3-sigma clipping for 448
# --- 3.1808454990386963 seconds ---
# 20fold 3-sigma clipping for 449
# --- 3.20168399810791 seconds ---
# 20fold 3-sigma clipping for 450
# --- 3.2150025367736816 seconds ---
# 20fold 3-sigma clipping for 451
# --- 3.1835854053497314 seconds ---
# 20fold 3-sigma clipping for 452
# --- 3.171999216079712 seconds ---
# 20fold 3-sigma clipping for 453
# --- 3.1929092407226562 seconds ---
# 20fold 3-sigma clipping for 454
# --- 3.2104310989379883 seconds ---
# 20fold 3-sigma clipping for 455
# --- 3.1921260356903076 seconds ---
# 20fold 3-sigma clipping for 456
# --- 3.1873700618743896 seconds ---
# 20fold 3-sigma clipping for 457
# --- 3.200660467147827 seconds ---
# 20fold 3-sigma clipping for 458
# --- 3.2094037532806396 seconds ---
# 20fold 3-sigma clipping for 459
# --- 3.177640914916992 seconds ---
# 20fold 3-sigma clipping for 460
# --- 3.1753156185150146 seconds ---
# 20fold 3-sigma clipping for 461
# --- 3.187221050262451 seconds ---
# 20fold 3-sigma clipping for 462
# --- 3.2156641483306885 seconds ---
# 20fold 3-sigma clipping for 463
# --- 3.1806015968322754 seconds ---
# 20fold 3-sigma clipping for 464
# --- 3.183772563934326 seconds ---
# 20fold 3-sigma clipping for 465
# --- 3.209954023361206 seconds ---
# 20fold 3-sigma clipping for 466
# --- 3.2195496559143066 seconds ---
# 20fold 3-sigma clipping for 467
# --- 3.189793825149536 seconds ---
# 20fold 3-sigma clipping for 468
# --- 3.1894288063049316 seconds ---
# 20fold 3-sigma clipping for 469
# --- 3.1933443546295166 seconds ---
# 20fold 3-sigma clipping for 470
# --- 3.206969738006592 seconds ---
# 20fold 3-sigma clipping for 471
# --- 3.189690589904785 seconds ---
# 20fold 3-sigma clipping for 472
# --- 3.193181276321411 seconds ---
# 20fold 3-sigma clipping for 473
# --- 3.2009217739105225 seconds ---
# 20fold 3-sigma clipping for 474
# --- 3.203691244125366 seconds ---
# 20fold 3-sigma clipping for 475
# --- 3.1754252910614014 seconds ---
# 20fold 3-sigma clipping for 476
# --- 3.176746129989624 seconds ---
# 20fold 3-sigma clipping for 477
# --- 3.1902434825897217 seconds ---
# 20fold 3-sigma clipping for 478
# --- 3.213174819946289 seconds ---
# 20fold 3-sigma clipping for 479
# --- 3.192427396774292 seconds ---
# 20fold 3-sigma clipping for 480
# --- 3.1907222270965576 seconds ---
# 20fold 3-sigma clipping for 481
# --- 3.195300817489624 seconds ---
# 20fold 3-sigma clipping for 482
# --- 3.1941864490509033 seconds ---
# 20fold 3-sigma clipping for 483
# --- 3.1643588542938232 seconds ---
# 20fold 3-sigma clipping for 484
# --- 3.1705844402313232 seconds ---
# 20fold 3-sigma clipping for 485
# --- 3.180265188217163 seconds ---
# 20fold 3-sigma clipping for 486
# --- 3.201174259185791 seconds ---
# 20fold 3-sigma clipping for 487
# --- 3.1849517822265625 seconds ---
# 20fold 3-sigma clipping for 488
# --- 3.187366485595703 seconds ---
# 20fold 3-sigma clipping for 489
# --- 3.196138858795166 seconds ---
# 20fold 3-sigma clipping for 490
# --- 3.2023227214813232 seconds ---
# 20fold 3-sigma clipping for 491
# --- 3.1721718311309814 seconds ---
# 20fold 3-sigma clipping for 492
# --- 3.181471824645996 seconds ---
# 20fold 3-sigma clipping for 493
# --- 3.187797784805298 seconds ---
# 20fold 3-sigma clipping for 494
# --- 3.2141706943511963 seconds ---
# 20fold 3-sigma clipping for 495
# --- 3.1801257133483887 seconds ---
# 20fold 3-sigma clipping for 496
# --- 3.1842689514160156 seconds ---
# 20fold 3-sigma clipping for 497
# --- 3.192580461502075 seconds ---
# 20fold 3-sigma clipping for 498
# --- 3.2026889324188232 seconds ---
# 20fold 3-sigma clipping for 499
# --- 3.179704189300537 seconds ---
# 20fold 3-sigma clipping for 500
# --- 3.183530569076538 seconds ---
# 20fold 3-sigma clipping for 501
# --- 3.197211980819702 seconds ---
# 20fold 3-sigma clipping for 502
# --- 3.220975875854492 seconds ---
# 20fold 3-sigma clipping for 503
# --- 3.195716142654419 seconds ---
# 20fold 3-sigma clipping for 504
# --- 3.188281536102295 seconds ---
# 20fold 3-sigma clipping for 505
# --- 3.1985692977905273 seconds ---
# 20fold 3-sigma clipping for 506
# --- 3.212186574935913 seconds ---
# 20fold 3-sigma clipping for 507
# --- 3.1875178813934326 seconds ---
# 20fold 3-sigma clipping for 508
# --- 3.174978733062744 seconds ---
# 20fold 3-sigma clipping for 509
# --- 3.2077815532684326 seconds ---
# 20fold 3-sigma clipping for 510
# --- 3.20477032661438 seconds ---
# 20fold 3-sigma clipping for 511
# --- 3.1928586959838867 seconds ---
# 20fold 3-sigma clipping for 512
# --- 3.1776061058044434 seconds ---
# 20fold 3-sigma clipping for 513
# --- 3.1852848529815674 seconds ---
# 20fold 3-sigma clipping for 514
# --- 3.1965956687927246 seconds ---
# 20fold 3-sigma clipping for 515
# --- 3.1731555461883545 seconds ---
# 20fold 3-sigma clipping for 516
# --- 3.197553873062134 seconds ---
# 20fold 3-sigma clipping for 517
# --- 3.198737859725952 seconds ---
# 20fold 3-sigma clipping for 518
# --- 3.204845905303955 seconds ---
# 20fold 3-sigma clipping for 519
# --- 3.175657033920288 seconds ---
# 20fold 3-sigma clipping for 520
# --- 3.179891586303711 seconds ---
# 20fold 3-sigma clipping for 521
# --- 3.2034835815429688 seconds ---
# 20fold 3-sigma clipping for 522
# --- 3.2177841663360596 seconds ---
# 20fold 3-sigma clipping for 523
# --- 3.1854751110076904 seconds ---
# 20fold 3-sigma clipping for 524
# --- 3.1885528564453125 seconds ---
# 20fold 3-sigma clipping for 525
# --- 3.1957814693450928 seconds ---
# 20fold 3-sigma clipping for 526
# --- 3.2229504585266113 seconds ---
# 20fold 3-sigma clipping for 527
# --- 3.1748292446136475 seconds ---
# 20fold 3-sigma clipping for 528
# --- 3.1760549545288086 seconds ---
# 20fold 3-sigma clipping for 529
# --- 3.2140400409698486 seconds ---
# 20fold 3-sigma clipping for 530
# --- 3.234199285507202 seconds ---
# 20fold 3-sigma clipping for 531
# --- 3.1985485553741455 seconds ---
# 20fold 3-sigma clipping for 532
# --- 3.1948835849761963 seconds ---
# 20fold 3-sigma clipping for 533
# --- 3.199817180633545 seconds ---
# 20fold 3-sigma clipping for 534
# --- 3.223665237426758 seconds ---
# 20fold 3-sigma clipping for 535
# --- 3.17986798286438 seconds ---
# 20fold 3-sigma clipping for 536
# --- 3.17021107673645 seconds ---
# 20fold 3-sigma clipping for 537
# --- 3.1857099533081055 seconds ---
# 20fold 3-sigma clipping for 538
# --- 3.2065913677215576 seconds ---
# 20fold 3-sigma clipping for 539
# --- 3.1906206607818604 seconds ---
# 20fold 3-sigma clipping for 540
# --- 3.197875499725342 seconds ---
# 20fold 3-sigma clipping for 541
# --- 3.2020673751831055 seconds ---
# 20fold 3-sigma clipping for 542
# --- 3.218352794647217 seconds ---
# 20fold 3-sigma clipping for 543
# --- 3.1878418922424316 seconds ---
# 20fold 3-sigma clipping for 544
# --- 3.1789958477020264 seconds ---
# 20fold 3-sigma clipping for 545
# --- 3.1955251693725586 seconds ---
# 20fold 3-sigma clipping for 546
# --- 3.211796522140503 seconds ---
# 20fold 3-sigma clipping for 547
# --- 3.200409412384033 seconds ---
# 20fold 3-sigma clipping for 548
# --- 3.1848394870758057 seconds ---
# 20fold 3-sigma clipping for 549
# --- 3.2016704082489014 seconds ---
# 20fold 3-sigma clipping for 550
# --- 3.2114925384521484 seconds ---
# 20fold 3-sigma clipping for 551
# --- 3.169354200363159 seconds ---
# 20fold 3-sigma clipping for 552
# --- 3.175933361053467 seconds ---
# 20fold 3-sigma clipping for 553
# --- 3.1870057582855225 seconds ---
# 20fold 3-sigma clipping for 554
# --- 3.210451602935791 seconds ---
# 20fold 3-sigma clipping for 555
# --- 3.1789755821228027 seconds ---
# 20fold 3-sigma clipping for 556
# --- 3.1661949157714844 seconds ---
# 20fold 3-sigma clipping for 557
# --- 3.1817197799682617 seconds ---
# 20fold 3-sigma clipping for 558
# --- 3.1945266723632812 seconds ---
# 20fold 3-sigma clipping for 559
# --- 3.1632065773010254 seconds ---
# 20fold 3-sigma clipping for 560
# --- 3.160327434539795 seconds ---
# 20fold 3-sigma clipping for 561
# --- 3.181260108947754 seconds ---
# 20fold 3-sigma clipping for 562
# --- 3.2124850749969482 seconds ---
# 20fold 3-sigma clipping for 563
# --- 3.1820995807647705 seconds ---
# 20fold 3-sigma clipping for 564
# --- 3.1826536655426025 seconds ---
# 20fold 3-sigma clipping for 565
# --- 3.1927735805511475 seconds ---
# 20fold 3-sigma clipping for 566
# --- 3.216387987136841 seconds ---
# 20fold 3-sigma clipping for 567
# --- 3.1884171962738037 seconds ---
# 20fold 3-sigma clipping for 568
# --- 3.1954050064086914 seconds ---
# 20fold 3-sigma clipping for 569
# --- 3.2230889797210693 seconds ---
# 20fold 3-sigma clipping for 570
# --- 3.2424399852752686 seconds ---
# 20fold 3-sigma clipping for 571
# --- 3.204451084136963 seconds ---
# 20fold 3-sigma clipping for 572
# --- 3.2078030109405518 seconds ---
# 20fold 3-sigma clipping for 573
# --- 3.2061285972595215 seconds ---
# 20fold 3-sigma clipping for 574
# --- 3.2261557579040527 seconds ---
# 20fold 3-sigma clipping for 575
# --- 3.1966304779052734 seconds ---
# 20fold 3-sigma clipping for 576
# --- 3.1980559825897217 seconds ---
# 20fold 3-sigma clipping for 577
# --- 3.208423137664795 seconds ---
# 20fold 3-sigma clipping for 578
# --- 3.2292721271514893 seconds ---
# 20fold 3-sigma clipping for 579
# --- 3.2074480056762695 seconds ---
# 20fold 3-sigma clipping for 580
# --- 3.208735942840576 seconds ---
# 20fold 3-sigma clipping for 581
# --- 3.2177343368530273 seconds ---
# 20fold 3-sigma clipping for 582
# --- 3.232494354248047 seconds ---
# 20fold 3-sigma clipping for 583
# --- 3.2072813510894775 seconds ---
# 20fold 3-sigma clipping for 584
# --- 3.218683958053589 seconds ---
# 20fold 3-sigma clipping for 585
# --- 3.2342703342437744 seconds ---
# 20fold 3-sigma clipping for 586
# --- 3.2467124462127686 seconds ---
# 20fold 3-sigma clipping for 587
# --- 3.2111141681671143 seconds ---
# 20fold 3-sigma clipping for 588
# --- 3.2134807109832764 seconds ---
# 20fold 3-sigma clipping for 589
# --- 3.227827787399292 seconds ---
# 20fold 3-sigma clipping for 590
# --- 3.2347946166992188 seconds ---
# 20fold 3-sigma clipping for 591
# --- 3.2144076824188232 seconds ---
# 20fold 3-sigma clipping for 592
# --- 3.214923858642578 seconds ---
# 20fold 3-sigma clipping for 593
# --- 3.2204604148864746 seconds ---
# 20fold 3-sigma clipping for 594
# --- 3.230835437774658 seconds ---
# 20fold 3-sigma clipping for 595
# --- 3.2016360759735107 seconds ---
# 20fold 3-sigma clipping for 596
# --- 3.208052158355713 seconds ---
# 20fold 3-sigma clipping for 597
# --- 3.2157459259033203 seconds ---
# 20fold 3-sigma clipping for 598
# --- 3.233065366744995 seconds ---
# 20fold 3-sigma clipping for 599
# --- 3.222470760345459 seconds ---
# 20fold 3-sigma clipping for 600
# --- 3.2058098316192627 seconds ---
# 20fold 3-sigma clipping for 601
# --- 3.2313692569732666 seconds ---
# 20fold 3-sigma clipping for 602
# --- 3.233168363571167 seconds ---
# 20fold 3-sigma clipping for 603
# --- 3.2025434970855713 seconds ---
# 20fold 3-sigma clipping for 604
# --- 3.2037911415100098 seconds ---
# 20fold 3-sigma clipping for 605
# --- 3.2265965938568115 seconds ---
# 20fold 3-sigma clipping for 606
# --- 3.242236852645874 seconds ---
# 20fold 3-sigma clipping for 607
# --- 3.2168543338775635 seconds ---
# 20fold 3-sigma clipping for 608
# --- 3.2092413902282715 seconds ---
# 20fold 3-sigma clipping for 609
# --- 3.226962089538574 seconds ---
# 20fold 3-sigma clipping for 610
# --- 3.2277374267578125 seconds ---
# 20fold 3-sigma clipping for 611
# --- 3.202338933944702 seconds ---
# 20fold 3-sigma clipping for 612
# --- 3.2008159160614014 seconds ---
# 20fold 3-sigma clipping for 613
# --- 3.2180912494659424 seconds ---
# 20fold 3-sigma clipping for 614
# --- 3.235583543777466 seconds ---
# 20fold 3-sigma clipping for 615
# --- 3.20660138130188 seconds ---
# 20fold 3-sigma clipping for 616
# --- 3.2237985134124756 seconds ---
# 20fold 3-sigma clipping for 617
# --- 3.248331069946289 seconds ---
# 20fold 3-sigma clipping for 618
# --- 3.258143901824951 seconds ---
# 20fold 3-sigma clipping for 619
# --- 3.2150838375091553 seconds ---
# 20fold 3-sigma clipping for 620
# --- 3.212217330932617 seconds ---
# 20fold 3-sigma clipping for 621
# --- 3.248843193054199 seconds ---
# 20fold 3-sigma clipping for 622
# --- 3.255467414855957 seconds ---
# 20fold 3-sigma clipping for 623
# --- 3.224386692047119 seconds ---
# 20fold 3-sigma clipping for 624
# --- 3.215967893600464 seconds ---
# 20fold 3-sigma clipping for 625
# --- 3.2162716388702393 seconds ---
# 20fold 3-sigma clipping for 626
# --- 3.221665859222412 seconds ---
# 20fold 3-sigma clipping for 627
# --- 3.2077980041503906 seconds ---
# 20fold 3-sigma clipping for 628
# --- 3.2094457149505615 seconds ---
# 20fold 3-sigma clipping for 629
# --- 3.230437994003296 seconds ---
# 20fold 3-sigma clipping for 630
# --- 3.244384288787842 seconds ---
# 20fold 3-sigma clipping for 631
# --- 3.2050695419311523 seconds ---
# 20fold 3-sigma clipping for 632
# --- 3.207277774810791 seconds ---
# 20fold 3-sigma clipping for 633
# --- 3.226074457168579 seconds ---
# 20fold 3-sigma clipping for 634
# --- 3.2344768047332764 seconds ---
# 20fold 3-sigma clipping for 635
# --- 3.1992225646972656 seconds ---
# 20fold 3-sigma clipping for 636
# --- 3.2077689170837402 seconds ---
# 20fold 3-sigma clipping for 637
# --- 3.208587884902954 seconds ---
# 20fold 3-sigma clipping for 638
# --- 3.2350711822509766 seconds ---
# 20fold 3-sigma clipping for 639
# --- 3.2226810455322266 seconds ---
# 20fold 3-sigma clipping for 640
# --- 3.2142562866210938 seconds ---
# 20fold 3-sigma clipping for 641
# --- 3.223945140838623 seconds ---
# 20fold 3-sigma clipping for 642
# --- 3.230539321899414 seconds ---
# 20fold 3-sigma clipping for 643
# --- 3.217226505279541 seconds ---
# 20fold 3-sigma clipping for 644
# --- 3.2263448238372803 seconds ---
# 20fold 3-sigma clipping for 645
# --- 3.2465240955352783 seconds ---
# 20fold 3-sigma clipping for 646
# --- 3.244016408920288 seconds ---
# 20fold 3-sigma clipping for 647
# --- 3.2259747982025146 seconds ---
# 20fold 3-sigma clipping for 648
# --- 3.231846809387207 seconds ---
# 20fold 3-sigma clipping for 649
# --- 3.24537992477417 seconds ---
# 20fold 3-sigma clipping for 650
# --- 3.2540383338928223 seconds ---
# 20fold 3-sigma clipping for 651
# --- 3.2409861087799072 seconds ---
# 20fold 3-sigma clipping for 652
# --- 3.249422311782837 seconds ---
# 20fold 3-sigma clipping for 653
# --- 3.2358086109161377 seconds ---
# 20fold 3-sigma clipping for 654
# --- 3.2738630771636963 seconds ---
# 20fold 3-sigma clipping for 655
# --- 3.227558135986328 seconds ---
# 20fold 3-sigma clipping for 656
# --- 3.217355251312256 seconds ---
# 20fold 3-sigma clipping for 657
# --- 3.2201452255249023 seconds ---
# 20fold 3-sigma clipping for 658
# --- 3.2590134143829346 seconds ---
# 20fold 3-sigma clipping for 659
# --- 3.228449583053589 seconds ---
# 20fold 3-sigma clipping for 660
# --- 3.211867332458496 seconds ---
# 20fold 3-sigma clipping for 661
# --- 3.24811053276062 seconds ---
# 20fold 3-sigma clipping for 662
# --- 3.254281520843506 seconds ---
# 20fold 3-sigma clipping for 663
# --- 3.228684425354004 seconds ---
# 20fold 3-sigma clipping for 664
# --- 3.197396993637085 seconds ---
# 20fold 3-sigma clipping for 665
# --- 3.239504337310791 seconds ---
# 20fold 3-sigma clipping for 666
# --- 3.2449209690093994 seconds ---
# 20fold 3-sigma clipping for 667
# --- 3.230210542678833 seconds ---
# 20fold 3-sigma clipping for 668
# --- 3.221100330352783 seconds ---
# 20fold 3-sigma clipping for 669
# --- 3.231848955154419 seconds ---
# 20fold 3-sigma clipping for 670
# --- 3.2420146465301514 seconds ---
# 20fold 3-sigma clipping for 671
# --- 3.176137685775757 seconds ---
# 20fold 3-sigma clipping for 672
# --- 3.166799545288086 seconds ---
# 20fold 3-sigma clipping for 673
# --- 3.1881442070007324 seconds ---
# 20fold 3-sigma clipping for 674
# --- 3.2171010971069336 seconds ---
# 20fold 3-sigma clipping for 675
# --- 3.163360834121704 seconds ---
# 20fold 3-sigma clipping for 676
# --- 3.1651523113250732 seconds ---
# 20fold 3-sigma clipping for 677
# --- 3.169980525970459 seconds ---
# 20fold 3-sigma clipping for 678
# --- 3.188570976257324 seconds ---
# 20fold 3-sigma clipping for 679
# --- 3.1678683757781982 seconds ---
# 20fold 3-sigma clipping for 680
# --- 3.1678123474121094 seconds ---
# 20fold 3-sigma clipping for 681
# --- 3.194687604904175 seconds ---
# 20fold 3-sigma clipping for 682
# --- 3.2056305408477783 seconds ---
# 20fold 3-sigma clipping for 683
# --- 3.162733793258667 seconds ---
# 20fold 3-sigma clipping for 684
# --- 3.1660661697387695 seconds ---
# 20fold 3-sigma clipping for 685
# --- 3.183973550796509 seconds ---
# 20fold 3-sigma clipping for 686
# --- 3.2049074172973633 seconds ---
# 20fold 3-sigma clipping for 687
# --- 3.176482915878296 seconds ---
# 20fold 3-sigma clipping for 688
# --- 3.177767038345337 seconds ---
# 20fold 3-sigma clipping for 689
# --- 3.2102482318878174 seconds ---
# 20fold 3-sigma clipping for 690
# --- 3.224825859069824 seconds ---
# 20fold 3-sigma clipping for 691
# --- 3.187407970428467 seconds ---
# 20fold 3-sigma clipping for 692
# --- 3.1838393211364746 seconds ---
# 20fold 3-sigma clipping for 693
# --- 3.1891613006591797 seconds ---
# 20fold 3-sigma clipping for 694
# --- 3.2019009590148926 seconds ---
# 20fold 3-sigma clipping for 695
# --- 3.1682004928588867 seconds ---
# 20fold 3-sigma clipping for 696
# --- 3.172589063644409 seconds ---
# 20fold 3-sigma clipping for 697
# --- 3.1883280277252197 seconds ---
# 20fold 3-sigma clipping for 698
# --- 3.194885492324829 seconds ---
# 20fold 3-sigma clipping for 699
# --- 3.1627278327941895 seconds ---
# 20fold 3-sigma clipping for 700
# --- 3.1604809761047363 seconds ---
# 20fold 3-sigma clipping for 701
# --- 3.168623447418213 seconds ---
# 20fold 3-sigma clipping for 702
# --- 3.1752514839172363 seconds ---
# 20fold 3-sigma clipping for 703
# --- 3.161421060562134 seconds ---
# 20fold 3-sigma clipping for 704
# --- 3.1641955375671387 seconds ---
# 20fold 3-sigma clipping for 705
# --- 3.181718587875366 seconds ---
# 20fold 3-sigma clipping for 706
# --- 3.1930644512176514 seconds ---
# 20fold 3-sigma clipping for 707
# --- 3.162665605545044 seconds ---
# 20fold 3-sigma clipping for 708
# --- 3.162804365158081 seconds ---
# 20fold 3-sigma clipping for 709
# --- 3.1876189708709717 seconds ---
# 20fold 3-sigma clipping for 710
# --- 3.211808681488037 seconds ---
# 20fold 3-sigma clipping for 711
# --- 3.1833560466766357 seconds ---
# 20fold 3-sigma clipping for 712
# --- 3.18680739402771 seconds ---
# 20fold 3-sigma clipping for 713
# --- 3.1943883895874023 seconds ---
# 20fold 3-sigma clipping for 714
# --- 3.200812339782715 seconds ---
# 20fold 3-sigma clipping for 715
# --- 3.168253183364868 seconds ---
# 20fold 3-sigma clipping for 716
# --- 3.180011749267578 seconds ---
# 20fold 3-sigma clipping for 717
# --- 3.192559242248535 seconds ---
# 20fold 3-sigma clipping for 718
# --- 3.2009849548339844 seconds ---
# 20fold 3-sigma clipping for 719
# --- 3.1838486194610596 seconds ---
# 20fold 3-sigma clipping for 720
# --- 3.1836280822753906 seconds ---
# 20fold 3-sigma clipping for 721
# --- 3.185858726501465 seconds ---
# 20fold 3-sigma clipping for 722
# --- 3.191535234451294 seconds ---
# 20fold 3-sigma clipping for 723
# --- 3.1677539348602295 seconds ---
# 20fold 3-sigma clipping for 724
# --- 3.1644139289855957 seconds ---
# 20fold 3-sigma clipping for 725
# --- 3.1867830753326416 seconds ---
# 20fold 3-sigma clipping for 726
# --- 3.213508129119873 seconds ---
# 20fold 3-sigma clipping for 727
# --- 3.179511547088623 seconds ---
# 20fold 3-sigma clipping for 728
# --- 3.180039405822754 seconds ---
# 20fold 3-sigma clipping for 729
# --- 3.2044730186462402 seconds ---
# 20fold 3-sigma clipping for 730
# --- 3.2153303623199463 seconds ---
# 20fold 3-sigma clipping for 731
# --- 3.1648170948028564 seconds ---
# 20fold 3-sigma clipping for 732
# --- 3.1651437282562256 seconds ---
# 20fold 3-sigma clipping for 733
# --- 3.1858129501342773 seconds ---
# 20fold 3-sigma clipping for 734
# --- 3.2027618885040283 seconds ---
# 20fold 3-sigma clipping for 735
# --- 3.1694040298461914 seconds ---
# 20fold 3-sigma clipping for 736
# --- 3.1731886863708496 seconds ---
# 20fold 3-sigma clipping for 737
# --- 3.18074893951416 seconds ---
# 20fold 3-sigma clipping for 738
# --- 3.2010061740875244 seconds ---
# 20fold 3-sigma clipping for 739
# --- 3.1776154041290283 seconds ---
# 20fold 3-sigma clipping for 740
# --- 3.1790595054626465 seconds ---
# 20fold 3-sigma clipping for 741
# --- 3.196584701538086 seconds ---
# 20fold 3-sigma clipping for 742
# --- 3.2220799922943115 seconds ---
# 20fold 3-sigma clipping for 743
# --- 3.1982922554016113 seconds ---
# 20fold 3-sigma clipping for 744
# --- 3.183319330215454 seconds ---
# 20fold 3-sigma clipping for 745
# --- 3.2043285369873047 seconds ---
# 20fold 3-sigma clipping for 746
# --- 3.209031581878662 seconds ---
# 20fold 3-sigma clipping for 747
# --- 3.180675983428955 seconds ---
# 20fold 3-sigma clipping for 748
# --- 3.18284010887146 seconds ---
# 20fold 3-sigma clipping for 749
# --- 3.2161130905151367 seconds ---
# 20fold 3-sigma clipping for 750
# --- 3.226977825164795 seconds ---
# 20fold 3-sigma clipping for 751
# --- 3.193446159362793 seconds ---
# 20fold 3-sigma clipping for 752
# --- 3.185493230819702 seconds ---
# 20fold 3-sigma clipping for 753
# --- 3.2126471996307373 seconds ---
# 20fold 3-sigma clipping for 754
# --- 3.214672803878784 seconds ---
# 20fold 3-sigma clipping for 755
# --- 3.1769604682922363 seconds ---
# 20fold 3-sigma clipping for 756
# --- 3.191072940826416 seconds ---
# 20fold 3-sigma clipping for 757
# --- 3.201651096343994 seconds ---
# 20fold 3-sigma clipping for 758
# --- 3.2147350311279297 seconds ---
# 20fold 3-sigma clipping for 759
# --- 3.2061824798583984 seconds ---
# 20fold 3-sigma clipping for 760
# --- 3.1860363483428955 seconds ---
# 20fold 3-sigma clipping for 761
# --- 3.204866647720337 seconds ---
# 20fold 3-sigma clipping for 762
# --- 3.2283108234405518 seconds ---
# 20fold 3-sigma clipping for 763
# --- 3.1977334022521973 seconds ---
# 20fold 3-sigma clipping for 764
# --- 3.20111346244812 seconds ---
# 20fold 3-sigma clipping for 765
# --- 3.214419364929199 seconds ---
# 20fold 3-sigma clipping for 766
# --- 3.2362220287323 seconds ---
# 20fold 3-sigma clipping for 767
# --- 3.212671995162964 seconds ---
# 20fold 3-sigma clipping for 768
# --- 3.197676420211792 seconds ---
# 20fold 3-sigma clipping for 769
# --- 3.204761028289795 seconds ---
# 20fold 3-sigma clipping for 770
# --- 3.212761878967285 seconds ---
# 20fold 3-sigma clipping for 771
# --- 3.2021169662475586 seconds ---
# 20fold 3-sigma clipping for 772
# --- 3.184459924697876 seconds ---
# 20fold 3-sigma clipping for 773
# --- 3.214106559753418 seconds ---
# 20fold 3-sigma clipping for 774
# --- 3.227372407913208 seconds ---
# 20fold 3-sigma clipping for 775
# --- 3.1928024291992188 seconds ---
# 20fold 3-sigma clipping for 776
# --- 3.1875507831573486 seconds ---
# 20fold 3-sigma clipping for 777
# --- 3.20208477973938 seconds ---
# 20fold 3-sigma clipping for 778
# --- 3.236112594604492 seconds ---
# 20fold 3-sigma clipping for 779
# --- 3.2253708839416504 seconds ---
# 20fold 3-sigma clipping for 780
# --- 3.206653356552124 seconds ---
# 20fold 3-sigma clipping for 781
# --- 3.217329502105713 seconds ---
# 20fold 3-sigma clipping for 782
# --- 3.225602865219116 seconds ---
# 20fold 3-sigma clipping for 783
# --- 3.1862640380859375 seconds ---
# 20fold 3-sigma clipping for 784
# --- 3.188538074493408 seconds ---
# 20fold 3-sigma clipping for 785
# --- 3.2023301124572754 seconds ---
# 20fold 3-sigma clipping for 786
# --- 3.226578712463379 seconds ---
# 20fold 3-sigma clipping for 787
# --- 3.193317413330078 seconds ---
# 20fold 3-sigma clipping for 788
# --- 3.188795328140259 seconds ---
# 20fold 3-sigma clipping for 789
# --- 3.1988537311553955 seconds ---
# 20fold 3-sigma clipping for 790
# --- 3.206782341003418 seconds ---
# 20fold 3-sigma clipping for 791
# --- 3.1807668209075928 seconds ---
# 20fold 3-sigma clipping for 792
# --- 3.1744449138641357 seconds ---
# 20fold 3-sigma clipping for 793
# --- 3.199803590774536 seconds ---
# 20fold 3-sigma clipping for 794
# --- 3.2202324867248535 seconds ---
# 20fold 3-sigma clipping for 795
# --- 3.203134775161743 seconds ---
# 20fold 3-sigma clipping for 796
# --- 3.1764938831329346 seconds ---
# 20fold 3-sigma clipping for 797
# --- 3.1975293159484863 seconds ---
# 20fold 3-sigma clipping for 798
# --- 3.2122092247009277 seconds ---
# 20fold 3-sigma clipping for 799
# --- 3.1768341064453125 seconds ---
# 20fold 3-sigma clipping for 800
# --- 3.176931381225586 seconds ---
# 20fold 3-sigma clipping for 801
# --- 3.2060019969940186 seconds ---
# 20fold 3-sigma clipping for 802
# --- 3.223848581314087 seconds ---
# 20fold 3-sigma clipping for 803
# --- 3.1862497329711914 seconds ---
# 20fold 3-sigma clipping for 804
# --- 3.1905341148376465 seconds ---
# 20fold 3-sigma clipping for 805
# --- 3.1958506107330322 seconds ---
# 20fold 3-sigma clipping for 806
# --- 3.203108787536621 seconds ---
# 20fold 3-sigma clipping for 807
# --- 3.1696054935455322 seconds ---
# 20fold 3-sigma clipping for 808
# --- 3.176983594894409 seconds ---
# 20fold 3-sigma clipping for 809
# --- 3.1912193298339844 seconds ---
# 20fold 3-sigma clipping for 810
# --- 3.1991069316864014 seconds ---
# 20fold 3-sigma clipping for 811
# --- 3.1721019744873047 seconds ---
# 20fold 3-sigma clipping for 812
# --- 3.1734583377838135 seconds ---
# 20fold 3-sigma clipping for 813
# --- 3.182199478149414 seconds ---
# 20fold 3-sigma clipping for 814
# --- 3.1978394985198975 seconds ---
# 20fold 3-sigma clipping for 815
# --- 3.164254665374756 seconds ---
# 20fold 3-sigma clipping for 816
# --- 3.173651695251465 seconds ---
# 20fold 3-sigma clipping for 817
# --- 3.189980983734131 seconds ---
# 20fold 3-sigma clipping for 818
# --- 3.2026355266571045 seconds ---
# 20fold 3-sigma clipping for 819
# --- 3.1637253761291504 seconds ---
# 20fold 3-sigma clipping for 820
# --- 3.1662516593933105 seconds ---
# 20fold 3-sigma clipping for 821
# --- 3.180511236190796 seconds ---
# 20fold 3-sigma clipping for 822
# --- 3.2013022899627686 seconds ---
# 20fold 3-sigma clipping for 823
# --- 3.166201114654541 seconds ---
# 20fold 3-sigma clipping for 824
# --- 3.182772159576416 seconds ---
# 20fold 3-sigma clipping for 825
# --- 3.1926565170288086 seconds ---
# 20fold 3-sigma clipping for 826
# --- 3.2075917720794678 seconds ---
# 20fold 3-sigma clipping for 827
# --- 3.171687126159668 seconds ---
# 20fold 3-sigma clipping for 828
# --- 3.1614773273468018 seconds ---
# 20fold 3-sigma clipping for 829
# --- 3.1817805767059326 seconds ---
# 20fold 3-sigma clipping for 830
# --- 3.213082790374756 seconds ---
# 20fold 3-sigma clipping for 831
# --- 3.188730478286743 seconds ---
# 20fold 3-sigma clipping for 832
# --- 3.1748619079589844 seconds ---
# 20fold 3-sigma clipping for 833
# --- 3.203028440475464 seconds ---
# 20fold 3-sigma clipping for 834
# --- 3.220982789993286 seconds ---
# 20fold 3-sigma clipping for 835
# --- 3.198521137237549 seconds ---
# 20fold 3-sigma clipping for 836
# --- 3.1851372718811035 seconds ---
# 20fold 3-sigma clipping for 837
# --- 3.192192554473877 seconds ---
# 20fold 3-sigma clipping for 838
# --- 3.2227602005004883 seconds ---
# 20fold 3-sigma clipping for 839
# --- 3.1882970333099365 seconds ---
# 20fold 3-sigma clipping for 840
# --- 3.1974284648895264 seconds ---
# 20fold 3-sigma clipping for 841
# --- 3.1972720623016357 seconds ---
# 20fold 3-sigma clipping for 842
# --- 3.206758737564087 seconds ---
# 20fold 3-sigma clipping for 843
# --- 3.174839973449707 seconds ---
# 20fold 3-sigma clipping for 844
# --- 3.176668643951416 seconds ---
# 20fold 3-sigma clipping for 845
# --- 3.201382875442505 seconds ---
# 20fold 3-sigma clipping for 846
# --- 3.216054916381836 seconds ---
# 20fold 3-sigma clipping for 847
# --- 3.1839182376861572 seconds ---
# 20fold 3-sigma clipping for 848
# --- 3.1707468032836914 seconds ---
# 20fold 3-sigma clipping for 849
# --- 3.1855969429016113 seconds ---
# 20fold 3-sigma clipping for 850
# --- 3.2080678939819336 seconds ---
# 20fold 3-sigma clipping for 851
# --- 3.17587947845459 seconds ---
# 20fold 3-sigma clipping for 852
# --- 3.17462158203125 seconds ---
# 20fold 3-sigma clipping for 853
# --- 3.2031126022338867 seconds ---
# 20fold 3-sigma clipping for 854
# --- 3.2247562408447266 seconds ---
# 20fold 3-sigma clipping for 855
# --- 3.2001216411590576 seconds ---
# 20fold 3-sigma clipping for 856
# --- 3.184305191040039 seconds ---
# 20fold 3-sigma clipping for 857
# --- 3.1920931339263916 seconds ---
# 20fold 3-sigma clipping for 858
# --- 3.2098517417907715 seconds ---
# 20fold 3-sigma clipping for 859
# --- 3.1774234771728516 seconds ---
# 20fold 3-sigma clipping for 860
# --- 3.1856987476348877 seconds ---
# 20fold 3-sigma clipping for 861
# --- 3.2112135887145996 seconds ---
# 20fold 3-sigma clipping for 862
# --- 3.2217838764190674 seconds ---
# 20fold 3-sigma clipping for 863
# --- 3.194330930709839 seconds ---
# 20fold 3-sigma clipping for 864
# --- 3.189650774002075 seconds ---
# 20fold 3-sigma clipping for 865
# --- 3.21336030960083 seconds ---
# 20fold 3-sigma clipping for 866
# --- 3.2135865688323975 seconds ---
# 20fold 3-sigma clipping for 867
# --- 3.1944844722747803 seconds ---
# 20fold 3-sigma clipping for 868
# --- 3.1962223052978516 seconds ---
# 20fold 3-sigma clipping for 869
# --- 3.2264583110809326 seconds ---
# 20fold 3-sigma clipping for 870
# --- 3.227443218231201 seconds ---
# 20fold 3-sigma clipping for 871
# --- 3.207595109939575 seconds ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 3>()
#       1 # -- data proprecessing for the image from row0 to row800
#       2 filtered_hsi0_half0 = sigma_clipping(cube0, "half1")
# ----> 3 np.save("filtered_hsi0_half1.npy", filtered_hsi0_half1)
#
# NameError: name 'filtered_hsi0_half1' is not defined
